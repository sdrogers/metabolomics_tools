# %%
# %load_ext autoreload
# %autoreload 2


import sys

basedir = '../'
sys.path.append(basedir)

import models
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
loader = models.FileLoader()
database_file = basedir + '/database/std1_mols.csv'
database = loader.load_database(database_file)
transformation_file = basedir + '/mulsubs/mulsub2.txt'
transformations = loader.load_transformation(transformation_file)
input_file = basedir + '/input/std1_csv/std1-file1.identified.csv'    
features = loader.load_features(input_file)

mass_tol = 2
rt_tol = 5

pd = models.PeakData(features,database,transformations,mass_tol,rt_tol)
# Out:
# Discretising peak data

# %%
from continuous_mass_clusterer import ContinuousGibbs
hp = models.HyperPars()
cg = ContinuousGibbs(pd,hp)
cg.set_n_samples(10)
print cg
cg.run()

# %%
# %matplotlib inline
import pylab as plt

max_cluster_size = cg.cluster_size.max()
for c in np.arange(max_cluster_size,2,-1):
    clusters = np.nonzero(cg.cluster_size==c)[0]
    for cl in clusters:
        peaks = np.nonzero(cg.Z==cl)[0]
        plt.figure(figsize=(10,5))
        plt.subplot(1,2,1)
        plt.plot(pd.mass[peaks],pd.rt[peaks],'ro')
        plt.plot(pd.transformed[peaks,cl].toarray(),pd.rt[peaks],'ko')
        plt.subplot(1,2,2)
        for p in peaks:
            plt.plot((pd.mass[p],pd.mass[p]),(0,pd.intensity[p]))
            tra = pd.possible[p,cl]-1
            plt.text(pd.mass[p],pd.intensity[p],pd.transformations[tra].name)

# %%
# Out:
# M+H

# %%
from continuous_mass_clusterer import ContinuousVB
hp = models.HyperPars()
vb = ContinuousVB(pd,hp)
print vb
vb.n_iterations = 100
vb.run()
# Out:
# Continuous Clusterer initialised - wow
# Variational Bayes for continuous mass model
# Hyperparameters: rt precision = 10 mass precision = 100 rt prior precision = 100 mass prior precision = 100 alpha = 100.0
# n_iterations = 100
# Running the clustering
# 525 peaks to be re-sampled
# Iteration 0
# Change in QZ: 108.083119334
# Iteration 1
# Change in QZ: 50.1719686292
# Iteration 2
# Change in QZ: 4.17031674103
# Iteration 3
# Change in QZ: 0.0179522966577
# Iteration 4
# Change in QZ: 6.38410440249e-05
# Iteration 5
# Change in QZ: 1.55810895616e-05
# Iteration 6
# Change in QZ: 3.79544079327e-06
# Iteration 7
# Change in QZ: 9.23652606387e-07
# Iteration 8
# Change in QZ: 2.24670241287e-07
# Iteration 9
# Change in QZ: 5.46373351196e-08
# Iteration 10
# Change in QZ: 1.32854183236e-08
# Iteration 11
# Change in QZ: 3.23039380426e-09
# Iteration 12
# Change in QZ: 7.85781451021e-10
# Iteration 13
# Change in QZ: 1.92215501972e-10
# Iteration 14
# Change in QZ: 5.02219849805e-11
# Iteration 15
# Change in QZ: 2.26461798305e-11
# Iteration 16
# Change in QZ: 3.66713808457e-11
# Iteration 17
# Change in QZ: 1.01795838668e-10
# Iteration 18
# Change in QZ: 3.01943976046e-10
# Iteration 19
# Change in QZ: 9.00380400222e-10
# Iteration 20
# Change in QZ: 2.68578997584e-09
# Iteration 21
# Change in QZ: 8.01342295634e-09
# Iteration 22
# Change in QZ: 2.39055481318e-08
# Iteration 23
# Change in QZ: 7.13198871593e-08
# Iteration 24
# Change in QZ: 2.12776228306e-07
# Iteration 25
# Change in QZ: 6.34776108913e-07
# Iteration 26
# Iteration 87
# Change in QZ: 8.9174051069e-19
# Iteration 88
# Change in QZ: 4.63290482413e-19
# Iteration 89
# Change in QZ: 1.34584302314e-18
# Iteration 90
# Change in QZ: 7.89656783033e-19
# Iteration 91
# Change in QZ: 4.47151287194e-19
# Iteration 92
# Change in QZ: 4.08158080512e-19
# Iteration 93
# Change in QZ: 5.61197133449e-19
# Iteration 94
# Change in QZ: 3.92468370672e-19
# Iteration 95
# Change in QZ: 5.44878174221e-19
# Iteration 96
# Change in QZ: 1.0029768356e-18
# Iteration 97
# Change in QZ: 2.4299253034e-20
# Iteration 98
# Change in QZ: 7.85750628781e-19
# Iteration 99
# Change in QZ: 1.0209980027e-18

# %%
print vb.ELogPi
# Out:
# [[-9.08148458 -9.08148458 -9.08148458 ..., -9.08148458 -9.08148458
#   -9.08148458]]

# %%
print np.nonzero(pd.possible[0,:])[0]
# Out:
# [0]

# %%
import scipy.sparse as sp
a = sp.lil_matrix((2,2))

# %%
a[0,0] = 1
a[1,1] = 4
print a
# Out:
#   (0, 0)	1.0
#   (1, 1)	4.0

# %%
b = a

# %%
print b
# Out:
#   (0, 0)	1.0
#   (1, 1)	4.0

# %%
b[0,1] = 2

# %%
print a
# Out:
#   (0, 0)	1.0
#   (0, 1)	2.0
#   (1, 1)	4.0

# %%
b = sp.lil_matrix(a,copy=True)

# %%
b[0,0] = 3
print a
# Out:
#   (0, 0)	10.0
#   (0, 1)	2.0
#   (1, 1)	4.0

# %%
a = sp.lil_matrix((2,2))
a[0,0] = 3
b = sp.lil_matrix((2,2))
b[0,0] = 2
c = a.multiply(b)
print c[0,0],a[0,0]
# Out:
# 6.0 3.0

# %%
d = sp.csr_matrix((3,3))

# %%
print dir(d)
# Out:
# ['__abs__', '__add__', '__array_priority__', '__bool__', '__class__', '__delattr__', '__dict__', '__div__', '__doc__', '__eq__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__idiv__', '__imul__', '__init__', '__isub__', '__iter__', '__itruediv__', '__le__', '__len__', '__lt__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__pow__', '__radd__', '__reduce__', '__reduce_ex__', '__repr__', '__rmul__', '__rsub__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__weakref__', '_binopt', '_boolean_index_to_array', '_check_boolean', '_cs_matrix__get_sorted', '_cs_matrix__set_sorted', '_get_dtype', '_get_row_slice', '_get_single_element', '_get_slice', '_get_submatrix', '_imag', '_index_to_arrays', '_mul_multivector', '_mul_scalar', '_mul_sparse_matrix', '_mul_vector', '_process_toarray_args', '_real', '_set_dtype', '_set_one', '_set_self', '_shape', '_slicetoarange', '_swap', '_unpack_index', '_with_data', 'arcsin', 'arcsinh', 'arctan', 'arctanh', 'asformat', 'asfptype', 'astype', 'ceil', 'check_format', 'conj', 'conjugate', 'copy', 'data', 'deg2rad', 'diagonal', 'dot', 'dtype', 'eliminate_zeros', 'expm1', 'floor', 'format', 'getH', 'get_shape', 'getcol', 'getformat', 'getmaxprint', 'getnnz', 'getrow', 'has_sorted_indices', 'indices', 'indptr', 'log1p', 'max', 'maxprint', 'mean', 'min', 'multiply', 'ndim', 'nnz', 'nonzero', 'prune', 'rad2deg', 'reshape', 'rint', 'set_shape', 'setdiag', 'shape', 'sign', 'sin', 'sinh', 'sort_indices', 'sorted_indices', 'sqrt', 'sum', 'sum_duplicates', 'tan', 'tanh', 'toarray', 'tobsr', 'tocoo', 'tocsc', 'tocsr', 'todense', 'todia', 'todok', 'tolil', 'transpose', 'trunc']

# %%
d._get_row_slice?
