# %% [markdown]
# # Test discrete clustering

# %% [markdown]
# ## Load the clustering module first

# %%
import sys

basedir = '../'
sys.path.append(basedir) # need to do this to be able to import the stuff below

from models import FileLoader, HyperPars
from discrete_mass_clusterer import DiscreteGibbs

# %% [markdown]
# ## Try on some synthetic data

# %%
# load synthetic data
input_file = basedir + '/input/synthetic/synthdata_0.txt'
database_file = basedir + '/database/std1_20_mols.csv'
transformation_file = basedir + '/mulsubs/mulsub_synth.txt'
mass_tol = 2
rt_tol = 5
loader = FileLoader()
peak_data = loader.load_model_input(input_file, database_file, transformation_file, mass_tol, rt_tol)
       
# run it through the model
hp = HyperPars()
nsamps = 20
mbc = DiscreteGibbs(peak_data, hp, nsamps)
mbc.run()
# Out:
# Discretising peak data at mass_tol 2 and rt_tol 5
# 1229 bins created
# DiscreteGibbs initialised
# SAMPLE 1 0.52s	Counter({'0': 1026, '1': 181, '2': 22})
# SAMPLE 2 0.51s	Counter({'0': 1024, '1': 187, '2': 16, '3': 2})
# SAMPLE 3 0.48s	Counter({'0': 1024, '1': 185, '2': 20})
# SAMPLE 4 0.49s	Counter({'0': 1014, '1': 205, '2': 10})
# SAMPLE 5 0.49s	Counter({'0': 1015, '1': 203, '2': 11})
# SAMPLE 6 0.53s	Counter({'0': 1026, '1': 183, '2': 18, '3': 2})
# SAMPLE 7 0.49s	Counter({'0': 1020, '1': 195, '2': 12, '3': 2})
# SAMPLE 8 0.49s	Counter({'0': 1021, '1': 193, '2': 14, '4': 1})
# SAMPLE 9 0.50s	Counter({'0': 1025, '1': 185, '2': 17, '3': 2})
# SAMPLE 10 0.49s	Counter({'0': 1026, '1': 183, '2': 18, '3': 2})
# SAMPLE 11 0.49s	Counter({'0': 1023, '1': 189, '2': 15, '3': 2})
# SAMPLE 12 0.49s	Counter({'0': 1024, '1': 188, '2': 14, '3': 3})
# SAMPLE 13 0.49s	Counter({'0': 1019, '1': 196, '2': 13, '3': 1})
# SAMPLE 14 0.49s	Counter({'0': 1016, '1': 202, '2': 10, '3': 1})
# SAMPLE 15 0.49s	Counter({'0': 1021, '1': 194, '2': 11, '3': 3})
# SAMPLE 16 0.50s	Counter({'0': 1025, '1': 185, '2': 17, '3': 2})
# SAMPLE 17 0.49s	Counter({'0': 1024, '1': 190, '2': 11, '3': 3, '4': 1})
# SAMPLE 18 0.49s	Counter({'0': 1020, '1': 194, '2': 14, '3': 1})
# SAMPLE 19 0.49s	Counter({'0': 1024, '1': 190, '2': 11, '3': 3, '4': 1})
# SAMPLE 20 0.49s	Counter({'0': 1022, '1': 191, '2': 14, '3': 2})
# DONE!
#
# Last sample report
# PrecursorBin bin_id=938, len(features)=3, mass_range=(167.08270342853365, 167.08337176068403), len(molecules)=0, rt_range=(1427.893101159614, 1437.893101159614)
# | feature_id | mass          | rt            | intensity     | annotation               | gt_metabolite | gt_adduct |
# | 974        | 209.117056987 | 1429.53322535 | 1193.70240541 | M+ACN+H @ 167.083231432  | 15            | M+ACN+H   |
# | 923        | 105.062213931 | 1429.14642139 | 1219.87162703 | M+ACN+2H @ 167.083325855 | 15            | M+ACN+2H  |
# | 947        | 185.11677238  | 1430.81695361 | 1421.16184371 | M+NH4 @ 167.082946825    | 15            | M+NH4     |
#
# PrecursorBin bin_id=1073, len(features)=3, mass_range=(377.1410172779045, 377.14252584499076), len(molecules)=0, rt_range=(977.4794970638369, 987.4794970638369)
# | feature_id | mass          | rt            | intensity     | annotation              | gt_metabolite | gt_adduct |
# | 1052       | 198.091582172 | 984.233457722 | 11388.7590181 | M+H+NH4 @ 377.142062338 | 17            | M+H+NH4   |
# | 1045       | 189.57804205  | 986.645218559 | 13343.3499601 | M+2H @ 377.141531195    | 17            | M+2H      |
# | 1090       | 400.13104778  | 986.191051279 | 13238.3547635 | M+Na @ 377.1418267      | 17            | M+Na      |
#
# PrecursorBin bin_id=87, len(features)=2, mass_range=(92.04720585015166, 92.04757403971145), len(molecules)=0, rt_range=(964.3357857077972, 974.3357857077972)
# | feature_id | mass          | rt            | intensity     | annotation            | gt_metabolite | gt_adduct |
# | 58         | 47.0309035231 | 968.818643743 | 34816.5216634 | M+2H @ 92.0472541421  | 1             | M+2H      |
# | 94         | 110.081219716 | 968.308154265 | 42978.2094315 | M+NH4 @ 92.0473941613 | 1             | M+NH4     |
#
# PrecursorBin bin_id=91, len(features)=2, mass_range=(93.05052118849228, 93.05089339132145), len(molecules)=0, rt_range=(959.5386140415674, 969.5386140415674)
# | feature_id | mass          | rt            | intensity     | annotation             | gt_metabolite | gt_adduct |
# | 100        | 111.084561512 | 968.260765549 | 1039.8736647  | M+NH4 @ 93.0507359565  | 1             | M+NH4     |
# | 71         | 56.045863866  | 967.203250157 | 1332.94080163 | M+H+NH4 @ 93.050625725 | 1             | M+H+NH4   |
#
# PrecursorBin bin_id=207, len(features)=2, mass_range=(268.08013231150943, 268.0812046341833), len(molecules)=0, rt_range=(913.609606724424, 923.609606724424)
# | feature_id | mass          | rt            | intensity     | annotation              | gt_metabolite | gt_adduct |
# | 180        | 135.047468556 | 919.923760529 | 175810.150274 | M+2H @ 268.080384208    | 3             | M+2H      |
# | 233        | 310.114982276 | 917.245758705 | 171939.108496 | M+ACN+H @ 268.081156721 | 3             | M+ACN+H   |
#
# PrecursorBin bin_id=362, len(features)=2, mass_range=(150.10126661228188, 150.10186701854914), len(molecules)=0, rt_range=(863.0579003659693, 873.0579003659693)
# | feature_id | mass          | rt            | intensity     | annotation               | gt_metabolite | gt_adduct |
# | 325        | 96.5714237845 | 868.101080105 | 118.301266421 | M+ACN+2H @ 150.101745562 | 5             | M+2ACN+2H |
# | 317        | 76.0581454543 | 865.451231673 | 125.090621951 | M+2H @ 150.101738005     | 5             | M+ACN+2H  |
#
# PrecursorBin bin_id=395, len(features)=2, mass_range=(235.1280871422664, 235.12902765649602), len(molecules)=0, rt_range=(998.0829378772924, 1008.0829378772924)
# | feature_id | mass          | rt            | intensity     | annotation            | gt_metabolite | gt_adduct |
# | 401        | 253.162345179 | 1003.41676347 | 36.7350375121 | M+NH4 @ 235.128519624 | 6             | M+NH4     |
# | 371        | 118.571764585 | 1003.84762696 | 35.3405692842 | M+2H @ 235.128976265  | 6             | M+2H      |
#
# PrecursorBin bin_id=454, len(features)=2, mass_range=(187.07137038230576, 187.07211866928384), len(molecules)=0, rt_range=(1129.9359083175596, 1139.9359083175596)
# | feature_id | mass          | rt            | intensity     | annotation                | gt_metabolite | gt_adduct |
# | 442        | 115.056314356 | 1137.42226869 | 204187.187572 | M+ACN+2H @ 187.071526704  | 7             | M+ACN+2H  |
# | 478        | 220.104929587 | 1138.03207597 | 205974.399451 | M+CH3OH+H @ 187.071438385 | 7             | M+CH3OH+H |
#
# PrecursorBin bin_id=566, len(features)=2, mass_range=(151.0492878580693, 151.04989205642914), len(molecules)=0, rt_range=(483.666105596779, 493.666105596779)
# | feature_id | mass          | rt            | intensity     | annotation                | gt_metabolite | gt_adduct |
# | 588        | 184.083179011 | 489.726894544 | 235994.188651 | M+CH3OH+H @ 151.049687809 | 9             | M+CH3OH+H |
# | 581        | 174.03853523  | 488.759777427 | 201049.98389  | M+Na @ 151.04931415       | 9             | M+Na      |
#
# PrecursorBin bin_id=686, len(features)=2, mass_range=(196.99494756091562, 196.99573554228184), len(molecules)=0, rt_range=(1261.7538602391937, 1271.7538602391937)
# | feature_id | mass          | rt            | intensity     | annotation               | gt_metabolite | gt_adduct |
# | 674        | 120.018189806 | 1266.65859098 | 22751.1413357 | M+ACN+2H @ 196.995277604 | 11            | M+ACN+2H  |
# | 663        | 99.5049431038 | 1265.33583105 | 25253.0621291 | M+2H @ 196.995333304     | 11            | M+2H      |
#
# PrecursorBin bin_id=726, len(features)=2, mass_range=(75.52742070787744, 75.5277228181645), len(molecules)=0, rt_range=(1165.4717415546315, 1175.4717415546315)
# | feature_id | mass          | rt            | intensity     | annotation              | gt_metabolite | gt_adduct |
# | 727        | 76.534848215  | 1170.47174155 | 482.689905836 | M+H @ 75.527571763      | 12            | M+2H      |
# | 746        | 117.561545497 | 1173.34979604 | 412.686930545 | M+ACN+H @ 75.5277199421 | 12            | M+2ACN+2H |
#
# PrecursorBin bin_id=749, len(features)=2, mass_range=(151.04633789232844, 151.04694207888838), len(molecules)=0, rt_range=(1166.8568828773875, 1176.8568828773875)
# | feature_id | mass          | rt            | intensity     | annotation            | gt_metabolite | gt_adduct |
# | 725        | 76.5306162856 | 1171.96792722 | 4520.079892   | M+2H @ 151.046679667  | 12            | M+2H      |
# | 758        | 169.080534189 | 1168.14162289 | 4153.60404181 | M+NH4 @ 151.046708634 | 12            | M+NH4     |
#
# PrecursorBin bin_id=819, len(features)=2, mass_range=(206.0962092872043, 206.09703367369022), len(molecules)=0, rt_range=(907.7288090437144, 917.7288090437144)
# | feature_id | mass          | rt            | intensity     | annotation            | gt_metabolite | gt_adduct |
# | 833        | 229.085586945 | 910.569113429 | 3987.07964638 | M+Na @ 206.096365865  | 13            | M+Na      |
# | 825        | 224.130410506 | 912.942144029 | 4135.12062983 | M+NH4 @ 206.096584951 | 13            | M+NH4     |
#
# PrecursorBin bin_id=872, len(features)=2, mass_range=(151.06303644457756, 151.06364069793187), len(molecules)=0, rt_range=(1046.9567553922755, 1056.9567553922755)
# | feature_id | mass          | rt            | intensity     | annotation             | gt_metabolite | gt_adduct |
# | 852        | 85.0522184238 | 1051.90156058 | 77469.4559452 | M+H+NH4 @ 151.06333484 | 14            | M+H+NH4   |
# | 848        | 76.538952664  | 1053.34292726 | 77964.6703347 | M+2H @ 151.063352424   | 14            | M+2H      |
#
# PrecursorBin bin_id=876, len(features)=2, mass_range=(152.066267226488, 152.06687549277345), len(molecules)=0, rt_range=(1043.4499510630576, 1053.4499510630576)
# | feature_id | mass          | rt            | intensity     | annotation              | gt_metabolite | gt_adduct |
# | 907        | 194.100415512 | 1048.51400928 | 6361.21979005 | M+ACN+H @ 152.066589957 | 14            | M+ACN+H   |
# | 885        | 170.100676652 | 1051.97444941 | 5943.70050565 | M+NH4 @ 152.066851097   | 14            | M+NH4     |
#
# PrecursorBin bin_id=1070, len(features)=2, mass_range=(377.14165269786974, 377.1431612674977), len(molecules)=0, rt_range=(979.5567741878162, 989.5567741878162)
# | feature_id | mass          | rt            | intensity     | annotation            | gt_metabolite | gt_adduct |
# | 1071       | 378.149683435 | 984.556774188 | 182.951701034 | M+H @ 377.142406983   | 17            | M+H       |
# | 1078       | 395.175997821 | 986.045049159 | 168.308099964 | M+NH4 @ 377.142172266 | 17            | M+NH4     |
#
# PrecursorBin bin_id=0, len(features)=1, mass_range=(63.523390999879105, 63.523645093951295), len(molecules)=0, rt_range=(825.3699425025724, 835.3699425025724)
# | feature_id | mass          | rt            | intensity    | annotation          | gt_metabolite | gt_adduct |
# | 1          | 64.5307944989 | 830.369942503 | 98.934648097 | M+H @ 63.5235180469 | 0             | M+2H      |
#
# PrecursorBin bin_id=8, len(features)=1, mass_range=(72.03671068061605, 72.03699882803507), len(molecules)=0, rt_range=(827.4484781801405, 837.4484781801405)
# | feature_id | mass          | rt           | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 9          | 73.0441312063 | 832.44847818 | 107.262318564 | M+H @ 72.0368547543 | 0             | M+H+NH4   |
#
# PrecursorBin bin_id=10, len(features)=1, mass_range=(73.03819308176055, 73.0384852351172), len(molecules)=0, rt_range=(825.1960454371476, 835.1960454371476)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 11         | 74.0456156104 | 830.196045437 | 29.1428118485 | M+H @ 73.0383391584 | 0             | M+H+NH4   |
#
# PrecursorBin bin_id=25, len(features)=1, mass_range=(128.0469547092472, 128.04746689809042), len(molecules)=0, rt_range=(823.6711638587913, 833.6711638587913)
# | feature_id | mass          | rt            | intensity     | annotation               | gt_metabolite | gt_adduct |
# | 12         | 85.5441793233 | 831.052316432 | 548.414027091 | M+ACN+2H @ 128.047256639 | 0             | M+ACN+2H  |
#
# PrecursorBin bin_id=26, len(features)=1, mass_range=(127.04702871650912, 127.04753690564036), len(molecules)=0, rt_range=(824.9145844466251, 834.9145844466251)
# | feature_id | mass          | rt            | intensity    | annotation               | gt_metabolite | gt_adduct |
# | 13         | 85.0440691796 | 825.169939339 | 109.21046067 | M+ACN+2H @ 127.047036352 | 0             | M+ACN+2H  |
#
# PrecursorBin bin_id=29, len(features)=1, mass_range=(129.05011953922707, 129.05063574073762), len(molecules)=0, rt_range=(823.5285243123449, 833.5285243123449)
# | feature_id | mass          | rt           | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 45         | 152.039847441 | 832.68004844 | 29.2241965874 | M+Na @ 129.050626361 | 0             | M+Na      |
#
# PrecursorBin bin_id=31, len(features)=1, mass_range=(143.0691543267371, 143.06972660449898), len(molecules)=0, rt_range=(826.0036049203371, 836.0036049203371)
# | feature_id | mass          | rt           | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 32         | 144.076716918 | 831.00360492 | 132664.272296 | M+H @ 143.069440466 | 0             | M+NH4     |
#
# PrecursorBin bin_id=39, len(features)=1, mass_range=(149.02885107311312, 149.02944718970963), len(molecules)=0, rt_range=(824.1360564802444, 834.1360564802444)
# | feature_id | mass          | rt           | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 40         | 150.036425583 | 829.13605648 | 91.7558747647 | M+H @ 149.029149131 | 0             | M+Na      |
#
# PrecursorBin bin_id=54, len(features)=1, mass_range=(169.07597925353247, 169.0766555588021), len(molecules)=0, rt_range=(826.069280917888, 836.069280917888)
# | feature_id | mass          | rt            | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 16         | 85.5454297589 | 827.762142914 | 341.184508899 | M+2H @ 169.076306614 | 0             | M+ACN+2H  |
#
# PrecursorBin bin_id=56, len(features)=1, mass_range=(170.0766467593309, 170.0773270672786), len(molecules)=0, rt_range=(821.007529849699, 831.007529849699)
# | feature_id | mass          | rt           | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 57         | 171.084263365 | 826.00752985 | 42.3729412007 | M+H @ 170.076986913 | 0             | M+ACN+H   |
#
# PrecursorBin bin_id=60, len(features)=1, mass_range=(46.52528906872637, 46.52547517025486), len(molecules)=0, rt_range=(963.7140505984279, 973.7140505984279)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 61         | 47.5326585715 | 968.714050598 | 973.194268064 | M+H @ 46.5253821195 | 1             | M+2H      |
#
# PrecursorBin bin_id=67, len(features)=1, mass_range=(55.03545032609963, 55.035670468341216), len(molecules)=0, rt_range=(962.6444931445058, 972.6444931445058)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 68         | 56.0428368492 | 967.644493145 | 142.180185621 | M+H @ 55.0355603972 | 1             | M+H+NH4   |
#
# PrecursorBin bin_id=68, len(features)=1, mass_range=(55.541641951424495, 55.541864118436635), len(molecules)=0, rt_range=(964.4666595465839, 974.4666595465839)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 69         | 56.5490294869 | 969.466659547 | 1.56306084217 | M+H @ 55.5417530349 | 1             | M+H+NH4   |
#
# PrecursorBin bin_id=73, len(features)=1, mass_range=(67.0389594267705, 67.03922758314454), len(molecules)=0, rt_range=(960.7252654700665, 970.7252654700665)
# | feature_id | mass          | rt           | intensity     | annotation         | gt_metabolite | gt_adduct |
# | 74         | 68.0463699569 | 965.72526547 | 42.4167328469 | M+H @ 67.039093505 | 1             | M+ACN+2H  |
#
# PrecursorBin bin_id=78, len(features)=1, mass_range=(68.04061630914755, 68.0408884721571), len(molecules)=0, rt_range=(962.9507872190848, 972.9507872190848)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 79         | 69.0480288426 | 967.950787219 | 11.2782112955 | M+H @ 68.0407523907 | 1             | M+ACN+2H  |
#
# PrecursorBin bin_id=81, len(features)=1, mass_range=(87.55219666521415, 87.55254687470122), len(molecules)=0, rt_range=(965.3773302886923, 975.3773302886923)
# | feature_id | mass          | rt            | intensity    | annotation        | gt_metabolite | gt_adduct |
# | 82         | 88.5596482219 | 970.377330289 | 40.064176194 | M+H @ 87.55237177 | 1             | M+2ACN+2H |
#
# PrecursorBin bin_id=88, len(features)=1, mass_range=(94.05137928184776, 94.05175548811731), len(molecules)=0, rt_range=(963.7957935336298, 973.7957935336298)
# | feature_id | mass          | rt            | intensity     | annotation            | gt_metabolite | gt_adduct |
# | 95         | 112.085425329 | 967.744815287 | 222.743417752 | M+NH4 @ 94.0515997738 | 1             | M+NH4     |
#
# PrecursorBin bin_id=93, len(features)=1, mass_range=(109.07372511652034, 109.07416141229339), len(molecules)=0, rt_range=(963.3081542645714, 973.3081542645714)
# | feature_id | mass          | rt            | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 64         | 55.5441881009 | 964.328506636 | 37289.2679763 | M+2H @ 109.073823298 | 1             | M+H+NH4   |
#
# PrecursorBin bin_id=101, len(features)=1, mass_range=(114.02918704912925, 114.02964316678968), len(molecules)=0, rt_range=(960.2954067792466, 970.2954067792466)
# | feature_id | mass         | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 102        | 115.03669156 | 965.295406779 | 33769.6382686 | M+H @ 114.029415108 | 1             | M+Na      |
#
# PrecursorBin bin_id=102, len(features)=1, mass_range=(116.03336326759052, 116.03382740197185), len(molecules)=0, rt_range=(961.1182300216819, 971.1182300216819)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 103        | 117.040871787 | 966.118230022 | 246.790514821 | M+H @ 116.033595335 | 1             | M+Na      |
#
# PrecursorBin bin_id=106, len(features)=1, mass_range=(124.07325734663075, 124.07375364065274), len(molecules)=0, rt_range=(960.6463291346257, 970.6463291346257)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 107        | 125.080781946 | 965.646329135 | 38048.2847097 | M+H @ 124.073505494 | 1             | M+CH3OH+H |
#
# PrecursorBin bin_id=120, len(features)=1, mass_range=(73.57577957413308, 73.57607387783999), len(molecules)=0, rt_range=(1375.2119311889253, 1385.2119311889253)
# | feature_id | mass         | rt            | intensity     | annotation         | gt_metabolite | gt_adduct |
# | 121        | 74.583203178 | 1380.21193119 | 14.0263879303 | M+H @ 73.575926726 | 2             | M+2H      |
#
# PrecursorBin bin_id=121, len(features)=1, mass_range=(73.57908324551704, 73.57937756243865), len(molecules)=0, rt_range=(1377.257226103986, 1387.257226103986)
# | feature_id | mass         | rt           | intensity     | annotation         | gt_metabolite | gt_adduct |
# | 122        | 74.586506856 | 1382.2572261 | 281.359313653 | M+H @ 73.579230404 | 2             | M+2H      |
#
# PrecursorBin bin_id=123, len(features)=1, mass_range=(81.0920486814913, 81.09237305033476), len(molecules)=0, rt_range=(1375.2478939964396, 1385.2478939964396)
# | feature_id | mass          | rt          | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 124        | 82.0994873179 | 1380.247894 | 321896.842655 | M+H @ 81.0922108659 | 2             | M+H+NH4   |
#
# PrecursorBin bin_id=127, len(features)=1, mass_range=(81.59374184333278, 81.5940682189529), len(molecules)=0, rt_range=(1373.5449816582934, 1383.5449816582934)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 128        | 82.6011814831 | 1378.54498166 | 25465.7713132 | M+H @ 81.5939050311 | 2             | M+H+NH4   |
#
# PrecursorBin bin_id=132, len(features)=1, mass_range=(93.09208764210993, 93.09246001120525), len(molecules)=0, rt_range=(1374.3384767225034, 1384.3384767225034)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 133        | 94.0995502786 | 1379.33847672 | 330437.787395 | M+H @ 93.0922738267 | 2             | M+ACN+2H  |
#
# PrecursorBin bin_id=133, len(features)=1, mass_range=(93.59056548872394, 93.59093985173462), len(molecules)=0, rt_range=(1377.1354676942376, 1387.1354676942376)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 134        | 94.5980291222 | 1382.13546769 | 4509.45820998 | M+H @ 93.5907526702 | 2             | M+ACN+2H  |
#
# PrecursorBin bin_id=135, len(features)=1, mass_range=(93.59512457833021, 93.59549895957728), len(molecules)=0, rt_range=(1379.2540852045638, 1389.2540852045638)
# | feature_id | mass          | rt           | intensity     | annotation         | gt_metabolite | gt_adduct |
# | 136        | 94.6025882209 | 1384.2540852 | 791.801859532 | M+H @ 93.595311769 | 2             | M+ACN+2H  |
#
# PrecursorBin bin_id=138, len(features)=1, mass_range=(94.09226759886054, 94.09264396868367), len(molecules)=0, rt_range=(1377.195073389363, 1387.195073389363)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 139        | 95.0997322358 | 1382.19507339 | 334.147564359 | M+H @ 94.0924557838 | 2             | M+ACN+2H  |
#
# PrecursorBin bin_id=139, len(features)=1, mass_range=(113.60525924845028, 113.60571367039613), len(molecules)=0, rt_range=(1372.980211152996, 1382.980211152996)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 140        | 114.612762911 | 1377.98021115 | 330670.753341 | M+H @ 113.605486459 | 2             | M+2ACN+2H |
#
# PrecursorBin bin_id=140, len(features)=1, mass_range=(114.10384993590765, 114.10430635222022), len(molecules)=0, rt_range=(1374.666597827673, 1384.666597827673)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 141        | 115.111354596 | 1379.66659783 | 5347.94205578 | M+H @ 114.104078144 | 2             | M+2ACN+2H |
#
# PrecursorBin bin_id=149, len(features)=1, mass_range=(146.16092806859027, 146.1615127134718), len(molecules)=0, rt_range=(1372.6692965859352, 1382.6692965859352)
# | feature_id | mass          | rt            | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 158        | 164.194806605 | 1380.59371943 | 23962.3711503 | M+NH4 @ 146.16098105 | 2             | M+NH4     |
#
# PrecursorBin bin_id=150, len(features)=1, mass_range=(147.15808945773927, 147.15867809127434), len(molecules)=0, rt_range=(1376.6115359879561, 1386.6115359879561)
# | feature_id | mass          | rt            | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 163        | 170.147524824 | 1381.11861862 | 245.264652685 | M+Na @ 147.158303744 | 2             | M+Na      |
#
# PrecursorBin bin_id=151, len(features)=1, mass_range=(147.16728913458653, 147.16787780492038), len(molecules)=0, rt_range=(1374.0421680931993, 1384.0421680931993)
# | feature_id | mass         | rt            | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 123        | 74.591087795 | 1380.10192288 | 61.8492354382 | M+2H @ 147.167622686 | 2             | M+2H      |
#
# PrecursorBin bin_id=153, len(features)=1, mass_range=(148.16110142821725, 148.16169407380823), len(molecules)=0, rt_range=(1378.3231384039716, 1388.3231384039716)
# | feature_id | mass         | rt            | intensity    | annotation          | gt_metabolite | gt_adduct |
# | 166        | 171.15054039 | 1378.65137049 | 8.2992725544 | M+Na @ 148.16131931 | 2             | M+Na      |
#
# PrecursorBin bin_id=154, len(features)=1, mass_range=(163.1809614450604, 163.18161417021162), len(molecules)=0, rt_range=(1376.393175910132, 1386.393175910132)
# | feature_id | mass          | rt            | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 125        | 82.5980385973 | 1381.88753309 | 4453.62540319 | M+2H @ 163.181524291 | 2             | M+H+NH4   |
#
# PrecursorBin bin_id=163, len(features)=1, mass_range=(169.14912900042862, 169.1498055982978), len(molecules)=0, rt_range=(1373.9758063849533, 1383.9758063849533)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 164        | 170.156743751 | 1378.97580638 | 51.9726688314 | M+H @ 169.149467299 | 2             | M+Na      |
#
# PrecursorBin bin_id=180, len(features)=1, mass_range=(135.0438686851893, 135.0444088617444), len(molecules)=0, rt_range=(911.7613355427312, 921.7613355427312)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 181        | 136.051415225 | 916.761335543 | 37.4760012499 | M+H @ 135.044138773 | 3             | M+2H      |
#
# PrecursorBin bin_id=182, len(features)=1, mass_range=(135.04363341793973, 135.04417359355378), len(molecules)=0, rt_range=(912.125814052719, 922.125814052719)
# | feature_id | mass          | rt            | intensity    | annotation          | gt_metabolite | gt_adduct |
# | 183        | 136.051179958 | 917.125814053 | 935.25753736 | M+H @ 135.043903506 | 3             | M+2H      |
#
# PrecursorBin bin_id=188, len(features)=1, mass_range=(143.55667199920055, 143.557246227037), len(molecules)=0, rt_range=(911.1011934193059, 921.1011934193059)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 189        | 144.564235565 | 916.101193419 | 1001.17501388 | M+H @ 143.556959113 | 3             | M+H+NH4   |
#
# PrecursorBin bin_id=211, len(features)=1, mass_range=(271.08797682043524, 271.0890611745112), len(molecules)=0, rt_range=(913.0626124365729, 923.0626124365729)
# | feature_id | mass          | rt            | intensity     | annotation              | gt_metabolite | gt_adduct |
# | 190        | 145.064580358 | 917.371550312 | 190.808381877 | M+H+NH4 @ 271.088058708 | 3             | M+H+NH4   |
#
# PrecursorBin bin_id=213, len(features)=1, mass_range=(269.0862429954035, 269.0873193425282), len(molecules)=0, rt_range=(912.446584267162, 922.446584267162)
# | feature_id | mass          | rt            | intensity  | annotation            | gt_metabolite | gt_adduct |
# | 221        | 287.120501808 | 915.989436654 | 278.814683 | M+NH4 @ 269.086676253 | 3             | M+NH4     |
#
# PrecursorBin bin_id=226, len(features)=1, mass_range=(291.06858693344265, 291.0697512101189), len(molecules)=0, rt_range=(915.3736043063943, 925.3736043063943)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 227        | 292.076445524 | 920.373604306 | 271.809354556 | M+H @ 291.069169072 | 3             | M+Na      |
#
# PrecursorBin bin_id=236, len(features)=1, mass_range=(312.1140689189463, 312.1153173777189), len(molecules)=0, rt_range=(911.8235959580161, 921.8235959580161)
# | feature_id | mass          | rt            | intensity     | annotation               | gt_metabolite | gt_adduct |
# | 204        | 177.577758964 | 912.853906722 | 263.238134658 | M+ACN+2H @ 312.114415922 | 3             | M+2ACN+2H |
#
# PrecursorBin bin_id=257, len(features)=1, mass_range=(80.05591985308733, 80.0562400774072), len(molecules)=0, rt_range=(1004.1261422373908, 1014.1261422373908)
# | feature_id | mass          | rt            | intensity    | annotation          | gt_metabolite | gt_adduct |
# | 258        | 81.0633564172 | 1009.12614224 | 5248.4214806 | M+H @ 80.0560799652 | 4             | M+ACN+2H  |
#
# PrecursorBin bin_id=268, len(features)=1, mass_range=(118.07563773529473, 118.07611003879028), len(molecules)=0, rt_range=(1005.4324451694246, 1015.4324451694246)
# | feature_id | mass          | rt            | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 280        | 141.065145779 | 1012.32322817 | 7002.47779454 | M+Na @ 118.075924699 | 4             | M+Na      |
#
# PrecursorBin bin_id=271, len(features)=1, mass_range=(135.10948965910322, 135.11003009814274), len(molecules)=0, rt_range=(1007.3642159557754, 1017.3642159557754)
# | feature_id | mass          | rt            | intensity     | annotation         | gt_metabolite | gt_adduct |
# | 247        | 68.5621151021 | 1011.61338788 | 1503.77238024 | M+2H @ 135.1096773 | 4             | M+H+NH4   |
#
# PrecursorBin bin_id=282, len(features)=1, mass_range=(142.06819112468185, 142.06875939858287), len(molecules)=0, rt_range=(1001.3459977087798, 1011.3459977087798)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 283        | 143.075751714 | 1006.34599771 | 464.859949553 | M+H @ 142.068475262 | 4             | M+Na      |
#
# PrecursorBin bin_id=292, len(features)=1, mass_range=(158.10518141251345, 158.10581383450392), len(molecules)=0, rt_range=(1007.7543946364709, 1017.7543946364709)
# | feature_id | mass          | rt            | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 253        | 80.0599751491 | 1011.94313107 | 2060863.50187 | M+2H @ 158.105397394 | 4             | M+ACN+2H  |
#
# PrecursorBin bin_id=293, len(features)=1, mass_range=(160.10919253281324, 160.10983297086423), len(molecules)=0, rt_range=(1002.7851296214014, 1012.7851296214014)
# | feature_id | mass         | rt            | intensity     | annotation               | gt_metabolite | gt_adduct |
# | 262        | 101.57526501 | 1011.54560726 | 8087.94437075 | M+ACN+2H @ 160.109428013 | 4             | M+2ACN+2H |
#
# PrecursorBin bin_id=314, len(features)=1, mass_range=(75.04613776118994, 75.04643794634136), len(molecules)=0, rt_range=(859.4193224625362, 869.4193224625362)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 315        | 76.0535643058 | 864.419322463 | 819.480422808 | M+H @ 75.0462878538 | 5             | M+ACN+2H  |
#
# PrecursorBin bin_id=318, len(features)=1, mass_range=(75.04918194137089, 75.04948213869905), len(molecules)=0, rt_range=(861.6841497104243, 871.6841497104243)
# | feature_id | mass         | rt           | intensity     | annotation        | gt_metabolite | gt_adduct |
# | 319        | 76.056608492 | 866.68414971 | 6600.11670321 | M+H @ 75.04933204 | 5             | M+ACN+2H  |
#
# PrecursorBin bin_id=322, len(features)=1, mass_range=(95.06074060130096, 95.06112084502386), len(molecules)=0, rt_range=(862.3640468250018, 872.3640468250018)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 323        | 96.0682071752 | 867.364046825 | 83542.9563524 | M+H @ 95.0609307232 | 5             | M+2ACN+2H |
#
# PrecursorBin bin_id=329, len(features)=1, mass_range=(110.06241168892485, 110.0628519394521), len(molecules)=0, rt_range=(864.4200654827868, 874.4200654827868)
# | feature_id | mass          | rt            | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 304        | 56.0386905836 | 868.876233315 | 1.17136800391 | M+2H @ 110.062828263 | 5             | M+2H      |
#
# PrecursorBin bin_id=331, len(features)=1, mass_range=(109.07183111043291, 109.07226739862993), len(molecules)=0, rt_range=(866.2995750595439, 876.2995750595439)
# | feature_id | mass          | rt            | intensity     | annotation              | gt_metabolite | gt_adduct |
# | 312        | 64.0565489147 | 869.350412822 | 4941.52011456 | M+H+NH4 @ 109.071995822 | 5             | M+H+NH4   |
#
# PrecursorBin bin_id=335, len(features)=1, mass_range=(111.07859938005011, 111.07904369533627), len(molecules)=0, rt_range=(862.4246619650974, 872.4246619650974)
# | feature_id | mass          | rt            | intensity     | annotation            | gt_metabolite | gt_adduct |
# | 341        | 129.112860581 | 867.558066328 | 1.99903148378 | M+NH4 @ 111.079035025 | 5             | M+NH4     |
#
# PrecursorBin bin_id=337, len(features)=1, mass_range=(126.09208053504021, 126.0925849043711), len(molecules)=0, rt_range=(860.7188219901201, 870.7188219901201)
# | feature_id | mass          | rt            | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 310        | 64.0535617917 | 866.865741884 | 808.178009864 | M+2H @ 126.092570679 | 5             | M+H+NH4   |
#
# PrecursorBin bin_id=347, len(features)=1, mass_range=(131.05664317121403, 131.0571673988352), len(molecules)=0, rt_range=(863.103803340698, 873.103803340698)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 348        | 132.064181737 | 868.103803341 | 74.5781992295 | M+H @ 131.056905285 | 5             | M+Na      |
#
# PrecursorBin bin_id=365, len(features)=1, mass_range=(151.1016541560591, 151.10225856388456), len(molecules)=0, rt_range=(862.865679885294, 872.865679885294)
# | feature_id | mass          | rt            | intensity    | annotation           | gt_metabolite | gt_adduct |
# | 321        | 76.5582277754 | 867.299817315 | 240.88681125 | M+2H @ 151.101902647 | 5             | M+ACN+2H  |
#
# PrecursorBin bin_id=371, len(features)=1, mass_range=(124.5736300075267, 124.57412830304332), len(molecules)=0, rt_range=(1000.6392878347657, 1010.6392878347657)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 372        | 125.581155607 | 1005.63928783 | 56775.5169768 | M+H @ 124.573879155 | 6             | M+H+NH4   |
#
# PrecursorBin bin_id=389, len(features)=1, mass_range=(158.59072364220992, 158.59135800637324), len(molecules)=0, rt_range=(999.4586452969464, 1009.4586452969464)
# | feature_id | mass          | rt           | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 390        | 159.598317276 | 1004.4586453 | 42.4635399149 | M+H @ 158.591040824 | 6             | M+2ACN+2H |
#
# PrecursorBin bin_id=391, len(features)=1, mass_range=(233.1249421435514, 233.125874645185), len(molecules)=0, rt_range=(997.8720693459275, 1007.8720693459275)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 392        | 234.132684846 | 1002.87206935 | 44.2886346226 | M+H @ 233.125408394 | 6             | M+H       |
#
# PrecursorBin bin_id=393, len(features)=1, mass_range=(233.12726100241673, 233.12819351332575), len(molecules)=0, rt_range=(998.2416804962434, 1008.2416804962434)
# | feature_id | mass          | rt            | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 405        | 256.116704666 | 1006.06182985 | 129.737019434 | M+Na @ 233.127483586 | 6             | M+Na      |
#
# PrecursorBin bin_id=394, len(features)=1, mass_range=(233.12452577725065, 233.12545827721874), len(molecules)=0, rt_range=(999.3746138785565, 1009.3746138785565)
# | feature_id | mass          | rt           | intensity     | annotation               | gt_metabolite | gt_adduct |
# | 382        | 138.083191973 | 1005.6887285 | 46.3584819304 | M+ACN+2H @ 233.125281938 | 6             | M+ACN+2H  |
#
# PrecursorBin bin_id=396, len(features)=1, mass_range=(249.1468774097525, 249.1478739992553), len(molecules)=0, rt_range=(998.2905386833312, 1008.2905386833312)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 397        | 250.154652156 | 1003.29053868 | 65734.6681984 | M+H @ 249.147375705 | 6             | M+NH4     |
#
# PrecursorBin bin_id=397, len(features)=1, mass_range=(252.15706064019014, 252.15806927044997), len(molecules)=0, rt_range=(1000.044503802013, 1010.044503802013)
# | feature_id | mass          | rt            | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 375        | 127.086106456 | 1004.41535832 | 23.1236843479 | M+2H @ 252.157660007 | 6             | M+H+NH4   |
#
# PrecursorBin bin_id=402, len(features)=1, mass_range=(255.10701166677535, 255.10803209686287), len(molecules)=0, rt_range=(998.5564203915808, 1008.5564203915808)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 403        | 256.114798334 | 1003.55642039 | 42.2075024042 | M+H @ 255.107521882 | 6             | M+Na      |
#
# PrecursorBin bin_id=410, len(features)=1, mass_range=(265.1503654918163, 265.1514260953994), len(molecules)=0, rt_range=(996.5850108736341, 1006.5850108736341)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 411        | 266.158172246 | 1001.58501087 | 9411.26147673 | M+H @ 265.150895794 | 6             | M+CH3OH+H |
#
# PrecursorBin bin_id=414, len(features)=1, mass_range=(275.1511014398732, 275.15220204648017), len(molecules)=0, rt_range=(997.7943917105767, 1007.7943917105767)
# | feature_id | mass         | rt            | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 381        | 138.58319945 | 1004.70410729 | 234.507935326 | M+2H @ 275.151845996 | 6             | M+ACN+2H  |
#
# PrecursorBin bin_id=430, len(features)=1, mass_range=(102.04557366281888, 102.04598184592989), len(molecules)=0, rt_range=(1134.301372746761, 1144.301372746761)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 431        | 103.053054206 | 1139.30137275 | 5602.19056387 | M+H @ 102.045777754 | 7             | M+H+NH4   |
#
# PrecursorBin bin_id=435, len(features)=1, mass_range=(102.5472835092588, 102.54769369921321), len(molecules)=0, rt_range=(1128.0292886825216, 1138.0292886825216)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 436        | 103.554765056 | 1133.02928868 | 631.746056735 | M+H @ 102.547488604 | 7             | M+H+NH4   |
#
# PrecursorBin bin_id=443, len(features)=1, mass_range=(135.06246474817965, 135.06300499911913), len(molecules)=0, rt_range=(1130.3366296838935, 1140.3366296838935)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 444        | 136.070011326 | 1135.33662968 | 5801.38662339 | M+H @ 135.062734874 | 7             | M+2ACN+2H |
#
# PrecursorBin bin_id=452, len(features)=1, mass_range=(187.07205538691838, 187.07280367663648), len(molecules)=0, rt_range=(1131.9483669272379, 1141.9483669272379)
# | feature_id | mass          | rt            | intensity    | annotation           | gt_metabolite | gt_adduct |
# | 423        | 94.5433438074 | 1135.22780201 | 1079.1775784 | M+2H @ 187.072134711 | 7             | M+2H      |
#
# PrecursorBin bin_id=455, len(features)=1, mass_range=(188.07520777966826, 188.075960082004), len(molecules)=0, rt_range=(1132.2323231948867, 1142.2323231948867)
# | feature_id | mass         | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 474        | 211.06469156 | 1140.85589441 | 134.203749649 | M+Na @ 188.07547048 | 7             | M+Na      |
#
# PrecursorBin bin_id=457, len(features)=1, mass_range=(188.07443240301066, 188.07518470224485), len(molecules)=0, rt_range=(1133.8747642698045, 1143.8747642698045)
# | feature_id | mass          | rt           | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 428        | 95.0445573861 | 1139.0404308 | 10913.2269747 | M+2H @ 188.074561868 | 7             | M+2H      |
#
# PrecursorBin bin_id=459, len(features)=1, mass_range=(203.09390607142075, 203.09471844866977), len(molecules)=0, rt_range=(1132.62755485968, 1142.62755485968)
# | feature_id | mass          | rt            | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 430        | 102.554491322 | 1138.74692731 | 1332486.35446 | M+2H @ 203.094429739 | 7             | M+H+NH4   |
#
# PrecursorBin bin_id=461, len(features)=1, mass_range=(204.098762001827, 204.09957839850782), len(molecules)=0, rt_range=(1127.4284220786583, 1137.4284220786583)
# | feature_id | mass          | rt            | intensity     | annotation        | gt_metabolite | gt_adduct |
# | 462        | 205.106446652 | 1132.42842208 | 1186.64242435 | M+H @ 204.0991702 | 7             | M+NH4     |
#
# PrecursorBin bin_id=463, len(features)=1, mass_range=(206.10424691875124, 206.10507133738776), len(molecules)=0, rt_range=(1132.3734394574853, 1142.3734394574853)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 432        | 104.059696672 | 1138.13168142 | 390.937034902 | M+2H @ 206.10484044 | 7             | M+H+NH4   |
#
# PrecursorBin bin_id=465, len(features)=1, mass_range=(204.09713869247832, 204.09795508266586), len(molecules)=0, rt_range=(1132.629335990543, 1142.629335990543)
# | feature_id | mass          | rt            | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 433        | 103.056213248 | 1134.88619644 | 180313.519142 | M+2H @ 204.097873592 | 7             | M+H+NH4   |
#
# PrecursorBin bin_id=481, len(features)=1, mass_range=(228.09823469518804, 228.09914708995163), len(molecules)=0, rt_range=(1132.0350376388421, 1142.0350376388421)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 482        | 229.105967345 | 1137.03503764 | 1036.82351404 | M+H @ 228.098690893 | 7             | M+ACN+H   |
#
# PrecursorBin bin_id=483, len(features)=1, mass_range=(230.10407893819394, 230.1049993563505), len(molecules)=0, rt_range=(1133.7061606023858, 1143.7061606023858)
# | feature_id | mass          | rt            | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 440        | 116.059617107 | 1138.68537192 | 643.267944081 | M+2H @ 230.104681309 | 7             | M+ACN+2H  |
#
# PrecursorBin bin_id=488, len(features)=1, mass_range=(111.5482046640967, 111.54865085780774), len(molecules)=0, rt_range=(590.3168741390931, 600.3168741390931)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 489        | 112.555704213 | 595.316874139 | 1869.35850574 | M+H @ 111.548427761 | 8             | M+2H      |
#
# PrecursorBin bin_id=494, len(features)=1, mass_range=(119.56002254298087, 119.56050078402754), len(molecules)=0, rt_range=(589.9447236046315, 599.9447236046315)
# | feature_id | mass          | rt            | intensity    | annotation          | gt_metabolite | gt_adduct |
# | 495        | 120.567538115 | 594.944723605 | 1173.4565698 | M+H @ 119.560261664 | 8             | M+H+NH4   |
#
# PrecursorBin bin_id=503, len(features)=1, mass_range=(131.55970574235022, 131.56023198222567), len(molecules)=0, rt_range=(590.5448853970234, 600.5448853970234)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 504        | 132.567245314 | 595.544885397 | 48361.2924436 | M+H @ 131.559968862 | 8             | M+ACN+2H  |
#
# PrecursorBin bin_id=505, len(features)=1, mass_range=(151.57133832431404, 151.5719446108799), len(molecules)=0, rt_range=(587.6081748985044, 597.6081748985044)
# | feature_id | mass         | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 506        | 152.57891792 | 592.608174899 | 419120.932228 | M+H @ 151.571641468 | 8             | M+2ACN+2H |
#
# PrecursorBin bin_id=511, len(features)=1, mass_range=(222.0940004034835, 222.0948887812619), len(molecules)=0, rt_range=(589.2925661499851, 599.2925661499851)
# | feature_id | mass          | rt            | intensity     | annotation              | gt_metabolite | gt_adduct |
# | 539        | 264.128198456 | 594.624222699 | 977.406045853 | M+ACN+H @ 222.094372901 | 8             | M+ACN+H   |
#
# PrecursorBin bin_id=512, len(features)=1, mass_range=(223.09643942993878, 223.09733181748126), len(molecules)=0, rt_range=(586.9579962439115, 596.9579962439115)
# | feature_id | mass          | rt            | intensity     | annotation            | gt_metabolite | gt_adduct |
# | 522        | 241.130541646 | 596.812912513 | 1890.00000888 | M+NH4 @ 223.096716091 | 8             | M+NH4     |
#
# PrecursorBin bin_id=515, len(features)=1, mass_range=(223.08997650279764, 223.09086886448836), len(molecules)=0, rt_range=(587.2313942023853, 597.2313942023853)
# | feature_id | mass          | rt            | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 531        | 246.079209605 | 594.863149489 | 184.753432259 | M+Na @ 223.089988525 | 8             | M+Na      |
#
# PrecursorBin bin_id=518, len(features)=1, mass_range=(222.09291029599103, 222.09379866940895), len(molecules)=0, rt_range=(586.0461936281359, 596.0461936281359)
# | feature_id | mass          | rt            | intensity     | annotation                | gt_metabolite | gt_adduct |
# | 537        | 255.126891649 | 595.303403425 | 47779.1261039 | M+CH3OH+H @ 222.093400447 | 8             | M+CH3OH+H |
#
# PrecursorBin bin_id=519, len(features)=1, mass_range=(240.12032539018847, 240.12128587341098), len(molecules)=0, rt_range=(591.4165239532697, 601.4165239532697)
# | feature_id | mass          | rt            | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 494        | 121.067576142 | 595.982751345 | 5828.79882244 | M+2H @ 240.120599381 | 8             | M+H+NH4   |
#
# PrecursorBin bin_id=526, len(features)=1, mass_range=(244.07573719270758, 244.07671349760895), len(molecules)=0, rt_range=(590.6475365032687, 600.6475365032687)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 527        | 245.083501797 | 595.647536503 | 1024.96674097 | M+H @ 244.076225345 | 8             | M+Na      |
#
# PrecursorBin bin_id=528, len(features)=1, mass_range=(245.07866992084843, 245.07965023748875), len(molecules)=0, rt_range=(589.8185403623606, 599.8185403623606)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 529        | 246.086436531 | 594.818540362 | 100.214141081 | M+H @ 245.079160079 | 8             | M+Na      |
#
# PrecursorBin bin_id=529, len(features)=1, mass_range=(244.06841131616457, 244.06938759176236), len(molecules)=0, rt_range=(587.3917303358884, 597.3917303358884)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 530        | 245.076175906 | 592.391730336 | 1551.83615339 | M+H @ 244.068899454 | 8             | M+Na      |
#
# PrecursorBin bin_id=535, len(features)=1, mass_range=(255.11614173794268, 255.11716220455057), len(molecules)=0, rt_range=(589.8316509056756, 599.8316509056756)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 536        | 256.123928423 | 594.831650906 | 183.098221149 | M+H @ 255.116651971 | 8             | M+CH3OH+H |
#
# PrecursorBin bin_id=541, len(features)=1, mass_range=(264.12262405119696, 264.1236805438062), len(molecules)=0, rt_range=(590.0889123000078, 600.0889123000078)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 505        | 133.068988782 | 592.434358755 | 2225.98412696 | M+2H @ 264.12342466 | 8             | M+ACN+2H  |
#
# PrecursorBin bin_id=551, len(features)=1, mass_range=(85.03472526440865, 85.03506540398999), len(molecules)=0, rt_range=(485.6933639136937, 495.6933639136937)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 552        | 86.0421717862 | 490.693363914 | 41.0454503767 | M+H @ 85.0348953342 | 9             | M+H+NH4   |
#
# PrecursorBin bin_id=559, len(features)=1, mass_range=(96.53953127702769, 96.5399174359251), len(molecules)=0, rt_range=(482.6586480979731, 492.6586480979731)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 560        | 97.5470008085 | 487.658648098 | 16284.8870297 | M+H @ 96.5397243565 | 9             | M+ACN+2H  |
#
# PrecursorBin bin_id=573, len(features)=1, mass_range=(169.08009269335653, 169.08076901507994), len(molecules)=0, rt_range=(482.4596956300041, 492.4596956300041)
# | feature_id | mass          | rt            | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 550        | 85.5475608241 | 488.427894584 | 90.0558276424 | M+2H @ 169.080568744 | 9             | M+H+NH4   |
#
# PrecursorBin bin_id=610, len(features)=1, mass_range=(93.54859747563518, 93.54897167077348), len(molecules)=0, rt_range=(817.7027205078022, 827.7027205078022)
# ...
#
# PrecursorBin bin_id=928, len(features)=1, mass_range=(103.55434263808763, 103.55475685628662), len(molecules)=0, rt_range=(1425.9901304711016, 1435.9901304711016)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 929        | 104.561826199 | 1430.99013047 | 36198.8385851 | M+H @ 103.554549747 | 15            | M+ACN+2H  |
#
# PrecursorBin bin_id=937, len(features)=1, mass_range=(165.07884894181763, 165.07950925853402), len(molecules)=0, rt_range=(1426.158774947535, 1436.158774947535)
# | feature_id | mass          | rt            | intensity     | annotation            | gt_metabolite | gt_adduct |
# | 946        | 183.112790654 | 1431.40389234 | 326414.187339 | M+NH4 @ 165.078965099 | 15            | M+NH4     |
#
# PrecursorBin bin_id=943, len(features)=1, mass_range=(167.0852730501619, 167.08594139259077), len(molecules)=0, rt_range=(1425.350130585648, 1435.350130585648)
# | feature_id | mass          | rt           | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 962        | 190.075063919 | 1431.7312272 | 1294.93088271 | M+Na @ 167.085842839 | 15            | M+Na      |
#
# PrecursorBin bin_id=945, len(features)=1, mass_range=(182.10514999085086, 182.10587841290766), len(molecules)=0, rt_range=(1426.4038923370977, 1436.4038923370977)
# | feature_id | mass          | rt            | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 915        | 92.0601015761 | 1432.11369625 | 300403.096889 | M+2H @ 182.105650248 | 15            | M+H+NH4   |
#
# PrecursorBin bin_id=952, len(features)=1, mass_range=(184.11183616615904, 184.1125726149766), len(molecules)=0, rt_range=(1427.7536270573837, 1437.7536270573837)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 953        | 185.119480843 | 1432.75362706 | 1231.98582039 | M+H @ 184.112204391 | 15            | M+NH4     |
#
# PrecursorBin bin_id=955, len(features)=1, mass_range=(189.0647561478885, 189.0655124084256), len(molecules)=0, rt_range=(1427.1584874910193, 1437.1584874910193)
# | feature_id | mass         | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 956        | 190.07241073 | 1432.15848749 | 1390.19380745 | M+H @ 189.065134278 | 15            | M+Na      |
#
# PrecursorBin bin_id=956, len(features)=1, mass_range=(188.05771294294985, 188.0584651753061), len(molecules)=0, rt_range=(1427.0487878685285, 1437.0487878685285)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 957        | 189.065365511 | 1432.04878787 | 1084.69074044 | M+H @ 188.058089059 | 15            | M+Na      |
#
# PrecursorBin bin_id=963, len(features)=1, mass_range=(197.10500311192015, 197.10579153350943), len(molecules)=0, rt_range=(1427.7990837918376, 1437.7990837918376)
# | feature_id | mass          | rt            | intensity    | annotation          | gt_metabolite | gt_adduct |
# | 964        | 198.112673775 | 1432.79908379 | 314818.68632 | M+H @ 197.105397323 | 15            | M+CH3OH+H |
#
# PrecursorBin bin_id=974, len(features)=1, mass_range=(207.10195405934596, 207.10278246881902), len(molecules)=0, rt_range=(1423.2235266926866, 1433.2235266926866)
# | feature_id | mass          | rt            | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 925        | 104.558628833 | 1431.71542685 | 2224.28379409 | M+2H @ 207.102704762 | 15            | M+ACN+2H  |
#
# PrecursorBin bin_id=986, len(features)=1, mass_range=(74.06037365855481, 74.06066990064194), len(molecules)=0, rt_range=(912.2338736499524, 922.2338736499524)
# | feature_id | mass          | rt           | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 987        | 75.0677982316 | 917.23387365 | 105145.600253 | M+H @ 74.0605217796 | 16            | M+H+NH4   |
#
# PrecursorBin bin_id=996, len(features)=1, mass_range=(87.06511979904023, 87.06546806021596), len(molecules)=0, rt_range=(911.4567275221768, 921.4567275221768)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 997        | 88.0725703816 | 916.456727522 | 17.7449494451 | M+H @ 87.0652939296 | 16            | M+ACN+2H  |
#
# PrecursorBin bin_id=1003, len(features)=1, mass_range=(131.09435346681659, 131.0948778452792), len(molecules)=0, rt_range=(915.3484441028864, 925.3484441028864)
# | feature_id | mass          | rt            | intensity     | annotation            | gt_metabolite | gt_adduct |
# | 1012       | 149.128611472 | 919.405410907 | 100458.639372 | M+NH4 @ 131.094785917 | 16            | M+NH4     |
#
# PrecursorBin bin_id=1007, len(features)=1, mass_range=(132.10082444346168, 132.10135284781623), len(molecules)=0, rt_range=(915.0800632132809, 925.0800632132809)
# | feature_id | mass          | rt           | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 983        | 67.0577140198 | 923.52016006 | 182.096496538 | M+2H @ 132.100875136 | 16            | M+2H      |
#
# PrecursorBin bin_id=1008, len(features)=1, mass_range=(132.09769394536457, 132.09822233719714), len(molecules)=0, rt_range=(914.4395900230354, 924.4395900230354)
# | feature_id | mass          | rt            | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 1021       | 155.086952449 | 916.276121727 | 7819.95931374 | M+Na @ 132.097731369 | 16            | M+Na      |
#
# PrecursorBin bin_id=1013, len(features)=1, mass_range=(149.11785204417836, 149.11844851677947), len(molecules)=0, rt_range=(912.530629813562, 922.530629813562)
# | feature_id | mass          | rt            | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 989        | 75.5664005653 | 919.664178403 | 718.457047342 | M+2H @ 149.118248227 | 16            | M+H+NH4   |
#
# PrecursorBin bin_id=1015, len(features)=1, mass_range=(149.12419006667278, 149.12478656462605), len(molecules)=0, rt_range=(913.5951676981741, 923.5951676981741)
# | feature_id | mass          | rt            | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 992        | 75.5695204074 | 914.613630484 | 7366.86839579 | M+2H @ 149.124487911 | 16            | M+H+NH4   |
#
# PrecursorBin bin_id=1017, len(features)=1, mass_range=(153.07633374384469, 153.07694605040425), len(molecules)=0, rt_range=(916.5363692451518, 926.5363692451518)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 1018       | 154.083916349 | 921.536369245 | 108069.151564 | M+H @ 153.076639897 | 16            | M+Na      |
#
# PrecursorBin bin_id=1036, len(features)=1, mass_range=(175.1283558837718, 175.1290563985964), len(molecules)=0, rt_range=(912.2928144033889, 922.2928144033889)
# | feature_id | mass          | rt           | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 1000       | 88.5715026212 | 916.03276727 | 38.9000594141 | M+2H @ 175.128452338 | 16            | M+ACN+2H  |
#
# PrecursorBin bin_id=1044, len(features)=1, mass_range=(188.57038845599007, 188.57114273905248), len(molecules)=0, rt_range=(981.6452185591658, 991.6452185591658)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 1040       | 189.578380563 | 988.622818914 | 160.759874624 | M+H @ 188.571104111 | 17            | M+2H      |
#
# PrecursorBin bin_id=1045, len(features)=1, mass_range=(188.5718114663844, 188.5725657551388), len(molecules)=0, rt_range=(977.4431325922644, 987.4431325922644)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 1046       | 189.579465063 | 982.443132592 | 185.500911044 | M+H @ 188.572188611 | 17            | M+2H      |
#
# PrecursorBin bin_id=1056, len(features)=1, mass_range=(209.0838030915985, 209.0846394284835), len(molecules)=0, rt_range=(974.8783815337117, 984.8783815337117)
# | feature_id | mass          | rt            | intensity     | annotation         | gt_metabolite | gt_adduct |
# | 1057       | 210.091497712 | 979.878381534 | 168.128470955 | M+H @ 209.08422126 | 17            | M+ACN+2H  |
#
# PrecursorBin bin_id=1062, len(features)=1, mass_range=(229.0954005250447, 229.09631690847957), len(molecules)=0, rt_range=(981.1817193959288, 991.1817193959288)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 1063       | 230.103135169 | 986.181719396 | 73986.4510146 | M+H @ 229.095858717 | 17            | M+2ACN+2H |
#
# PrecursorBin bin_id=1081, len(features)=1, mass_range=(395.16464156847576, 395.1662222302034), len(molecules)=0, rt_range=(977.874185028826, 987.874185028826)
# | feature_id | mass          | rt            | intensity    | annotation           | gt_metabolite | gt_adduct |
# | 1053       | 198.590190246 | 982.847991616 | 236.76643552 | M+2H @ 395.165827588 | 17            | M+H+NH4   |
#
# PrecursorBin bin_id=1091, len(features)=1, mass_range=(409.16781845566805, 409.1694551302152), len(molecules)=0, rt_range=(976.0973848587631, 986.0973848587631)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 1092       | 410.175913245 | 981.097384859 | 214.853236547 | M+H @ 409.168636793 | 17            | M+CH3OH+H |
#
# PrecursorBin bin_id=1093, len(features)=1, mass_range=(409.1670111481433, 409.16864781946117), len(molecules)=0, rt_range=(975.4549394378575, 985.4549394378575)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 1094       | 410.175105936 | 980.454939438 | 12881.6210894 | M+H @ 409.167829484 | 17            | M+CH3OH+H |
#
# PrecursorBin bin_id=1097, len(features)=1, mass_range=(417.1641660731246, 417.16583473312625), len(molecules)=0, rt_range=(977.3753803712201, 987.3753803712201)
# | feature_id | mass          | rt            | intensity    | annotation           | gt_metabolite | gt_adduct |
# | 1055       | 209.589775993 | 983.502031156 | 67064.255738 | M+2H @ 417.164999081 | 17            | M+ACN+2H  |
#
# PrecursorBin bin_id=1101, len(features)=1, mass_range=(418.16764651752186, 418.1693191914533), len(molecules)=0, rt_range=(980.5530698618918, 990.5530698618918)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 1102       | 419.175759306 | 985.553069862 | 12374.9701047 | M+H @ 418.168482854 | 17            | M+ACN+H   |
#
# PrecursorBin bin_id=1109, len(features)=1, mass_range=(62.51918915064852, 62.51943922790527), len(molecules)=0, rt_range=(1238.8872185303394, 1248.8872185303394)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 1110       | 63.5265906413 | 1243.88721853 | 530.159989519 | M+H @ 62.5193141893 | 18            | M+2H      |
#
# PrecursorBin bin_id=1115, len(features)=1, mass_range=(71.03247064532708, 71.03275477577792), len(molecules)=0, rt_range=(1237.5014616598955, 1247.5014616598955)
# | feature_id | mass          | rt            | intensity    | annotation          | gt_metabolite | gt_adduct |
# | 1116       | 72.0398891625 | 1242.50146166 | 556.94832173 | M+H @ 71.0326127106 | 18            | M+H+NH4   |
#
# PrecursorBin bin_id=1117, len(features)=1, mass_range=(82.53125076068581, 82.53158088634909), len(molecules)=0, rt_range=(1238.0987013887684, 1248.0987013887684)
# | feature_id | mass          | rt            | intensity    | annotation          | gt_metabolite | gt_adduct |
# | 1118       | 83.5386922755 | 1243.09870139 | 248.56826846 | M+H @ 82.5314158235 | 18            | M+ACN+2H  |
#
# PrecursorBin bin_id=1118, len(features)=1, mass_range=(82.52760431375893, 82.52793442483642), len(molecules)=0, rt_range=(1237.4469858121622, 1247.4469858121622)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 1119       | 83.5350458213 | 1242.44698581 | 2538.18853849 | M+H @ 82.5277693693 | 18            | M+ACN+2H  |
#
# PrecursorBin bin_id=1120, len(features)=1, mass_range=(83.02936387826612, 83.02969599638588), len(molecules)=0, rt_range=(1239.1262178256757, 1249.1262178256757)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 1121       | 84.0368063893 | 1244.12621783 | 163.138326053 | M+H @ 83.0295299373 | 18            | M+ACN+2H  |
#
# PrecursorBin bin_id=1146, len(features)=1, mass_range=(147.02042224167505, 147.02101032454019), len(molecules)=0, rt_range=(1239.3868880661703, 1249.3868880661703)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 1147       | 148.027992735 | 1244.38688807 | 516.148007953 | M+H @ 147.020716283 | 18            | M+Na      |
#
# PrecursorBin bin_id=1148, len(features)=1, mass_range=(146.01715354233013, 146.01773761211243), len(molecules)=0, rt_range=(1240.6674078425756, 1250.6674078425756)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 1149       | 147.024722029 | 1245.66740784 | 19113.2655362 | M+H @ 146.017445577 | 18            | M+Na      |
#
# PrecursorBin bin_id=1161, len(features)=1, mass_range=(165.06233276571604, 165.06299301636759), len(molecules)=0, rt_range=(1236.8939069187256, 1246.8939069187256)
# | feature_id | mass          | rt           | intensity     | annotation               | gt_metabolite | gt_adduct |
# | 1125       | 104.052019025 | 1243.5813176 | 250.176751558 | M+ACN+2H @ 165.062936042 | 18            | M+2ACN+2H |
#
# PrecursorBin bin_id=1166, len(features)=1, mass_range=(166.06482041892102, 166.06548467953124), len(molecules)=0, rt_range=(1235.0507135124724, 1245.0507135124724)
# | feature_id | mass          | rt            | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 1124       | 84.0398785937 | 1241.18169033 | 1010.71527523 | M+2H @ 166.065204283 | 18            | M+ACN+2H  |
#
# PrecursorBin bin_id=1182, len(features)=1, mass_range=(89.03685064704132, 89.03720679515621), len(molecules)=0, rt_range=(770.6781088801865, 780.6781088801865)
# | feature_id | mass          | rt           | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 1183       | 90.0443051731 | 775.67810888 | 175122.531456 | M+H @ 89.0370287211 | 19            | M+ACN+2H  |
#
# PrecursorBin bin_id=1190, len(features)=1, mass_range=(109.55006024023658, 109.55049844135394), len(molecules)=0, rt_range=(770.8633033978859, 780.8633033978859)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 1191       | 110.557555793 | 775.863303398 | 125725.485414 | M+H @ 109.550279341 | 19            | M+2ACN+2H |
#
# PrecursorBin bin_id=1203, len(features)=1, mass_range=(139.05404223188737, 139.05459844916874), len(molecules)=0, rt_range=(773.9021337105545, 783.9021337105545)
# | feature_id | mass         | rt            | intensity     | annotation              | gt_metabolite | gt_adduct |
# | 1182       | 79.047753416 | 778.013078204 | 353.012274075 | M+H+NH4 @ 139.054404825 | 19            | M+H+NH4   |
#
# PrecursorBin bin_id=1207, len(features)=1, mass_range=(157.08162536203878, 157.08225368979686), len(molecules)=0, rt_range=(769.5108422864988, 779.5108422864988)
# | feature_id | mass          | rt           | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 1181       | 79.5483254253 | 775.58462114 | 46.3815364689 | M+2H @ 157.082097947 | 19            | M+H+NH4   |
#
# PrecursorBin bin_id=1210, len(features)=1, mass_range=(161.03885859595297, 161.03950275267565), len(molecules)=0, rt_range=(774.782284099682, 784.782284099682)
# | feature_id | mass          | rt          | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 1211       | 162.046457126 | 779.7822841 | 8.62963642728 | M+H @ 161.039180674 | 19            | M+Na      |
#
# Empty bins=1022
# Occupied bins=207

# %% [markdown]
# ## Try on std1 pos data

# %%
# load std1 file
input_file = basedir + '/input/std1_csv/std1-file1.identified.csv'    
database_file = basedir + '/database/std1_mols.csv'
transformation_file = basedir + '/mulsubs/mulsub.txt'
mass_tol = 2
rt_tol = 5
loader = FileLoader()
peak_data = loader.load_model_input(input_file, database_file, transformation_file, mass_tol, rt_tol)
    
# run it through the model
hp = HyperPars()
nsamps = 20
mbc = DiscreteGibbs(peak_data, hp, nsamps)
mbc.run()
# Out:
# Discretising peak data at mass_tol 2 and rt_tol 5
# 4999 bins created
# DiscreteGibbs initialised
# SAMPLE 1 3.44s	Counter({'0': 4763, '1': 218, '2': 18})
# SAMPLE 2 3.09s	Counter({'0': 4770, '1': 206, '2': 21, '3': 2})
# SAMPLE 3 3.01s	Counter({'0': 4768, '1': 210, '2': 20, '4': 1})
# SAMPLE 4 2.97s	Counter({'0': 4764, '1': 217, '2': 17, '3': 1})
# SAMPLE 5 2.97s	Counter({'0': 4763, '1': 218, '2': 18})
# SAMPLE 6 2.96s	Counter({'0': 4766, '1': 214, '2': 17, '3': 2})
# SAMPLE 7 2.97s	Counter({'0': 4768, '1': 210, '2': 19, '3': 2})
# SAMPLE 8 2.98s	Counter({'0': 4766, '1': 212, '2': 21})
# SAMPLE 9 2.99s	Counter({'0': 4765, '1': 215, '2': 18, '3': 1})
# SAMPLE 10 2.97s	Counter({'0': 4767, '1': 210, '2': 22})
# SAMPLE 11 3.00s	Counter({'0': 4769, '1': 207, '2': 22, '3': 1})
# SAMPLE 12 2.99s	Counter({'0': 4769, '1': 206, '2': 24})
# SAMPLE 13 3.02s	Counter({'0': 4767, '1': 212, '2': 18, '3': 2})
# SAMPLE 14 2.97s	Counter({'0': 4763, '1': 218, '2': 18})
# SAMPLE 15 3.05s	Counter({'0': 4769, '1': 207, '2': 22, '3': 1})
# SAMPLE 16 3.01s	Counter({'0': 4766, '1': 213, '2': 19, '3': 1})
# SAMPLE 17 2.97s	Counter({'0': 4761, '1': 224, '2': 12, '3': 2})
# SAMPLE 18 2.97s	Counter({'0': 4766, '1': 213, '2': 19, '3': 1})
# SAMPLE 19 2.98s	Counter({'0': 4762, '1': 222, '2': 13, '3': 2})
# SAMPLE 20 3.00s	Counter({'0': 4768, '1': 209, '2': 21, '3': 1})
# DONE!
#
# Last sample report
# PrecursorBin bin_id=398, len(features)=3, mass_range=(190.09463125110747, 190.09539163115326), len(molecules)=0, rt_range=(1417.199951171875, 1427.199951171875)
# | feature_id | mass          | rt            | intensity     | annotation               | gt_metabolite | gt_adduct |
# | 2195       | 116.567964978 | 1427.02001953 | 14392.3876953 | M+ACN+2H @ 190.094827949 | None          | None      |
# | 2072       | 213.084039422 | 1425.40002441 | 16200.9638672 | M+Na @ 190.094818342     | None          | None      |
# | 3346       | 96.0547156469 | 1425.40002441 | 5985.64599609 | M+2H @ 190.09487839      | None          | None      |
#
# PrecursorBin bin_id=151, len(features)=2, mass_range=(243.0846433648904, 243.08561570540857), len(molecules)=0, rt_range=(1155.530029296875, 1165.530029296875)
# | feature_id | mass          | rt            | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 383        | 266.074236449 | 1163.81005859 | 340702.8125   | M+Na @ 243.085015369 | None          | None      |
# | 2056       | 282.047947233 | 1163.81005859 | 16447.0078125 | M+K @ 243.084788913  | None          | None      |
#
# PrecursorBin bin_id=205, len(features)=2, mass_range=(173.08352247136895, 173.08421480684353), len(molecules)=0, rt_range=(329.9670104980469, 339.9670104980469)
# | feature_id | mass          | rt            | intensity    | annotation           | gt_metabolite | gt_adduct |
# | 206        | 174.091145091 | 334.967010498 | 712898.125   | M+H @ 173.083868639  | None          | None      |
# | 1437       | 191.117586935 | 334.967010498 | 32890.921875 | M+NH4 @ 173.08376138 | None          | None      |
#
# PrecursorBin bin_id=270, len(features)=2, mass_range=(174.11107228918698, 174.111768734869), len(molecules)=0, rt_range=(1580.760009765625, 1590.760009765625)
# | feature_id | mass          | rt            | intensity     | annotation               | gt_metabolite | gt_adduct |
# | 2067       | 108.57617235  | 1587.36999512 | 16293.3388672 | M+ACN+2H @ 174.111242692 | None          | None      |
# | 1567       | 197.100462039 | 1587.36999512 | 27938.2617188 | M+Na @ 174.111240959     | None          | None      |
#
# PrecursorBin bin_id=446, len(features)=2, mass_range=(155.0689150562624, 155.0695353331632), len(molecules)=0, rt_range=(1520.969970703125, 1530.969970703125)
# | feature_id | mass          | rt            | intensity     | annotation              | gt_metabolite | gt_adduct |
# | 2502       | 178.058224985 | 1529.19995117 | 11125.2617188 | M+Na @ 155.069003904    | None          | None      |
# | 2916       | 200.040114812 | 1525.9699707  | 8081.01025391 | M+2Na-H @ 155.068949104 | None          | None      |
#
# PrecursorBin bin_id=501, len(features)=2, mass_range=(101.52779792430354, 101.52820403630747), len(molecules)=0, rt_range=(1915.260009765625, 1925.260009765625)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 502        | 102.535277432 | 1920.26000977 | 225745.828125 | M+H @ 101.52800098  | None          | None      |
# | 501        | 102.535290331 | 1920.26000977 | 225745.828125 | M+H @ 101.528013879 | None          | None      |
#
# PrecursorBin bin_id=635, len(features)=2, mass_range=(101.04732940816758, 101.04773359829359), len(molecules)=0, rt_range=(1040.449951171875, 1050.449951171875)
# | feature_id | mass          | rt            | intensity    | annotation          | gt_metabolite | gt_adduct |
# | 636        | 102.054807955 | 1045.44995117 | 169021.59375 | M+H @ 101.047531503 | None          | None      |
# | 637        | 102.054832644 | 1045.44995117 | 169021.59375 | M+H @ 101.047556192 | None          | None      |
#
# PrecursorBin bin_id=1269, len(features)=2, mass_range=(577.1280549603194, 577.1303634771563), len(molecules)=0, rt_range=(98.1259994506836, 108.1259994506836)
# | feature_id | mass          | rt            | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 2042       | 600.118195278 | 101.503997803 | 16721.0351562 | M+Na @ 577.128974198 | None          | None      |
# | 3126       | 616.092375535 | 101.503997803 | 6958.43261719 | M+K @ 577.129217215  | None          | None      |
#
# PrecursorBin bin_id=1342, len(features)=2, mass_range=(190.1309853396434, 190.13174586510578), len(molecules)=0, rt_range=(1953.4599609375, 1963.4599609375)
# | feature_id | mass         | rt            | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 3632       | 96.072971063 | 1958.45996094 | 5093.40380859 | M+2H @ 190.131389222 | None          | None      |
# | 4173       | 213.12047118 | 1961.66003418 | 3524.85644531 | M+Na @ 190.1312501   | None          | None      |
#
# PrecursorBin bin_id=1380, len(features)=2, mass_range=(113.06716383812253, 113.06761610768243), len(molecules)=0, rt_range=(1028.1600341796875, 1038.1600341796875)
# | feature_id | mass          | rt            | intensity   | annotation          | gt_metabolite | gt_adduct |
# | 1381       | 114.074666425 | 1033.16003418 | 35648.71875 | M+H @ 113.067389973 | None          | None      |
# | 1380       | 114.074659373 | 1033.16003418 | 35648.71875 | M+H @ 113.067382921 | None          | None      |
#
# PrecursorBin bin_id=1397, len(features)=2, mass_range=(231.07339326622156, 231.07431756164323), len(molecules)=0, rt_range=(453.4649963378906, 463.4649963378906)
# | feature_id | mass          | rt            | intensity     | annotation                | gt_metabolite | gt_adduct |
# | 4132       | 264.107420875 | 458.464996338 | 3653.98852539 | M+CH3OH+H @ 231.073929673 | None          | None      |
# | 1399       | 254.06297937  | 461.540008545 | 34568.7851562 | M+Na @ 231.07375829       | None          | None      |
#
# PrecursorBin bin_id=1463, len(features)=2, mass_range=(254.93087141564138, 254.9318911411665), len(molecules)=0, rt_range=(2042.739990234375, 2052.739990234375)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 1464       | 255.93865773  | 2047.73999023 | 31973.3710938 | M+H @ 254.931381278 | None          | None      |
# | 1465       | 255.938713359 | 2047.73999023 | 31973.3710938 | M+H @ 254.931436907 | None          | None      |
#
# PrecursorBin bin_id=1654, len(features)=2, mass_range=(83.08074448385702, 83.08107680749961), len(molecules)=0, rt_range=(2735.52001953125, 2745.52001953125)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 1655       | 84.0881870977 | 2740.52001953 | 25173.0097656 | M+H @ 83.0809106457 | None          | None      |
# | 1654       | 84.0881821475 | 2740.52001953 | 25173.0097656 | M+H @ 83.0809056955 | None          | None      |
#
# PrecursorBin bin_id=1709, len(features)=2, mass_range=(176.02353919044947, 176.02424328601444), len(molecules)=0, rt_range=(1194.6600341796875, 1204.6600341796875)
# | feature_id | mass         | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 1710       | 177.03116769 | 1199.66003418 | 23725.9257812 | M+H @ 176.023891238 | None          | None      |
# | 1709       | 177.03118169 | 1199.66003418 | 23725.9257812 | M+H @ 176.023905238 | None          | None      |
#
# PrecursorBin bin_id=2128, len(features)=2, mass_range=(89.49936908821425, 89.49972708640661), len(molecules)=0, rt_range=(2696.68994140625, 2706.68994140625)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 2129       | 90.5068245393 | 2701.68994141 | 15321.4140625 | M+H @ 89.4995480873 | None          | None      |
# | 2128       | 90.5068432368 | 2701.68994141 | 15321.4140625 | M+H @ 89.4995667848 | None          | None      |
#
# PrecursorBin bin_id=2405, len(features)=2, mass_range=(311.17488918570024, 311.1761338877464), len(molecules)=0, rt_range=(826.7260131835938, 836.7260131835938)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 2406       | 312.182787989 | 831.726013184 | 12125.8720703 | M+H @ 311.175511537 | None          | None      |
# | 2405       | 312.18271399  | 831.726013184 | 12125.8720703 | M+H @ 311.175437538 | None          | None      |
#
# PrecursorBin bin_id=2665, len(features)=2, mass_range=(73.08897301766163, 73.08926537413842), len(molecules)=0, rt_range=(2747.89990234375, 2757.89990234375)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 2665       | 74.0963853112 | 2752.89990234 | 9558.21777344 | M+H @ 73.0891088592 | None          | None      |
# | 2666       | 74.0963956479 | 2752.89990234 | 9558.21777344 | M+H @ 73.0891191959 | None          | None      |
#
# PrecursorBin bin_id=2789, len(features)=2, mass_range=(519.2166107913639, 519.2186876619609), len(molecules)=0, rt_range=(847.0419921875, 857.0419921875)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 2791       | 520.224998186 | 852.041992188 | 8825.41210938 | M+H @ 519.217721734 | None          | None      |
# | 2790       | 520.224925679 | 852.041992188 | 8825.41210938 | M+H @ 519.217649227 | None          | None      |
#
# PrecursorBin bin_id=2817, len(features)=2, mass_range=(326.0164751378988, 326.0177792064075), len(molecules)=0, rt_range=(560.0659790039062, 570.0659790039062)
# | feature_id | mass          | rt            | intensity    | annotation          | gt_metabolite | gt_adduct |
# | 2818       | 327.024403624 | 565.065979004 | 8642.9296875 | M+H @ 326.017127172 | None          | None      |
# | 2819       | 327.024225371 | 565.065979004 | 8642.9296875 | M+H @ 326.016948919 | None          | None      |
#
# PrecursorBin bin_id=3817, len(features)=2, mass_range=(170.72765287430454, 170.72833578628186), len(molecules)=0, rt_range=(912.7119750976562, 922.7119750976562)
# | feature_id | mass          | rt            | intensity    | annotation          | gt_metabolite | gt_adduct |
# | 3819       | 171.735133633 | 917.711975098 | 4560.3828125 | M+H @ 170.727857181 | None          | None      |
# | 3818       | 171.735270782 | 917.711975098 | 4560.3828125 | M+H @ 170.72799433  | None          | None      |
#
# PrecursorBin bin_id=3836, len(features)=2, mass_range=(243.05423360511531, 243.05520582399419), len(molecules)=0, rt_range=(709.75, 719.75)
# | feature_id | mass          | rt     | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 3837       | 244.061996167 | 714.75 | 4509.71826172 | M+H @ 243.054719715 | None          | None      |
# | 3838       | 244.062000712 | 714.75 | 4509.71826172 | M+H @ 243.05472426  | None          | None      |
#
# PrecursorBin bin_id=4059, len(features)=2, mass_range=(102.12637125338449, 102.12677975968651), len(molecules)=0, rt_range=(742.47998046875, 752.47998046875)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 4059       | 103.133841094 | 747.479980469 | 3830.12304688 | M+H @ 102.126564642 | None          | None      |
# | 4060       | 103.133851959 | 747.479980469 | 3830.12304688 | M+H @ 102.126575507 | None          | None      |
#
# PrecursorBin bin_id=5, len(features)=1, mass_range=(232.12044365667631, 232.1213721403079), len(molecules)=0, rt_range=(333.0450134277344, 343.0450134277344)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 901        | 271.083870981 | 338.045013428 | 87657.3671875 | M+K @ 232.120712661 | None          | None      |
#
# PrecursorBin bin_id=13, len(features)=1, mass_range=(131.09423087861902, 131.0947552565913), len(molecules)=0, rt_range=(778.7739868164062, 788.7739868164062)
# | feature_id | mass          | rt            | intensity     | annotation              | gt_metabolite | gt_adduct |
# | 1455       | 173.128140447 | 786.726013184 | 32261.8867188 | M+ACN+H @ 131.094314892 | None          | None      |
#
# PrecursorBin bin_id=18, len(features)=1, mass_range=(123.03165786768211, 123.03214999529784), len(molecules)=0, rt_range=(450.3890075683594, 460.3890075683594)
# | feature_id | mass          | rt            | intensity     | annotation              | gt_metabolite | gt_adduct |
# | 2082       | 165.065530759 | 453.846008301 | 16041.9726562 | M+ACN+H @ 123.031705203 | None          | None      |
#
# PrecursorBin bin_id=20, len(features)=1, mass_range=(136.03809873567135, 136.0386428891546), len(molecules)=0, rt_range=(616.1920166015625, 626.1920166015625)
# | feature_id | mass          | rt            | intensity     | annotation              | gt_metabolite | gt_adduct |
# | 2407       | 178.072090271 | 616.697998047 | 12109.9384766 | M+ACN+H @ 136.038264716 | None          | None      |
#
# PrecursorBin bin_id=22, len(features)=1, mass_range=(121.53959659877653, 121.54008275813523), len(molecules)=0, rt_range=(2098.840087890625, 2108.840087890625)
# | feature_id | mass         | rt            | intensity | annotation          | gt_metabolite | gt_adduct |
# | 23         | 122.54711613 | 2103.84008789 | 4106479.0 | M+H @ 121.539839678 | None          | None      |
#
# PrecursorBin bin_id=23, len(features)=1, mass_range=(264.1036614420073, 264.1047178587659), len(molecules)=0, rt_range=(1763.4000244140625, 1773.4000244140625)
# | feature_id | mass          | rt            | intensity | annotation           | gt_metabolite | gt_adduct |
# | 35         | 133.059345439 | 1768.40002441 | 3345997.0 | M+2H @ 264.104137974 | None          | None      |
#
# PrecursorBin bin_id=33, len(features)=1, mass_range=(137.0472660558098, 137.04781424597041), len(molecules)=0, rt_range=(351.32598876953125, 361.32598876953125)
# | feature_id | mass          | rt            | intensity    | annotation              | gt_metabolite | gt_adduct |
# | 464        | 179.081238513 | 357.842987061 | 258563.53125 | M+ACN+H @ 137.047412958 | None          | None      |
#
# PrecursorBin bin_id=37, len(features)=1, mass_range=(254.10226435303264, 254.10328076412287), len(molecules)=0, rt_range=(333.0450134277344, 343.0450134277344)
# | feature_id | mass          | rt            | intensity  | annotation          | gt_metabolite | gt_adduct |
# | 38         | 255.110049011 | 338.045013428 | 2962731.25 | M+H @ 254.102772559 | None          | None      |
#
# PrecursorBin bin_id=54, len(features)=1, mass_range=(169.00390558761782, 169.00458160459223), len(molecules)=0, rt_range=(995.239990234375, 1005.239990234375)
# | feature_id | mass          | rt           | intensity     | annotation              | gt_metabolite | gt_adduct |
# | 1025       | 211.037912186 | 1004.7199707 | 63347.1601562 | M+ACN+H @ 169.004086631 | None          | None      |
#
# PrecursorBin bin_id=59, len(features)=1, mass_range=(166.0051208936705, 166.00578491548214), len(molecules)=0, rt_range=(2208.830078125, 2218.830078125)
# | feature_id | mass          | rt            | intensity | annotation          | gt_metabolite | gt_adduct |
# | 60         | 167.012729357 | 2213.83007812 | 2392735.0 | M+H @ 166.005452905 | None          | None      |
#
# PrecursorBin bin_id=74, len(features)=1, mass_range=(126.04250005301348, 126.04300422402203), len(molecules)=0, rt_range=(967.4439697265625, 977.4439697265625)
# | feature_id | mass          | rt            | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 2809       | 149.031867856 | 975.611999512 | 8701.29980469 | M+Na @ 126.042646775 | None          | None      |
#
# PrecursorBin bin_id=86, len(features)=1, mass_range=(204.06283807701007, 204.06365432999488), len(molecules)=0, rt_range=(558.6129760742188, 568.6129760742188)
# | feature_id | mass          | rt            | intensity  | annotation              | gt_metabolite | gt_adduct |
# | 257        | 246.096771222 | 563.612976074 | 531303.125 | M+ACN+H @ 204.062945667 | None          | None      |
#
# PrecursorBin bin_id=92, len(features)=1, mass_range=(354.0550248779678, 354.0564411008998), len(molecules)=0, rt_range=(307.7560119628906, 317.7560119628906)
# | feature_id | mass          | rt            | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 1927       | 377.044720443 | 317.579986572 | 18655.0449219 | M+Na @ 354.055499362 | None          | None      |
#
# PrecursorBin bin_id=103, len(features)=1, mass_range=(80.51313494040461, 80.51345699358849), len(molecules)=0, rt_range=(2715.389892578125, 2725.389892578125)
# | feature_id | mass          | rt            | intensity   | annotation          | gt_metabolite | gt_adduct |
# | 105        | 81.5205755772 | 2720.38989258 | 1652647.875 | M+H @ 80.5132991252 | None          | None      |
#
# PrecursorBin bin_id=104, len(features)=1, mass_range=(80.51313809862731, 80.51346015182381), len(molecules)=0, rt_range=(2715.389892578125, 2725.389892578125)
# | feature_id | mass         | rt            | intensity   | annotation         | gt_metabolite | gt_adduct |
# | 104        | 81.520572419 | 2720.38989258 | 1652647.875 | M+H @ 80.513295967 | None          | None      |
#
# PrecursorBin bin_id=123, len(features)=1, mass_range=(100.10772870167017, 100.10812913338583), len(molecules)=0, rt_range=(809.5360107421875, 819.5360107421875)
# | feature_id | mass         | rt           | intensity  | annotation              | gt_metabolite | gt_adduct |
# | 2705       | 142.14170245 | 813.07800293 | 9263.28125 | M+ACN+H @ 100.107876895 | None          | None      |
#
# PrecursorBin bin_id=129, len(features)=1, mass_range=(126.04246539831583, 126.04296956918576), len(molecules)=0, rt_range=(420.1789855957031, 430.1789855957031)
# | feature_id | mass          | rt            | intensity     | annotation              | gt_metabolite | gt_adduct |
# | 2326       | 168.076317848 | 421.990997314 | 12902.3544922 | M+ACN+H @ 126.042492293 | None          | None      |
#
# PrecursorBin bin_id=133, len(features)=1, mass_range=(204.0628783310565, 204.06369458420235), len(molecules)=0, rt_range=(818.1640014648438, 828.1640014648438)
# | feature_id | mass          | rt           | intensity    | annotation              | gt_metabolite | gt_adduct |
# | 477        | 246.096914016 | 824.59197998 | 248920.21875 | M+ACN+H @ 204.063088461 | None          | None      |
#
# PrecursorBin bin_id=142, len(features)=1, mass_range=(233.12366077478544, 233.12459327129352), len(molecules)=0, rt_range=(333.0450134277344, 343.0450134277344)
# | feature_id | mass          | rt            | intensity    | annotation           | gt_metabolite | gt_adduct |
# | 344        | 256.113296373 | 338.045013428 | 381577.40625 | M+Na @ 233.124075293 | None          | None      |
#
# PrecursorBin bin_id=158, len(features)=1, mass_range=(93.05757258975842, 93.05794482079324), len(molecules)=0, rt_range=(607.22802734375, 617.22802734375)
# | feature_id | mass          | rt           | intensity     | annotation              | gt_metabolite | gt_adduct |
# | 2198       | 135.091458729 | 609.24597168 | 14335.1992188 | M+ACN+H @ 93.0576331735 | None          | None      |
#
# PrecursorBin bin_id=159, len(features)=1, mass_range=(267.10970514026747, 267.11077358122486), len(molecules)=0, rt_range=(701.9019775390625, 711.9019775390625)
# | feature_id | mass          | rt            | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 2087       | 290.099353032 | 703.763977051 | 15965.7089844 | M+Na @ 267.110131952 | None          | None      |
#
# PrecursorBin bin_id=165, len(features)=1, mass_range=(78.0137215718605, 78.01403362737089), len(molecules)=0, rt_range=(492.83099365234375, 502.83099365234375)
# | feature_id | mass          | rt            | intensity     | annotation              | gt_metabolite | gt_adduct |
# | 3205       | 120.047604375 | 497.830993652 | 6649.04150391 | M+ACN+H @ 78.0137788199 | None          | None      |
#
# PrecursorBin bin_id=174, len(features)=1, mass_range=(121.53949148779533, 121.53997764673359), len(molecules)=0, rt_range=(2341.199951171875, 2351.199951171875)
# | feature_id | mass          | rt            | intensity  | annotation          | gt_metabolite | gt_adduct |
# | 175        | 122.547011019 | 2346.19995117 | 863218.625 | M+H @ 121.539734567 | None          | None      |
#
# PrecursorBin bin_id=175, len(features)=1, mass_range=(323.1205904483883, 323.12188293333514), len(molecules)=0, rt_range=(759.177978515625, 769.177978515625)
# | feature_id | mass          | rt            | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 1205       | 346.110510308 | 767.231994629 | 46442.1210938 | M+Na @ 323.121289228 | None          | None      |
#
# PrecursorBin bin_id=177, len(features)=1, mass_range=(279.0836780693847, 279.08479440632965), len(molecules)=0, rt_range=(1188.1700439453125, 1198.1700439453125)
# | feature_id | mass         | rt            | intensity | annotation          | gt_metabolite | gt_adduct |
# | 178        | 280.09151269 | 1193.17004395 | 832643.0  | M+H @ 279.084236238 | None          | None      |
#
# PrecursorBin bin_id=181, len(features)=1, mass_range=(173.08356623654353, 173.08425857219314), len(molecules)=0, rt_range=(333.0450134277344, 343.0450134277344)
# | feature_id | mass          | rt            | intensity     | annotation            | gt_metabolite | gt_adduct |
# | 1451       | 191.117555063 | 342.639007568 | 32359.9765625 | M+NH4 @ 173.083729508 | None          | None      |
#
# PrecursorBin bin_id=188, len(features)=1, mass_range=(243.07101642440085, 243.07198871041112), len(molecules)=0, rt_range=(705.0339965820312, 715.0339965820312)
# | feature_id | mass          | rt            | intensity     | annotation              | gt_metabolite | gt_adduct |
# | 1645       | 285.105087989 | 710.033996582 | 25411.3769531 | M+ACN+H @ 243.071262434 | None          | None      |
#
# PrecursorBin bin_id=190, len(features)=1, mass_range=(164.0468353533504, 164.0474915420042), len(molecules)=0, rt_range=(334.5820007324219, 344.5820007324219)
# | feature_id | mass          | rt            | intensity   | annotation             | gt_metabolite | gt_adduct |
# | 2628       | 206.080997795 | 334.967010498 | 9963.921875 | M+ACN+H @ 164.04717224 | None          | None      |
#
# PrecursorBin bin_id=192, len(features)=1, mass_range=(133.03700150775882, 133.03753365682917), len(molecules)=0, rt_range=(1048.239990234375, 1058.239990234375)
# | feature_id | mass          | rt            | intensity    | annotation              | gt_metabolite | gt_adduct |
# | 960        | 88.0391496736 | 1054.81005859 | 74966.234375 | M+ACN+2H @ 133.03719734 | None          | None      |
#
# PrecursorBin bin_id=193, len(features)=1, mass_range=(128.11965489935653, 128.1201673790011), len(molecules)=0, rt_range=(310.9639892578125, 320.9639892578125)
# | feature_id | mass         | rt            | intensity   | annotation              | gt_metabolite | gt_adduct |
# | 811        | 170.15359631 | 315.963989258 | 108001.6875 | M+ACN+H @ 128.119770755 | None          | None      |
#
# PrecursorBin bin_id=194, len(features)=1, mass_range=(101.52784098902067, 101.52824710119687), len(molecules)=0, rt_range=(2231.840087890625, 2241.840087890625)
# | feature_id | mass          | rt            | intensity  | annotation              | gt_metabolite | gt_adduct |
# | 1128       | 146.499337972 | 2235.30004883 | 52054.8125 | M+2Na-H @ 101.528172263 | None          | None      |
#
# PrecursorBin bin_id=208, len(features)=1, mass_range=(536.1600732249045, 536.1622178694867), len(molecules)=0, rt_range=(616.1920166015625, 626.1920166015625)
# | feature_id | mass          | rt            | intensity    | annotation            | gt_metabolite | gt_adduct |
# | 390        | 291.069605606 | 616.697998047 | 334877.28125 | M+2Na @ 536.160769052 | None          | None      |
#
# PrecursorBin bin_id=210, len(features)=1, mass_range=(466.12856345215846, 466.13042797014134), len(molecules)=0, rt_range=(740.9559936523438, 750.9559936523438)
# | feature_id | mass          | rt            | intensity     | annotation            | gt_metabolite | gt_adduct |
# | 1065       | 245.062730391 | 745.955993652 | 58625.5664062 | M+H+Na @ 466.12896325 | None          | None      |
#
# PrecursorBin bin_id=214, len(features)=1, mass_range=(348.04590265364493, 348.04729484003997), len(molecules)=0, rt_range=(903.6220092773438, 913.6220092773438)
# | feature_id | mass          | rt            | intensity   | annotation           | gt_metabolite | gt_adduct |
# | 1180       | 371.035712592 | 911.645996094 | 47860.40625 | M+Na @ 348.046491512 | None          | None      |
#
# PrecursorBin bin_id=224, len(features)=1, mass_range=(254.93625459898854, 254.93727434604645), len(molecules)=0, rt_range=(2109.260009765625, 2119.260009765625)
# | feature_id | mass          | rt            | intensity     | annotation              | gt_metabolite | gt_adduct |
# | 479        | 296.970682928 | 2111.30004883 | 247596.953125 | M+ACN+H @ 254.936857373 | None          | None      |
#
# PrecursorBin bin_id=240, len(features)=1, mass_range=(121.53946553795095, 121.53995169678541), len(molecules)=0, rt_range=(2419.989990234375, 2429.989990234375)
# | feature_id | mass          | rt            | intensity   | annotation          | gt_metabolite | gt_adduct |
# | 241        | 122.546985069 | 2424.98999023 | 557317.4375 | M+H @ 121.539708617 | None          | None      |
#
# PrecursorBin bin_id=251, len(features)=1, mass_range=(412.2573849592289, 412.2590339920668), len(molecules)=0, rt_range=(194.07000732421875, 204.07000732421875)
# | feature_id | mass          | rt            | intensity  | annotation          | gt_metabolite | gt_adduct |
# | 252        | 413.265485928 | 199.070007324 | 538642.375 | M+H @ 412.258209476 | None          | None      |
#
# PrecursorBin bin_id=257, len(features)=1, mass_range=(204.06268597089854, 204.06350222327495), len(molecules)=0, rt_range=(844.0780029296875, 854.0780029296875)
# | feature_id | mass          | rt           | intensity     | annotation              | gt_metabolite | gt_adduct |
# | 808        | 246.096726871 | 849.07800293 | 108653.890625 | M+ACN+H @ 204.062901316 | None          | None      |
#
# PrecursorBin bin_id=261, len(features)=1, mass_range=(125.01431189207636, 125.01481195032406), len(molecules)=0, rt_range=(970.6119995117188, 980.6119995117188)
# | feature_id | mass          | rt            | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 1200       | 148.003533492 | 978.768005371 | 46637.5859375 | M+Na @ 125.014312412 | None          | None      |
#
# PrecursorBin bin_id=275, len(features)=1, mass_range=(242.089381409533, 242.09034976899537), len(molecules)=0, rt_range=(416.9909973144531, 426.9909973144531)
# | feature_id | mass          | rt            | intensity    | annotation           | gt_metabolite | gt_adduct |
# | 1226       | 265.078897036 | 425.178985596 | 44599.609375 | M+Na @ 242.089675955 | None          | None      |
#
# PrecursorBin bin_id=277, len(features)=1, mass_range=(72.5244571094987, 72.52474720790734), len(molecules)=0, rt_range=(2143.6298828125, 2153.6298828125)
# | feature_id | mass          | rt            | intensity     | annotation              | gt_metabolite | gt_adduct |
# | 1027       | 114.558287165 | 2151.61010742 | 63099.6796875 | M+ACN+H @ 72.5244616095 | None          | None      |
#
# PrecursorBin bin_id=285, len(features)=1, mass_range=(72.52444726880529, 72.52473736717457), len(molecules)=0, rt_range=(2148.110107421875, 2158.110107421875)
# | feature_id | mass        | rt            | intensity  | annotation         | gt_metabolite | gt_adduct |
# | 286        | 73.53186877 | 2153.11010742 | 474317.375 | M+H @ 72.524592318 | None          | None      |
#
# PrecursorBin bin_id=313, len(features)=1, mass_range=(89.51835156845391, 89.51870964257634), len(molecules)=0, rt_range=(2379.800048828125, 2389.800048828125)
# | feature_id | mass          | rt            | intensity    | annotation          | gt_metabolite | gt_adduct |
# | 314        | 90.5258070575 | 2384.80004883 | 418969.96875 | M+H @ 89.5185306055 | None          | None      |
#
# PrecursorBin bin_id=324, len(features)=1, mass_range=(166.00499303154396, 166.00565705284413), len(molecules)=0, rt_range=(2715.389892578125, 2725.389892578125)
# | feature_id | mass         | rt      | intensity   | annotation          | gt_metabolite | gt_adduct |
# | 346        | 167.01260037 | 2715.75 | 379912.9375 | M+H @ 166.005323918 | None          | None      |
#
# PrecursorBin bin_id=331, len(features)=1, mass_range=(124.97857646452862, 124.9790763798343), len(molecules)=0, rt_range=(2606.360107421875, 2616.360107421875)
# | feature_id | mass          | rt            | intensity    | annotation          | gt_metabolite | gt_adduct |
# | 332        | 125.986102874 | 2611.36010742 | 389154.71875 | M+H @ 124.978826422 | None          | None      |
#
# PrecursorBin bin_id=335, len(features)=1, mass_range=(124.97857314678329, 124.9790730620757), len(molecules)=0, rt_range=(2743.260009765625, 2753.260009765625)
# | feature_id | mass          | rt            | intensity    | annotation          | gt_metabolite | gt_adduct |
# | 337        | 125.986097668 | 2752.89990234 | 385112.65625 | M+H @ 124.978821216 | None          | None      |
#
# PrecursorBin bin_id=341, len(features)=1, mass_range=(166.02606659663692, 166.0267307022315), len(molecules)=0, rt_range=(352.8429870605469, 362.8429870605469)
# | feature_id | mass          | rt            | intensity     | annotation              | gt_metabolite | gt_adduct |
# | 3043       | 210.997604675 | 357.842987061 | 7371.35742188 | M+2Na-H @ 166.026438967 | None          | None      |
#
# PrecursorBin bin_id=368, len(features)=1, mass_range=(207.03158075520864, 207.0324088831879), len(molecules)=0, rt_range=(2110.739990234375, 2120.739990234375)
# | feature_id | mass          | rt            | intensity    | annotation          | gt_metabolite | gt_adduct |
# | 369        | 208.039271271 | 2115.73999023 | 357191.28125 | M+H @ 207.031994819 | None          | None      |
#
# PrecursorBin bin_id=402, len(features)=1, mass_range=(338.00786737159785, 338.00921940577143), len(molecules)=0, rt_range=(1011.6900024414062, 1021.6900024414062)
# | feature_id | mass          | rt            | intensity     | annotation            | gt_metabolite | gt_adduct |
# | 1621       | 191.993317806 | 1015.19000244 | 26244.3964844 | M+2Na @ 338.008193452 | None          | None      |
#
# PrecursorBin bin_id=416, len(features)=1, mass_range=(69.00530988716675, 69.00558590895834), len(molecules)=0, rt_range=(2097.35009765625, 2107.35009765625)
# | feature_id | mass          | rt            | intensity | annotation          | gt_metabolite | gt_adduct |
# | 417        | 70.0127243501 | 2102.35009766 | 305452.0  | M+H @ 69.0054478981 | None          | None      |
#
# PrecursorBin bin_id=481, len(features)=1, mass_range=(228.07383761489004, 228.07474991206507), len(molecules)=0, rt_range=(467.3089904785156, 477.3089904785156)
# | feature_id | mass          | rt            | intensity    | annotation              | gt_metabolite | gt_adduct |
# | 4796       | 270.108071039 | 469.225006104 | 2000.9921875 | M+ACN+H @ 228.074245484 | None          | None      |
#
# PrecursorBin bin_id=496, len(features)=1, mass_range=(392.12818573513067, 392.12975425101064), len(molecules)=0, rt_range=(467.3089904785156, 477.3089904785156)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 497        | 393.136246445 | 472.308990479 | 228337.828125 | M+H @ 392.128969993 | None          | None      |
#
# PrecursorBin bin_id=504, len(features)=1, mass_range=(245.08908872577743, 245.09006908409307), len(molecules)=0, rt_range=(826.7260131835938, 836.7260131835938)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 505        | 246.096855357 | 831.726013184 | 222817.984375 | M+H @ 245.089578905 | None          | None      |
#
# PrecursorBin bin_id=512, len(features)=1, mass_range=(167.98182479385247, 167.9824967224955), len(molecules)=0, rt_range=(880.7139892578125, 890.7139892578125)
# | feature_id | mass          | rt            | intensity     | annotation              | gt_metabolite | gt_adduct |
# | 1899       | 210.015675259 | 885.713989258 | 19201.8339844 | M+ACN+H @ 167.981849704 | None          | None      |
#
# PrecursorBin bin_id=521, len(features)=1, mass_range=(486.22293718270913, 486.22488207834766), len(molecules)=0, rt_range=(340.6910095214844, 350.6910095214844)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 522        | 487.231186083 | 345.691009521 | 214428.859375 | M+H @ 486.223909631 | None          | None      |
#
# PrecursorBin bin_id=538, len(features)=1, mass_range=(248.1152382221345, 248.1162306850723), len(molecules)=0, rt_range=(357.4259948730469, 367.4259948730469)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 3728       | 287.078761706 | 362.425994873 | 4827.17822266 | M+K @ 248.115603386 | None          | None      |
#
# PrecursorBin bin_id=539, len(features)=1, mass_range=(197.0768898028379, 197.07767811197374), len(molecules)=0, rt_range=(1135.510009765625, 1145.510009765625)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 540        | 198.084560409 | 1140.51000977 | 206950.515625 | M+H @ 197.077283957 | None          | None      |
#
# PrecursorBin bin_id=556, len(features)=1, mass_range=(391.27872687777506, 391.28029199581283), len(molecules)=0, rt_range=(194.07000732421875, 204.07000732421875)
# | feature_id | mass          | rt            | intensity    | annotation           | gt_metabolite | gt_adduct |
# | 758        | 414.268762264 | 199.070007324 | 123470.09375 | M+Na @ 391.279541184 | None          | None      |
#
# PrecursorBin bin_id=558, len(features)=1, mass_range=(270.09707959448934, 270.0981599849685), len(molecules)=0, rt_range=(355.89300537109375, 365.89300537109375)
# | feature_id | mass          | rt            | intensity     | annotation         | gt_metabolite | gt_adduct |
# | 559        | 271.104896242 | 360.893005371 | 197049.421875 | M+H @ 270.09761979 | None          | None      |
#
# PrecursorBin bin_id=598, len(features)=1, mass_range=(179.07865555046848, 179.0793718665233), len(molecules)=0, rt_range=(1372.2900390625, 1382.2900390625)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 2300       | 218.041956573 | 1374.09997559 | 13191.4980469 | M+K @ 179.078798253 | None          | None      |
#
# PrecursorBin bin_id=600, len(features)=1, mass_range=(245.0890676282274, 245.09004798645864), len(molecules)=0, rt_range=(790.52197265625, 800.52197265625)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 601        | 246.096834259 | 795.521972656 | 183462.265625 | M+H @ 245.089557807 | None          | None      |
#
# PrecursorBin bin_id=604, len(features)=1, mass_range=(179.07865658911817, 179.07937290517714), len(molecules)=0, rt_range=(1401.1600341796875, 1411.1600341796875)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 2394       | 218.041993418 | 1401.32995605 | 12237.1230469 | M+K @ 179.078835098 | None          | None      |
#
# PrecursorBin bin_id=624, len(features)=1, mass_range=(150.02744450783334, 150.0280446188116), len(molecules)=0, rt_range=(2569.0400390625, 2579.0400390625)
# | feature_id | mass          | rt            | intensity | annotation          | gt_metabolite | gt_adduct |
# | 625        | 151.035021015 | 2574.04003906 | 176117.25 | M+H @ 150.027744563 | None          | None      |
#
# PrecursorBin bin_id=625, len(features)=1, mass_range=(150.02745359726262, 150.0280537082772), len(molecules)=0, rt_range=(2569.0400390625, 2579.0400390625)
# | feature_id | mass          | rt            | intensity | annotation          | gt_metabolite | gt_adduct |
# | 626        | 151.035030105 | 2574.04003906 | 176117.25 | M+H @ 150.027753653 | None          | None      |
#
# PrecursorBin bin_id=654, len(features)=1, mass_range=(383.089365448288, 383.09089780881453), len(molecules)=0, rt_range=(263.8999938964844, 273.8999938964844)
# | feature_id | mass          | rt            | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 4087       | 406.079356826 | 267.113006592 | 3742.50146484 | M+Na @ 383.090135746 | None          | None      |
#
# PrecursorBin bin_id=677, len(features)=1, mass_range=(398.1188784070994, 398.120470885798), len(molecules)=0, rt_range=(462.68701171875, 472.68701171875)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 678        | 399.126951098 | 467.687011719 | 147779.671875 | M+H @ 398.119674646 | None          | None      |
#
# PrecursorBin bin_id=686, len(features)=1, mass_range=(266.09915422416174, 266.10021862290745), len(molecules)=0, rt_range=(1763.4000244140625, 1773.4000244140625)
# | feature_id | mass          | rt            | intensity     | annotation               | gt_metabolite | gt_adduct |
# | 3888       | 154.570475818 | 1765.31005859 | 4369.57275391 | M+ACN+2H @ 266.099849629 | None          | None      |
#
# PrecursorBin bin_id=688, len(features)=1, mass_range=(82.50964468572654, 82.50997472496537), len(molecules)=0, rt_range=(2097.35009765625, 2107.35009765625)
# | feature_id | mass         | rt            | intensity    | annotation             | gt_metabolite | gt_adduct |
# | 870        | 124.54347351 | 2103.84008789 | 93622.453125 | M+ACN+H @ 82.509647955 | None          | None      |
#
# PrecursorBin bin_id=693, len(features)=1, mass_range=(465.24455966916236, 465.24642065112295), len(molecules)=0, rt_range=(333.0450134277344, 343.0450134277344)
# | feature_id | mass          | rt            | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 869        | 488.234708939 | 338.045013428 | 93624.2109375 | M+Na @ 465.245487859 | None          | None      |
#
# PrecursorBin bin_id=715, len(features)=1, mass_range=(576.1246587556167, 576.1269632588607), len(molecules)=0, rt_range=(98.1259994506836, 108.1259994506836)
# | feature_id | mass          | rt            | intensity     | annotation            | gt_metabolite | gt_adduct |
# | 968        | 594.159735166 | 101.503997803 | 73687.3671875 | M+NH4 @ 576.125909611 | None          | None      |
#
# PrecursorBin bin_id=728, len(features)=1, mass_range=(133.04956672382835, 133.05009892315965), len(molecules)=0, rt_range=(1763.4000244140625, 1773.4000244140625)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 729        | 134.057109275 | 1768.40002441 | 131887.265625 | M+H @ 133.049832823 | None          | None      |
#
# PrecursorBin bin_id=745, len(features)=1, mass_range=(189.04193903865837, 189.04269520792684), len(molecules)=0, rt_range=(352.8429870605469, 362.8429870605469)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 746        | 190.049593575 | 357.842987061 | 126532.703125 | M+H @ 189.042317123 | None          | None      |
#
# PrecursorBin bin_id=755, len(features)=1, mass_range=(145.49182474971624, 145.49240671817918), len(molecules)=0, rt_range=(2160.169921875, 2170.169921875)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 756        | 146.499392186 | 2165.16992188 | 123853.710938 | M+H @ 145.492115734 | None          | None      |
#
# PrecursorBin bin_id=770, len(features)=1, mass_range=(130.99538880260164, 130.9959127852048), len(molecules)=0, rt_range=(1260.449951171875, 1270.449951171875)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 771        | 132.002927246 | 1265.44995117 | 119143.304688 | M+H @ 130.995650794 | None          | None      |
#
# PrecursorBin bin_id=789, len(features)=1, mass_range=(158.9611744527027, 158.9618102986722), len(molecules)=0, rt_range=(-0.5779299736022949, 9.422070026397705)
# | feature_id | mass          | rt            | intensity     | annotation              | gt_metabolite | gt_adduct |
# | 2928       | 200.995034348 | 5.88184976578 | 8035.16699219 | M+ACN+H @ 158.961208793 | None          | None      |
#
# PrecursorBin bin_id=795, len(features)=1, mass_range=(341.10978526533796, 341.11114970720786), len(molecules)=0, rt_range=(415.39599609375, 425.39599609375)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 4331       | 380.073482012 | 425.178985596 | 3118.63476562 | M+K @ 341.110323692 | None          | None      |
#
# PrecursorBin bin_id=823, len(features)=1, mass_range=(84.02076892438565, 84.02110500813352), len(molecules)=0, rt_range=(560.0659790039062, 570.0659790039062)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 824        | 85.0282134183 | 565.065979004 | 104106.179688 | M+H @ 84.0209369663 | None          | None      |
#
# PrecursorBin bin_id=830, len(features)=1, mass_range=(169.9978359865017, 169.99851597920562), len(molecules)=0, rt_range=(2116.679931640625, 2126.679931640625)
# | feature_id | mass          | rt            | intensity     | annotation             | gt_metabolite | gt_adduct |
# | 3192       | 212.032097675 | 2118.70996094 | 6703.87353516 | M+ACN+H @ 169.99827212 | None          | None      |
#
# PrecursorBin bin_id=851, len(features)=1, mass_range=(140.13083932716256, 140.13139985164094), len(molecules)=0, rt_range=(812.427978515625, 822.427978515625)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 852        | 141.138396041 | 817.427978516 | 96695.2890625 | M+H @ 140.131119589 | None          | None      |
#
# PrecursorBin bin_id=852, len(features)=1, mass_range=(149.01884366311324, 149.01943973968005), len(molecules)=0, rt_range=(348.2959899902344, 358.2959899902344)
# | feature_id | mass         | rt           | intensity     | annotation              | gt_metabolite | gt_adduct |
# | 2482       | 191.05287531 | 356.32598877 | 11354.2822266 | M+ACN+H @ 149.019049754 | None          | None      |
#
# PrecursorBin bin_id=862, len(features)=1, mass_range=(210.0747124236077, 210.075552724138), len(molecules)=0, rt_range=(826.7260131835938, 836.7260131835938)
# | feature_id | mass          | rt            | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 1505       | 233.064339955 | 833.153991699 | 29852.9785156 | M+Na @ 210.075118875 | None          | None      |
#
# PrecursorBin bin_id=866, len(features)=1, mass_range=(170.999499134738, 171.0001831341025), len(molecules)=0, rt_range=(999.719970703125, 1009.719970703125)
# | feature_id | mass          | rt           | intensity     | annotation             | gt_metabolite | gt_adduct |
# | 4648       | 213.033634325 | 1009.2199707 | 2392.57836914 | M+ACN+H @ 170.99980877 | None          | None      |
#
# PrecursorBin bin_id=885, len(features)=1, mass_range=(244.08781693989462, 244.08879329311512), len(molecules)=0, rt_range=(1155.530029296875, 1165.530029296875)
# | feature_id | mass         | rt            | intensity     | annotation         | gt_metabolite | gt_adduct |
# | 1674       | 267.07744628 | 1162.17004395 | 24531.9394531 | M+Na @ 244.0882252 | None          | None      |
#
# PrecursorBin bin_id=904, len(features)=1, mass_range=(152.56489653479022, 152.56550679559686), len(molecules)=0, rt_range=(1766.4599609375, 1776.4599609375)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 905        | 153.572478117 | 1771.45996094 | 87294.1640625 | M+H @ 152.565201665 | None          | None      |
#
# PrecursorBin bin_id=922, len(features)=1, mass_range=(205.06608391852475, 205.06690418450094), len(molecules)=0, rt_range=(822.447998046875, 832.447998046875)
# | feature_id | mass          | rt            | intensity     | annotation              | gt_metabolite | gt_adduct |
# | 1714       | 247.100183826 | 826.020019531 | 23553.3535156 | M+ACN+H @ 205.066358271 | None          | None      |
#
# PrecursorBin bin_id=950, len(features)=1, mass_range=(173.03066037424733, 173.0313524982731), len(molecules)=0, rt_range=(859.0900268554688, 869.0900268554688)
# | feature_id | mass          | rt            | intensity  | annotation          | gt_metabolite | gt_adduct |
# | 951        | 174.038282888 | 864.090026855 | 76628.4375 | M+H @ 173.031006436 | None          | None      |
#
# PrecursorBin bin_id=954, len(features)=1, mass_range=(290.14652586725316, 290.14768645567784), len(molecules)=0, rt_range=(1103.72998046875, 1113.72998046875)
# | feature_id | mass         | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 3782       | 313.13621462 | 1107.07995605 | 4645.13574219 | M+Na @ 290.14699354 | None          | None      |
#
# PrecursorBin bin_id=980, len(features)=1, mass_range=(112.95604591523501, 112.95649774032232), len(molecules)=0, rt_range=(2013.5899658203125, 2023.5899658203125)
# | feature_id | mass          | rt            | intensity    | annotation              | gt_metabolite | gt_adduct |
# | 1036       | 154.989907843 | 2020.13000488 | 61633.828125 | M+ACN+H @ 112.956082288 | None          | None      |
#
# PrecursorBin bin_id=1021, len(features)=1, mass_range=(109.51397604173346, 109.51441409851373), len(molecules)=0, rt_range=(-2.023469924926758, 7.976530075073242)
# | feature_id | mass          | rt           | intensity | annotation              | gt_metabolite | gt_adduct |
# | 2301       | 154.485269926 | 4.4220700264 | 13191.25  | M+2Na-H @ 109.514104218 | None          | None      |
#
# PrecursorBin bin_id=1028, len(features)=1, mass_range=(74.03656219002426, 74.03685833686532), len(molecules)=0, rt_range=(397.3190002441406, 407.3190002441406)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 1029       | 75.0439867154 | 402.319000244 | 62574.2890625 | M+H @ 74.0367102634 | None          | None      |
#
# PrecursorBin bin_id=1042, len(features)=1, mass_range=(274.09179920936066, 274.0928955787502), len(molecules)=0, rt_range=(380.9150085449219, 390.9150085449219)
# | feature_id | mass         | rt            | intensity     | annotation                | gt_metabolite | gt_adduct |
# | 4689       | 307.12579339 | 389.131011963 | 2299.26220703 | M+CH3OH+H @ 274.092302188 | None          | None      |
#
# PrecursorBin bin_id=1050, len(features)=1, mass_range=(413.2606443102868, 413.26229735617017), len(molecules)=0, rt_range=(210.63800048828125, 220.63800048828125)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# ...
#
# PrecursorBin bin_id=3227, len(features)=1, mass_range=(95.04727262626454, 95.04765281611543), len(molecules)=0, rt_range=(1414.010009765625, 1424.010009765625)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 3228       | 96.0547391732 | 1419.01000977 | 6517.90039062 | M+H @ 95.0474627212 | None          | None      |
#
# PrecursorBin bin_id=3292, len(features)=1, mass_range=(237.09896877990428, 237.09991717767622), len(molecules)=0, rt_range=(689.1939697265625, 699.1939697265625)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 3622       | 276.062378478 | 697.409973145 | 5121.09912109 | M+K @ 237.099220158 | None          | None      |
#
# PrecursorBin bin_id=3346, len(features)=1, mass_range=(156.12566973212714, 156.1262942360551), len(molecules)=0, rt_range=(-3.4562400579452515, 6.5437599420547485)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 3347       | 157.133258436 | 1.54375994205 | 5978.97998047 | M+H @ 156.125981984 | None          | None      |
#
# PrecursorBin bin_id=3407, len(features)=1, mass_range=(152.0943385676239, 152.09494694619494), len(molecules)=0, rt_range=(340.6910095214844, 350.6910095214844)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 3408       | 153.101919209 | 345.691009521 | 5775.55175781 | M+H @ 152.094642757 | None          | None      |
#
# PrecursorBin bin_id=3408, len(features)=1, mass_range=(152.09430284002104, 152.09491121844917), len(molecules)=0, rt_range=(340.6910095214844, 350.6910095214844)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 3409       | 153.101883481 | 345.691009521 | 5775.55175781 | M+H @ 152.094607029 | None          | None      |
#
# PrecursorBin bin_id=3409, len(features)=1, mass_range=(602.1350145703344, 602.1374231152098), len(molecules)=0, rt_range=(1184.9300537109375, 1194.9300537109375)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 3410       | 603.143495295 | 1189.93005371 | 5774.91845703 | M+H @ 602.136218843 | None          | None      |
#
# PrecursorBin bin_id=3428, len(features)=1, mass_range=(189.00450592804327, 189.00526194757902), len(molecules)=0, rt_range=(853.0360107421875, 863.0360107421875)
# | feature_id | mass         | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 3429       | 190.01216039 | 858.036010742 | 5707.86865234 | M+H @ 189.004883938 | None          | None      |
#
# PrecursorBin bin_id=3431, len(features)=1, mass_range=(279.082008738978, 279.08312506924557), len(molecules)=0, rt_range=(1110.43994140625, 1120.43994140625)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 3432       | 280.089843356 | 1115.43994141 | 5706.33789062 | M+H @ 279.082566904 | None          | None      |
#
# PrecursorBin bin_id=3537, len(features)=1, mass_range=(342.11876054646643, 342.12012902424556), len(molecules)=0, rt_range=(371.427001953125, 381.427001953125)
# | feature_id | mass          | rt            | intensity     | annotation                  | gt_metabolite | gt_adduct |
# | 4251       | 403.183998366 | 379.559997559 | 3330.86035156 | M+IsoProp+H @ 342.119207037 | None          | None      |
#
# PrecursorBin bin_id=3553, len(features)=1, mass_range=(432.0991262240799, 432.10085462404163), len(molecules)=0, rt_range=(242.06199645996094, 252.06199645996094)
# | feature_id | mass          | rt           | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 3554       | 433.107266876 | 247.06199646 | 5334.81640625 | M+H @ 432.099990424 | None          | None      |
#
# PrecursorBin bin_id=3554, len(features)=1, mass_range=(636.1821847452811, 636.1847294791096), len(molecules)=0, rt_range=(94.8904037475586, 104.8904037475586)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 3555       | 637.190733564 | 99.8904037476 | 5331.13867188 | M+H @ 636.183457112 | None          | None      |
#
# PrecursorBin bin_id=3619, len(features)=1, mass_range=(138.07108168523422, 138.07163397066552), len(molecules)=0, rt_range=(1491.77001953125, 1501.77001953125)
# | feature_id | mass         | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 3620       | 139.07863428 | 1496.77001953 | 5121.61816406 | M+H @ 138.071357828 | None          | None      |
#
# PrecursorBin bin_id=3621, len(features)=1, mass_range=(275.05455191609417, 275.0556521365023), len(molecules)=0, rt_range=(692.4099731445312, 702.4099731445312)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 3621       | 276.062480727 | 697.409973145 | 5121.09912109 | M+H @ 275.055204275 | None          | None      |
#
# PrecursorBin bin_id=3693, len(features)=1, mass_range=(392.0105157930318, 392.0120838382311), len(molecules)=0, rt_range=(309.36199951171875, 319.36199951171875)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 3694       | 393.018576268 | 314.361999512 | 4908.83935547 | M+H @ 392.011299816 | None          | None      |
#
# PrecursorBin bin_id=3735, len(features)=1, mass_range=(265.0742467368228, 265.0753070359303), len(molecules)=0, rt_range=(420.1789855957031, 430.1789855957031)
# | feature_id | mass          | rt            | intensity    | annotation          | gt_metabolite | gt_adduct |
# | 3736       | 266.082053338 | 425.178985596 | 4802.1015625 | M+H @ 265.074776886 | None          | None      |
#
# PrecursorBin bin_id=3768, len(features)=1, mass_range=(273.14648374934427, 273.14757633746444), len(molecules)=0, rt_range=(329.9670104980469, 339.9670104980469)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 3769       | 274.154306495 | 334.967010498 | 4673.55615234 | M+H @ 273.147030043 | None          | None      |
#
# PrecursorBin bin_id=3869, len(features)=1, mass_range=(654.7034385711041, 654.7060573900961), len(molecules)=0, rt_range=(1761.8599853515625, 1771.8599853515625)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 3993       | 655.711771963 | 1771.45996094 | 4055.31347656 | M+H @ 654.704495511 | None          | None      |
#
# PrecursorBin bin_id=3878, len(features)=1, mass_range=(256.03999607775336, 256.041020239786), len(molecules)=0, rt_range=(1420.4000244140625, 1430.4000244140625)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 3879       | 257.047784611 | 1425.40002441 | 4390.30957031 | M+H @ 256.040508159 | None          | None      |
#
# PrecursorBin bin_id=3904, len(features)=1, mass_range=(190.06857045218092, 190.06933072798327), len(molecules)=0, rt_range=(1601.6700439453125, 1611.6700439453125)
# | feature_id | mass          | rt            | intensity     | annotation         | gt_metabolite | gt_adduct |
# | 3905       | 191.076227042 | 1606.67004395 | 4288.07128906 | M+H @ 190.06895059 | None          | None      |
#
# PrecursorBin bin_id=3935, len(features)=1, mass_range=(219.05870404978725, 219.05958028635592), len(molecules)=0, rt_range=(1133.8199462890625, 1143.8199462890625)
# | feature_id | mass         | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 3936       | 220.06641862 | 1138.81994629 | 4198.44091797 | M+H @ 219.059142168 | None          | None      |
#
# PrecursorBin bin_id=3968, len(features)=1, mass_range=(279.0598068310108, 279.06092307247064), len(molecules)=0, rt_range=(1193.0400390625, 1203.0400390625)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 3969       | 280.067641404 | 1198.04003906 | 4106.89794922 | M+H @ 279.060364952 | None          | None      |
#
# PrecursorBin bin_id=3969, len(features)=1, mass_range=(279.05978645648884, 279.06090269786716), len(molecules)=0, rt_range=(1193.0400390625, 1203.0400390625)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 3970       | 280.067621029 | 1198.04003906 | 4106.89794922 | M+H @ 279.060344577 | None          | None      |
#
# PrecursorBin bin_id=4001, len(features)=1, mass_range=(126.06761194420223, 126.06811621565855), len(molecules)=0, rt_range=(39.99980163574219, 49.99980163574219)
# | feature_id | mass          | rt            | intensity     | annotation            | gt_metabolite | gt_adduct |
# | 4694       | 75.0322029558 | 44.9998016357 | 2292.69677734 | M+H+Na @ 126.06790838 | None          | None      |
#
# PrecursorBin bin_id=4069, len(features)=1, mass_range=(92.0077129863114, 92.00808101789941), len(molecules)=0, rt_range=(18.683300018310547, 28.683300018310547)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 4070       | 93.0151734541 | 23.6833000183 | 3787.49169922 | M+H @ 92.0078970021 | None          | None      |
#
# PrecursorBin bin_id=4118, len(features)=1, mass_range=(217.97956443195056, 217.9804363519521), len(molecules)=0, rt_range=(441.0589904785156, 451.0589904785156)
# | feature_id | mass          | rt            | intensity    | annotation          | gt_metabolite | gt_adduct |
# | 4119       | 218.987276844 | 446.058990479 | 3676.1472168 | M+H @ 217.980000392 | None          | None      |
#
# PrecursorBin bin_id=4197, len(features)=1, mass_range=(189.0993162801072, 189.1000726788851), len(molecules)=0, rt_range=(398.9649963378906, 408.9649963378906)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 4198       | 190.106970931 | 403.964996338 | 3464.63549805 | M+H @ 189.099694479 | None          | None      |
#
# PrecursorBin bin_id=4294, len(features)=1, mass_range=(452.15909772519484, 452.16090636520306), len(molecules)=0, rt_range=(307.7560119628906, 317.7560119628906)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 4295       | 453.167278497 | 312.756011963 | 3198.30444336 | M+H @ 452.160002045 | None          | None      |
#
# PrecursorBin bin_id=4334, len(features)=1, mass_range=(265.1433206798233, 265.14438125522724), len(molecules)=0, rt_range=(96.50399780273438, 106.50399780273438)
# | feature_id | mass         | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 4335       | 266.15112742 | 101.503997803 | 3109.59521484 | M+H @ 265.143850968 | None          | None      |
#
# PrecursorBin bin_id=4364, len(features)=1, mass_range=(184.02420933050416, 184.02494542881368), len(molecules)=0, rt_range=(1082.02001953125, 1092.02001953125)
# | feature_id | mass          | rt            | intensity     | annotation         | gt_metabolite | gt_adduct |
# | 4365       | 185.031853832 | 1087.02001953 | 3053.90673828 | M+H @ 184.02457738 | None          | None      |
#
# PrecursorBin bin_id=4396, len(features)=1, mass_range=(204.02664900085207, 204.02746510908028), len(molecules)=0, rt_range=(1171.93994140625, 1181.93994140625)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 4397       | 205.034333507 | 1176.93994141 | 2975.41210938 | M+H @ 204.027057055 | None          | None      |
#
# PrecursorBin bin_id=4414, len(features)=1, mass_range=(420.0414077400402, 420.04308790903144), len(molecules)=0, rt_range=(265.6969909667969, 275.6969909667969)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 4415       | 421.049524277 | 270.696990967 | 2941.05078125 | M+H @ 420.042247825 | None          | None      |
#
# PrecursorBin bin_id=4490, len(features)=1, mass_range=(108.0607758096371, 108.06120805360483), len(molecules)=0, rt_range=(1137.18994140625, 1147.18994140625)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 4491       | 109.068268384 | 1142.18994141 | 2760.68383789 | M+H @ 108.060991932 | None          | None      |
#
# PrecursorBin bin_id=4496, len(features)=1, mass_range=(107.04634902268398, 107.04677720893645), len(molecules)=0, rt_range=(1115.4599609375, 1125.4599609375)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 4497       | 108.053839568 | 1120.45996094 | 2746.56396484 | M+H @ 107.046563116 | None          | None      |
#
# PrecursorBin bin_id=4497, len(features)=1, mass_range=(107.04636428987178, 107.04679247618532), len(molecules)=0, rt_range=(1115.4599609375, 1125.4599609375)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 4498       | 108.053854835 | 1120.45996094 | 2746.56396484 | M+H @ 107.046578383 | None          | None      |
#
# PrecursorBin bin_id=4504, len(features)=1, mass_range=(257.056584382872, 257.05761261126605), len(molecules)=0, rt_range=(1191.4100341796875, 1201.4100341796875)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 4505       | 258.064374949 | 1196.41003418 | 2735.62988281 | M+H @ 257.057098497 | None          | None      |
#
# PrecursorBin bin_id=4505, len(features)=1, mass_range=(257.05657939068647, 257.0576076190605), len(molecules)=0, rt_range=(1191.4100341796875, 1201.4100341796875)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 4506       | 258.064369957 | 1196.41003418 | 2735.62988281 | M+H @ 257.057093505 | None          | None      |
#
# PrecursorBin bin_id=4526, len(features)=1, mass_range=(439.14427855784163, 439.1460351384691), len(molecules)=0, rt_range=(420.1789855957031, 430.1789855957031)
# | feature_id | mass        | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 4527       | 440.1524333 | 425.178985596 | 2686.63037109 | M+H @ 439.145156848 | None          | None      |
#
# PrecursorBin bin_id=4544, len(features)=1, mass_range=(116.05810454737589, 116.05856878072255), len(molecules)=0, rt_range=(1110.43994140625, 1120.43994140625)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 4545       | 117.065613116 | 1115.43994141 | 2625.46655273 | M+H @ 116.058336664 | None          | None      |
#
# PrecursorBin bin_id=4578, len(features)=1, mass_range=(659.281514277366, 659.2841514086973), len(molecules)=0, rt_range=(296.3110046386719, 306.3110046386719)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 4579       | 660.290109295 | 301.311004639 | 2550.27148438 | M+H @ 659.282832843 | None          | None      |
#
# PrecursorBin bin_id=4637, len(features)=1, mass_range=(285.10043107954084, 285.10157148354597), len(molecules)=0, rt_range=(703.468017578125, 713.468017578125)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 4638       | 286.108277734 | 708.468017578 | 2424.46069336 | M+H @ 285.101001282 | None          | None      |
#
# PrecursorBin bin_id=4769, len(features)=1, mass_range=(257.1562835210688, 257.15731214826013), len(molecules)=0, rt_range=(1193.0400390625, 1203.0400390625)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 4982       | 258.164326884 | 1201.30004883 | 1360.16455078 | M+H @ 257.157050432 | None          | None      |
#
# Empty bins=4768
# Occupied bins=231
