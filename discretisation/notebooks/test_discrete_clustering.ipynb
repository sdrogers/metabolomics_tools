# %% [markdown]
# # Test discrete clustering

# %% [markdown]
# ## Load the clustering module first

# %%
import sys

basedir = '../'
sys.path.append(basedir) # need to do this to be able to import the stuff below

from discrete_mass_clusterer import DiscreteGibbs, DiscreteVB
from continuous_mass_clusterer import ContinuousVB
from models import FileLoader, HyperPars
import scipy.sparse as sp

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Try on std1 pos data

# %%
# load std1 file
input_file = basedir + '/input/std1_csv/std1-file1.identified.csv'    
database_file = basedir + '/database/std1_mols.csv'
transformation_file = basedir + '/mulsubs/mulsub.txt'
mass_tol = 2
rt_tol = 5
loader = FileLoader()
peak_data = loader.load_model_input(input_file, database_file, transformation_file, mass_tol, rt_tol)
# Out:
# Discretising peak data at mass_tol 2 and rt_tol 5
# 4999 bins created

# %%
# try gibbs sampling
hp = HyperPars()
mbc = DiscreteGibbs(peak_data, hp)
mbc.nsamps = 20
mbc.run()
# Out:
# DiscreteGibbs initialised
# BURN 1 3.22s	Counter({'0': 4763, '1': 218, '2': 18})
# BURN 2 2.90s	Counter({'0': 4765, '1': 215, '2': 18, '3': 1})
# BURN 3 2.91s	Counter({'0': 4771, '1': 204, '2': 22, '3': 2})
# BURN 4 2.94s	Counter({'0': 4767, '1': 212, '2': 18, '3': 2})
# BURN 5 2.91s	Counter({'0': 4764, '1': 218, '2': 15, '3': 2})
# BURN 6 2.93s	Counter({'0': 4767, '1': 213, '2': 16, '3': 3})
# BURN 7 3.08s	Counter({'0': 4764, '1': 216, '2': 19})
# BURN 8 2.97s	Counter({'0': 4758, '1': 229, '2': 11, '3': 1})
# BURN 9 3.00s	Counter({'0': 4767, '1': 210, '2': 22})
# BURN 10 2.92s	Counter({'0': 4765, '1': 214, '2': 20})
# SAMPLE 11 2.91s	Counter({'0': 4766, '1': 214, '2': 17, '3': 2})
# SAMPLE 12 2.91s	Counter({'0': 4765, '1': 216, '2': 16, '3': 2})
# SAMPLE 13 2.90s	Counter({'0': 4764, '1': 218, '2': 15, '3': 2})
# SAMPLE 14 2.97s	Counter({'0': 4763, '1': 218, '2': 18})
# SAMPLE 15 2.98s	Counter({'0': 4759, '1': 226, '2': 14})
# SAMPLE 16 3.00s	Counter({'0': 4764, '1': 216, '2': 19})
# SAMPLE 17 3.14s	Counter({'0': 4765, '1': 214, '2': 20})
# SAMPLE 18 3.16s	Counter({'0': 4765, '1': 214, '2': 20})
# SAMPLE 19 3.11s	Counter({'0': 4764, '1': 216, '2': 19})
# SAMPLE 20 3.01s	Counter({'0': 4761, '1': 222, '2': 16})
# DONE!
#
# Last sample report
# PrecursorBin bin_id=207, len(features)=2, mass_centre=382.08684519, mass_range=(382.08608101641835, 382.08760936379906), len(molecules)=0, rt_centre=268.899993896, rt_range=(263.8999938964844, 273.8999938964844)
# | feature_id | mass          | rt            | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 4415       | 421.049524277 | 270.696990967 | 2941.05078125 | M+K @ 382.086365956  | None          | None      |
# | 1975       | 405.076023128 | 267.113006592 | 17869.4023438 | M+Na @ 382.086802047 | None          | None      |
#
# PrecursorBin bin_id=270, len(features)=2, mass_centre=174.111420512, mass_range=(174.11107228918698, 174.111768734869), len(molecules)=0, rt_centre=1585.76000977, rt_range=(1580.760009765625, 1590.760009765625)
# | feature_id | mass          | rt            | intensity     | annotation               | gt_metabolite | gt_adduct |
# | 2067       | 108.57617235  | 1587.36999512 | 16293.3388672 | M+ACN+2H @ 174.111242692 | None          | None      |
# | 1567       | 197.100462039 | 1587.36999512 | 27938.2617188 | M+Na @ 174.111240959     | None          | None      |
#
# PrecursorBin bin_id=285, len(features)=2, mass_centre=72.524592318, mass_range=(72.52444726880529, 72.52473736717457), len(molecules)=0, rt_centre=2153.11010742, rt_range=(2148.110107421875, 2158.110107421875)
# | feature_id | mass          | rt            | intensity     | annotation              | gt_metabolite | gt_adduct |
# | 286        | 73.53186877   | 2153.11010742 | 474317.375    | M+H @ 72.524592318      | None          | None      |
# | 1027       | 114.558287165 | 2151.61010742 | 63099.6796875 | M+ACN+H @ 72.5244616095 | None          | None      |
#
# PrecursorBin bin_id=538, len(features)=2, mass_centre=248.115734454, mass_range=(248.1152382221345, 248.1162306850723), len(molecules)=0, rt_centre=362.425994873, rt_range=(357.4259948730469, 367.4259948730469)
# | feature_id | mass          | rt            | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 559        | 271.104896242 | 360.893005371 | 197049.421875 | M+Na @ 248.115675162 | None          | None      |
# | 3728       | 287.078761706 | 362.425994873 | 4827.17822266 | M+K @ 248.115603386  | None          | None      |
#
# PrecursorBin bin_id=624, len(features)=2, mass_centre=150.027744563, mass_range=(150.02744450783334, 150.0280446188116), len(molecules)=0, rt_centre=2574.04003906, rt_range=(2569.0400390625, 2579.0400390625)
# | feature_id | mass          | rt            | intensity | annotation          | gt_metabolite | gt_adduct |
# | 626        | 151.035030105 | 2574.04003906 | 176117.25 | M+H @ 150.027753653 | None          | None      |
# | 625        | 151.035021015 | 2574.04003906 | 176117.25 | M+H @ 150.027744563 | None          | None      |
#
# PrecursorBin bin_id=1035, len(features)=2, mass_centre=153.982631391, mass_range=(153.98232342591288, 153.98293935643844), len(molecules)=0, rt_centre=2020.13000488, rt_range=(2015.1300048828125, 2025.1300048828125)
# | feature_id | mass          | rt            | intensity     | annotation               | gt_metabolite | gt_adduct |
# | 1120       | 98.5119498401 | 2020.13000488 | 52688.8671875 | M+ACN+2H @ 153.982797673 | None          | None      |
# | 1036       | 154.989907843 | 2020.13000488 | 61633.828125  | M+H @ 153.982631391      | None          | None      |
#
# PrecursorBin bin_id=1269, len(features)=2, mass_centre=577.129209219, mass_range=(577.1280549603194, 577.1303634771563), len(molecules)=0, rt_centre=103.125999451, rt_range=(98.1259994506836, 108.1259994506836)
# | feature_id | mass          | rt            | intensity     | annotation            | gt_metabolite | gt_adduct |
# | 2042       | 600.118195278 | 101.503997803 | 16721.0351562 | M+Na @ 577.128974198  | None          | None      |
# | 1680       | 595.163390633 | 101.503997803 | 24385.4804688 | M+NH4 @ 577.129565078 | None          | None      |
#
# PrecursorBin bin_id=1379, len(features)=2, mass_centre=113.067382921, mass_range=(113.06715678577189, 113.06760905530356), len(molecules)=0, rt_centre=1033.16003418, rt_range=(1028.1600341796875, 1038.1600341796875)
# | feature_id | mass          | rt            | intensity   | annotation          | gt_metabolite | gt_adduct |
# | 1380       | 114.074659373 | 1033.16003418 | 35648.71875 | M+H @ 113.067382921 | None          | None      |
# | 1381       | 114.074666425 | 1033.16003418 | 35648.71875 | M+H @ 113.067389973 | None          | None      |
#
# PrecursorBin bin_id=1575, len(features)=2, mass_centre=226.110257097, mass_range=(226.10980487691953, 226.11070931794794), len(molecules)=0, rt_centre=319.20199585, rt_range=(314.2019958496094, 324.2019958496094)
# | feature_id | mass          | rt            | intensity     | annotation              | gt_metabolite | gt_adduct |
# | 2663       | 268.143940082 | 322.441009521 | 9586.42578125 | M+ACN+H @ 226.110114527 | None          | None      |
# | 2134       | 249.099284793 | 317.579986572 | 15212.3349609 | M+Na @ 226.110063713    | None          | None      |
#
# PrecursorBin bin_id=1653, len(features)=2, mass_centre=83.0809056955, mass_range=(83.0807395336523, 83.08107185727509), len(molecules)=0, rt_centre=2740.52001953, rt_range=(2735.52001953125, 2745.52001953125)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 1654       | 84.0881821475 | 2740.52001953 | 25173.0097656 | M+H @ 83.0809056955 | None          | None      |
# | 1655       | 84.0881870977 | 2740.52001953 | 25173.0097656 | M+H @ 83.0809106457 | None          | None      |
#
# PrecursorBin bin_id=2790, len(features)=2, mass_centre=519.217721734, mass_range=(519.2166832986522, 519.2187601695391), len(molecules)=0, rt_centre=852.041992188, rt_range=(847.0419921875, 857.0419921875)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 2791       | 520.224998186 | 852.041992188 | 8825.41210938 | M+H @ 519.217721734 | None          | None      |
# | 2790       | 520.224925679 | 852.041992188 | 8825.41210938 | M+H @ 519.217649227 | None          | None      |
#
# PrecursorBin bin_id=3407, len(features)=2, mass_centre=152.094642757, mass_range=(152.0943385676239, 152.09494694619494), len(molecules)=0, rt_centre=345.691009521, rt_range=(340.6910095214844, 350.6910095214844)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 3408       | 153.101919209 | 345.691009521 | 5775.55175781 | M+H @ 152.094642757 | None          | None      |
# | 3409       | 153.101883481 | 345.691009521 | 5775.55175781 | M+H @ 152.094607029 | None          | None      |
#
# PrecursorBin bin_id=3817, len(features)=2, mass_centre=170.72799433, mass_range=(170.72765287430454, 170.72833578628186), len(molecules)=0, rt_centre=917.711975098, rt_range=(912.7119750976562, 922.7119750976562)
# | feature_id | mass          | rt            | intensity    | annotation          | gt_metabolite | gt_adduct |
# | 3819       | 171.735133633 | 917.711975098 | 4560.3828125 | M+H @ 170.727857181 | None          | None      |
# | 3818       | 171.735270782 | 917.711975098 | 4560.3828125 | M+H @ 170.72799433  | None          | None      |
#
# PrecursorBin bin_id=4058, len(features)=2, mass_centre=102.126564642, mass_range=(102.12636038844343, 102.126768894702), len(molecules)=0, rt_centre=747.479980469, rt_range=(742.47998046875, 752.47998046875)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 4060       | 103.133851959 | 747.479980469 | 3830.12304688 | M+H @ 102.126575507 | None          | None      |
# | 4059       | 103.133841094 | 747.479980469 | 3830.12304688 | M+H @ 102.126564642 | None          | None      |
#
# PrecursorBin bin_id=4497, len(features)=2, mass_centre=107.046578383, mass_range=(107.04636428987178, 107.04679247618532), len(molecules)=0, rt_centre=1120.45996094, rt_range=(1115.4599609375, 1125.4599609375)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 4498       | 108.053854835 | 1120.45996094 | 2746.56396484 | M+H @ 107.046578383 | None          | None      |
# | 4497       | 108.053839568 | 1120.45996094 | 2746.56396484 | M+H @ 107.046563116 | None          | None      |
#
# PrecursorBin bin_id=4505, len(features)=2, mass_centre=257.057093505, mass_range=(257.05657939068647, 257.0576076190605), len(molecules)=0, rt_centre=1196.41003418, rt_range=(1191.4100341796875, 1201.4100341796875)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 4506       | 258.064369957 | 1196.41003418 | 2735.62988281 | M+H @ 257.057093505 | None          | None      |
# | 4505       | 258.064374949 | 1196.41003418 | 2735.62988281 | M+H @ 257.057098497 | None          | None      |
#
# PrecursorBin bin_id=5, len(features)=1, mass_centre=232.120907898, mass_range=(232.12044365667631, 232.1213721403079), len(molecules)=0, rt_centre=338.045013428, rt_range=(333.0450134277344, 343.0450134277344)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 901        | 271.083870981 | 338.045013428 | 87657.3671875 | M+K @ 232.120712661 | None          | None      |
#
# PrecursorBin bin_id=6, len(features)=1, mass_centre=80.5133144159, mass_range=(80.51315338923384, 80.5134754424915), len(molecules)=0, rt_centre=2106.83007812, rt_range=(2101.830078125, 2111.830078125)
# | feature_id | mass         | rt            | intensity | annotation              | gt_metabolite | gt_adduct |
# | 23         | 122.54711613 | 2103.84008789 | 4106479.0 | M+ACN+H @ 80.5132905754 | None          | None      |
#
# PrecursorBin bin_id=9, len(features)=1, mass_centre=166.005541751, mass_range=(166.0052097400455, 166.00587376221253), len(molecules)=0, rt_centre=2114.26000977, rt_range=(2109.260009765625, 2119.260009765625)
# | feature_id | mass          | rt            | intensity    | annotation              | gt_metabolite | gt_adduct |
# | 369        | 208.039271271 | 2115.73999023 | 357191.28125 | M+ACN+H @ 166.005445716 | None          | None      |
#
# PrecursorBin bin_id=13, len(features)=1, mass_centre=131.094493068, mass_range=(131.09423087861902, 131.0947552565913), len(molecules)=0, rt_centre=783.773986816, rt_range=(778.7739868164062, 788.7739868164062)
# | feature_id | mass          | rt            | intensity     | annotation              | gt_metabolite | gt_adduct |
# | 1455       | 173.128140447 | 786.726013184 | 32261.8867188 | M+ACN+H @ 131.094314892 | None          | None      |
#
# PrecursorBin bin_id=23, len(features)=1, mass_centre=264.10418965, mass_range=(264.1036614420073, 264.1047178587659), len(molecules)=0, rt_centre=1768.40002441, rt_range=(1763.4000244140625, 1773.4000244140625)
# | feature_id | mass          | rt            | intensity | annotation           | gt_metabolite | gt_adduct |
# | 35         | 133.059345439 | 1768.40002441 | 3345997.0 | M+2H @ 264.104137974 | None          | None      |
#
# PrecursorBin bin_id=37, len(features)=1, mass_centre=254.102772559, mass_range=(254.10226435303264, 254.10328076412287), len(molecules)=0, rt_centre=338.045013428, rt_range=(333.0450134277344, 343.0450134277344)
# | feature_id | mass          | rt            | intensity  | annotation          | gt_metabolite | gt_adduct |
# | 38         | 255.110049011 | 338.045013428 | 2962731.25 | M+H @ 254.102772559 | None          | None      |
#
# PrecursorBin bin_id=54, len(features)=1, mass_centre=169.004243596, mass_range=(169.00390558761782, 169.00458160459223), len(molecules)=0, rt_centre=1000.23999023, rt_range=(995.239990234375, 1005.239990234375)
# | feature_id | mass          | rt           | intensity     | annotation              | gt_metabolite | gt_adduct |
# | 1025       | 211.037912186 | 1004.7199707 | 63347.1601562 | M+ACN+H @ 169.004086631 | None          | None      |
#
# PrecursorBin bin_id=59, len(features)=1, mass_centre=166.005452905, mass_range=(166.0051208936705, 166.00578491548214), len(molecules)=0, rt_centre=2213.83007812, rt_range=(2208.830078125, 2218.830078125)
# | feature_id | mass          | rt            | intensity | annotation          | gt_metabolite | gt_adduct |
# | 60         | 167.012729357 | 2213.83007812 | 2392735.0 | M+H @ 166.005452905 | None          | None      |
#
# PrecursorBin bin_id=65, len(features)=1, mass_centre=80.5132885405, mass_range=(80.51312751389975, 80.5134495670539), len(molecules)=0, rt_centre=2347.75, rt_range=(2342.75, 2352.75)
# | feature_id | mass          | rt            | intensity  | annotation              | gt_metabolite | gt_adduct |
# | 175        | 122.547011019 | 2346.19995117 | 863218.625 | M+ACN+H @ 80.5131854642 | None          | None      |
#
# PrecursorBin bin_id=86, len(features)=1, mass_centre=204.063246204, mass_range=(204.06283807701007, 204.06365432999488), len(molecules)=0, rt_centre=563.612976074, rt_range=(558.6129760742188, 568.6129760742188)
# | feature_id | mass          | rt            | intensity  | annotation              | gt_metabolite | gt_adduct |
# | 257        | 246.096771222 | 563.612976074 | 531303.125 | M+ACN+H @ 204.062945667 | None          | None      |
#
# PrecursorBin bin_id=103, len(features)=1, mass_centre=80.513295967, mass_range=(80.51313494040461, 80.51345699358849), len(molecules)=0, rt_centre=2720.38989258, rt_range=(2715.389892578125, 2725.389892578125)
# | feature_id | mass          | rt            | intensity   | annotation          | gt_metabolite | gt_adduct |
# | 105        | 81.5205755772 | 2720.38989258 | 1652647.875 | M+H @ 80.5132991252 | None          | None      |
#
# PrecursorBin bin_id=104, len(features)=1, mass_centre=80.5132991252, mass_range=(80.51313809862731, 80.51346015182381), len(molecules)=0, rt_centre=2720.38989258, rt_range=(2715.389892578125, 2725.389892578125)
# | feature_id | mass         | rt            | intensity   | annotation         | gt_metabolite | gt_adduct |
# | 104        | 81.520572419 | 2720.38989258 | 1652647.875 | M+H @ 80.513295967 | None          | None      |
#
# PrecursorBin bin_id=113, len(features)=1, mass_centre=112.027143074, mass_range=(112.0269190193894, 112.0273671279617), len(molecules)=0, rt_centre=546.122009277, rt_range=(541.1220092773438, 551.1220092773438)
# | feature_id | mass          | rt            | intensity     | annotation              | gt_metabolite | gt_adduct |
# | 1716       | 154.060759909 | 544.653991699 | 23530.6699219 | M+ACN+H @ 112.026934354 | None          | None      |
#
# PrecursorBin bin_id=125, len(features)=1, mass_centre=151.063156427, mass_range=(151.06285430114823, 151.06345855377393), len(molecules)=0, rt_centre=804.323974609, rt_range=(799.323974609375, 809.323974609375)
# | feature_id | mass          | rt            | intensity     | annotation              | gt_metabolite | gt_adduct |
# | 2967       | 193.096899507 | 802.854003906 | 7806.43945312 | M+ACN+H @ 151.063073952 | None          | None      |
#
# PrecursorBin bin_id=132, len(features)=1, mass_centre=148.015892092, mass_range=(148.01559606014865, 148.01618812371703), len(molecules)=0, rt_centre=356.32598877, rt_range=(351.32598876953125, 361.32598876953125)
# | feature_id | mass          | rt            | intensity     | annotation             | gt_metabolite | gt_adduct |
# | 746        | 190.049593575 | 357.842987061 | 126532.703125 | M+ACN+H @ 148.01576802 | None          | None      |
#
# PrecursorBin bin_id=144, len(features)=1, mass_centre=204.063391855, mass_range=(204.06298372803272, 204.0637999816001), len(molecules)=0, rt_centre=795.521972656, rt_range=(790.52197265625, 800.52197265625)
# | feature_id | mass          | rt            | intensity     | annotation              | gt_metabolite | gt_adduct |
# | 601        | 246.096834259 | 795.521972656 | 183462.265625 | M+ACN+H @ 204.063008704 | None          | None      |
#
# PrecursorBin bin_id=147, len(features)=1, mass_centre=257.102405717, mass_range=(257.1018915125505, 257.1029199221734), len(molecules)=0, rt_centre=1189.93005371, rt_range=(1184.9300537109375, 1194.9300537109375)
# | feature_id | mass         | rt            | intensity | annotation          | gt_metabolite | gt_adduct |
# | 178        | 280.09151269 | 1193.17004395 | 832643.0  | M+Na @ 257.10229161 | None          | None      |
#
# PrecursorBin bin_id=151, len(features)=1, mass_centre=243.085129535, mass_range=(243.0846433648904, 243.08561570540857), len(molecules)=0, rt_centre=1160.5300293, rt_range=(1155.530029296875, 1165.530029296875)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 2056       | 282.047947233 | 1163.81005859 | 16447.0078125 | M+K @ 243.084788913 | None          | None      |
#
# PrecursorBin bin_id=158, len(features)=1, mass_centre=93.0577587053, mass_range=(93.05757258975842, 93.05794482079324), len(molecules)=0, rt_centre=612.228027344, rt_range=(607.22802734375, 617.22802734375)
# | feature_id | mass          | rt           | intensity     | annotation              | gt_metabolite | gt_adduct |
# | 2198       | 135.091458729 | 609.24597168 | 14335.1992188 | M+ACN+H @ 93.0576331735 | None          | None      |
#
# PrecursorBin bin_id=165, len(features)=1, mass_centre=78.0138775996, mass_range=(78.0137215718605, 78.01403362737089), len(molecules)=0, rt_centre=497.830993652, rt_range=(492.83099365234375, 502.83099365234375)
# | feature_id | mass          | rt            | intensity     | annotation              | gt_metabolite | gt_adduct |
# | 3205       | 120.047604375 | 497.830993652 | 6649.04150391 | M+ACN+H @ 78.0137788199 | None          | None      |
#
# PrecursorBin bin_id=167, len(features)=1, mass_centre=408.152890601, mass_range=(408.1520742952153, 408.1537069067777), len(molecules)=0, rt_centre=587.0, rt_range=(582.0, 592.0)
# | feature_id | mass          | rt            | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 1338       | 431.142098292 | 585.531982422 | 37486.8554688 | M+Na @ 408.152877212 | None          | None      |
#
# PrecursorBin bin_id=169, len(features)=1, mass_centre=175.095385921, mass_range=(175.09503573055105, 175.09573611209476), len(molecules)=0, rt_centre=1138.81994629, rt_range=(1133.8199462890625, 1143.8199462890625)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 2983       | 214.058422315 | 1138.81994629 | 7723.86669922 | M+K @ 175.095263995 | None          | None      |
#
# PrecursorBin bin_id=175, len(features)=1, mass_centre=323.121236691, mass_range=(323.1205904483883, 323.12188293333514), len(molecules)=0, rt_centre=764.177978516, rt_range=(759.177978515625, 769.177978515625)
# | feature_id | mass          | rt            | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 1205       | 346.110510308 | 767.231994629 | 46442.1210938 | M+Na @ 323.121289228 | None          | None      |
#
# PrecursorBin bin_id=180, len(features)=1, mass_centre=390.276311943, mass_range=(390.27553139062746, 390.27709249587525), len(molecules)=0, rt_centre=199.070007324, rt_range=(194.07000732421875, 204.07000732421875)
# | feature_id | mass          | rt            | intensity  | annotation           | gt_metabolite | gt_adduct |
# | 252        | 413.265485928 | 199.070007324 | 538642.375 | M+Na @ 390.276264848 | None          | None      |
#
# PrecursorBin bin_id=181, len(features)=1, mass_centre=173.083912404, mass_range=(173.08356623654353, 173.08425857219314), len(molecules)=0, rt_centre=338.045013428, rt_range=(333.0450134277344, 343.0450134277344)
# | feature_id | mass          | rt            | intensity  | annotation          | gt_metabolite | gt_adduct |
# | 206        | 174.091145091 | 334.967010498 | 712898.125 | M+H @ 173.083868639 | None          | None      |
#
# PrecursorBin bin_id=190, len(features)=1, mass_centre=164.047163448, mass_range=(164.0468353533504, 164.0474915420042), len(molecules)=0, rt_centre=339.582000732, rt_range=(334.5820007324219, 344.5820007324219)
# | feature_id | mass          | rt            | intensity   | annotation             | gt_metabolite | gt_adduct |
# | 2628       | 206.080997795 | 334.967010498 | 9963.921875 | M+ACN+H @ 164.04717224 | None          | None      |
#
# PrecursorBin bin_id=194, len(features)=1, mass_centre=101.528044045, mass_range=(101.52784098902067, 101.52824710119687), len(molecules)=0, rt_centre=2236.84008789, rt_range=(2231.840087890625, 2241.840087890625)
# | feature_id | mass          | rt            | intensity  | annotation              | gt_metabolite | gt_adduct |
# | 1128       | 146.499337972 | 2235.30004883 | 52054.8125 | M+2Na-H @ 101.528172263 | None          | None      |
#
# PrecursorBin bin_id=205, len(features)=1, mass_centre=173.083868639, mass_range=(173.08352247136895, 173.08421480684353), len(molecules)=0, rt_centre=334.967010498, rt_range=(329.9670104980469, 339.9670104980469)
# | feature_id | mass          | rt            | intensity    | annotation           | gt_metabolite | gt_adduct |
# | 1437       | 191.117586935 | 334.967010498 | 32890.921875 | M+NH4 @ 173.08376138 | None          | None      |
#
# PrecursorBin bin_id=210, len(features)=1, mass_centre=466.129495711, mass_range=(466.12856345215846, 466.13042797014134), len(molecules)=0, rt_centre=745.955993652, rt_range=(740.9559936523438, 750.9559936523438)
# | feature_id | mass          | rt            | intensity     | annotation            | gt_metabolite | gt_adduct |
# | 1065       | 245.062730391 | 745.955993652 | 58625.5664062 | M+H+Na @ 466.12896325 | None          | None      |
#
# PrecursorBin bin_id=224, len(features)=1, mass_centre=254.936764473, mass_range=(254.93625459898854, 254.93727434604645), len(molecules)=0, rt_centre=2114.26000977, rt_range=(2109.260009765625, 2119.260009765625)
# | feature_id | mass          | rt            | intensity     | annotation              | gt_metabolite | gt_adduct |
# | 479        | 296.970682928 | 2111.30004883 | 247596.953125 | M+ACN+H @ 254.936857373 | None          | None      |
#
# PrecursorBin bin_id=240, len(features)=1, mass_centre=121.539708617, mass_range=(121.53946553795095, 121.53995169678541), len(molecules)=0, rt_centre=2424.98999023, rt_range=(2419.989990234375, 2429.989990234375)
# | feature_id | mass          | rt            | intensity   | annotation          | gt_metabolite | gt_adduct |
# | 241        | 122.546985069 | 2424.98999023 | 557317.4375 | M+H @ 121.539708617 | None          | None      |
#
# PrecursorBin bin_id=247, len(features)=1, mass_centre=231.053821304, mass_range=(231.05335919663105, 231.0542834119163), len(molecules)=0, rt_centre=841.776000977, rt_range=(836.7760009765625, 846.7760009765625)
# | feature_id | mass          | rt            | intensity     | annotation              | gt_metabolite | gt_adduct |
# | 1864       | 273.087472778 | 838.895996094 | 19903.6582031 | M+ACN+H @ 231.053647223 | None          | None      |
#
# PrecursorBin bin_id=261, len(features)=1, mass_centre=125.014561921, mass_range=(125.01431189207636, 125.01481195032406), len(molecules)=0, rt_centre=975.611999512, rt_range=(970.6119995117188, 980.6119995117188)
# | feature_id | mass          | rt            | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 1200       | 148.003533492 | 978.768005371 | 46637.5859375 | M+Na @ 125.014312412 | None          | None      |
#
# PrecursorBin bin_id=278, len(features)=1, mass_centre=157.956488655, mass_range=(157.9561727416919, 157.9568045676465), len(molecules)=0, rt_centre=1260.89001465, rt_range=(1255.8900146484375, 1265.8900146484375)
# | feature_id | mass          | rt            | intensity     | annotation              | gt_metabolite | gt_adduct |
# | 2887       | 199.990331852 | 1263.93005371 | 8208.05566406 | M+ACN+H @ 157.956506297 | None          | None      |
#
# PrecursorBin bin_id=313, len(features)=1, mass_centre=89.5185306055, mass_range=(89.51835156845391, 89.51870964257634), len(molecules)=0, rt_centre=2384.80004883, rt_range=(2379.800048828125, 2389.800048828125)
# | feature_id | mass          | rt            | intensity    | annotation          | gt_metabolite | gt_adduct |
# | 314        | 90.5258070575 | 2384.80004883 | 418969.96875 | M+H @ 89.5185306055 | None          | None      |
#
# PrecursorBin bin_id=321, len(features)=1, mass_centre=124.978850691, mass_range=(124.97860073359185, 124.97910064899462), len(molecules)=0, rt_centre=2606.68994141, rt_range=(2601.68994140625, 2611.68994140625)
# | feature_id | mass          | rt            | intensity    | annotation          | gt_metabolite | gt_adduct |
# | 332        | 125.986102874 | 2611.36010742 | 389154.71875 | M+H @ 124.978826422 | None          | None      |
#
# PrecursorBin bin_id=322, len(features)=1, mass_centre=221.089608097, mass_range=(221.08916591729172, 221.09005027572408), len(molecules)=0, rt_centre=708.468017578, rt_range=(703.468017578125, 713.468017578125)
# | feature_id | mass          | rt            | intensity     | annotation               | gt_metabolite | gt_adduct |
# | 1645       | 285.105087989 | 710.033996582 | 25411.3769531 | M+ACN+Na @ 221.089317806 | None          | None      |
#
# PrecursorBin bin_id=324, len(features)=1, mass_centre=166.005325042, mass_range=(166.00499303154396, 166.00565705284413), len(molecules)=0, rt_centre=2720.38989258, rt_range=(2715.389892578125, 2725.389892578125)
# | feature_id | mass         | rt      | intensity   | annotation          | gt_metabolite | gt_adduct |
# | 346        | 167.01260037 | 2715.75 | 379912.9375 | M+H @ 166.005323918 | None          | None      |
#
# PrecursorBin bin_id=335, len(features)=1, mass_centre=124.978823104, mass_range=(124.97857314678329, 124.9790730620757), len(molecules)=0, rt_centre=2748.26000977, rt_range=(2743.260009765625, 2753.260009765625)
# | feature_id | mass          | rt            | intensity    | annotation          | gt_metabolite | gt_adduct |
# | 337        | 125.986097668 | 2752.89990234 | 385112.65625 | M+H @ 124.978821216 | None          | None      |
#
# PrecursorBin bin_id=343, len(features)=1, mass_centre=255.106019921, mass_range=(255.10550970867857, 255.10653013275825), len(molecules)=0, rt_centre=338.045013428, rt_range=(333.0450134277344, 343.0450134277344)
# | feature_id | mass          | rt            | intensity    | annotation          | gt_metabolite | gt_adduct |
# | 344        | 256.113296373 | 338.045013428 | 381577.40625 | M+H @ 255.106019921 | None          | None      |
#
# PrecursorBin bin_id=358, len(features)=1, mass_centre=166.005298616, mass_range=(166.0049666053046, 166.00563062649903), len(molecules)=0, rt_centre=41.9440002441, rt_range=(36.944000244140625, 46.944000244140625)
# | feature_id | mass          | rt            | intensity     | annotation              | gt_metabolite | gt_adduct |
# | 2388       | 104.523126823 | 37.3166007996 | 12274.4638672 | M+ACN+2H @ 166.00515164 | None          | None      |
#
# PrecursorBin bin_id=382, len(features)=1, mass_centre=265.066959997, mass_range=(265.0664298627505, 265.0674901305905), len(molecules)=0, rt_centre=1163.81005859, rt_range=(1158.81005859375, 1168.81005859375)
# | feature_id | mass          | rt            | intensity   | annotation          | gt_metabolite | gt_adduct |
# | 383        | 266.074236449 | 1163.81005859 | 340702.8125 | M+H @ 265.066959997 | None          | None      |
#
# PrecursorBin bin_id=389, len(features)=1, mass_centre=290.062329154, mass_range=(290.0617490296338, 290.0629092789504), len(molecules)=0, rt_centre=616.697998047, rt_range=(611.697998046875, 621.697998046875)
# | feature_id | mass          | rt            | intensity    | annotation          | gt_metabolite | gt_adduct |
# | 390        | 291.069605606 | 616.697998047 | 334877.28125 | M+H @ 290.062329154 | None          | None      |
#
# PrecursorBin bin_id=398, len(features)=1, mass_centre=190.095011441, mass_range=(190.09463125110747, 190.09539163115326), len(molecules)=0, rt_centre=1422.19995117, rt_range=(1417.199951171875, 1427.199951171875)
# | feature_id | mass         | rt            | intensity     | annotation              | gt_metabolite | gt_adduct |
# | 2811       | 235.06592853 | 1420.60998535 | 8680.47070312 | M+2Na-H @ 190.094762822 | None          | None      |
#
# PrecursorBin bin_id=402, len(features)=1, mass_centre=338.008543389, mass_range=(338.00786737159785, 338.00921940577143), len(molecules)=0, rt_centre=1016.69000244, rt_range=(1011.6900024414062, 1021.6900024414062)
# | feature_id | mass          | rt            | intensity     | annotation            | gt_metabolite | gt_adduct |
# | 1621       | 191.993317806 | 1015.19000244 | 26244.3964844 | M+2Na @ 338.008193452 | None          | None      |
#
# PrecursorBin bin_id=416, len(features)=1, mass_centre=69.0054478981, mass_range=(69.00530988716675, 69.00558590895834), len(molecules)=0, rt_centre=2102.35009766, rt_range=(2097.35009765625, 2107.35009765625)
# | feature_id | mass          | rt            | intensity | annotation          | gt_metabolite | gt_adduct |
# | 417        | 70.0127243501 | 2102.35009766 | 305452.0  | M+H @ 69.0054478981 | None          | None      |
#
# PrecursorBin bin_id=417, len(features)=1, mass_centre=151.049145929, mass_range=(151.0488438307779, 151.04944802736162), len(molecules)=0, rt_centre=862.572021484, rt_range=(857.572021484375, 867.572021484375)
# | feature_id | mass         | rt            | intensity     | annotation         | gt_metabolite | gt_adduct |
# | 3429       | 190.01216039 | 858.036010742 | 5707.86865234 | M+K @ 151.04900207 | None          | None      |
#
# PrecursorBin bin_id=437, len(features)=1, mass_centre=201.060952351, mass_range=(201.0605502287782, 201.0613544725876), len(molecules)=0, rt_centre=1375.69995117, rt_range=(1370.699951171875, 1380.699951171875)
# | feature_id | mass          | rt            | intensity     | annotation              | gt_metabolite | gt_adduct |
# | 2759       | 243.094522843 | 1380.47998047 | 8978.57617188 | M+ACN+H @ 201.060697287 | None          | None      |
#
# PrecursorBin bin_id=463, len(features)=1, mass_centre=178.073962061, mass_range=(178.0736059132393, 178.07431820908755), len(molecules)=0, rt_centre=357.842987061, rt_range=(352.8429870605469, 362.8429870605469)
# | feature_id | mass          | rt            | intensity    | annotation          | gt_metabolite | gt_adduct |
# | 464        | 179.081238513 | 357.842987061 | 258563.53125 | M+H @ 178.073962061 | None          | None      |
#
# PrecursorBin bin_id=476, len(features)=1, mass_centre=245.089637564, mass_range=(245.08914738499726, 245.0901277435475), len(molecules)=0, rt_centre=824.59197998, rt_range=(819.5919799804688, 829.5919799804688)
# | feature_id | mass          | rt           | intensity    | annotation          | gt_metabolite | gt_adduct |
# | 477        | 246.096914016 | 824.59197998 | 248920.21875 | M+H @ 245.089637564 | None          | None      |
#
# PrecursorBin bin_id=496, len(features)=1, mass_centre=392.128969993, mass_range=(392.12818573513067, 392.12975425101064), len(molecules)=0, rt_centre=472.308990479, rt_range=(467.3089904785156, 477.3089904785156)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 497        | 393.136246445 | 472.308990479 | 228337.828125 | M+H @ 392.128969993 | None          | None      |
#
# PrecursorBin bin_id=500, len(features)=1, mass_centre=101.528013879, mass_range=(101.52781082256652, 101.52821693462204), len(molecules)=0, rt_centre=1920.26000977, rt_range=(1915.260009765625, 1925.260009765625)
# | feature_id | mass          | rt            | intensity     | annotation         | gt_metabolite | gt_adduct |
# | 502        | 102.535277432 | 1920.26000977 | 225745.828125 | M+H @ 101.52800098 | None          | None      |
#
# PrecursorBin bin_id=501, len(features)=1, mass_centre=101.52800098, mass_range=(101.52779792430354, 101.52820403630747), len(molecules)=0, rt_centre=1920.26000977, rt_range=(1915.260009765625, 1925.260009765625)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 501        | 102.535290331 | 1920.26000977 | 225745.828125 | M+H @ 101.528013879 | None          | None      |
#
# PrecursorBin bin_id=504, len(features)=1, mass_centre=245.089578905, mass_range=(245.08908872577743, 245.09006908409307), len(molecules)=0, rt_centre=831.726013184, rt_range=(826.7260131835938, 836.7260131835938)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 505        | 246.096855357 | 831.726013184 | 222817.984375 | M+H @ 245.089578905 | None          | None      |
#
# PrecursorBin bin_id=521, len(features)=1, mass_centre=486.223909631, mass_range=(486.22293718270913, 486.22488207834766), len(molecules)=0, rt_centre=345.691009521, rt_range=(340.6910095214844, 350.6910095214844)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 522        | 487.231186083 | 345.691009521 | 214428.859375 | M+H @ 486.223909631 | None          | None      |
#
# PrecursorBin bin_id=539, len(features)=1, mass_centre=197.077283957, mass_range=(197.0768898028379, 197.07767811197374), len(molecules)=0, rt_centre=1140.51000977, rt_range=(1135.510009765625, 1145.510009765625)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 540        | 198.084560409 | 1140.51000977 | 206950.515625 | M+H @ 197.077283957 | None          | None      |
#
# PrecursorBin bin_id=604, len(features)=1, mass_centre=179.079014747, mass_range=(179.07865658911817, 179.07937290517714), len(molecules)=0, rt_centre=1406.16003418, rt_range=(1401.1600341796875, 1411.1600341796875)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 2394       | 218.041993418 | 1401.32995605 | 12237.1230469 | M+K @ 179.078835098 | None          | None      |
#
# PrecursorBin bin_id=635, len(features)=1, mass_centre=101.047531503, mass_range=(101.04732940816758, 101.04773359829359), len(molecules)=0, rt_centre=1045.44995117, rt_range=(1040.449951171875, 1050.449951171875)
# | feature_id | mass          | rt            | intensity    | annotation          | gt_metabolite | gt_adduct |
# | 637        | 102.054832644 | 1045.44995117 | 169021.59375 | M+H @ 101.047556192 | None          | None      |
#
# PrecursorBin bin_id=636, len(features)=1, mass_centre=101.047556192, mass_range=(101.0473540966385, 101.04775828686327), len(molecules)=0, rt_centre=1045.44995117, rt_range=(1040.449951171875, 1050.449951171875)
# | feature_id | mass          | rt            | intensity    | annotation          | gt_metabolite | gt_adduct |
# | 636        | 102.054807955 | 1045.44995117 | 169021.59375 | M+H @ 101.047531503 | None          | None      |
#
# PrecursorBin bin_id=654, len(features)=1, mass_centre=383.090131629, mass_range=(383.089365448288, 383.09089780881453), len(molecules)=0, rt_centre=268.899993896, rt_range=(263.8999938964844, 273.8999938964844)
# | feature_id | mass          | rt            | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 4087       | 406.079356826 | 267.113006592 | 3742.50146484 | M+Na @ 383.090135746 | None          | None      |
#
# PrecursorBin bin_id=677, len(features)=1, mass_centre=398.119674646, mass_range=(398.1188784070994, 398.120470885798), len(molecules)=0, rt_centre=467.687011719, rt_range=(462.68701171875, 472.68701171875)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 678        | 399.126951098 | 467.687011719 | 147779.671875 | M+H @ 398.119674646 | None          | None      |
#
# PrecursorBin bin_id=686, len(features)=1, mass_centre=266.099686424, mass_range=(266.09915422416174, 266.10021862290745), len(molecules)=0, rt_centre=1768.40002441, rt_range=(1763.4000244140625, 1773.4000244140625)
# | feature_id | mass          | rt            | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 729        | 134.057109275 | 1768.40002441 | 131887.265625 | M+2H @ 266.099665647 | None          | None      |
#
# PrecursorBin bin_id=715, len(features)=1, mass_centre=576.125811007, mass_range=(576.1246587556167, 576.1269632588607), len(molecules)=0, rt_centre=103.125999451, rt_range=(98.1259994506836, 108.1259994506836)
# | feature_id | mass          | rt            | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 1209       | 599.115132659 | 101.503997803 | 46344.0664062 | M+Na @ 576.125911579 | None          | None      |
#
# PrecursorBin bin_id=755, len(features)=1, mass_centre=145.492115734, mass_range=(145.49182474971624, 145.49240671817918), len(molecules)=0, rt_centre=2165.16992188, rt_range=(2160.169921875, 2170.169921875)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 756        | 146.499392186 | 2165.16992188 | 123853.710938 | M+H @ 145.492115734 | None          | None      |
#
# PrecursorBin bin_id=757, len(features)=1, mass_centre=413.261485812, mass_range=(413.2606592894659, 413.26231233540915), len(molecules)=0, rt_centre=199.070007324, rt_range=(194.07000732421875, 204.07000732421875)
# | feature_id | mass          | rt            | intensity    | annotation          | gt_metabolite | gt_adduct |
# | 758        | 414.268762264 | 199.070007324 | 123470.09375 | M+H @ 413.261485812 | None          | None      |
#
# PrecursorBin bin_id=770, len(features)=1, mass_centre=130.995650794, mass_range=(130.99538880260164, 130.9959127852048), len(molecules)=0, rt_centre=1265.44995117, rt_range=(1260.449951171875, 1270.449951171875)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 771        | 132.002927246 | 1265.44995117 | 119143.304688 | M+H @ 130.995650794 | None          | None      |
#
# PrecursorBin bin_id=789, len(features)=1, mass_centre=158.961492376, mass_range=(158.9611744527027, 158.9618102986722), len(molecules)=0, rt_centre=4.4220700264, rt_range=(-0.5779299736022949, 9.422070026397705)
# | feature_id | mass          | rt            | intensity     | annotation              | gt_metabolite | gt_adduct |
# | 2928       | 200.995034348 | 5.88184976578 | 8035.16699219 | M+ACN+H @ 158.961208793 | None          | None      |
#
# PrecursorBin bin_id=795, len(features)=1, mass_centre=341.110467486, mass_range=(341.10978526533796, 341.11114970720786), len(molecules)=0, rt_centre=420.395996094, rt_range=(415.39599609375, 425.39599609375)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 4331       | 380.073482012 | 425.178985596 | 3118.63476562 | M+K @ 341.110323692 | None          | None      |
#
# PrecursorBin bin_id=807, len(features)=1, mass_centre=245.089450419, mass_range=(245.08896023988066, 245.08994059768233), len(molecules)=0, rt_centre=849.07800293, rt_range=(844.0780029296875, 854.0780029296875)
# | feature_id | mass          | rt           | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 808        | 246.096726871 | 849.07800293 | 108653.890625 | M+H @ 245.089450419 | None          | None      |
#
# PrecursorBin bin_id=810, len(features)=1, mass_centre=169.146319858, mass_range=(169.14598156536715, 169.1466581506466), len(molecules)=0, rt_centre=315.963989258, rt_range=(310.9639892578125, 320.9639892578125)
# | feature_id | mass         | rt            | intensity   | annotation          | gt_metabolite | gt_adduct |
# | 811        | 170.15359631 | 315.963989258 | 108001.6875 | M+H @ 169.146319858 | None          | None      |
#
# PrecursorBin bin_id=823, len(features)=1, mass_centre=84.0209369663, mass_range=(84.02076892438565, 84.02110500813352), len(molecules)=0, rt_centre=565.065979004, rt_range=(560.0659790039062, 570.0659790039062)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 824        | 85.0282134183 | 565.065979004 | 104106.179688 | M+H @ 84.0209369663 | None          | None      |
#
# PrecursorBin bin_id=830, len(features)=1, mass_centre=169.998175983, mass_range=(169.9978359865017, 169.99851597920562), len(molecules)=0, rt_centre=2121.67993164, rt_range=(2116.679931640625, 2126.679931640625)
# | feature_id | mass          | rt            | intensity     | annotation             | gt_metabolite | gt_adduct |
# | 3192       | 212.032097675 | 2118.70996094 | 6703.87353516 | M+ACN+H @ 169.99827212 | None          | None      |
#
# PrecursorBin bin_id=839, len(features)=1, mass_centre=148.073263074, mass_range=(148.0729669271309, 148.0735592201832), len(molecules)=0, rt_centre=407.24899292, rt_range=(402.2489929199219, 412.2489929199219)
# | feature_id | mass          | rt            | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 1029       | 75.0439867154 | 402.319000244 | 62574.2890625 | M+2H @ 148.073420527 | None          | None      |
#
# PrecursorBin bin_id=851, len(features)=1, mass_centre=140.131119589, mass_range=(140.13083932716256, 140.13139985164094), len(molecules)=0, rt_centre=817.427978516, rt_range=(812.427978515625, 822.427978515625)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 852        | 141.138396041 | 817.427978516 | 96695.2890625 | M+H @ 140.131119589 | None          | None      |
#
# PrecursorBin bin_id=852, len(features)=1, mass_centre=149.019141701, mass_range=(149.01884366311324, 149.01943973968005), len(molecules)=0, rt_centre=353.29598999, rt_range=(348.2959899902344, 358.2959899902344)
# | feature_id | mass         | rt           | intensity     | annotation              | gt_metabolite | gt_adduct |
# | 2482       | 191.05287531 | 356.32598877 | 11354.2822266 | M+ACN+H @ 149.019049754 | None          | None      |
#
# PrecursorBin bin_id=853, len(features)=1, mass_centre=186.052593608, mass_range=(186.05222150279522, 186.05296571316964), len(molecules)=0, rt_centre=831.726013184, rt_range=(826.7260131835938, 836.7260131835938)
# | feature_id | mass          | rt            | intensity | annotation            | gt_metabolite | gt_adduct |
# | 1174       | 204.086427189 | 830.297973633 | 48293.5   | M+NH4 @ 186.052601634 | None          | None      |
#
# PrecursorBin bin_id=862, len(features)=1, mass_centre=210.075132574, mass_range=(210.0747124236077, 210.075552724138), len(molecules)=0, rt_centre=831.726013184, rt_range=(826.7260131835938, 836.7260131835938)
# | feature_id | mass          | rt            | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 1505       | 233.064339955 | 833.153991699 | 29852.9785156 | M+Na @ 210.075118875 | None          | None      |
#
# PrecursorBin bin_id=866, len(features)=1, mass_centre=170.999841134, mass_range=(170.999499134738, 171.0001831341025), len(molecules)=0, rt_centre=1004.7199707, rt_range=(999.719970703125, 1009.719970703125)
# | feature_id | mass          | rt           | intensity     | annotation             | gt_metabolite | gt_adduct |
# | 4648       | 213.033634325 | 1009.2199707 | 2392.57836914 | M+ACN+H @ 170.99980877 | None          | None      |
#
# PrecursorBin bin_id=868, len(features)=1, mass_centre=487.227432487, mass_range=(487.2264580324837, 487.2284069422137), len(molecules)=0, rt_centre=338.045013428, rt_range=(333.0450134277344, 343.0450134277344)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 869        | 488.234708939 | 338.045013428 | 93624.2109375 | M+H @ 487.227432487 | None          | None      |
#
# PrecursorBin bin_id=869, len(features)=1, mass_centre=123.536197058, mass_range=(123.5359499856889, 123.53644413047714), len(molecules)=0, rt_centre=2103.84008789, rt_range=(2098.840087890625, 2108.840087890625)
# | feature_id | mass         | rt            | intensity    | annotation          | gt_metabolite | gt_adduct |
# | 870        | 124.54347351 | 2103.84008789 | 93622.453125 | M+H @ 123.536197058 | None          | None      |
#
# PrecursorBin bin_id=885, len(features)=1, mass_centre=244.088305117, mass_range=(244.08781693989462, 244.08879329311512), len(molecules)=0, rt_centre=1160.5300293, rt_range=(1155.530029296875, 1165.530029296875)
# | feature_id | mass         | rt            | intensity     | annotation         | gt_metabolite | gt_adduct |
# | 1674       | 267.07744628 | 1162.17004395 | 24531.9394531 | M+Na @ 244.0882252 | None          | None      |
#
# PrecursorBin bin_id=901, len(features)=1, mass_centre=318.128462024, mass_range=(318.12782576705865, 318.12909828090676), len(molecules)=0, rt_centre=402.319000244, rt_range=(397.3190002441406, 407.3190002441406)
# | feature_id | mass          | rt           | intensity     | annotation             | gt_metabolite | gt_adduct |
# | 3131       | 171.062310936 | 407.24899292 | 6946.02050781 | M+H+Na @ 318.128124341 | None          | None      |
#
# PrecursorBin bin_id=904, len(features)=1, mass_centre=152.565201665, mass_range=(152.56489653479022, 152.56550679559686), len(molecules)=0, rt_centre=1771.45996094, rt_range=(1766.4599609375, 1776.4599609375)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 905        | 153.572478117 | 1771.45996094 | 87294.1640625 | M+H @ 152.565201665 | None          | None      |
#
# PrecursorBin bin_id=922, len(features)=1, mass_centre=205.066494052, mass_range=(205.06608391852475, 205.06690418450094), len(molecules)=0, rt_centre=827.447998047, rt_range=(822.447998046875, 832.447998046875)
# | feature_id | mass          | rt            | intensity     | annotation              | gt_metabolite | gt_adduct |
# | 1714       | 247.100183826 | 826.020019531 | 23553.3535156 | M+ACN+H @ 205.066358271 | None          | None      |
#
# PrecursorBin bin_id=925, len(features)=1, mass_centre=347.982173661, mass_range=(347.98147769656254, 347.98286962525714), len(molecules)=0, rt_centre=1.54375994205, rt_range=(-3.4562400579452515, 6.5437599420547485)
# | feature_id | mass          | rt           | intensity     | annotation           | gt_metabolite | gt_adduct |
# | 2617       | 174.998499783 | 4.4220700264 | 10050.0761719 | M+2H @ 347.982446661 | None          | None      |
#
# PrecursorBin bin_id=950, len(features)=1, mass_centre=173.031006436, mass_range=(173.03066037424733, 173.0313524982731), len(molecules)=0, rt_centre=864.090026855, rt_range=(859.0900268554688, 869.0900268554688)
# | feature_id | mass          | rt            | intensity  | annotation          | gt_metabolite | gt_adduct |
# | 951        | 174.038282888 | 864.090026855 | 76628.4375 | M+H @ 173.031006436 | None          | None      |
#
# PrecursorBin bin_id=959, len(features)=1, mass_centre=87.0318732216, mass_range=(87.03169915788088, 87.03204728537376), len(molecules)=0, rt_centre=1054.81005859, rt_range=(1049.81005859375, 1059.81005859375)
# ...
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 3555       | 637.190733564 | 99.8904037476 | 5331.13867188 | M+H @ 636.183457112 | None          | None      |
#
# PrecursorBin bin_id=3620, len(features)=1, mass_centre=275.055204275, mass_range=(275.05465416495247, 275.05575438576955), len(molecules)=0, rt_centre=697.409973145, rt_range=(692.4099731445312, 702.4099731445312)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 3622       | 276.062378478 | 697.409973145 | 5121.09912109 | M+H @ 275.055102026 | None          | None      |
#
# PrecursorBin bin_id=3621, len(features)=1, mass_centre=275.055102026, mass_range=(275.05455191609417, 275.0556521365023), len(molecules)=0, rt_centre=697.409973145, rt_range=(692.4099731445312, 702.4099731445312)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 3621       | 276.062480727 | 697.409973145 | 5121.09912109 | M+H @ 275.055204275 | None          | None      |
#
# PrecursorBin bin_id=3693, len(features)=1, mass_centre=392.011299816, mass_range=(392.0105157930318, 392.0120838382311), len(molecules)=0, rt_centre=314.361999512, rt_range=(309.36199951171875, 319.36199951171875)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 3694       | 393.018576268 | 314.361999512 | 4908.83935547 | M+H @ 392.011299816 | None          | None      |
#
# PrecursorBin bin_id=3768, len(features)=1, mass_centre=273.147030043, mass_range=(273.14648374934427, 273.14757633746444), len(molecules)=0, rt_centre=334.967010498, rt_range=(329.9670104980469, 339.9670104980469)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 3769       | 274.154306495 | 334.967010498 | 4673.55615234 | M+H @ 273.147030043 | None          | None      |
#
# PrecursorBin bin_id=3781, len(features)=1, mass_centre=312.128938168, mass_range=(312.12831391059336, 312.129562426346), len(molecules)=0, rt_centre=1107.07995605, rt_range=(1102.0799560546875, 1112.0799560546875)
# | feature_id | mass         | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 3782       | 313.13621462 | 1107.07995605 | 4645.13574219 | M+H @ 312.128938168 | None          | None      |
#
# PrecursorBin bin_id=3836, len(features)=1, mass_centre=243.054719715, mass_range=(243.05423360511531, 243.05520582399419), len(molecules)=0, rt_centre=714.75, rt_range=(709.75, 719.75)
# | feature_id | mass          | rt     | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 3837       | 244.061996167 | 714.75 | 4509.71826172 | M+H @ 243.054719715 | None          | None      |
#
# PrecursorBin bin_id=3837, len(features)=1, mass_centre=243.05472426, mass_range=(243.05423815071237, 243.05521036960943), len(molecules)=0, rt_centre=714.75, rt_range=(709.75, 719.75)
# | feature_id | mass          | rt     | intensity     | annotation         | gt_metabolite | gt_adduct |
# | 3838       | 244.062000712 | 714.75 | 4509.71826172 | M+H @ 243.05472426 | None          | None      |
#
# PrecursorBin bin_id=3878, len(features)=1, mass_centre=256.040508159, mass_range=(256.03999607775336, 256.041020239786), len(molecules)=0, rt_centre=1425.40002441, rt_range=(1420.4000244140625, 1430.4000244140625)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 3879       | 257.047784611 | 1425.40002441 | 4390.30957031 | M+H @ 256.040508159 | None          | None      |
#
# PrecursorBin bin_id=3887, len(features)=1, mass_centre=153.563199366, mass_range=(153.56289223943503, 153.56350649223248), len(molecules)=0, rt_centre=1765.31005859, rt_range=(1760.31005859375, 1770.31005859375)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 3888       | 154.570475818 | 1765.31005859 | 4369.57275391 | M+H @ 153.563199366 | None          | None      |
#
# PrecursorBin bin_id=3904, len(features)=1, mass_centre=190.06895059, mass_range=(190.06857045218092, 190.06933072798327), len(molecules)=0, rt_centre=1606.67004395, rt_range=(1601.6700439453125, 1611.6700439453125)
# | feature_id | mass          | rt            | intensity     | annotation         | gt_metabolite | gt_adduct |
# | 3905       | 191.076227042 | 1606.67004395 | 4288.07128906 | M+H @ 190.06895059 | None          | None      |
#
# PrecursorBin bin_id=3935, len(features)=1, mass_centre=219.059142168, mass_range=(219.05870404978725, 219.05958028635592), len(molecules)=0, rt_centre=1138.81994629, rt_range=(1133.8199462890625, 1143.8199462890625)
# | feature_id | mass         | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 3936       | 220.06641862 | 1138.81994629 | 4198.44091797 | M+H @ 219.059142168 | None          | None      |
#
# PrecursorBin bin_id=3968, len(features)=1, mass_centre=279.060364952, mass_range=(279.0598068310108, 279.06092307247064), len(molecules)=0, rt_centre=1198.04003906, rt_range=(1193.0400390625, 1203.0400390625)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 3969       | 280.067641404 | 1198.04003906 | 4106.89794922 | M+H @ 279.060364952 | None          | None      |
#
# PrecursorBin bin_id=3969, len(features)=1, mass_centre=279.060344577, mass_range=(279.05978645648884, 279.06090269786716), len(molecules)=0, rt_centre=1198.04003906, rt_range=(1193.0400390625, 1203.0400390625)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 3970       | 280.067621029 | 1198.04003906 | 4106.89794922 | M+H @ 279.060344577 | None          | None      |
#
# PrecursorBin bin_id=3992, len(features)=1, mass_centre=654.704495511, mass_range=(654.7031861016984, 654.7058049196804), len(molecules)=0, rt_centre=1771.45996094, rt_range=(1766.4599609375, 1776.4599609375)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 3993       | 655.711771963 | 1771.45996094 | 4055.31347656 | M+H @ 654.704495511 | None          | None      |
#
# PrecursorBin bin_id=4014, len(features)=1, mass_centre=291.131338602, mass_range=(291.13075633914207, 291.13192086449646), len(molecules)=0, rt_centre=455.389007568, rt_range=(450.3890075683594, 460.3890075683594)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 4015       | 292.138615054 | 455.389007568 | 3991.28271484 | M+H @ 291.131338602 | None          | None      |
#
# PrecursorBin bin_id=4049, len(features)=1, mass_centre=379.087111644, mass_range=(379.0863534696872, 379.08786981813375), len(molecules)=0, rt_centre=428.394012451, rt_range=(423.3940124511719, 433.3940124511719)
# | feature_id | mass        | rt            | intensity     | annotation                  | gt_metabolite | gt_adduct |
# | 4527       | 440.1524333 | 425.178985596 | 2686.63037109 | M+IsoProp+H @ 379.087641971 | None          | None      |
#
# PrecursorBin bin_id=4069, len(features)=1, mass_centre=92.0078970021, mass_range=(92.0077129863114, 92.00808101789941), len(molecules)=0, rt_centre=23.6833000183, rt_range=(18.683300018310547, 28.683300018310547)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 4070       | 93.0151734541 | 23.6833000183 | 3787.49169922 | M+H @ 92.0078970021 | None          | None      |
#
# PrecursorBin bin_id=4118, len(features)=1, mass_centre=217.980000392, mass_range=(217.97956443195056, 217.9804363519521), len(molecules)=0, rt_centre=446.058990479, rt_range=(441.0589904785156, 451.0589904785156)
# | feature_id | mass          | rt            | intensity    | annotation          | gt_metabolite | gt_adduct |
# | 4119       | 218.987276844 | 446.058990479 | 3676.1472168 | M+H @ 217.980000392 | None          | None      |
#
# PrecursorBin bin_id=4172, len(features)=1, mass_centre=212.113194728, mass_range=(212.11277050199428, 212.11361895477322), len(molecules)=0, rt_centre=1961.66003418, rt_range=(1956.6600341796875, 1966.6600341796875)
# | feature_id | mass         | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 4173       | 213.12047118 | 1961.66003418 | 3524.85644531 | M+H @ 212.113194728 | None          | None      |
#
# PrecursorBin bin_id=4190, len(features)=1, mass_centre=176.066310294, mass_range=(176.06595816092997, 176.06666242617112), len(molecules)=0, rt_centre=799.91998291, rt_range=(794.9199829101562, 804.9199829101562)
# | feature_id | mass          | rt           | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 4191       | 177.073586746 | 799.91998291 | 3483.67773438 | M+H @ 176.066310294 | None          | None      |
#
# PrecursorBin bin_id=4197, len(features)=1, mass_centre=189.099694479, mass_range=(189.0993162801072, 189.1000726788851), len(molecules)=0, rt_centre=403.964996338, rt_range=(398.9649963378906, 408.9649963378906)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 4198       | 190.106970931 | 403.964996338 | 3464.63549805 | M+H @ 189.099694479 | None          | None      |
#
# PrecursorBin bin_id=4294, len(features)=1, mass_centre=452.160002045, mass_range=(452.15909772519484, 452.16090636520306), len(molecules)=0, rt_centre=312.756011963, rt_range=(307.7560119628906, 317.7560119628906)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 4295       | 453.167278497 | 312.756011963 | 3198.30444336 | M+H @ 452.160002045 | None          | None      |
#
# PrecursorBin bin_id=4334, len(features)=1, mass_centre=265.143850968, mass_range=(265.1433206798233, 265.14438125522724), len(molecules)=0, rt_centre=101.503997803, rt_range=(96.50399780273438, 106.50399780273438)
# | feature_id | mass         | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 4335       | 266.15112742 | 101.503997803 | 3109.59521484 | M+H @ 265.143850968 | None          | None      |
#
# PrecursorBin bin_id=4337, len(features)=1, mass_centre=506.162710667, mass_range=(506.16169834145114, 506.16372299229386), len(molecules)=0, rt_centre=420.395996094, rt_range=(415.39599609375, 425.39599609375)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 4338       | 507.169987119 | 420.395996094 | 3106.86279297 | M+H @ 506.162710667 | None          | None      |
#
# PrecursorBin bin_id=4364, len(features)=1, mass_centre=184.02457738, mass_range=(184.02420933050416, 184.02494542881368), len(molecules)=0, rt_centre=1087.02001953, rt_range=(1082.02001953125, 1092.02001953125)
# | feature_id | mass          | rt            | intensity     | annotation         | gt_metabolite | gt_adduct |
# | 4365       | 185.031853832 | 1087.02001953 | 3053.90673828 | M+H @ 184.02457738 | None          | None      |
#
# PrecursorBin bin_id=4470, len(features)=1, mass_centre=239.157130743, mass_range=(239.1566524287178, 239.1576090572408), len(molecules)=0, rt_centre=312.756011963, rt_range=(307.7560119628906, 317.7560119628906)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 4471       | 240.164407195 | 312.756011963 | 2805.38354492 | M+H @ 239.157130743 | None          | None      |
#
# PrecursorBin bin_id=4490, len(features)=1, mass_centre=108.060991932, mass_range=(108.0607758096371, 108.06120805360483), len(molecules)=0, rt_centre=1142.18994141, rt_range=(1137.18994140625, 1147.18994140625)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 4491       | 109.068268384 | 1142.18994141 | 2760.68383789 | M+H @ 108.060991932 | None          | None      |
#
# PrecursorBin bin_id=4544, len(features)=1, mass_centre=116.058336664, mass_range=(116.05810454737589, 116.05856878072255), len(molecules)=0, rt_centre=1115.43994141, rt_range=(1110.43994140625, 1120.43994140625)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 4545       | 117.065613116 | 1115.43994141 | 2625.46655273 | M+H @ 116.058336664 | None          | None      |
#
# PrecursorBin bin_id=4564, len(features)=1, mass_centre=182.057618397, mass_range=(182.05725428186227, 182.05798251233588), len(molecules)=0, rt_centre=562.161010742, rt_range=(557.1610107421875, 567.1610107421875)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 4565       | 183.064894849 | 562.161010742 | 2580.24804688 | M+H @ 182.057618397 | None          | None      |
#
# PrecursorBin bin_id=4578, len(features)=1, mass_centre=659.282832843, mass_range=(659.281514277366, 659.2841514086973), len(molecules)=0, rt_centre=301.311004639, rt_range=(296.3110046386719, 306.3110046386719)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 4579       | 660.290109295 | 301.311004639 | 2550.27148438 | M+H @ 659.282832843 | None          | None      |
#
# PrecursorBin bin_id=4637, len(features)=1, mass_centre=285.101001282, mass_range=(285.10043107954084, 285.10157148354597), len(molecules)=0, rt_centre=708.468017578, rt_range=(703.468017578125, 713.468017578125)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 4638       | 286.108277734 | 708.468017578 | 2424.46069336 | M+H @ 285.101001282 | None          | None      |
#
# PrecursorBin bin_id=4693, len(features)=1, mass_centre=74.0249265038, mass_range=(74.0247784539752, 74.02507455368122), len(molecules)=0, rt_centre=44.9998016357, rt_range=(39.99980163574219, 49.99980163574219)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 4694       | 75.0322029558 | 44.9998016357 | 2292.69677734 | M+H @ 74.0249265038 | None          | None      |
#
# PrecursorBin bin_id=4769, len(features)=1, mass_centre=257.156797835, mass_range=(257.1562835210688, 257.15731214826013), len(molecules)=0, rt_centre=1198.04003906, rt_range=(1193.0400390625, 1203.0400390625)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 4982       | 258.164326884 | 1201.30004883 | 1360.16455078 | M+H @ 257.157050432 | None          | None      |
#
# PrecursorBin bin_id=4770, len(features)=1, mass_centre=140.524820808, mass_range=(140.52453975806318, 140.5251018573464), len(molecules)=0, rt_centre=1342.08996582, rt_range=(1337.0899658203125, 1347.0899658203125)
# | feature_id | mass         | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 4771       | 141.53209726 | 1342.08996582 | 2075.68652344 | M+H @ 140.524820808 | None          | None      |
#
# PrecursorBin bin_id=4795, len(features)=1, mass_centre=269.100794587, mass_range=(269.1002563857766, 269.10133278895495), len(molecules)=0, rt_centre=469.225006104, rt_range=(464.2250061035156, 474.2250061035156)
# | feature_id | mass          | rt            | intensity    | annotation          | gt_metabolite | gt_adduct |
# | 4796       | 270.108071039 | 469.225006104 | 2000.9921875 | M+H @ 269.100794587 | None          | None      |
#
# PrecursorBin bin_id=4956, len(features)=1, mass_centre=215.042528502, mass_range=(215.04209841731648, 215.04295858743052), len(molecules)=0, rt_centre=444.477996826, rt_range=(439.4779968261719, 449.4779968261719)
# | feature_id | mass          | rt            | intensity     | annotation          | gt_metabolite | gt_adduct |
# | 4957       | 216.049804954 | 444.477996826 | 1490.38452148 | M+H @ 215.042528502 | None          | None      |
#
# Empty bins=4761
# Occupied bins=238

# %%
# try vb
mbc = DiscreteVB(peak_data, hp)
vb = ContinuousVB(peak_data, hp)
mbc.n_iterations = 20
vb.n_iterations = 20

print mbc
mbc.run()       

print vb
vb.run()
# Out:
# DiscreteVB initialised
# Continuous Clusterer initialised - wow
# Variational Bayes for discrete mass model
# Hyperparameters alpha=100.0, mass_prec=100, mass_prior_prec=100, rt_prec=10, rt_prior_prec=100
# n_iterations = 20
# 254 peaks to be re-sampled
# Iteration 0
# Change in QZ: 47.0000000268
# Iteration 1
# Change in QZ: 13.5820041988
# Iteration 2
# Change in QZ: 1.47380234743
# Iteration 3
# Change in QZ: 2.60210859275e-05
# Iteration 4
# Change in QZ: 6.11228310882e-16
# Iteration 5
# Change in QZ: 1.39107219291e-23
# Iteration 6
# Change in QZ: 3.62496859605e-26
# Iteration 7
# Change in QZ: 3.62496831168e-26
# Iteration 8
# Change in QZ: 3.62496831168e-26
# Iteration 9
# Change in QZ: 3.62496831168e-26
# Iteration 10
# Change in QZ: 3.62496831168e-26
# Iteration 11
# Change in QZ: 3.62496831168e-26
# Iteration 12
# Change in QZ: 3.62496831168e-26
# Iteration 13
# Change in QZ: 3.62496831168e-26
# Iteration 14
# Change in QZ: 3.62496831168e-26
# Iteration 15
# Change in QZ: 3.62496831168e-26
# Iteration 16
# Change in QZ: 3.62496831168e-26
# Iteration 17
# Change in QZ: 3.62496831168e-26
# Iteration 18
# Change in QZ: 3.62496831168e-26
# Iteration 19
# Change in QZ: 3.62496831168e-26
# Variational Bayes for continuous mass model
# Hyperparameters alpha=100.0, mass_prec=100, mass_prior_prec=100, rt_prec=10, rt_prior_prec=100
# n_iterations = 20
# Running the clustering
# 254 peaks to be re-sampled
# Iteration 0
# Change in QZ: 46.9999289668
# Iteration 1
# Change in QZ: 14.6080020961
# Iteration 2
# Change in QZ: 1.16773570265
# Iteration 3
# Change in QZ: 3.35664676006e-06
# Iteration 4
# Change in QZ: 1.93955905883e-16
# Iteration 5
# Change in QZ: 1.4155196142e-16
# Iteration 6
# Change in QZ: 5.19678483274e-16
# Iteration 7
# Change in QZ: 1.41268245087e-15
# Iteration 8
# Change in QZ: 4.32498475814e-15
# Iteration 9
# Change in QZ: 1.2813458039e-14
# Iteration 10
# Change in QZ: 3.72341927854e-14
# Iteration 11
# Change in QZ: 1.11404481278e-13
# Iteration 12
# Change in QZ: 3.38258112435e-13
# Iteration 13
# Change in QZ: 1.00060820874e-12
# Iteration 14
# Change in QZ: 2.99268165947e-12
# Iteration 15
# Change in QZ: 8.93113545324e-12
# Iteration 16
# Change in QZ: 2.66050902083e-11
# Iteration 17
# Change in QZ: 7.94222683193e-11
# Iteration 18
# Change in QZ: 2.36845982912e-10
# Iteration 19
# Change in QZ: 7.0652401549e-10

# %%
# plot sparsity for VB results
I = np.identity(peak_data.num_peaks) # exclude those peaks in its own cluster
mbc_QZ = mbc.QZ.todense() - I
vb_QZ = vb.QZ.todense() - I
mbc_QZ = sp.csr_matrix(mbc_QZ)
vb_QZ = sp.csr_matrix(vb_QZ)

plt.figure()
plt.subplot(1, 2, 1)
plt.spy(mbc_QZ)
plt.title('discrete QZ')
plt.subplot(1, 2, 2)
plt.spy(vb_QZ)
plt.title('continous QZ')
plt.show()    
Q_change = (np.square(mbc_QZ-vb_QZ)).sum()
print "Discrete - continuous QZ change: " + str(Q_change)
# Out:
# Discrete - continuous QZ change: -8.50210645064e-21
