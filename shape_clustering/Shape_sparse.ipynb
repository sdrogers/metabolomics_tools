# %% [markdown]
# <p>Test the sparse version of the clusterer<p>

# %%
import numpy as np
import pylab as plt
from scipy.stats import beta
from scipy.special import gammaln
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from peak_clusterer_sparse import data_generator_sparse,hyper,shape_cluster_gibbs_sparse

# %%
h = hyper()
dg = data_generator_sparse(h,seed=1,n_peaks=100)
dg._make_data()

# %%
print dg.K
sc = shape_cluster_gibbs_sparse(dg.corr_mat,h,output = 1,infinite = False,track=True,n_samples=100,n_burn=90)
sc._initialise_clustering()
sc._sample()
sc._summary()
# Out:
#  13
# Creating likelihood matrices
# Sample 0
# Sample 10
# Sample 20
# Sample 30
# Sample 40
# Sample 50
# Sample 60
# Sample 70
# Sample 80
# Sample 90
# K = 30
# Best Log Like = 2426.51415373 (K = 28)

# %%
sc._summary()
# Out:
# K = 14
# Best Log Like = -69455.6721725 (K = 14)

# %%
dg._make_data()
plt.figure()
a = np.array(dg.corr_mat.todense())
plt.pcolor(a)

# %%
from scipy.sparse import lil_matrix
a = lil_matrix((3,3))

# %%
a[1,2] = 1
a[2,2] = 2

# %%
for (i,j) in enumerate(a):
    print i,j
# Out:
# 0
# 1   (0, 2)	1.0
# 2   (0, 2)	2.0

# %%
a = np.array([1,2,3,4])
a[[1,2]] = [3,4]

# %%
print a
# Out:
# [1 3 4 4]

# %%
print a.shape
# Out:
# (4,)

# %%
np.exp(2426-2336)
# Out:
# 1.2204032943178408e+39
