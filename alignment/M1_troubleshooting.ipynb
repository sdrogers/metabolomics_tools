# %% [markdown]
# <h1>Checking the low recall when aligning M1 data</h1>

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
import os
sys.path.insert(1, os.path.join(sys.path[0], '..'))

# %%
from discretisation.preprocessing import FileLoader
from models import HyperPars as AlignmentHyperPars
from discretisation.adduct_cluster import AdductCluster, Peak
from shared_bin_matching import SharedBinMatching as Aligner
from ground_truth import GroundTruth

# %% [markdown]
# Define input parameters

# %%
input_dir = '/home/joewandy/git/metabolomics_tools/alignment/input/M1_4'
database_file = None
transformation_file = '/home/joewandy/git/metabolomics_tools/discretisation/mulsubs/pos_transformations.yml'

# %%
hp = AlignmentHyperPars()    
hp.within_file_mass_tol = 10
hp.within_file_rt_tol = 5
hp.across_file_mass_tol = 30
hp.across_file_rt_tol = 100
hp.alpha_mass = 1.0
hp.dp_alpha = 100.0
hp.t = 0
hp.mass_clustering_n_iterations = 100
hp.rt_clustering_nsamps = 200
hp.rt_clustering_burnin = 100

print hp
# Out:
# Hyperparameters across_file_mass_tol=30, across_file_rt_tol=100, alpha_mass=1.0, beta=0.1, dp_alpha=100.0, mass_clustering_n_iterations=100, rt_clustering_burnin=100, rt_clustering_nsamps=200, t=0, within_file_mass_tol=10, within_file_rt_tol=5

# %%
loader = FileLoader()
data_list = loader.load_model_input(input_dir, database_file, 0, 0, make_bins=False)
# Out:
# 5842 features read from M1_1.txt
# 7515 features read from M1_2.txt
# 9132 features read from M1_3.txt
# 5876 features read from M1_4.txt

# %% [markdown]
# For some reasons, the cell below that does precursor clustering for each file takes **a lot** longer to run in the notebook vs. when run outside ... Not sure why??!

# %%
clustering_results = []
for peak_data in data_list:

    ac = AdductCluster(mass_tol=hp.within_file_mass_tol, rt_tol=hp.within_file_rt_tol, 
                       alpha=hp.alpha_mass, mh_biggest=True, transformation_file=transformation_file, verbose=2)

    peak_list = peak_data.features
    ac.init_from_list(peak_list)

    ac.init_vb()
    for n in range(hp.mass_clustering_n_iterations):
        print "VB step %d file %d " % (n, j)
        sys.stdout.flush()
        ac.vb_step()
        
    clustering_results.append(ac)

# %% [markdown]
# <hr/>

# %% [markdown]
# Workaround by loading results produced from outside the notebook

# %%
aligner = Aligner.resume_from('/home/joewandy/git/metabolomics_tools/alignment/input/M1_4/results.project')
# Out:
# Project loaded from /home/joewandy/git/metabolomics_tools/alignment/input/M1_4/results.project time taken = 18.5390169621

# %%
data_list = aligner.data_list
hp = aligner.hp
file_adduct_clusterers = aligner.clustering_results # list of adduct clusterer for each file
file_clusterings = aligner.file_data # dict of file idx to the list of clusters in that file

# %% [markdown]
# Find some big clusters in the first file. We have performed MAP assignment of each peak feature into its most likely cluster.

# %%
def plot_biggest(file_idx, threshold):

    ac = file_adduct_clusterers[file_idx]
    clusters_list = file_clusterings[file_idx]
    singleton_count = 0
    
    big_clusters = []
    biggest = clusters_list[0]
    for cluster in clusters_list:
        if cluster.N == 1:
            singleton_count += 1
        if cluster.N >= threshold:
            big_clusters.append(cluster)
            if cluster.N >= biggest.N:
                biggest = cluster

    print "Singleton count {}".format(singleton_count)
    print "{} big clusters found".format(len(big_clusters))
    print "Biggest has {} members".format(biggest.N)

    for c in big_clusters:
        ac.cluster_plot(c)

# %%
plot_biggest(file_idx=0, threshold=4)

# %%
plot_biggest(file_idx=1, threshold=4)

# %% [markdown]
# Print out all the aligned peaksets

# %%
aligned_peaksets = []
i = 0
for i in range(len(aligner.alignment_results)):
    peakset = aligner.alignment_results[i].peakset
    aligned_peaksets.append(peakset)

# %% [markdown]
# Load the ground truth and check the annotations

# %%
file_list = aligner.file_list
gt_file = '/home/joewandy/git/metabolomics_tools/alignment/input/M1_4/ground_truth/ground_truth.txt'
gt = GroundTruth(gt_file, file_list, data_list)
# Out:
# Loaded 1007 ground truth entries

# %%
def found_in(gt_entry, aligned_peaksets):
    for ps in aligned_peaksets:
        ps_keys = [f._get_key() for f in ps]
        for f in gt_entry:
            if f._get_key() not in ps_keys:
                all_found = False
        if all_found:
            return True
    return False

# %%
groups = gt.gt_features
not_found_list = []
found_list = []
for group in groups:
    found = found_in(group, aligned_peaksets)
    if not found: # store the not-found ground truth entries
        not_found_list.append(group)
    else:
        found_list.append(group)

# %%
print "Aligned peaksets that agree with ground truth = %d/%d" % (len(found_list), len(groups)) 
print "Aligned peaksets that disagree with ground truth = %d/%d" % (len(not_found_list), len(groups))
# Out:
# Aligned peaksets that agree with ground truth = 691/1007
# Aligned peaksets that disagree with ground truth = 316/1007

# %% [markdown]
# Print the found ones

# %%
i = 0
for group in found_list:
    print "Group %d" % i
    i += 1
    for f in group:
        key = f._get_key()
        annot = aligner.annotations[key]
        print "- id %s mass %.4f rt %.2f MAP_trans %s" % ((key, f.mass, f.rt, annot))
# Out:
# Group 0
# - id (117, 0) mass 128.9968 rt 223.98 MAP_trans M+H@127.98956(0.7973)
# - id (148, 1) mass 128.9958 rt 226.02 MAP_trans M+H@127.98884(1.0000)
# - id (229, 2) mass 128.9965 rt 223.98 MAP_trans M+H@127.98918(1.0000)
# - id (197, 3) mass 128.9964 rt 220.02 MAP_trans M+H@127.98913(0.9963)
# Group 1
# - id (142, 0) mass 116.0774 rt 222.00 MAP_trans M+H@115.07012(1.0000)
# - id (156, 1) mass 116.0773 rt 222.00 MAP_trans M+H@115.07009(1.0000)
# - id (8574, 2) mass 116.0777 rt 222.00 MAP_trans M+H@115.07039(1.0000)
# - id (88, 3) mass 116.0782 rt 220.02 MAP_trans M+H@115.07096(1.0000)
# Group 2
# - id (287, 0) mass 279.0475 rt 222.00 MAP_trans M+H@278.04028(1.0000)
# - id (1302, 1) mass 279.0507 rt 222.00 MAP_trans M+H@278.04348(1.0000)
# - id (1413, 2) mass 279.0473 rt 222.00 MAP_trans M+H@278.04023(1.0000)
# - id (300, 3) mass 279.0507 rt 220.02 MAP_trans M+H@278.04302(1.0000)
# Group 3
# - id (303, 0) mass 200.0499 rt 223.98 MAP_trans M+H@199.04277(1.0000)
# - id (257, 1) mass 200.0500 rt 226.02 MAP_trans M+H@199.04328(1.0000)
# - id (259, 2) mass 200.0498 rt 226.02 MAP_trans M+H@199.04270(1.0000)
# - id (253, 3) mass 200.0505 rt 223.98 MAP_trans M+H@199.04329(1.0000)
# Group 4
# - id (317, 0) mass 202.1858 rt 220.02 MAP_trans M+H@201.17851(1.0000)
# - id (717, 1) mass 202.1850 rt 220.02 MAP_trans M+H@201.17776(1.0000)
# - id (364, 2) mass 202.1845 rt 220.02 MAP_trans M+H@201.17727(1.0000)
# - id (325, 3) mass 202.1849 rt 220.02 MAP_trans M+H@201.17767(1.0000)
# Group 5
# - id (329, 0) mass 214.0407 rt 226.02 MAP_trans M+H@213.03342(0.9999)
# - id (901, 1) mass 214.0430 rt 228.00 MAP_trans M+H@213.03568(1.0000)
# - id (752, 2) mass 214.0421 rt 226.02 MAP_trans M+H@213.03482(0.9863)
# - id (317, 3) mass 214.0420 rt 223.98 MAP_trans M+H@213.03472(0.9889)
# Group 6
# - id (330, 0) mass 207.5549 rt 226.02 MAP_trans M+H@206.54758(1.0000)
# - id (766, 1) mass 207.5568 rt 228.00 MAP_trans M+H@206.54949(1.0000)
# - id (683, 2) mass 207.5569 rt 226.02 MAP_trans M+H@206.54988(1.0000)
# - id (385, 3) mass 207.5525 rt 223.98 MAP_trans M+H@206.54516(1.0000)
# Group 7
# - id (334, 0) mass 215.5415 rt 226.02 MAP_trans M+H@214.53418(1.0000)
# - id (916, 1) mass 215.5398 rt 228.00 MAP_trans M+H@214.53252(1.0000)
# - id (1040, 2) mass 215.5406 rt 228.00 MAP_trans M+H@214.53338(1.0000)
# - id (286, 3) mass 215.5459 rt 223.98 MAP_trans M+H@214.53866(1.0000)
# - id (334, 0) mass 215.5415 rt 226.02 MAP_trans M+H@214.53418(1.0000)
# Group 8
# - id (351, 0) mass 215.0367 rt 226.02 MAP_trans M+H@214.02946(1.0000)
# - id (643, 1) mass 215.0359 rt 228.00 MAP_trans M+H@214.02857(1.0000)
# - id (792, 2) mass 215.0358 rt 228.00 MAP_trans M+H@214.02849(1.0000)
# - id (427, 3) mass 215.0363 rt 223.98 MAP_trans M+H@214.02902(1.0000)
# Group 9
# - id (354, 0) mass 222.0466 rt 226.02 MAP_trans M+H@221.03929(1.0000)
# - id (998, 1) mass 222.0474 rt 228.00 MAP_trans M+H@221.04008(1.0000)
# - id (1155, 2) mass 222.0476 rt 228.00 MAP_trans M+H@221.04029(1.0000)
# - id (301, 3) mass 222.0473 rt 226.02 MAP_trans M+H@221.04006(1.0000)
# Group 10
# - id (376, 0) mass 233.0388 rt 222.00 MAP_trans M+H@232.03151(1.0000)
# - id (921, 1) mass 233.0385 rt 220.02 MAP_trans M+H@232.03120(1.0000)
# - id (1200, 2) mass 233.0402 rt 220.02 MAP_trans M+H@232.03289(1.0000)
# - id (573, 3) mass 233.0415 rt 217.98 MAP_trans M+H@232.03424(1.0000)
# Group 11
# - id (381, 0) mass 222.5483 rt 226.02 MAP_trans M+H@221.54102(1.0000)
# - id (945, 1) mass 222.5492 rt 228.00 MAP_trans M+H@221.54228(1.0000)
# - id (855, 2) mass 222.5495 rt 228.00 MAP_trans M+H@221.54227(1.0000)
# - id (357, 3) mass 222.5476 rt 226.02 MAP_trans M+H@221.54028(1.0000)
# Group 12
# - id (409, 0) mass 281.0762 rt 226.02 MAP_trans M+H@280.06892(1.0000)
# - id (508, 1) mass 281.0780 rt 226.02 MAP_trans M+H@280.07059(1.0000)
# - id (971, 2) mass 281.0787 rt 228.00 MAP_trans M+H@280.07155(1.0000)
# - id (379, 3) mass 281.0769 rt 223.98 MAP_trans M+H@280.06963(1.0000)
# Group 13
# - id (419, 0) mass 235.5439 rt 228.00 MAP_trans M+H@234.53662(1.0000)
# - id (1078, 1) mass 235.5427 rt 228.00 MAP_trans M+H@234.53547(1.0000)
# - id (942, 2) mass 235.5405 rt 228.00 MAP_trans M+H@234.53319(1.0000)
# - id (392, 3) mass 235.5380 rt 226.02 MAP_trans M+H@234.53075(0.9795)
# Group 14
# - id (431, 0) mass 213.5428 rt 226.02 MAP_trans M+H@212.53556(1.0000)
# - id (619, 1) mass 213.5435 rt 228.00 MAP_trans M+H@212.53620(1.0000)
# - id (937, 2) mass 213.5431 rt 228.00 MAP_trans M+H@212.53576(1.0000)
# - id (420, 3) mass 213.5421 rt 223.98 MAP_trans M+H@212.53508(1.0000)
# Group 15
# - id (436, 0) mass 211.0245 rt 223.98 MAP_trans M+H@210.01737(1.0000)
# - id (851, 1) mass 211.0239 rt 223.98 MAP_trans M+H@210.01660(1.0000)
# - id (995, 2) mass 211.0257 rt 223.98 MAP_trans M+H@210.01841(1.0000)
# - id (304, 3) mass 211.0248 rt 222.00 MAP_trans M+H@210.01746(1.0000)
# Group 16
# - id (443, 0) mass 235.0380 rt 226.02 MAP_trans M+H@234.03070(1.0000)
# - id (1027, 1) mass 235.0387 rt 228.00 MAP_trans M+H@234.03146(1.0000)
# - id (1229, 2) mass 235.0385 rt 228.00 MAP_trans M+H@234.03122(1.0000)
# - id (439, 3) mass 235.0378 rt 223.98 MAP_trans M+H@234.03054(0.8021)
# Group 17
# - id (453, 0) mass 220.0420 rt 223.98 MAP_trans M+H@219.03385(0.9994)
# - id (620, 1) mass 220.0419 rt 223.98 MAP_trans M+H@219.03499(0.9951)
# - id (865, 2) mass 220.0432 rt 223.98 MAP_trans M+H@219.03575(0.9983)
# - id (395, 3) mass 220.0424 rt 222.00 MAP_trans M+H@219.03515(1.0000)
# Group 18
# - id (474, 0) mass 221.0322 rt 220.02 MAP_trans M+H@220.02496(0.9500)
# - id (954, 1) mass 221.0319 rt 222.00 MAP_trans M+H@220.02466(1.0000)
# - id (1028, 2) mass 221.0352 rt 220.02 MAP_trans M+H@220.02790(1.0000)
# - id (437, 3) mass 221.0324 rt 220.02 MAP_trans M+H@220.02513(1.0000)
# Group 19
# - id (494, 0) mass 247.0436 rt 223.98 MAP_trans M+H@246.03604(1.0000)
# - id (1137, 1) mass 247.0432 rt 226.02 MAP_trans M+H@246.03578(1.0000)
# - id (1356, 2) mass 247.0441 rt 226.02 MAP_trans M+H@246.03684(1.0000)
# - id (590, 3) mass 247.0429 rt 222.00 MAP_trans M+H@246.03571(1.0000)
# Group 20
# - id (504, 0) mass 263.0306 rt 220.02 MAP_trans M+H@262.02330(1.0000)
# - id (1398, 1) mass 263.0306 rt 222.00 MAP_trans M+H@262.02395(1.0000)
# - id (1431, 2) mass 263.0314 rt 220.02 MAP_trans M+H@262.02424(1.0000)
# - id (521, 3) mass 263.0322 rt 220.02 MAP_trans M+H@262.02517(1.0000)
# Group 21
# - id (505, 0) mass 230.9966 rt 223.98 MAP_trans M+H@229.98936(1.0000)
# - id (1171, 1) mass 230.9953 rt 228.00 MAP_trans M+H@229.98789(1.0000)
# - id (1047, 2) mass 230.9950 rt 228.00 MAP_trans M+H@229.98768(1.0000)
# - id (443, 3) mass 231.0010 rt 222.00 MAP_trans M+H@229.99416(0.9227)
# Group 22
# - id (571, 0) mass 244.0485 rt 228.00 MAP_trans M+H@243.04118(1.0000)
# - id (1311, 1) mass 244.0491 rt 229.98 MAP_trans M+H@243.04154(1.0000)
# - id (980, 2) mass 244.0497 rt 228.00 MAP_trans M+H@243.04234(1.0000)
# - id (608, 3) mass 244.0513 rt 228.00 MAP_trans M+H@243.04399(1.0000)
# Group 23
# - id (605, 0) mass 281.5834 rt 226.02 MAP_trans M+H@280.57610(1.0000)
# - id (1262, 1) mass 281.5830 rt 228.00 MAP_trans M+H@280.57598(1.0000)
# - id (1579, 2) mass 281.5837 rt 228.00 MAP_trans M+H@280.57642(1.0000)
# - id (771, 3) mass 281.5842 rt 223.98 MAP_trans M+H@280.57619(1.0000)
# Group 24
# - id (606, 0) mass 267.0226 rt 222.00 MAP_trans M+H@266.01586(1.0000)
# - id (1381, 1) mass 267.0238 rt 223.98 MAP_trans M+H@266.01679(1.0000)
# - id (1433, 2) mass 267.0213 rt 223.98 MAP_trans M+H@266.01377(1.0000)
# - id (659, 3) mass 267.0225 rt 220.02 MAP_trans M+H@266.01525(1.0000)
# Group 25
# - id (645, 0) mass 335.0444 rt 222.00 MAP_trans M+H@334.03718(1.0000)
# - id (1914, 1) mass 335.0495 rt 223.98 MAP_trans M+H@334.04232(1.0000)
# - id (1196, 2) mass 335.0469 rt 222.00 MAP_trans M+H@334.03966(1.0000)
# - id (754, 3) mass 335.0423 rt 220.02 MAP_trans M+H@334.03494(1.0000)
# Group 26
# - id (680, 0) mass 288.0823 rt 228.00 MAP_trans M+H@287.07498(1.0000)
# - id (1538, 1) mass 288.0803 rt 226.02 MAP_trans M+H@287.07302(1.0000)
# - id (1745, 2) mass 288.0780 rt 226.02 MAP_trans M+H@287.07054(1.0000)
# - id (465, 3) mass 288.0742 rt 223.98 MAP_trans M+H@287.06712(0.8621)
# Group 27
# - id (690, 0) mass 290.0844 rt 226.02 MAP_trans M+H@289.07713(1.0000)
# - id (1739, 1) mass 290.0839 rt 226.02 MAP_trans M+H@289.07674(1.0000)
# - id (1444, 2) mass 290.0818 rt 226.02 MAP_trans M+H@289.07442(1.0000)
# - id (713, 3) mass 290.0857 rt 222.00 MAP_trans M+H@289.07848(0.9973)
# Group 28
# - id (734, 0) mass 303.5797 rt 228.00 MAP_trans M+H@302.57239(1.0000)
# - id (1820, 1) mass 303.5804 rt 228.00 MAP_trans M+H@302.57288(1.0000)
# - id (1750, 2) mass 303.5802 rt 228.00 MAP_trans M+H@302.57277(1.0000)
# - id (657, 3) mass 303.5789 rt 226.02 MAP_trans M+H@302.57160(1.0000)
# Group 29
# - id (743, 0) mass 287.0604 rt 228.00 MAP_trans M+H@286.05309(1.0000)
# - id (1851, 1) mass 287.0642 rt 229.98 MAP_trans M+H@286.05663(1.0000)
# - id (2038, 2) mass 287.0678 rt 228.00 MAP_trans M+H@286.06052(1.0000)
# - id (693, 3) mass 287.0674 rt 226.02 MAP_trans M+H@286.05990(1.0000)
# Group 30
# - id (745, 0) mass 425.0669 rt 223.98 MAP_trans M+H@424.05952(1.0000)
# - id (2014, 1) mass 425.0687 rt 226.02 MAP_trans M+H@424.06127(1.0000)
# - id (2069, 2) mass 425.0650 rt 226.02 MAP_trans M+H@424.05767(1.0000)
# - id (821, 3) mass 425.0660 rt 222.00 MAP_trans M+H@424.05779(1.0000)
# Group 31
# - id (760, 0) mass 445.0840 rt 220.02 MAP_trans M+H@444.07675(1.0000)
# - id (737, 1) mass 445.0856 rt 223.98 MAP_trans M+H@444.07837(1.0000)
# - id (2419, 2) mass 445.0821 rt 222.00 MAP_trans M+H@444.07572(1.0000)
# - id (1013, 3) mass 445.0860 rt 220.02 MAP_trans M+H@444.07896(1.0000)
# Group 32
# - id (765, 0) mass 303.0764 rt 228.00 MAP_trans M+H@302.06849(1.0000)
# - id (1359, 1) mass 303.0773 rt 228.00 MAP_trans M+H@302.06943(1.0000)
# - id (1534, 2) mass 303.0760 rt 228.00 MAP_trans M+H@302.06870(1.0000)
# - id (716, 3) mass 303.0749 rt 226.02 MAP_trans M+H@302.06768(1.0000)
# Group 33
# - id (800, 0) mass 312.0790 rt 228.00 MAP_trans M+H@311.07213(1.0000)
# - id (2011, 1) mass 312.0821 rt 228.00 MAP_trans M+H@311.07507(1.0000)
# - id (1832, 2) mass 312.0815 rt 228.00 MAP_trans M+H@311.07359(1.0000)
# - id (731, 3) mass 312.0778 rt 223.98 MAP_trans M+H@311.07040(1.0000)
# Group 34
# - id (801, 0) mass 334.0776 rt 228.00 MAP_trans M+H@333.07119(1.0000)
# - id (1887, 1) mass 334.0780 rt 228.00 MAP_trans M+H@333.07062(1.0000)
# - id (1862, 2) mass 334.0799 rt 228.00 MAP_trans M+H@333.07158(1.0000)
# - id (895, 3) mass 334.0782 rt 226.02 MAP_trans M+H@333.07104(1.0000)
# Group 35
# - id (810, 0) mass 349.0396 rt 222.00 MAP_trans M+H@348.03173(1.0000)
# - id (1619, 1) mass 349.0444 rt 223.98 MAP_trans M+H@348.03713(1.0000)
# - id (1978, 2) mass 349.0429 rt 222.00 MAP_trans M+H@348.03596(1.0000)
# - id (766, 3) mass 349.0354 rt 220.02 MAP_trans M+H@348.02814(1.0000)
# Group 36
# - id (844, 0) mass 395.0603 rt 222.00 MAP_trans M+H@394.05309(1.0000)
# - id (1962, 1) mass 395.0554 rt 223.98 MAP_trans M+H@394.04819(1.0000)
# - id (1990, 2) mass 395.0594 rt 223.98 MAP_trans M+H@394.05089(1.0000)
# - id (715, 3) mass 395.0571 rt 222.00 MAP_trans M+H@394.04986(1.0000)
# Group 37
# - id (853, 0) mass 337.0592 rt 222.00 MAP_trans M+H@336.05193(1.0000)
# - id (1938, 1) mass 337.0633 rt 222.00 MAP_trans M+H@336.05627(1.0000)
# - id (1865, 2) mass 337.0623 rt 222.00 MAP_trans M+H@336.05488(1.0000)
# - id (757, 3) mass 337.0630 rt 222.00 MAP_trans M+H@336.05573(1.0000)
# Group 38
# - id (897, 0) mass 296.0732 rt 228.00 MAP_trans M+H@295.06594(1.0000)
# - id (1418, 1) mass 296.0651 rt 226.02 MAP_trans M+H@295.05783(1.0000)
# - id (1494, 2) mass 296.0697 rt 228.00 MAP_trans M+H@295.06241(1.0000)
# - id (614, 3) mass 296.0643 rt 223.98 MAP_trans M+H@295.05696(1.0000)
# Group 39
# - id (1178, 0) mass 399.0885 rt 222.00 MAP_trans M+H@398.08112(1.0000)
# - id (2646, 1) mass 399.0942 rt 223.98 MAP_trans M+H@398.08678(1.0000)
# - id (1211, 2) mass 399.0968 rt 223.98 MAP_trans M+H@398.08993(1.0000)
# - id (1215, 3) mass 399.0977 rt 220.02 MAP_trans M+H@398.09046(1.0000)
# Group 40
# - id (923, 0) mass 361.5288 rt 220.02 MAP_trans M+H@360.52152(1.0000)
# Group 41
# - id (105, 0) mass 105.1121 rt 216.00 MAP_trans M+H@104.10481(1.0000)
# - id (104, 1) mass 105.1118 rt 216.00 MAP_trans M+H@104.10453(1.0000)
# - id (148, 2) mass 105.1122 rt 214.02 MAP_trans M+H@104.10491(1.0000)
# - id (115, 3) mass 105.1120 rt 216.00 MAP_trans M+H@104.10471(1.0000)
# Group 42
# - id (331, 0) mass 203.0508 rt 216.00 MAP_trans M+H@202.04349(1.0000)
# - id (307, 1) mass 203.0540 rt 211.98 MAP_trans M+H@202.04670(1.0000)
# - id (277, 2) mass 203.0541 rt 210.00 MAP_trans M+H@202.04683(1.0000)
# - id (403, 3) mass 203.0511 rt 214.02 MAP_trans M+H@202.04381(1.0000)
# Group 43
# - id (394, 0) mass 219.0328 rt 216.00 MAP_trans M+H@218.02548(1.0000)
# - id (965, 1) mass 219.0327 rt 214.02 MAP_trans M+H@218.02545(1.0000)
# - id (957, 2) mass 219.0324 rt 214.02 MAP_trans M+H@218.02510(1.0000)
# - id (434, 3) mass 219.0328 rt 216.00 MAP_trans M+H@218.02554(1.0000)
# Group 44
# - id (751, 0) mass 300.0382 rt 216.00 MAP_trans M+H@299.03097(1.0000)
# - id (1623, 1) mass 300.0385 rt 211.98 MAP_trans M+H@299.03112(1.0000)
# - id (1603, 2) mass 300.0372 rt 211.98 MAP_trans M+H@299.02940(1.0000)
# - id (817, 3) mass 300.0374 rt 214.02 MAP_trans M+H@299.03008(1.0000)
# Group 45
# - id (812, 0) mass 513.9890 rt 216.00 MAP_trans M+H@512.98169(1.0000)
# - id (1862, 1) mass 513.9871 rt 214.02 MAP_trans M+H@512.97980(1.0000)
# - id (2025, 2) mass 513.9908 rt 214.02 MAP_trans M+H@512.98241(1.0000)
# - id (803, 3) mass 513.9846 rt 214.02 MAP_trans M+H@512.97734(1.0000)
# Group 46
# - id (987, 0) mass 382.0782 rt 216.00 MAP_trans M+H@381.07093(1.0000)
# - id (1895, 1) mass 382.0742 rt 211.98 MAP_trans M+H@381.06696(1.0000)
# - id (2400, 2) mass 382.0783 rt 214.02 MAP_trans M+H@381.07098(1.0000)
# - id (987, 0) mass 382.0782 rt 216.00 MAP_trans M+H@381.07093(1.0000)
# Group 47
# - id (902, 0) mass 334.5725 rt 229.98 MAP_trans M+H@333.56519(1.0000)
# - id (2068, 1) mass 334.5785 rt 228.00 MAP_trans M+H@333.57136(1.0000)
# - id (1992, 2) mass 334.5768 rt 228.00 MAP_trans M+H@333.56950(1.0000)
# - id (683, 3) mass 334.5737 rt 226.02 MAP_trans M+H@333.56654(1.0000)
# Group 48
# - id (5490, 0) mass 104.1032 rt 217.98 MAP_trans M+H@103.09595(1.0000)
# - id (7090, 1) mass 104.1029 rt 216.00 MAP_trans M+H@103.09563(1.0000)
# - id (8571, 2) mass 104.1029 rt 214.02 MAP_trans M+H@103.09558(1.0000)
# - id (5529, 3) mass 104.1035 rt 216.00 MAP_trans M+H@103.09625(1.0000)
# Group 49
# - id (183, 0) mass 139.9169 rt 214.02 MAP_trans M+H@138.90959(1.0000)
# - id (284, 1) mass 139.9192 rt 211.98 MAP_trans M+H@138.91190(1.0000)
# - id (281, 2) mass 139.9199 rt 211.98 MAP_trans M+H@138.91265(1.0000)
# - id (182, 3) mass 139.9189 rt 211.98 MAP_trans M+H@138.91165(1.0000)
# Group 50
# - id (260, 0) mass 381.0801 rt 214.02 MAP_trans M+H@380.07284(1.0000)
# - id (409, 1) mass 381.0813 rt 210.00 MAP_trans M+H@380.07401(1.0000)
# - id (2140, 2) mass 381.0825 rt 210.00 MAP_trans M+H@380.07525(1.0000)
# - id (227, 3) mass 381.0821 rt 214.02 MAP_trans M+H@380.07482(1.0000)
# Group 51
# - id (5487, 0) mass 101.9528 rt 214.02 MAP_trans M+H@100.94557(1.0000)
# - id (98, 1) mass 101.9540 rt 210.00 MAP_trans M+H@100.94670(1.0000)
# - id (8563, 2) mass 101.9539 rt 210.00 MAP_trans M+H@100.94659(1.0000)
# - id (26, 3) mass 101.9533 rt 211.98 MAP_trans M+H@100.94603(1.0000)
# Group 52
# - id (956, 0) mass 366.0690 rt 216.00 MAP_trans [M-H2O]+H [C13]@382.06761(0.9997)
# - id (2147, 1) mass 366.0759 rt 210.00 MAP_trans [M-H2O]+H [C13]@382.07481(0.9999)
# - id (826, 3) mass 366.0740 rt 214.02 MAP_trans [M-H2O]+H [C13]@382.07243(0.9999)
# Group 53
# - id (91, 0) mass 133.9881 rt 198.00 MAP_trans M+H@132.98104(1.0000)
# - id (70, 3) mass 133.9887 rt 196.02 MAP_trans M+H@132.98139(1.0000)
# Group 54
# - id (163, 0) mass 137.5115 rt 196.02 MAP_trans M+H@136.50426(1.0000)
# - id (100, 3) mass 137.5102 rt 196.02 MAP_trans M+H@136.50290(1.0000)
# Group 55
# - id (166, 0) mass 175.0405 rt 192.00 MAP_trans M+H@174.03327(1.0000)
# - id (124, 3) mass 175.0450 rt 192.00 MAP_trans M+H@174.03773(1.0000)
# Group 56
# - id (181, 0) mass 141.9759 rt 198.00 MAP_trans M+H@140.96851(1.0000)
# - id (155, 3) mass 141.9773 rt 196.02 MAP_trans M+H@140.97007(1.0000)
# Group 57
# - id (197, 0) mass 145.4923 rt 198.00 MAP_trans M+H@144.48504(1.0000)
# - id (156, 3) mass 145.4984 rt 196.02 MAP_trans M+H@144.49112(1.0000)
# Group 58
# - id (289, 0) mass 247.1134 rt 192.00 MAP_trans M+H@246.10608(1.0000)
# - id (187, 3) mass 247.1138 rt 190.02 MAP_trans M+H@246.10652(1.0000)
# Group 59
# - id (301, 0) mass 256.9100 rt 196.02 MAP_trans M+H@255.90271(1.0000)
# - id (314, 3) mass 256.9115 rt 193.98 MAP_trans M+H@255.90422(1.0000)
# Group 60
# - id (309, 0) mass 258.9414 rt 196.02 MAP_trans M+H@257.93410(1.0000)
# - id (247, 3) mass 258.9390 rt 193.98 MAP_trans M+H@257.93175(1.0000)
# Group 61
# - id (359, 0) mass 380.8943 rt 192.00 MAP_trans M+H@379.88702(0.9449)
# - id (445, 3) mass 380.8907 rt 190.02 MAP_trans M+H@379.88320(1.0000)
# Group 62
# - id (572, 0) mass 388.8893 rt 193.98 MAP_trans M+H@387.88204(1.0000)
# - id (460, 3) mass 388.8933 rt 193.98 MAP_trans M+H@387.88607(1.0000)
# Group 63
# - id (161, 0) mass 232.9382 rt 190.02 MAP_trans M+H@231.93090(1.0000)
# - id (195, 1) mass 232.9398 rt 187.98 MAP_trans M+H@231.93259(1.0000)
# - id (137, 2) mass 232.9401 rt 187.98 MAP_trans M+H@231.93238(1.0000)
# - id (130, 3) mass 232.9392 rt 190.02 MAP_trans M+H@231.93193(1.0000)
# Group 64
# - id (174, 0) mass 198.9438 rt 187.98 MAP_trans M+H@197.93650(1.0000)
# - id (247, 1) mass 198.9453 rt 187.98 MAP_trans M+H@197.93803(1.0000)
# - id (182, 2) mass 198.9476 rt 187.98 MAP_trans M+H@197.94029(1.0000)
# - id (138, 3) mass 198.9409 rt 187.98 MAP_trans M+H@197.93361(1.0000)
# Group 65
# - id (5475, 0) mass 234.9705 rt 190.02 MAP_trans M+H@233.96285(1.0000)
# - id (7063, 1) mass 234.9708 rt 187.98 MAP_trans M+H@233.96325(1.0000)
# - id (8544, 2) mass 234.9705 rt 187.98 MAP_trans M+H@233.96304(1.0000)
# - id (5521, 3) mass 234.9690 rt 187.98 MAP_trans M+H@233.96190(1.0000)
# Group 66
# - id (275, 0) mass 284.9485 rt 196.02 MAP_trans M+H@283.94124(1.0000)
# - id (461, 1) mass 284.9490 rt 187.98 MAP_trans M+H@283.94174(1.0000)
# - id (493, 2) mass 284.9446 rt 190.02 MAP_trans M+H@283.93735(1.0000)
# - id (248, 3) mass 284.9508 rt 192.00 MAP_trans M+H@283.94352(1.0000)
# Group 67
# - id (358, 0) mass 286.9511 rt 196.02 MAP_trans M+H@285.94384(1.0000)
# - id (429, 1) mass 286.9579 rt 193.98 MAP_trans M+H@285.95056(1.0000)
# - id (495, 2) mass 286.9516 rt 192.00 MAP_trans M+H@285.94427(1.0000)
# - id (389, 3) mass 286.9492 rt 196.02 MAP_trans M+H@285.94195(1.0000)
# Group 68
# - id (485, 0) mass 366.8999 rt 193.98 MAP_trans M+H@365.89264(1.0000)
# - id (517, 1) mass 366.9003 rt 186.00 MAP_trans M+H@365.89302(1.0000)
# - id (313, 2) mass 366.8904 rt 181.98 MAP_trans M+H@365.88311(1.0000)
# Group 69
# - id (188, 0) mass 219.9831 rt 193.98 MAP_trans M+H@218.97579(0.9347)
# - id (252, 1) mass 219.9844 rt 190.02 MAP_trans M+H@218.97750(0.9935)
# - id (291, 2) mass 219.9904 rt 190.02 MAP_trans M+H@218.98308(1.0000)
# - id (173, 3) mass 219.9854 rt 190.02 MAP_trans M+H@218.97812(1.0000)
# Group 70
# - id (247, 0) mass 250.9548 rt 190.02 MAP_trans M+H@249.94706(1.0000)
# - id (343, 1) mass 250.9542 rt 187.98 MAP_trans M+H@249.94717(1.0000)
# - id (335, 2) mass 250.9528 rt 187.98 MAP_trans M+H@249.94548(1.0000)
# - id (234, 3) mass 250.9539 rt 187.98 MAP_trans M+H@249.94667(1.0000)
# Group 71
# - id (156, 0) mass 218.9793 rt 190.02 MAP_trans M+H@217.97200(1.0000)
# - id (288, 1) mass 218.9789 rt 190.02 MAP_trans M+H@217.97159(1.0000)
# - id (279, 2) mass 218.9786 rt 190.02 MAP_trans M+H@217.97133(1.0000)
# - id (144, 3) mass 218.9846 rt 190.02 MAP_trans M+H@217.97766(1.0000)
# Group 72
# - id (475, 0) mass 361.1567 rt 190.02 MAP_trans M+H@360.14942(1.0000)
# - id (670, 1) mass 361.1569 rt 190.02 MAP_trans M+H@360.14943(1.0000)
# - id (710, 2) mass 361.1545 rt 190.02 MAP_trans M+H@360.14718(1.0000)
# Group 73
# - id (109, 0) mass 129.0274 rt 192.00 MAP_trans M+H [C13]@127.01733(0.8355)
# Group 74
# - id (756, 0) mass 434.3936 rt 196.02 MAP_trans M+H@433.38636(1.0000)
# - id (943, 1) mass 434.3846 rt 187.98 MAP_trans M+H@433.37732(0.7523)
# - id (777, 2) mass 434.3886 rt 190.02 MAP_trans M+H@433.38136(1.0000)
# Group 75
# - id (37, 0) mass 86.0978 rt 271.98 MAP_trans M+H@85.09048(1.0000)
# - id (46, 1) mass 86.0956 rt 271.98 MAP_trans M+H@85.08837(1.0000)
# - id (63, 2) mass 86.0957 rt 271.98 MAP_trans M+H@85.08845(1.0000)
# - id (181, 3) mass 86.0976 rt 271.98 MAP_trans M+H@85.09036(1.0000)
# Group 76
# - id (1120, 0) mass 268.1176 rt 271.98 MAP_trans M+H@267.11003(1.0000)
# - id (2461, 1) mass 268.1161 rt 271.98 MAP_trans M+H@267.10890(1.0000)
# - id (2689, 2) mass 268.1152 rt 270.00 MAP_trans M+H@267.10838(1.0000)
# - id (1019, 3) mass 268.1178 rt 270.00 MAP_trans M+H@267.11026(1.0000)
# Group 77
# - id (128, 0) mass 114.8948 rt 210.00 MAP_trans M+H@113.88750(1.0000)
# - id (126, 1) mass 114.8980 rt 208.02 MAP_trans M+H@113.89068(1.0000)
# - id (188, 2) mass 114.8972 rt 208.02 MAP_trans M+H@113.88988(1.0000)
# - id (75, 3) mass 114.8998 rt 210.00 MAP_trans M+H@113.89255(1.0000)
# Group 78
# - id (1184, 0) mass 166.0907 rt 342.00 MAP_trans M+H@165.08341(1.0000)
# - id (2600, 1) mass 166.0903 rt 343.98 MAP_trans M+H@165.08298(1.0000)
# - id (2840, 2) mass 166.0896 rt 339.96 MAP_trans M+H@165.08244(1.0000)
# - id (1113, 3) mass 166.0909 rt 339.96 MAP_trans M+H@165.08364(1.0000)
# Group 79
# - id (1428, 0) mass 193.0532 rt 840.00 MAP_trans M+H@192.04589(1.0000)
# - id (2848, 1) mass 193.0554 rt 837.96 MAP_trans M+H@192.04811(1.0000)
# - id (8699, 2) mass 193.0560 rt 837.96 MAP_trans M+H@192.04872(1.0000)
# - id (1367, 3) mass 193.0566 rt 837.96 MAP_trans M+H@192.04928(1.0000)
# Group 80
# - id (1473, 0) mass 277.1775 rt 895.98 MAP_trans M+H@276.16964(1.0000)
# - id (2890, 1) mass 277.1778 rt 894.00 MAP_trans M+H@276.17033(1.0000)
# - id (3277, 2) mass 277.1721 rt 895.98 MAP_trans M+H@276.16487(1.0000)
# - id (1401, 3) mass 277.1787 rt 895.98 MAP_trans M+H@276.17144(1.0000)
# Group 81
# - id (1461, 0) mass 260.2125 rt 865.98 MAP_trans M+H@259.20523(1.0000)
# - id (3228, 2) mass 260.2121 rt 865.98 MAP_trans M+H@259.20477(1.0000)
# Group 82
# - id (1462, 0) mass 164.0243 rt 929.94 MAP_trans M+H@163.01734(1.0000)
# - id (2881, 1) mass 164.0239 rt 929.94 MAP_trans M+H@163.01661(1.0000)
# - id (3258, 2) mass 164.0250 rt 927.96 MAP_trans M+H@163.01753(1.0000)
# - id (1400, 3) mass 164.0249 rt 929.94 MAP_trans M+H@163.01724(1.0000)
# Group 83
# - id (1496, 0) mass 247.9795 rt 931.98 MAP_trans M+H@246.97223(1.0000)
# - id (2901, 1) mass 247.9775 rt 929.94 MAP_trans M+H@246.97020(1.0000)
# - id (3366, 2) mass 247.9852 rt 927.96 MAP_trans M+H@246.97784(0.6655)
# - id (1436, 3) mass 247.9806 rt 927.96 MAP_trans M+H@246.97329(1.0000)
# Group 84
# - id (1544, 0) mass 98.0631 rt 1151.94 MAP_trans M+H@97.05587(1.0000)
# - id (2974, 1) mass 98.0643 rt 1151.94 MAP_trans M+H@97.05700(1.0000)
# - id (3765, 2) mass 98.0631 rt 1151.94 MAP_trans M+H@97.05578(1.0000)
# - id (1561, 3) mass 98.0637 rt 1151.94 MAP_trans M+H@97.05658(1.0000)
# Group 85
# - id (1693, 0) mass 115.0433 rt 1151.94 MAP_trans M+H@114.03607(1.0000)
# - id (3161, 1) mass 115.0436 rt 1151.94 MAP_trans M+H@114.03634(1.0000)
# - id (3891, 2) mass 115.0433 rt 1151.94 MAP_trans M+H@114.03600(1.0000)
# - id (1690, 3) mass 115.0438 rt 1151.94 MAP_trans M+H@114.03650(1.0000)
# Group 86
# - id (1717, 0) mass 116.0393 rt 1151.94 MAP_trans M+H@115.03203(1.0000)
# - id (3194, 1) mass 116.0402 rt 1151.94 MAP_trans M+H@115.03297(1.0000)
# - id (3813, 2) mass 116.0382 rt 1151.94 MAP_trans M+H@115.03084(1.0000)
# - id (1698, 3) mass 116.0387 rt 1151.94 MAP_trans M+H@115.03145(1.0000)
# Group 87
# - id (1739, 0) mass 119.0618 rt 1151.94 MAP_trans M+H@118.05452(1.0000)
# - id (3241, 1) mass 119.0605 rt 1151.94 MAP_trans M+H@118.05324(1.0000)
# - id (3930, 2) mass 119.0599 rt 1151.94 MAP_trans M+H@118.05233(1.0000)
# - id (1755, 3) mass 119.0607 rt 1151.94 MAP_trans M+H@118.05344(1.0000)
# Group 88
# - id (1744, 0) mass 114.0380 rt 1151.94 MAP_trans M+H@113.03074(1.0000)
# - id (3092, 1) mass 114.0382 rt 1151.94 MAP_trans M+H@113.03093(1.0000)
# - id (3876, 2) mass 114.0370 rt 1151.94 MAP_trans M+H@113.02968(1.0000)
# - id (1617, 3) mass 114.0384 rt 1151.94 MAP_trans M+H@113.03108(1.0000)
# Group 89
# - id (1869, 0) mass 178.0359 rt 1151.94 MAP_trans M+H@177.02895(1.0000)
# - id (3283, 1) mass 178.0359 rt 1151.94 MAP_trans M+H@177.02875(1.0000)
# - id (4079, 2) mass 178.0341 rt 1151.94 MAP_trans M+H@177.02680(1.0000)
# - id (1571, 3) mass 178.0358 rt 1151.94 MAP_trans M+H@177.02851(1.0000)
# Group 90
# - id (1880, 0) mass 189.0279 rt 1151.94 MAP_trans M+H@188.02065(1.0000)
# - id (3421, 1) mass 189.0275 rt 1151.94 MAP_trans M+H@188.02020(1.0000)
# - id (4187, 2) mass 189.0286 rt 1151.94 MAP_trans M+H@188.02129(1.0000)
# - id (1875, 3) mass 189.0271 rt 1151.94 MAP_trans M+H@188.01987(1.0000)
# Group 91
# - id (1885, 0) mass 201.0249 rt 1151.94 MAP_trans M+H@200.01760(1.0000)
# - id (3363, 1) mass 201.0251 rt 1151.94 MAP_trans M+H@200.01783(1.0000)
# - id (4116, 2) mass 201.0245 rt 1151.94 MAP_trans M+H@200.01721(1.0000)
# - id (1919, 3) mass 201.0259 rt 1151.94 MAP_trans M+H@200.01865(1.0000)
# Group 92
# - id (1886, 0) mass 168.5362 rt 1151.94 MAP_trans M+H@167.52897(1.0000)
# - id (3349, 1) mass 168.5350 rt 1151.94 MAP_trans M+H@167.52776(1.0000)
# - id (4044, 2) mass 168.5367 rt 1151.94 MAP_trans M+H@167.52943(1.0000)
# - id (1871, 3) mass 168.5351 rt 1151.94 MAP_trans M+H@167.52780(1.0000)
# Group 93
# - id (1889, 0) mass 176.5262 rt 1151.94 MAP_trans M+H@175.51884(1.0000)
# - id (3368, 1) mass 176.5256 rt 1151.94 MAP_trans M+H@175.51828(1.0000)
# - id (4063, 2) mass 176.5261 rt 1151.94 MAP_trans M+H@175.51879(1.0000)
# - id (1885, 3) mass 176.5256 rt 1151.94 MAP_trans M+H@175.51836(1.0000)
# Group 94
# - id (1893, 0) mass 200.0192 rt 1151.94 MAP_trans M+H@199.01193(1.0000)
# - id (3361, 1) mass 200.0194 rt 1151.94 MAP_trans M+H@199.01207(1.0000)
# - id (4081, 2) mass 200.0174 rt 1151.94 MAP_trans M+H@199.01011(1.0000)
# - id (1890, 3) mass 200.0191 rt 1151.94 MAP_trans M+H@199.01189(1.0000)
# Group 95
# - id (1896, 0) mass 202.0192 rt 1151.94 MAP_trans M+H@201.01194(1.0000)
# - id (3367, 1) mass 202.0189 rt 1151.94 MAP_trans M+H@201.01162(1.0000)
# - id (4082, 2) mass 202.0194 rt 1151.94 MAP_trans M+H@201.01217(1.0000)
# - id (1884, 3) mass 202.0198 rt 1151.94 MAP_trans M+H@201.01257(1.0000)
# Group 96
# - id (1899, 0) mass 177.5238 rt 1151.94 MAP_trans M+H@176.51652(1.0000)
# - id (3369, 1) mass 177.5239 rt 1151.94 MAP_trans M+H@176.51662(1.0000)
# - id (4154, 2) mass 177.5267 rt 1151.94 MAP_trans M+H@176.51944(1.0000)
# - id (1887, 3) mass 177.5262 rt 1151.94 MAP_trans M+H@176.51888(1.0000)
# Group 97
# - id (1902, 0) mass 180.0436 rt 1151.94 MAP_trans M+H@179.03628(1.0000)
# - id (3404, 1) mass 180.0417 rt 1151.94 MAP_trans M+H@179.03444(1.0000)
# - id (4159, 2) mass 180.0384 rt 1151.94 MAP_trans M+H@179.03112(1.0000)
# - id (1921, 3) mass 180.0386 rt 1151.94 MAP_trans M+H@179.03136(1.0000)
# Group 98
# - id (1913, 0) mass 189.5291 rt 1151.94 MAP_trans M+H@188.52182(0.9408)
# - id (3295, 1) mass 189.5275 rt 1151.94 MAP_trans M+H@188.52024(0.8180)
# - id (4188, 2) mass 189.5293 rt 1151.94 MAP_trans M+H@188.52204(1.0000)
# - id (1910, 3) mass 189.5283 rt 1151.94 MAP_trans M+H@188.52075(0.8875)
# Group 99
# - id (1914, 0) mass 174.0155 rt 1151.94 MAP_trans M+H@173.00815(1.0000)
# - id (3364, 1) mass 174.0179 rt 1151.94 MAP_trans M+H@173.01066(1.0000)
# - id (4131, 2) mass 174.0183 rt 1151.94 MAP_trans M+H@173.01102(1.0000)
# - id (1876, 3) mass 174.0159 rt 1151.94 MAP_trans M+H@173.00857(1.0000)
# Group 100
# - id (1922, 0) mass 197.0164 rt 1151.94 MAP_trans M+H@196.00908(1.0000)
# - id (3438, 1) mass 197.0163 rt 1151.94 MAP_trans M+H@196.00906(1.0000)
# - id (4092, 2) mass 197.0164 rt 1151.94 MAP_trans M+H@196.00911(1.0000)
# - id (1913, 3) mass 197.0165 rt 1151.94 MAP_trans M+H@196.00921(1.0000)
# Group 101
# - id (1931, 0) mass 190.0257 rt 1151.94 MAP_trans M+H@189.01840(1.0000)
# - id (3429, 1) mass 190.0259 rt 1151.94 MAP_trans M+H@189.01865(1.0000)
# - id (4096, 2) mass 190.0263 rt 1151.94 MAP_trans M+H@189.01899(1.0000)
# - id (1911, 3) mass 190.0259 rt 1151.94 MAP_trans M+H@189.01867(1.0000)
# Group 102
# - id (1932, 0) mass 198.0159 rt 1151.94 MAP_trans M+H@197.00851(1.0000)
# - id (3458, 1) mass 198.0148 rt 1151.94 MAP_trans M+H@197.00783(1.0000)
# - id (4094, 2) mass 198.0163 rt 1151.94 MAP_trans M+H@197.00870(1.0000)
# - id (1938, 3) mass 198.0171 rt 1151.94 MAP_trans M+H@197.00979(1.0000)
# Group 103
# - id (1944, 0) mass 185.5362 rt 1151.94 MAP_trans M+H@184.52888(1.0000)
# - id (3373, 1) mass 185.5378 rt 1151.94 MAP_trans M+H@184.53076(1.0000)
# - id (4182, 2) mass 185.5340 rt 1151.94 MAP_trans M+H@184.52676(1.0000)
# - id (1901, 3) mass 185.5361 rt 1151.94 MAP_trans M+H@184.52881(1.0000)
# Group 104
# - id (1946, 0) mass 207.0216 rt 1151.94 MAP_trans M+H@206.01432(1.0000)
# - id (3499, 1) mass 207.0214 rt 1151.94 MAP_trans M+H@206.01414(1.0000)
# - id (4120, 2) mass 207.0204 rt 1151.94 MAP_trans M+H@206.01311(1.0000)
# - id (1951, 3) mass 207.0214 rt 1151.94 MAP_trans M+H@206.01414(1.0000)
# Group 105
# - id (1965, 0) mass 206.0208 rt 1151.94 MAP_trans M+H@205.01351(1.0000)
# - id (3324, 1) mass 206.0208 rt 1151.94 MAP_trans M+H@205.01351(1.0000)
# - id (4119, 2) mass 206.0196 rt 1151.94 MAP_trans M+H@205.01233(1.0000)
# - id (1922, 3) mass 206.0204 rt 1151.94 MAP_trans M+H@205.01317(1.0000)
# Group 106
# - id (1966, 0) mass 208.0147 rt 1151.94 MAP_trans M+H@207.00744(1.0000)
# - id (3504, 1) mass 208.0157 rt 1151.94 MAP_trans M+H@207.00847(1.0000)
# - id (4121, 2) mass 208.0172 rt 1151.94 MAP_trans M+H@207.01040(1.0000)
# - id (1933, 3) mass 208.0177 rt 1151.94 MAP_trans M+H@207.01039(1.0000)
# Group 107
# - id (1972, 0) mass 206.5223 rt 1151.94 MAP_trans [M-CO]+2H [C13]@438.02218(0.9999)
# - id (3489, 1) mass 206.5210 rt 1151.94 MAP_trans [M-CO]+2H [C13]@438.01880(1.0000)
# - id (4118, 2) mass 206.5220 rt 1151.94 MAP_trans [M-CO]+2H [C13]@438.02041(1.0000)
# - id (1923, 3) mass 206.5228 rt 1151.94 MAP_trans [M-CO]+2H [C13]@438.02076(0.9999)
# Group 108
# - id (1977, 0) mass 215.9977 rt 1151.94 MAP_trans M+H@214.99072(1.0000)
# - id (3397, 1) mass 216.0032 rt 1151.94 MAP_trans M+H@214.99593(1.0000)
# - id (4129, 2) mass 216.0007 rt 1151.94 MAP_trans M+H@214.99342(1.0000)
# - id (1943, 3) mass 216.0019 rt 1151.94 MAP_trans M+H@214.99482(1.0000)
# Group 109
# - id (2023, 0) mass 280.0084 rt 1151.94 MAP_trans M+H@279.00013(1.0000)
# - id (3424, 1) mass 280.0080 rt 1151.94 MAP_trans M+H@279.00069(1.0000)
# - id (4168, 2) mass 280.0081 rt 1153.98 MAP_trans M+H@279.00148(1.0000)
# - id (1954, 3) mass 280.0092 rt 1151.94 MAP_trans M+H@279.00199(1.0000)
# Group 110
# - id (2047, 0) mass 264.0195 rt 1151.94 MAP_trans M+H@263.01271(1.0000)
# - id (3477, 1) mass 264.0197 rt 1151.94 MAP_trans M+H@263.01238(1.0000)
# - id (4225, 2) mass 264.0213 rt 1151.94 MAP_trans M+H@263.01398(1.0000)
# - id (2017, 3) mass 264.0192 rt 1151.94 MAP_trans M+H@263.01209(1.0000)
# Group 111
# - id (2069, 0) mass 286.0372 rt 1151.94 MAP_trans M+H@285.02997(1.0000)
# - id (3602, 1) mass 286.0374 rt 1151.94 MAP_trans M+H@285.02974(1.0000)
# - id (4374, 2) mass 286.0366 rt 1151.94 MAP_trans M+H@285.02931(1.0000)
# - id (2079, 3) mass 286.0367 rt 1151.94 MAP_trans M+H@285.02953(1.0000)
# Group 112
# - id (2071, 0) mass 286.5335 rt 1151.94 MAP_trans M+H@285.52599(1.0000)
# - id (3603, 1) mass 286.5335 rt 1151.94 MAP_trans M+H@285.52624(1.0000)
# - id (4379, 2) mass 286.5340 rt 1151.94 MAP_trans M+H@285.52630(1.0000)
# - id (2080, 3) mass 286.5359 rt 1151.94 MAP_trans M+H@285.52854(1.0000)
# Group 113
# - id (2076, 0) mass 285.5356 rt 1151.94 MAP_trans M+H@284.52834(1.0000)
# - id (3599, 1) mass 285.5358 rt 1151.94 MAP_trans M+H@284.52851(1.0000)
# - id (4263, 2) mass 285.5349 rt 1151.94 MAP_trans M+H@284.52760(1.0000)
# - id (2078, 3) mass 285.5361 rt 1151.94 MAP_trans M+H@284.52878(1.0000)
# Group 114
# - id (2077, 0) mass 294.0134 rt 1151.94 MAP_trans M+H@293.00608(1.0000)
# - id (3550, 1) mass 294.0145 rt 1151.94 MAP_trans M+H@293.00709(1.0000)
# - id (4257, 2) mass 294.0142 rt 1151.94 MAP_trans M+H@293.00679(1.0000)
# - id (2095, 3) mass 294.0131 rt 1151.94 MAP_trans M+H@293.00550(1.0000)
# Group 115
# - id (2088, 0) mass 377.0447 rt 1151.94 MAP_trans M+H@376.03760(1.0000)
# - id (3555, 1) mass 377.0423 rt 1151.94 MAP_trans M+H@376.03505(1.0000)
# - id (4355, 2) mass 377.0470 rt 1151.94 MAP_trans M+H@376.03938(1.0000)
# - id (2090, 3) mass 377.0471 rt 1151.94 MAP_trans M+H@376.03977(1.0000)
# Group 116
# - id (2106, 0) mass 277.5466 rt 1151.94 MAP_trans M+H@276.53966(1.0000)
# - id (3527, 1) mass 277.5490 rt 1149.96 MAP_trans M+H@276.54171(1.0000)
# - id (4354, 2) mass 277.5476 rt 1151.94 MAP_trans M+H@276.54037(1.0000)
# - id (2065, 3) mass 277.5467 rt 1151.94 MAP_trans M+H@276.53945(1.0000)
# Group 117
# - id (2160, 0) mass 439.0292 rt 1151.94 MAP_trans M+H@438.02218(1.0000)
# - id (3572, 1) mass 439.0265 rt 1149.96 MAP_trans M+H@438.01880(1.0000)
# - id (4408, 2) mass 439.0281 rt 1151.94 MAP_trans M+H@438.02041(1.0000)
# - id (2123, 3) mass 439.0278 rt 1151.94 MAP_trans M+H@438.02076(1.0000)
# Group 118
# - id (2179, 0) mass 421.1541 rt 1151.94 MAP_trans M+H@420.14671(1.0000)
# - id (3664, 1) mass 421.1455 rt 1151.94 MAP_trans M+H@420.13818(1.0000)
# - id (4491, 2) mass 421.1499 rt 1155.96 MAP_trans M+H@420.14260(1.0000)
# - id (2210, 3) mass 421.1444 rt 1153.98 MAP_trans M+H@420.13708(1.0000)
# Group 119
# - id (2132, 0) mass 540.0114 rt 1153.98 MAP_trans M+H@539.00415(1.0000)
# - id (3547, 1) mass 540.0087 rt 1147.98 MAP_trans M+H@539.00142(1.0000)
# - id (4309, 2) mass 540.0055 rt 1147.98 MAP_trans M+H@538.99818(1.0000)
# Group 120
# - id (2163, 0) mass 299.6021 rt 1151.94 MAP_trans M+H@298.59482(1.0000)
# - id (3617, 1) mass 299.6016 rt 1151.94 MAP_trans M+H@298.59432(1.0000)
# - id (4360, 2) mass 299.6056 rt 1153.98 MAP_trans M+H@298.59829(1.0000)
# - id (2108, 3) mass 299.6015 rt 1151.94 MAP_trans M+H@298.59426(1.0000)
# Group 121
# - id (2045, 0) mass 332.5599 rt 1145.94 MAP_trans M+H@331.55267(1.0000)
# - id (3473, 1) mass 332.5614 rt 1145.94 MAP_trans M+H@331.55409(1.0000)
# - id (4240, 2) mass 332.5608 rt 1145.94 MAP_trans M+H@331.55348(1.0000)
# - id (2010, 3) mass 332.5602 rt 1147.98 MAP_trans M+H@331.55294(1.0000)
# Group 122
# - id (2098, 0) mass 405.5855 rt 1145.94 MAP_trans M+H@404.57827(1.0000)
# - id (3556, 1) mass 405.5831 rt 1145.94 MAP_trans M+H@404.57582(1.0000)
# - id (4328, 2) mass 405.5848 rt 1147.98 MAP_trans M+H@404.57757(1.0000)
# - id (2072, 3) mass 405.5852 rt 1147.98 MAP_trans M+H@404.57790(1.0000)
# Group 123
# - id (2196, 0) mass 398.0986 rt 1149.96 MAP_trans M+H@397.09135(1.0000)
# - id (2191, 3) mass 398.0990 rt 1147.98 MAP_trans M+H@397.09176(1.0000)
# Group 124
# - id (2219, 0) mass 537.9643 rt 1147.98 MAP_trans M+H@536.95706(1.0000)
# - id (2139, 3) mass 537.9775 rt 1147.98 MAP_trans M+H@536.97024(1.0000)
# - id (3628, 1) mass 537.9753 rt 1145.94 MAP_trans M+H@536.96797(1.0000)
# Group 125
# - id (2173, 0) mass 494.1044 rt 1147.98 MAP_trans M+H@493.09715(1.0000)
# - id (3687, 1) mass 494.1073 rt 1147.98 MAP_trans M+H@493.09998(1.0000)
# - id (4420, 2) mass 494.1059 rt 1149.96 MAP_trans M+H@493.09864(1.0000)
# - id (2155, 3) mass 494.1062 rt 1149.96 MAP_trans M+H@493.09889(1.0000)
# Group 126
# - id (2215, 0) mass 494.6067 rt 1149.96 MAP_trans M+H@493.59944(1.0000)
# - id (3604, 1) mass 494.6073 rt 1147.98 MAP_trans M+H@493.60001(1.0000)
# - id (4449, 2) mass 494.6088 rt 1147.98 MAP_trans M+H@493.60178(1.0000)
# - id (2158, 3) mass 494.6069 rt 1149.96 MAP_trans M+H@493.59961(1.0000)
# Group 127
# - id (2114, 0) mass 279.5596 rt 1149.96 MAP_trans M+H@278.55235(1.0000)
# - id (3534, 1) mass 279.5567 rt 1149.96 MAP_trans M+H@278.54947(0.9908)
# - id (4314, 2) mass 279.5524 rt 1151.94 MAP_trans M+H@278.54457(1.0000)
# - id (2133, 3) mass 279.5614 rt 1151.94 MAP_trans M+H@278.55416(0.9446)
# Group 128
# - id (2218, 0) mass 537.6306 rt 1149.96 MAP_trans M+H@536.62332(1.0000)
# - id (3620, 1) mass 537.6267 rt 1145.94 MAP_trans M+H@536.61940(1.0000)
# - id (4492, 2) mass 537.6309 rt 1147.98 MAP_trans M+H@536.62360(1.0000)
# - id (2138, 3) mass 537.6167 rt 1147.98 MAP_trans M+H@536.60946(1.0000)
# Group 129
# - id (1780, 0) mass 138.9834 rt 1147.98 MAP_trans M+H@137.97617(1.0000)
# - id (4016, 2) mass 138.9847 rt 1149.96 MAP_trans M+H@137.97744(0.9847)
# Group 130
# - id (1938, 0) mass 199.5261 rt 1149.96 MAP_trans M+H@198.51878(1.0000)
# - id (4265, 2) mass 199.5253 rt 1151.94 MAP_trans M+H@198.51799(1.0000)
# Group 131
# - id (2115, 0) mass 363.1407 rt 1149.96 MAP_trans M+H@362.13339(1.0000)
# - id (3523, 1) mass 363.1320 rt 1149.96 MAP_trans M+H@362.12471(1.0000)
# - id (4313, 2) mass 363.1340 rt 1151.94 MAP_trans M+H@362.12671(1.0000)
# Group 132
# - id (2133, 0) mass 495.1183 rt 1147.98 MAP_trans M+H@494.10966(1.0000)
# - id (3600, 1) mass 495.1221 rt 1147.98 MAP_trans M+H@494.11485(1.0000)
# - id (4451, 2) mass 495.1143 rt 1147.98 MAP_trans M+H@494.10703(1.0000)
# Group 133
# - id (2207, 0) mass 367.0828 rt 1151.94 MAP_trans M+H@366.07547(0.9249)
# Group 134
# - id (1490, 0) mass 147.0496 rt 1001.94 MAP_trans M+H@146.04231(1.0000)
# - id (2925, 1) mass 147.0509 rt 997.98 MAP_trans M+H@146.04359(1.0000)
# - id (3500, 2) mass 147.0532 rt 1001.94 MAP_trans M+H@146.04596(1.0000)
# - id (1455, 3) mass 147.0540 rt 997.98 MAP_trans M+H@146.04670(1.0000)
# Group 135
# - id (1516, 0) mass 225.0843 rt 999.96 MAP_trans M+H@224.07706(1.0000)
# - id (2929, 1) mass 225.0854 rt 997.98 MAP_trans M+H@224.07814(1.0000)
# - id (3607, 2) mass 225.0860 rt 999.96 MAP_trans M+H@224.07871(1.0000)
# - id (1475, 3) mass 225.0854 rt 999.96 MAP_trans M+H@224.07817(1.0000)
# Group 136
# - id (1527, 0) mass 208.0741 rt 999.96 MAP_trans M+H@207.06679(1.0000)
# - id (2924, 1) mass 208.0742 rt 997.98 MAP_trans M+H@207.06689(1.0000)
# - id (3453, 2) mass 208.0743 rt 999.96 MAP_trans M+H@207.06698(1.0000)
# - id (1481, 3) mass 208.0745 rt 999.96 MAP_trans M+H@207.06700(1.0000)
# Group 137
# - id (1581, 0) mass 398.1235 rt 999.96 MAP_trans M+H@397.11547(1.0000)
# - id (3001, 1) mass 398.1224 rt 999.96 MAP_trans M+H@397.11514(1.0000)
# - id (3786, 2) mass 398.1243 rt 999.96 MAP_trans M+H@397.11701(1.0000)
# - id (1555, 3) mass 398.1240 rt 999.96 MAP_trans M+H@397.11670(1.0000)
# Group 138
# - id (1586, 0) mass 406.1167 rt 999.96 MAP_trans M+H@405.10946(1.0000)
# - id (3019, 1) mass 406.1175 rt 999.96 MAP_trans M+H@405.10961(1.0000)
# - id (3741, 2) mass 406.1188 rt 1001.94 MAP_trans M+H@405.11146(1.0000)
# - id (1572, 3) mass 406.1182 rt 999.96 MAP_trans M+H@405.11109(1.0000)
# Group 139
# - id (1587, 0) mass 406.6210 rt 1001.94 MAP_trans M+H@405.61376(1.0000)
# - id (3013, 1) mass 406.6198 rt 999.96 MAP_trans M+H@405.61254(1.0000)
# - id (3732, 2) mass 406.6210 rt 1001.94 MAP_trans M+H@405.61372(1.0000)
# - id (1557, 3) mass 406.6200 rt 999.96 MAP_trans M+H@405.61270(1.0000)
# Group 140
# - id (1589, 0) mass 443.0913 rt 999.96 MAP_trans M+H@442.08384(1.0000)
# - id (3035, 1) mass 443.0911 rt 997.98 MAP_trans M+H@442.08383(1.0000)
# - id (3803, 2) mass 443.0974 rt 999.96 MAP_trans M+H@442.09021(1.0000)
# - id (1581, 3) mass 443.0953 rt 997.98 MAP_trans M+H@442.08778(1.0000)
# Group 141
# - id (1608, 0) mass 599.6987 rt 999.96 MAP_trans M+H@598.69130(1.0000)
# - id (3049, 1) mass 599.7003 rt 999.96 MAP_trans M+H@598.69341(1.0000)
# - id (3818, 2) mass 599.7026 rt 1001.94 MAP_trans M+H@598.69471(1.0000)
# - id (1606, 3) mass 599.7017 rt 999.96 MAP_trans M+H@598.69466(1.0000)
# Group 142
# - id (1613, 0) mass 599.1960 rt 999.96 MAP_trans M+H@598.18880(1.0000)
# - id (3048, 1) mass 599.1976 rt 999.96 MAP_trans M+H@598.19060(1.0000)
# - id (3817, 2) mass 599.1982 rt 1001.94 MAP_trans M+H@598.19098(1.0000)
# - id (1605, 3) mass 599.1972 rt 999.96 MAP_trans M+H@598.19046(1.0000)
# Group 143
# - id (1618, 0) mass 795.2444 rt 997.98 MAP_trans M+H@794.23636(1.0000)
# - id (3089, 1) mass 795.2578 rt 997.98 MAP_trans M+H@794.25081(1.0000)
# - id (3832, 2) mass 795.2433 rt 999.96 MAP_trans M+H@794.23625(1.0000)
# - id (1610, 3) mass 795.2446 rt 997.98 MAP_trans M+H@794.23787(1.0000)
# Group 144
# - id (1620, 0) mass 591.7084 rt 999.96 MAP_trans M+H@590.70167(1.0000)
# - id (3057, 1) mass 591.7105 rt 999.96 MAP_trans M+H@590.70356(1.0000)
# - id (3836, 2) mass 591.7129 rt 1001.94 MAP_trans M+H@590.70523(1.0000)
# - id (1637, 3) mass 591.7120 rt 999.96 MAP_trans M+H@590.70503(1.0000)
# Group 145
# - id (1621, 0) mass 592.2125 rt 1001.94 MAP_trans M+H@591.20522(1.0000)
# - id (3047, 1) mass 592.2155 rt 999.96 MAP_trans M+H@591.20827(1.0000)
# - id (3837, 2) mass 592.2144 rt 1001.94 MAP_trans M+H@591.20709(1.0000)
# - id (1638, 3) mass 592.2149 rt 997.98 MAP_trans M+H@591.20761(1.0000)
# Group 146
# - id (1628, 0) mass 792.2547 rt 999.96 MAP_trans M+H@791.24700(1.0000)
# - id (3070, 1) mass 792.2547 rt 997.98 MAP_trans M+H@791.24745(1.0000)
# - id (3829, 2) mass 792.2542 rt 999.96 MAP_trans M+H@791.24905(1.0000)
# - id (1630, 3) mass 792.2555 rt 997.98 MAP_trans M+H@791.24851(1.0000)
# Group 147
# - id (1629, 0) mass 792.7511 rt 999.96 MAP_trans M+H@791.74495(1.0000)
# - id (3063, 1) mass 792.7595 rt 997.98 MAP_trans M+H@791.75224(1.0000)
# - id (3830, 2) mass 792.7567 rt 999.96 MAP_trans M+H@791.74946(1.0000)
# - id (1631, 3) mass 792.7546 rt 997.98 MAP_trans M+H@791.74653(1.0000)
# Group 148
# - id (1641, 0) mass 795.4040 rt 1001.94 MAP_trans M+H@794.39677(1.0000)
# - id (1632, 3) mass 795.3953 rt 995.94 MAP_trans M+H@794.38803(1.0000)
# Group 149
# - id (1609, 0) mass 485.1086 rt 999.96 MAP_trans M+H@484.10133(1.0000)
# - id (2999, 1) mass 485.0982 rt 997.98 MAP_trans M+H@484.09091(1.0000)
# - id (3773, 2) mass 485.0891 rt 1001.94 MAP_trans M+H@484.08185(1.0000)
# - id (1614, 3) mass 485.1025 rt 995.94 MAP_trans M+H@484.09525(1.0000)
# Group 150
# - id (1639, 0) mass 791.2884 rt 999.96 MAP_trans M+H@790.28109(1.0000)
# - id (3841, 2) mass 791.2873 rt 999.96 MAP_trans M+H@790.28004(1.0000)
# - id (1608, 3) mass 791.2951 rt 999.96 MAP_trans M+H@790.28771(1.0000)
# Group 151
# - id (1667, 0) mass 472.1068 rt 1001.94 MAP_trans M+H@471.09874(1.0000)
# - id (1587, 3) mass 472.0897 rt 999.96 MAP_trans M+H@471.08271(1.0000)
# Group 152
# - id (1530, 0) mass 436.1492 rt 959.94 MAP_trans M+H@435.14195(1.0000)
# - id (2933, 1) mass 436.1449 rt 961.98 MAP_trans M+H@435.13779(1.0000)
# - id (3695, 2) mass 436.1532 rt 965.94 MAP_trans M+H@435.14588(1.0000)
# - id (1482, 3) mass 436.1468 rt 963.96 MAP_trans M+H@435.13953(1.0000)
# Group 153
# - id (1536, 0) mass 532.0822 rt 963.96 MAP_trans M+H@531.07491(1.0000)
# - id (2934, 1) mass 532.0858 rt 963.96 MAP_trans M+H@531.07858(1.0000)
# - id (3869, 2) mass 532.0867 rt 963.96 MAP_trans M+H@531.08012(1.0000)
# - id (1493, 3) mass 532.0846 rt 963.96 MAP_trans M+H@531.07779(1.0000)
# Group 154
# - id (1611, 0) mass 303.1237 rt 1011.96 MAP_trans M+H@302.11645(1.0000)
# - id (2993, 1) mass 303.1307 rt 1013.94 MAP_trans M+H@302.12338(1.0000)
# - id (3711, 2) mass 303.1308 rt 1013.94 MAP_trans M+H@302.12356(1.0000)
# Group 155
# - id (1554, 0) mass 440.1543 rt 977.94 MAP_trans M+H@439.14699(1.0000)
# - id (2965, 1) mass 440.1549 rt 975.96 MAP_trans M+H@439.14675(1.0000)
# - id (3717, 2) mass 440.1568 rt 977.94 MAP_trans M+H@439.14953(1.0000)
# - id (1534, 3) mass 440.1611 rt 977.94 MAP_trans M+H@439.15379(1.0000)
# Group 156
# - id (1565, 0) mass 165.0971 rt 1075.98 MAP_trans M+H@164.08948(1.0000)
# - id (2966, 1) mass 165.0965 rt 1075.98 MAP_trans M+H@164.08895(1.0000)
# - id (3682, 2) mass 165.0951 rt 1077.96 MAP_trans M+H@164.08785(1.0000)
# - id (1517, 3) mass 165.0974 rt 1073.94 MAP_trans M+H@164.09014(1.0000)
# Group 157
# - id (1745, 0) mass 349.1244 rt 1073.94 MAP_trans M+H@348.11680(1.0000)
# - id (3253, 1) mass 349.1297 rt 1075.98 MAP_trans M+H@348.12240(1.0000)
# - id (4014, 2) mass 349.1279 rt 1075.98 MAP_trans M+H@348.12057(1.0000)
# - id (1736, 3) mass 349.1224 rt 1075.98 MAP_trans M+H@348.11508(1.0000)
# Group 158
# - id (1627, 0) mass 785.2749 rt 999.96 MAP_trans [M-CO]+NH4@795.23372(0.5342)
# Group 159
# - id (1626, 0) mass 784.7826 rt 999.96 MAP_trans M+H@783.77536(1.0000)
# Group 160
# - id (1637, 0) mass 444.0940 rt 999.96 MAP_trans M+H [C13]@442.08384(0.9999)
# Group 161
# - id (1640, 0) mass 377.1446 rt 1025.94 MAP_trans M+H@376.13732(1.0000)
# - id (3072, 1) mass 377.1461 rt 1025.94 MAP_trans M+H@376.13885(1.0000)
# - id (3820, 2) mass 377.1470 rt 1027.98 MAP_trans M+H@376.13949(1.0000)
# - id (1604, 3) mass 377.1462 rt 1025.94 MAP_trans M+H@376.13892(1.0000)
# Group 162
# - id (1671, 0) mass 378.1374 rt 1025.94 MAP_trans M+H@377.13013(1.0000)
# - id (3105, 1) mass 378.1441 rt 1025.94 MAP_trans M+H@377.13684(1.0000)
# - id (3864, 2) mass 378.1421 rt 1027.98 MAP_trans M+H@377.13484(1.0000)
# - id (1657, 3) mass 378.1437 rt 1025.94 MAP_trans M+H@377.13640(1.0000)
# Group 163
# - id (1867, 0) mass 212.0816 rt 1115.94 MAP_trans M+H@211.07432(1.0000)
# - id (3248, 1) mass 212.0813 rt 1117.98 MAP_trans M+H@211.07407(1.0000)
# - id (4058, 2) mass 212.0827 rt 1117.98 MAP_trans M+H@211.07542(1.0000)
# - id (1817, 3) mass 212.0790 rt 1117.98 MAP_trans M+H@211.07168(1.0000)
# Group 164
# - id (1774, 0) mass 207.1474 rt 1121.94 MAP_trans M+H@206.14008(1.0000)
# - id (3171, 1) mass 207.1507 rt 1121.94 MAP_trans M+H@206.14345(1.0000)
# - id (3949, 2) mass 207.1487 rt 1121.94 MAP_trans M+H@206.14140(1.0000)
# - id (1790, 3) mass 207.1492 rt 1121.94 MAP_trans M+H@206.14199(1.0000)
# Group 165
# - id (2000, 0) mass 471.1654 rt 1121.94 MAP_trans M+H@470.15823(1.0000)
# - id (3356, 1) mass 471.1670 rt 1121.94 MAP_trans M+H@470.15979(1.0000)
# - id (4231, 2) mass 471.1688 rt 1123.98 MAP_trans M+H@470.16222(1.0000)
# - id (2006, 3) mass 471.1635 rt 1123.98 MAP_trans M+H@470.15642(1.0000)
# Group 166
# - id (2012, 0) mass 409.1780 rt 1121.94 MAP_trans M+H@408.17077(1.0000)
# - id (3435, 1) mass 409.1818 rt 1121.94 MAP_trans M+H@408.17451(1.0000)
# - id (4253, 2) mass 409.1839 rt 1123.98 MAP_trans M+H@408.17665(1.0000)
# - id (1961, 3) mass 409.1778 rt 1121.94 MAP_trans M+H@408.17050(1.0000)
# Group 167
# - id (2049, 0) mass 455.1777 rt 1121.94 MAP_trans M+H@454.17039(1.0000)
# - id (3520, 1) mass 455.1849 rt 1121.94 MAP_trans M+H@454.17766(1.0000)
# - id (4242, 2) mass 455.1755 rt 1125.96 MAP_trans M+H@454.16876(1.0000)
# - id (2027, 3) mass 455.1727 rt 1123.98 MAP_trans M+H@454.16546(1.0000)
# Group 168
# - id (1878, 0) mass 435.2328 rt 1085.94 MAP_trans M+H@434.22556(1.0000)
# - id (3333, 1) mass 435.2342 rt 1085.94 MAP_trans M+H@434.22697(1.0000)
# - id (4112, 2) mass 435.2225 rt 1085.94 MAP_trans M+H@434.21522(1.0000)
# - id (1873, 3) mass 435.2327 rt 1083.96 MAP_trans M+H@434.22542(1.0000)
# Group 169
# - id (1687, 0) mass 390.0956 rt 1043.94 MAP_trans M+H@389.08876(1.0000)
# - id (3148, 1) mass 390.0947 rt 1043.94 MAP_trans M+H@389.08736(1.0000)
# - id (3934, 2) mass 390.0946 rt 1045.98 MAP_trans M+H@389.08700(1.0000)
# - id (1683, 3) mass 390.0933 rt 1043.94 MAP_trans M+H@389.08686(1.0000)
# Group 170
# - id (1718, 0) mass 390.5946 rt 1043.94 MAP_trans M+H@389.58734(1.0000)
# - id (3118, 1) mass 390.5939 rt 1043.94 MAP_trans M+H@389.58660(1.0000)
# - id (3937, 2) mass 390.5955 rt 1045.98 MAP_trans M+H@389.58827(1.0000)
# - id (1729, 3) mass 390.5945 rt 1045.98 MAP_trans M+H@389.58721(1.0000)
# Group 171
# - id (1752, 0) mass 410.6104 rt 1043.94 MAP_trans M+H@409.60314(1.0000)
# - id (3175, 1) mass 410.6078 rt 1043.94 MAP_trans M+H@409.60056(1.0000)
# - id (3931, 2) mass 410.6089 rt 1045.98 MAP_trans M+H@409.60164(1.0000)
# - id (1737, 3) mass 410.6096 rt 1043.94 MAP_trans M+H@409.60227(1.0000)
# Group 172
# - id (1797, 0) mass 760.2171 rt 1043.94 MAP_trans M+H@759.20873(1.0000)
# - id (3186, 1) mass 760.2155 rt 1043.94 MAP_trans M+H@759.20886(1.0000)
# - id (3992, 2) mass 760.2216 rt 1045.98 MAP_trans M+H@759.21508(1.0000)
# - id (1769, 3) mass 760.2111 rt 1043.94 MAP_trans M+H@759.20387(1.0000)
# Group 173
# - id (1690, 0) mass 342.1275 rt 1049.94 MAP_trans M+H@341.12025(1.0000)
# Group 174
# - id (1837, 0) mass 460.6611 rt 1069.98 MAP_trans M+H@459.65378(1.0000)
# - id (3307, 1) mass 460.6671 rt 1069.98 MAP_trans M+H@459.65984(1.0000)
# Group 175
# - id (1703, 0) mass 362.1048 rt 1069.98 MAP_trans M+H@361.09756(1.0000)
# - id (3178, 1) mass 362.1115 rt 1071.96 MAP_trans M+H@361.10393(1.0000)
# Group 176
# - id (1936, 0) mass 266.0903 rt 1123.98 MAP_trans M+H@265.08304(1.0000)
# - id (3347, 1) mass 266.0896 rt 1125.96 MAP_trans M+H@265.08231(1.0000)
# - id (4124, 2) mass 266.0917 rt 1127.94 MAP_trans M+H@265.08441(1.0000)
# - id (1902, 3) mass 266.0898 rt 1125.96 MAP_trans M+H@265.08250(1.0000)
# Group 177
# - id (1719, 0) mass 361.1046 rt 1053.96 MAP_trans M+H@360.09733(1.0000)
# - id (3132, 1) mass 361.1048 rt 1053.96 MAP_trans M+H@360.09753(1.0000)
# - id (3875, 2) mass 361.1065 rt 1055.94 MAP_trans M+H@360.09920(1.0000)
# - id (1668, 3) mass 361.1062 rt 1053.96 MAP_trans M+H@360.09892(1.0000)
# Group 178
# - id (1746, 0) mass 361.6086 rt 1053.96 MAP_trans M+H@360.60135(1.0000)
# - id (3169, 1) mass 361.6059 rt 1055.94 MAP_trans M+H@360.59858(1.0000)
# - id (3913, 2) mass 361.6017 rt 1055.94 MAP_trans M+H@360.59439(1.0000)
# - id (1693, 3) mass 361.6019 rt 1055.94 MAP_trans M+H@360.59467(1.0000)
# Group 179
# ...
# Group 615
# - id (4980, 0) mass 351.1882 rt 2277.90 MAP_trans M+H@350.18092(1.0000)
# - id (6493, 1) mass 351.1897 rt 2279.94 MAP_trans M+H@350.18236(1.0000)
# - id (7980, 2) mass 351.1891 rt 2279.94 MAP_trans M+H@350.18216(1.0000)
# - id (4946, 3) mass 351.1938 rt 2277.90 MAP_trans M+H@350.18679(1.0000)
# Group 616
# - id (5015, 0) mass 277.6563 rt 2275.92 MAP_trans M+H@276.64904(1.0000)
# - id (6525, 1) mass 277.6554 rt 2277.90 MAP_trans M+H@276.64815(1.0000)
# - id (7964, 2) mass 277.6531 rt 2277.90 MAP_trans M+H@276.64587(1.0000)
# - id (4990, 3) mass 277.6571 rt 2277.90 MAP_trans M+H@276.64982(1.0000)
# Group 617
# - id (5025, 0) mass 277.1535 rt 2275.92 MAP_trans M+H@276.14623(1.0000)
# - id (6503, 1) mass 277.1537 rt 2277.90 MAP_trans M+H@276.14640(1.0000)
# - id (7960, 2) mass 277.1535 rt 2277.90 MAP_trans M+H@276.14620(1.0000)
# - id (4993, 3) mass 277.1557 rt 2277.90 MAP_trans M+H@276.14839(1.0000)
# Group 618
# - id (5037, 0) mass 353.2604 rt 2275.92 MAP_trans M+H@352.25311(1.0000)
# - id (6547, 1) mass 353.2684 rt 2277.90 MAP_trans M+H@352.26115(1.0000)
# - id (7979, 2) mass 353.2666 rt 2277.90 MAP_trans M+H@352.25930(1.0000)
# - id (5026, 3) mass 353.2625 rt 2277.90 MAP_trans M+H@352.25446(1.0000)
# Group 619
# - id (5041, 0) mass 352.1870 rt 2277.90 MAP_trans M+H@351.17970(1.0000)
# - id (6543, 1) mass 352.1841 rt 2279.94 MAP_trans M+H@351.17680(1.0000)
# - id (8015, 2) mass 352.1819 rt 2279.94 MAP_trans M+H@351.17463(1.0000)
# - id (5018, 3) mass 352.1872 rt 2277.90 MAP_trans M+H@351.17955(1.0000)
# Group 620
# - id (5507, 0) mass 185.1168 rt 2277.90 MAP_trans M+H@184.10953(1.0000)
# - id (7150, 1) mass 185.1131 rt 2279.94 MAP_trans M+H@184.10579(1.0000)
# - id (8615, 2) mass 185.1130 rt 2279.94 MAP_trans M+H@184.10577(1.0000)
# - id (5547, 3) mass 185.1162 rt 2279.94 MAP_trans M+H@184.10897(1.0000)
# Group 621
# - id (5023, 0) mass 415.7382 rt 2273.94 MAP_trans M+H@414.73097(1.0000)
# - id (5039, 3) mass 415.7498 rt 2277.90 MAP_trans M+H@414.74257(1.0000)
# Group 622
# - id (4844, 0) mass 470.2231 rt 2181.90 MAP_trans M+H@469.21585(1.0000)
# - id (7458, 1) mass 470.2228 rt 2185.92 MAP_trans M+H@469.21553(1.0000)
# - id (7730, 2) mass 470.2308 rt 2185.92 MAP_trans M+H@469.22367(1.0000)
# Group 623
# - id (4913, 0) mass 471.2281 rt 2185.92 MAP_trans M+H@470.22086(0.9636)
# - id (6371, 1) mass 471.2311 rt 2183.94 MAP_trans M+H@470.22386(0.9929)
# - id (7816, 2) mass 471.2379 rt 2185.92 MAP_trans M+H@470.23063(0.9218)
# Group 624
# - id (4854, 0) mass 476.2288 rt 2219.94 MAP_trans M+H@475.22181(1.0000)
# Group 625
# - id (4926, 0) mass 476.7378 rt 2219.94 MAP_trans M+H@475.73050(1.0000)
# Group 626
# - id (4887, 0) mass 441.7487 rt 2199.90 MAP_trans M+H@440.74140(1.0000)
# Group 627
# - id (5757, 0) mass 441.2442 rt 2199.90 MAP_trans M+H@440.23692(1.0000)
# Group 628
# - id (4963, 0) mass 373.6801 rt 2255.94 MAP_trans M+H@372.67281(1.0000)
# - id (6461, 1) mass 373.6806 rt 2257.92 MAP_trans M+H@372.67336(1.0000)
# - id (7821, 2) mass 373.6815 rt 2255.94 MAP_trans M+H@372.67425(1.0000)
# - id (5839, 3) mass 373.6815 rt 2257.92 MAP_trans M+H@372.67423(1.0000)
# Group 629
# - id (5800, 0) mass 373.1780 rt 2255.94 MAP_trans M+H@372.17120(1.0000)
# - id (7471, 1) mass 373.1792 rt 2257.92 MAP_trans M+H@372.17153(1.0000)
# - id (9095, 2) mass 373.1801 rt 2257.92 MAP_trans M+H@372.17161(1.0000)
# - id (5838, 3) mass 373.1810 rt 2257.92 MAP_trans M+H@372.17432(1.0000)
# Group 630
# - id (4979, 0) mass 343.2280 rt 2263.92 MAP_trans M+H@342.22075(1.0000)
# - id (6522, 1) mass 343.2280 rt 2267.94 MAP_trans M+H@342.22076(1.0000)
# - id (7922, 2) mass 343.2306 rt 2267.94 MAP_trans M+H@342.22327(1.0000)
# - id (4956, 3) mass 343.2314 rt 2265.90 MAP_trans M+H@342.22411(1.0000)
# Group 631
# - id (5034, 0) mass 469.2362 rt 2265.90 MAP_trans M+H@468.22889(1.0000)
# - id (6565, 1) mass 469.2380 rt 2267.94 MAP_trans M+H@468.23068(1.0000)
# - id (8002, 2) mass 469.2404 rt 2267.94 MAP_trans M+H@468.23314(1.0000)
# - id (5031, 3) mass 469.2429 rt 2267.94 MAP_trans M+H@468.23562(1.0000)
# Group 632
# - id (4994, 0) mass 200.2050 rt 2293.92 MAP_trans M+H@199.19776(1.0000)
# - id (6507, 1) mass 200.2096 rt 2295.90 MAP_trans M+H@199.20231(1.0000)
# - id (7965, 2) mass 200.2060 rt 2297.94 MAP_trans M+H@199.19869(1.0000)
# - id (4971, 3) mass 200.2048 rt 2295.90 MAP_trans M+H@199.19756(1.0000)
# Group 633
# - id (5028, 0) mass 396.7064 rt 2293.92 MAP_trans M+H@395.69916(1.0000)
# - id (6545, 1) mass 396.7050 rt 2297.94 MAP_trans M+H@395.69773(1.0000)
# - id (7982, 2) mass 396.7023 rt 2297.94 MAP_trans M+H@395.69507(1.0000)
# - id (5003, 3) mass 396.7070 rt 2297.94 MAP_trans M+H@395.69971(1.0000)
# Group 634
# - id (5808, 0) mass 439.2299 rt 2295.90 MAP_trans M+H@438.22349(1.0000)
# - id (5842, 3) mass 439.2282 rt 2299.92 MAP_trans M+H@438.22096(1.0000)
# Group 635
# - id (5816, 0) mass 439.7328 rt 2295.90 MAP_trans M+H@438.72551(1.0000)
# - id (5861, 3) mass 439.7299 rt 2297.94 MAP_trans M+H@438.72265(1.0000)
# Group 636
# - id (4996, 0) mass 431.7312 rt 2259.90 MAP_trans M+H@430.72390(1.0000)
# Group 637
# - id (5812, 0) mass 431.2264 rt 2259.90 MAP_trans M+H@430.21926(1.0000)
# Group 638
# - id (5054, 0) mass 365.1790 rt 2315.94 MAP_trans M+H@364.17175(1.0000)
# - id (7472, 1) mass 365.1810 rt 2317.92 MAP_trans M+H@364.17357(1.0000)
# - id (8064, 2) mass 365.1798 rt 2317.92 MAP_trans M+H@364.17251(1.0000)
# - id (5850, 3) mass 365.1823 rt 2317.92 MAP_trans M+H@364.17500(1.0000)
# Group 639
# - id (5076, 0) mass 374.1852 rt 2315.94 MAP_trans M+H@373.17785(1.0000)
# - id (7490, 1) mass 374.1823 rt 2317.92 MAP_trans M+H@373.17475(1.0000)
# - id (9047, 2) mass 374.1839 rt 2317.92 MAP_trans M+H@373.17647(1.0000)
# - id (5847, 3) mass 374.1859 rt 2315.94 MAP_trans M+H@373.17889(1.0000)
# Group 640
# - id (4997, 0) mass 431.7348 rt 2317.92 MAP_trans M+H@430.72755(1.0000)
# Group 641
# - id (5814, 0) mass 431.2302 rt 2317.92 MAP_trans M+H@430.22288(1.0000)
# Group 642
# - id (5066, 0) mass 182.1006 rt 2379.90 MAP_trans M+H@181.09329(1.0000)
# - id (5135, 3) mass 182.1043 rt 2381.94 MAP_trans M+H@181.09697(0.9011)
# Group 643
# - id (5024, 0) mass 177.0913 rt 2333.94 MAP_trans M+H@176.08399(1.0000)
# Group 644
# - id (5143, 0) mass 363.1864 rt 2365.92 MAP_trans M+H@362.17917(1.0000)
# - id (6654, 1) mass 363.1890 rt 2367.90 MAP_trans M+H@362.18126(1.0000)
# Group 645
# - id (5722, 0) mass 425.2274 rt 2285.94 MAP_trans M+H@424.22041(1.0000)
# Group 646
# - id (5797, 0) mass 425.7292 rt 2283.90 MAP_trans M+H@424.72192(1.0000)
# Group 647
# - id (5080, 0) mass 484.2465 rt 2325.90 MAP_trans M+H@483.23924(1.0000)
# - id (6646, 1) mass 484.2459 rt 2327.94 MAP_trans M+H@483.23861(1.0000)
# - id (8077, 2) mass 484.2469 rt 2327.94 MAP_trans M+H@483.23965(1.0000)
# - id (5106, 3) mass 484.2469 rt 2327.94 MAP_trans M+H@483.23962(1.0000)
# Group 648
# - id (5110, 0) mass 484.7525 rt 2325.90 MAP_trans M+H@483.74520(1.0000)
# - id (6658, 1) mass 484.7517 rt 2327.94 MAP_trans M+H@483.74444(1.0000)
# - id (8092, 2) mass 484.7531 rt 2327.94 MAP_trans M+H@483.74586(1.0000)
# - id (5115, 3) mass 484.7566 rt 2327.94 MAP_trans M+H@483.74930(1.0000)
# Group 649
# - id (5754, 0) mass 432.2358 rt 2323.92 MAP_trans M+H@431.22848(1.0000)
# - id (7441, 1) mass 432.2387 rt 2325.90 MAP_trans M+H@431.23145(1.0000)
# - id (9031, 2) mass 432.2364 rt 2325.90 MAP_trans M+H@431.22910(1.0000)
# - id (5817, 3) mass 432.2382 rt 2325.90 MAP_trans M+H@431.23097(1.0000)
# Group 650
# - id (5084, 0) mass 501.2089 rt 2309.94 MAP_trans M+H@500.20177(1.0000)
# - id (6613, 1) mass 501.2048 rt 2311.92 MAP_trans M+H@500.19752(1.0000)
# - id (8075, 2) mass 501.2048 rt 2311.92 MAP_trans M+H@500.19753(1.0000)
# - id (5096, 3) mass 501.2061 rt 2311.92 MAP_trans M+H@500.19887(1.0000)
# Group 651
# - id (5093, 0) mass 445.2350 rt 2309.94 MAP_trans M+H@444.22772(1.0000)
# - id (6612, 1) mass 445.2437 rt 2313.90 MAP_trans M+H@444.23640(1.0000)
# - id (8065, 2) mass 445.2434 rt 2309.94 MAP_trans M+H@444.23586(1.0000)
# - id (5081, 3) mass 445.2444 rt 2311.92 MAP_trans M+H@444.23731(1.0000)
# Group 652
# - id (5119, 0) mass 315.2080 rt 2343.90 MAP_trans M+H@314.20073(1.0000)
# - id (6636, 1) mass 315.2050 rt 2345.94 MAP_trans M+H@314.19774(1.0000)
# - id (8088, 2) mass 315.2031 rt 2345.94 MAP_trans M+H@314.19578(1.0000)
# - id (5126, 3) mass 315.2097 rt 2343.90 MAP_trans M+H@314.20239(1.0000)
# Group 653
# - id (5125, 0) mass 349.1717 rt 2343.90 MAP_trans M+H@348.16447(0.9907)
# - id (6657, 1) mass 349.1702 rt 2345.94 MAP_trans M+H@348.16289(1.0000)
# - id (8080, 2) mass 349.1759 rt 2345.94 MAP_trans M+H@348.16867(1.0000)
# - id (5095, 3) mass 349.1745 rt 2343.90 MAP_trans M+H@348.16705(1.0000)
# Group 654
# - id (5106, 0) mass 446.2440 rt 2305.92 MAP_trans M+H@445.23670(1.0000)
# - id (8054, 2) mass 446.2325 rt 2309.94 MAP_trans M+H@445.22525(1.0000)
# - id (5053, 3) mass 446.2418 rt 2307.90 MAP_trans M+H@445.23453(1.0000)
# Group 655
# - id (5139, 0) mass 373.6789 rt 2359.92 MAP_trans M+H@372.67157(1.0000)
# - id (6678, 1) mass 373.6756 rt 2361.90 MAP_trans M+H@372.66833(1.0000)
# - id (8137, 2) mass 373.6816 rt 2361.90 MAP_trans M+H@372.67433(1.0000)
# - id (5142, 3) mass 373.6775 rt 2359.92 MAP_trans M+H@372.67025(1.0000)
# Group 656
# - id (5157, 0) mass 373.1788 rt 2359.92 MAP_trans M+H@372.17149(1.0000)
# - id (6673, 1) mass 373.1761 rt 2361.90 MAP_trans M+H@372.16879(1.0000)
# - id (8119, 2) mass 373.1776 rt 2361.90 MAP_trans M+H@372.17028(1.0000)
# - id (5162, 3) mass 373.1784 rt 2359.92 MAP_trans M+H@372.17108(1.0000)
# Group 657
# - id (5200, 0) mass 409.1985 rt 2413.92 MAP_trans M+H@408.19118(1.0000)
# Group 658
# - id (5833, 0) mass 347.2258 rt 2415.90 MAP_trans M+H@346.21855(1.0000)
# Group 659
# - id (5145, 0) mass 389.1941 rt 2381.94 MAP_trans M+H@388.18672(1.0000)
# - id (8098, 2) mass 389.1959 rt 2383.92 MAP_trans M+H@388.18808(1.0000)
# Group 660
# - id (5169, 0) mass 389.6974 rt 2381.94 MAP_trans M+H@388.69042(1.0000)
# - id (8174, 2) mass 389.6981 rt 2383.92 MAP_trans M+H@388.69080(1.0000)
# Group 661
# - id (5153, 0) mass 263.2168 rt 2385.90 MAP_trans M+H@262.20952(1.0000)
# - id (8129, 2) mass 263.2198 rt 2387.94 MAP_trans M+H@262.21255(1.0000)
# Group 662
# - id (5166, 0) mass 447.2425 rt 2385.90 MAP_trans M+H@446.23513(1.0000)
# - id (9114, 2) mass 447.2443 rt 2387.94 MAP_trans M+H@446.23728(1.0000)
# Group 663
# - id (5197, 0) mass 447.7493 rt 2385.90 MAP_trans M+H@446.74206(1.0000)
# - id (8173, 2) mass 447.7489 rt 2387.94 MAP_trans M+H@446.74159(1.0000)
# Group 664
# - id (5158, 0) mass 349.2271 rt 2413.92 MAP_trans M+H@348.21981(1.0000)
# - id (6747, 1) mass 349.2263 rt 2415.90 MAP_trans M+H@348.21904(1.0000)
# - id (5178, 3) mass 349.2218 rt 2363.94 MAP_trans M+H@348.21454(1.0000)
# Group 665
# - id (5229, 0) mass 499.1912 rt 2411.94 MAP_trans M+H@498.18398(1.0000)
# - id (6744, 1) mass 499.1877 rt 2413.92 MAP_trans M+H@498.18041(1.0000)
# - id (8218, 2) mass 499.1910 rt 2411.94 MAP_trans M+H@498.18376(1.0000)
# - id (5228, 3) mass 499.2016 rt 2411.94 MAP_trans M+H@498.19433(1.0000)
# Group 666
# - id (5262, 0) mass 347.2248 rt 2477.94 MAP_trans M+H@346.21752(1.0000)
# - id (8281, 2) mass 347.2246 rt 2479.92 MAP_trans M+H@346.21729(1.0000)
# - id (5293, 3) mass 347.2240 rt 2475.90 MAP_trans M+H@346.21674(1.0000)
# Group 667
# - id (5277, 0) mass 345.2095 rt 2477.94 MAP_trans M+H@344.20227(1.0000)
# - id (8311, 2) mass 345.2090 rt 2477.94 MAP_trans M+H@344.20185(1.0000)
# - id (5291, 3) mass 345.2073 rt 2473.92 MAP_trans M+H@344.20001(1.0000)
# Group 668
# - id (5282, 0) mass 199.1036 rt 2525.88 MAP_trans M+H@198.09630(1.0000)
# - id (6813, 1) mass 199.1027 rt 2527.92 MAP_trans M+H@198.09547(1.0000)
# Group 669
# - id (5323, 0) mass 345.2095 rt 2525.88 MAP_trans M+H@344.20221(1.0000)
# - id (6848, 1) mass 345.2090 rt 2525.88 MAP_trans M+H@344.20170(1.0000)
# Group 670
# - id (5326, 0) mass 291.2091 rt 2525.88 MAP_trans M+H@290.20177(1.0000)
# - id (6839, 1) mass 291.2074 rt 2527.92 MAP_trans M+H@290.19974(1.0000)
# Group 671
# - id (5333, 0) mass 346.2075 rt 2525.88 MAP_trans M+H@345.20019(1.0000)
# - id (6849, 1) mass 346.2066 rt 2525.88 MAP_trans M+H@345.19927(1.0000)
# Group 672
# - id (5313, 0) mass 333.2145 rt 2499.90 MAP_trans M+H@332.20718(1.0000)
# - id (6814, 1) mass 333.2141 rt 2501.94 MAP_trans M+H@332.20680(1.0000)
# - id (8328, 2) mass 333.2162 rt 2501.94 MAP_trans M+H@332.20890(1.0000)
# - id (5298, 3) mass 333.2166 rt 2497.92 MAP_trans M+H@332.20935(1.0000)
# Group 673
# - id (5837, 0) mass 279.1952 rt 2499.90 MAP_trans M+H@278.18796(1.0000)
# - id (7511, 1) mass 279.1939 rt 2501.94 MAP_trans M+H@278.18664(1.0000)
# - id (9089, 2) mass 279.2003 rt 2501.94 MAP_trans M+H@278.19306(1.0000)
# - id (5703, 3) mass 279.1956 rt 2497.92 MAP_trans M+H@278.18833(1.0000)
# Group 674
# - id (5338, 0) mass 191.1087 rt 2603.88 MAP_trans M+H@190.10143(1.0000)
# - id (6860, 1) mass 191.1058 rt 2605.92 MAP_trans M+H@190.09854(1.0000)
# - id (8380, 2) mass 191.1087 rt 2603.88 MAP_trans M+H@190.10142(1.0000)
# - id (5364, 3) mass 191.1081 rt 2601.90 MAP_trans M+H@190.10081(1.0000)
# Group 675
# - id (5367, 0) mass 329.2189 rt 2603.88 MAP_trans M+H@328.21160(1.0000)
# - id (6897, 1) mass 329.2203 rt 2605.92 MAP_trans M+H@328.21284(1.0000)
# - id (8413, 2) mass 329.2200 rt 2603.88 MAP_trans M+H@328.21272(1.0000)
# - id (5385, 3) mass 329.2220 rt 2599.92 MAP_trans M+H@328.21476(1.0000)
# Group 676
# - id (5370, 0) mass 275.2134 rt 2603.88 MAP_trans M+H@274.20614(1.0000)
# - id (6890, 1) mass 275.2179 rt 2605.92 MAP_trans M+H@274.21063(1.0000)
# - id (8390, 2) mass 275.2143 rt 2603.88 MAP_trans M+H@274.20706(1.0000)
# - id (5374, 3) mass 275.2139 rt 2601.90 MAP_trans M+H@274.20666(1.0000)
# Group 677
# - id (5371, 0) mass 307.2317 rt 2603.88 MAP_trans M+H@306.22449(1.0000)
# - id (6893, 1) mass 307.2364 rt 2605.92 MAP_trans M+H@306.22925(1.0000)
# - id (8408, 2) mass 307.2358 rt 2603.88 MAP_trans M+H@306.22915(1.0000)
# - id (5387, 3) mass 307.2322 rt 2599.92 MAP_trans M+H@306.22495(1.0000)
# Group 678
# - id (5411, 0) mass 309.2150 rt 2707.92 MAP_trans M+H@308.20777(1.0000)
# - id (6929, 1) mass 309.2162 rt 2711.88 MAP_trans M+H@308.20889(1.0000)
# Group 679
# - id (5391, 0) mass 199.1786 rt 2707.92 MAP_trans M+H@198.17134(1.0000)
# - id (6925, 1) mass 199.1783 rt 2711.88 MAP_trans M+H@198.17103(1.0000)
# - id (8429, 2) mass 199.1742 rt 2709.90 MAP_trans M+H@198.16693(1.0000)
# - id (5417, 3) mass 199.1738 rt 2707.92 MAP_trans M+H@198.16650(1.0000)
# Group 680
# - id (5376, 0) mass 331.2332 rt 2625.90 MAP_trans M+H@330.22593(1.0000)
# - id (6906, 1) mass 331.2305 rt 2629.92 MAP_trans M+H@330.22326(1.0000)
# - id (8419, 2) mass 331.2356 rt 2627.88 MAP_trans M+H@330.22829(1.0000)
# - id (5403, 3) mass 331.2345 rt 2623.92 MAP_trans M+H@330.22722(1.0000)
# Group 681
# - id (5378, 0) mass 291.2413 rt 2627.88 MAP_trans M+H@290.23398(1.0000)
# - id (6887, 1) mass 291.2444 rt 2629.92 MAP_trans M+H@290.23752(1.0000)
# - id (8425, 2) mass 291.2441 rt 2627.88 MAP_trans M+H@290.23683(1.0000)
# - id (5384, 3) mass 291.2442 rt 2623.92 MAP_trans M+H@290.23695(1.0000)
# Group 682
# - id (5414, 0) mass 361.2345 rt 2733.90 MAP_trans M+H@360.22699(1.0000)
# - id (6944, 1) mass 361.2339 rt 2737.92 MAP_trans M+H@360.22637(1.0000)
# - id (8467, 2) mass 361.2341 rt 2735.88 MAP_trans M+H@360.22686(1.0000)
# - id (5444, 3) mass 361.2344 rt 2733.90 MAP_trans M+H@360.22703(1.0000)
# Group 683
# - id (5408, 0) mass 330.2167 rt 2701.92 MAP_trans M+H@329.20946(1.0000)
# - id (6931, 1) mass 330.2163 rt 2705.88 MAP_trans M+H@329.20900(1.0000)
# - id (8445, 2) mass 330.2248 rt 2701.92 MAP_trans M+H@329.21757(0.7990)
# - id (5433, 3) mass 330.2186 rt 2701.92 MAP_trans M+H@329.21128(1.0000)
# Group 684
# - id (5409, 0) mass 329.2195 rt 2701.92 MAP_trans M+H@328.21226(1.0000)
# - id (6933, 1) mass 329.2191 rt 2705.88 MAP_trans M+H@328.21180(1.0000)
# - id (8449, 2) mass 329.2191 rt 2701.92 MAP_trans M+H@328.21208(1.0000)
# - id (5429, 3) mass 329.2222 rt 2701.92 MAP_trans M+H@328.21490(1.0000)
# Group 685
# - id (5526, 0) mass 535.3254 rt 1105.98 MAP_trans M+H@534.31814(1.0000)
# Group 686
# - id (5531, 0) mass 534.9953 rt 1103.94 MAP_trans M+H@533.98826(1.0000)
# Group 687
# - id (5534, 0) mass 534.6595 rt 1103.94 MAP_trans M+H@533.65226(1.0000)
# Group 688
# - id (5724, 0) mass 425.2258 rt 2357.94 MAP_trans M+H@424.21854(1.0000)
# Group 689
# - id (5799, 0) mass 425.7344 rt 2357.94 MAP_trans M+H@424.72714(1.0000)
# Group 690
# - id (5770, 0) mass 440.2371 rt 2219.94 MAP_trans M+H@439.22983(1.0000)

# %% [markdown]
# Print the not-found ones

# %%
def find_overlap(gt_entry, aligned_peaksets):
    overlap = []
    for ps in aligned_peaksets:
        ps_keys = [f._get_key() for f in ps]
        any_found = False
        for f in gt_entry:
            if f._get_key() in ps_keys:
                any_found = True
        if any_found:
            overlap.append(ps)
    return overlap

def print_peakset(peakset):
    print "\tPeakset"
    for f in peakset:
        key = f._get_key()
        annot = aligner.annotations[key]
        print "\t- id %s mass %.4f rt %.2f MAP_trans %s" % ((key, f.mass, f.rt, annot))

# %%
for group in not_found_list:
    
    print "Ground Truth Group %d" % i
    i += 1
    for f in group:
        key = f._get_key()
        print "- id %s mass %.4f rt %.2f" % ((key, f.mass, f.rt))
    
    print "Overlapping peaksets:"
    overlap = find_overlap(group, aligned_peaksets)
    for ps in overlap:
        print_peakset(ps)
    print
# Out:
# Ground Truth Group 691
# - id (157, 0) mass 133.0316 rt 226.02
# - id (241, 1) mass 133.0371 rt 226.02
# - id (312, 2) mass 133.0342 rt 228.00
# - id (125, 3) mass 133.0340 rt 222.00
# Overlapping peaksets:
# 	Peakset
# 	- id (157, 0) mass 133.0316 rt 226.02 MAP_trans [M-CO2]+Na [C13]@153.02872(0.7968)
# 	- id (125, 3) mass 133.0340 rt 222.00 MAP_trans [M-CO2]+Na [C13]@153.03164(0.7972)
#
# Ground Truth Group 692
# - id (215, 0) mass 156.0391 rt 226.02
# - id (279, 1) mass 156.0393 rt 226.02
# - id (324, 2) mass 156.0412 rt 226.02
# - id (171, 3) mass 156.0426 rt 222.00
# Overlapping peaksets:
# 	Peakset
# 	- id (215, 0) mass 156.0391 rt 226.02 MAP_trans M+H@155.03176(1.0000)
# 	- id (324, 2) mass 156.0412 rt 226.02 MAP_trans M+H@155.03399(0.8923)
# 	- id (171, 3) mass 156.0426 rt 222.00 MAP_trans M+H@155.03534(1.0000)
# 	Peakset
# 	- id (279, 1) mass 156.0393 rt 226.02 MAP_trans [M-CO]+H [C13]@182.02356(1.0000)
#
# Ground Truth Group 693
# - id (221, 0) mass 198.0324 rt 223.98
# - id (318, 1) mass 198.0328 rt 223.98
# - id (719, 2) mass 198.0349 rt 223.98
# - id (266, 3) mass 198.0326 rt 222.00
# Overlapping peaksets:
# 	Peakset
# 	- id (221, 0) mass 198.0324 rt 223.98 MAP_trans [M-CO2]+Na@219.03385(1.0000)
# 	- id (719, 2) mass 198.0349 rt 223.98 MAP_trans [M-CO2]+Na@219.03575(1.0000)
# 	Peakset
# 	- id (266, 3) mass 198.0326 rt 222.00 MAP_trans M+H@197.02532(0.9715)
#
# Ground Truth Group 694
# - id (324, 0) mass 206.5316 rt 223.98
# - id (662, 1) mass 206.5338 rt 226.02
# - id (759, 2) mass 206.5340 rt 226.02
# - id (261, 3) mass 206.5293 rt 222.00
# Overlapping peaksets:
# 	Peakset
# 	- id (662, 1) mass 206.5338 rt 226.02 MAP_trans M+H [C13]@204.52364(0.8093)
# 	Peakset
# 	- id (759, 2) mass 206.5340 rt 226.02 MAP_trans M+H@205.52681(0.9865)
# 	- id (261, 3) mass 206.5293 rt 222.00 MAP_trans M+H@205.52202(0.8641)
# 	Peakset
# 	- id (324, 0) mass 206.5316 rt 223.98 MAP_trans M+2H [C13]@410.04537(0.8730)
#
# Ground Truth Group 695
# - id (421, 0) mass 212.0226 rt 222.00
# - id (780, 1) mass 212.0234 rt 223.98
# - id (760, 2) mass 212.0215 rt 223.98
# - id (419, 3) mass 212.0209 rt 222.00
# Overlapping peaksets:
# 	Peakset
# 	- id (760, 2) mass 212.0215 rt 223.98 MAP_trans [M-H2O]+Na [C13]@206.03996(0.9999)
# 	Peakset
# 	- id (421, 0) mass 212.0226 rt 222.00 MAP_trans M+H@211.01538(1.0000)
# 	- id (780, 1) mass 212.0234 rt 223.98 MAP_trans M+H@211.01611(1.0000)
# 	- id (419, 3) mass 212.0209 rt 222.00 MAP_trans M+H@211.01363(1.0000)
#
# Ground Truth Group 696
# - id (422, 0) mass 229.0459 rt 223.98
# - id (947, 1) mass 229.0482 rt 226.02
# - id (992, 2) mass 229.0493 rt 226.02
# - id (396, 3) mass 229.0487 rt 223.98
# Overlapping peaksets:
# 	Peakset
# 	- id (422, 0) mass 229.0459 rt 223.98 MAP_trans [M-H2O]+ACN+H [C13]@204.01928(0.9999)
# 	- id (992, 2) mass 229.0493 rt 226.02 MAP_trans [M-H2O]+ACN+H [C13]@204.02356(1.0000)
# 	Peakset
# 	- id (396, 3) mass 229.0487 rt 223.98 MAP_trans M+H@228.04140(1.0000)
#
# Ground Truth Group 697
# - id (452, 0) mass 245.0158 rt 222.00
# - id (966, 1) mass 245.0160 rt 223.98
# - id (968, 2) mass 245.0185 rt 223.98
# - id (402, 3) mass 245.0144 rt 220.02
# Overlapping peaksets:
# 	Peakset
# 	- id (452, 0) mass 245.0158 rt 222.00 MAP_trans [M-CO2]+Na@266.01586(0.6056)
# 	- id (402, 3) mass 245.0144 rt 220.02 MAP_trans [M-CO2]+Na@266.01525(0.5056)
# 	Peakset
# 	- id (966, 1) mass 245.0160 rt 223.98 MAP_trans M+H@244.00868(0.5784)
# 	- id (968, 2) mass 245.0185 rt 223.98 MAP_trans M+H@244.01165(0.9995)
#
# Ground Truth Group 698
# - id (675, 0) mass 284.0435 rt 222.00
# - id (1327, 1) mass 284.0365 rt 223.98
# - id (1510, 2) mass 284.0466 rt 222.00
# - id (571, 3) mass 284.0420 rt 220.02
# Overlapping peaksets:
# 	Peakset
# 	- id (675, 0) mass 284.0435 rt 222.00 MAP_trans M+H [C13]@282.03393(0.9999)
# 	Peakset
# 	- id (1510, 2) mass 284.0466 rt 222.00 MAP_trans M+NH4@266.01377(0.8797)
# 	Peakset
# 	- id (571, 3) mass 284.0420 rt 220.02 MAP_trans M+H@283.03469(1.0000)
#
# Ground Truth Group 699
# - id (699, 0) mass 362.0979 rt 226.02
# - id (2176, 1) mass 362.1073 rt 228.00
# - id (1821, 2) mass 362.1046 rt 228.00
# - id (805, 3) mass 362.0958 rt 223.98
# Overlapping peaksets:
# 	Peakset
# 	- id (2176, 1) mass 362.1073 rt 228.00 MAP_trans M+H@361.10003(1.0000)
# 	- id (1821, 2) mass 362.1046 rt 228.00 MAP_trans M+H@361.09735(1.0000)
# 	- id (805, 3) mass 362.0958 rt 223.98 MAP_trans M+H@361.08854(1.0000)
#
# Ground Truth Group 700
# - id (710, 0) mass 294.0702 rt 226.02
# - id (1601, 1) mass 294.0738 rt 228.00
# - id (1440, 2) mass 294.0708 rt 228.00
# - id (477, 3) mass 294.0669 rt 223.98
# Overlapping peaksets:
# 	Peakset
# 	- id (710, 0) mass 294.0702 rt 226.02 MAP_trans [M-H2O]+H@311.07213(0.7518)
# 	- id (1440, 2) mass 294.0708 rt 228.00 MAP_trans [M-H2O]+H@311.07359(1.0000)
# 	- id (477, 3) mass 294.0669 rt 223.98 MAP_trans [M-H2O]+H@311.07040(0.9916)
#
# Ground Truth Group 701
# - id (726, 0) mass 294.5712 rt 228.00
# - id (1957, 1) mass 294.5733 rt 228.00
# - id (2116, 2) mass 294.5757 rt 229.98
# - id (572, 3) mass 294.5703 rt 226.02
# Overlapping peaksets:
# 	Peakset
# 	- id (1957, 1) mass 294.5733 rt 228.00 MAP_trans [M-H2O]+H@311.57633(0.9999)
# 	- id (2116, 2) mass 294.5757 rt 229.98 MAP_trans [M-H2O]+H@311.57902(1.0000)
# 	Peakset
# 	- id (572, 3) mass 294.5703 rt 226.02 MAP_trans M+H@293.56338(0.6729)
#
# Ground Truth Group 702
# - id (749, 0) mass 310.0771 rt 226.02
# - id (1638, 1) mass 310.0752 rt 226.02
# - id (1747, 2) mass 310.0717 rt 226.02
# - id (848, 3) mass 310.0827 rt 226.02
# Overlapping peaksets:
# 	Peakset
# 	- id (749, 0) mass 310.0771 rt 226.02 MAP_trans [M-H2O]+ACN+H@286.05309(0.9850)
# 	- id (848, 3) mass 310.0827 rt 226.02 MAP_trans [M-H2O]+ACN+H@286.05990(0.9999)
# 	Peakset
# 	- id (1638, 1) mass 310.0752 rt 226.02 MAP_trans M+H@309.06804(0.7667)
# 	- id (1747, 2) mass 310.0717 rt 226.02 MAP_trans M+H@309.06442(0.9612)
#
# Ground Truth Group 703
# - id (769, 0) mass 314.0570 rt 223.98
# - id (1386, 1) mass 314.0526 rt 223.98
# - id (1553, 2) mass 314.0611 rt 223.98
# - id (787, 3) mass 314.0641 rt 223.98
# Overlapping peaksets:
# 	Peakset
# 	- id (1553, 2) mass 314.0611 rt 223.98 MAP_trans [M-CO]+Na [C13]@318.06395(0.9999)
# 	Peakset
# 	- id (769, 0) mass 314.0570 rt 223.98 MAP_trans M+H@313.04969(1.0000)
# 	- id (1386, 1) mass 314.0526 rt 223.98 MAP_trans M+H@313.04529(1.0000)
# 	- id (787, 3) mass 314.0641 rt 223.98 MAP_trans M+H@313.05681(1.0000)
#
# Ground Truth Group 704
# - id (823, 0) mass 321.0635 rt 223.98
# - id (2109, 1) mass 321.0567 rt 223.98
# - id (1700, 2) mass 321.0624 rt 223.98
# - id (811, 3) mass 321.0658 rt 223.98
# Overlapping peaksets:
# 	Peakset
# 	- id (2109, 1) mass 321.0567 rt 223.98 MAP_trans M+H@320.04943(1.0000)
# 	- id (1700, 2) mass 321.0624 rt 223.98 MAP_trans M+H@320.05509(1.0000)
# 	- id (811, 3) mass 321.0658 rt 223.98 MAP_trans M+H@320.05819(1.0000)
# 	Peakset
# 	- id (823, 0) mass 321.0635 rt 223.98 MAP_trans [M-CH2O2]+NH4 [C13]@348.03173(0.9999)
#
# Ground Truth Group 705
# - id (845, 0) mass 396.0568 rt 223.98
# - id (1964, 1) mass 396.0542 rt 223.98
# - id (2059, 2) mass 396.0541 rt 223.98
# - id (892, 3) mass 396.0534 rt 220.02
# Overlapping peaksets:
# 	Peakset
# 	- id (1964, 1) mass 396.0542 rt 223.98 MAP_trans [M-CO]+H [C13]@422.03786(1.0000)
# 	Peakset
# 	- id (2598, 1) mass 396.0471 rt 271.98 MAP_trans M+H@395.03987(1.0000)
# 	- id (2059, 2) mass 396.0541 rt 223.98 MAP_trans M+H@395.04741(0.5243)
# 	- id (892, 3) mass 396.0534 rt 220.02 MAP_trans M+H@395.04609(1.0000)
#
# Ground Truth Group 706
# - id (981, 0) mass 409.0607 rt 223.98
# - id (1830, 1) mass 409.0650 rt 226.02
# - id (2333, 2) mass 409.0692 rt 226.02
# - id (700, 3) mass 409.0642 rt 223.98
# Overlapping peaksets:
# 	Peakset
# 	- id (2333, 2) mass 409.0692 rt 226.02 MAP_trans [M-H2O]+H@426.07371(0.9999)
# 	Peakset
# 	- id (981, 0) mass 409.0607 rt 223.98 MAP_trans M+H@408.05346(1.0000)
# 	- id (1830, 1) mass 409.0650 rt 226.02 MAP_trans M+H@408.05841(0.9775)
# 	- id (700, 3) mass 409.0642 rt 223.98 MAP_trans M+H@408.05636(0.9997)
#
# Ground Truth Group 707
# - id (988, 0) mass 388.0430 rt 222.00
# - id (1737, 1) mass 388.0474 rt 222.00
# - id (2234, 2) mass 388.0450 rt 222.00
# - id (967, 3) mass 388.0441 rt 216.00
# Overlapping peaksets:
# 	Peakset
# 	- id (2234, 2) mass 388.0450 rt 222.00 MAP_trans [M-CH2O2]+Na@411.05973(0.9999)
# 	Peakset
# 	- id (967, 3) mass 388.0441 rt 216.00 MAP_trans [M-CO]+ACN+H@374.00348(0.5775)
#
# Ground Truth Group 708
# - id (1026, 0) mass 506.0804 rt 223.98
# - id (2413, 1) mass 506.0806 rt 226.02
# - id (2676, 2) mass 506.0804 rt 223.98
# - id (1199, 3) mass 506.0765 rt 222.00
# Overlapping peaksets:
# 	Peakset
# 	- id (1199, 3) mass 506.0765 rt 222.00 MAP_trans M+Na [C13]@482.08413(0.9999)
# 	Peakset
# 	- id (1026, 0) mass 506.0804 rt 223.98 MAP_trans M+H@505.07360(1.0000)
# 	- id (2413, 1) mass 506.0806 rt 226.02 MAP_trans M+H@505.07339(1.0000)
# 	- id (2676, 2) mass 506.0804 rt 223.98 MAP_trans M+H@505.07407(1.0000)
#
# Ground Truth Group 709
# - id (16, 0) mass 85.9488 rt 223.98
# Overlapping peaksets:
#
# Ground Truth Group 710
# - id (585, 0) mass 278.0430 rt 222.00
# - id (1238, 1) mass 278.0487 rt 223.98
# - id (1457, 2) mass 278.0478 rt 222.00
# - id (578, 3) mass 278.0478 rt 222.00
# Overlapping peaksets:
# 	Peakset
# 	- id (585, 0) mass 278.0430 rt 222.00 MAP_trans M+H@277.03575(0.9519)
# 	- id (1457, 2) mass 278.0478 rt 222.00 MAP_trans M+H@277.04056(1.0000)
# 	- id (578, 3) mass 278.0478 rt 222.00 MAP_trans M+H@277.04055(0.5885)
# 	Peakset
# 	- id (1238, 1) mass 278.0487 rt 223.98 MAP_trans [M-CH2O2]+H [C13]@322.04333(0.9999)
#
# Ground Truth Group 711
# - id (780, 0) mass 444.0671 rt 217.98
# - id (2096, 1) mass 444.0731 rt 217.98
# - id (2336, 2) mass 444.0734 rt 217.98
# - id (861, 3) mass 444.0652 rt 217.98
# Overlapping peaksets:
# 	Peakset
# 	- id (2096, 1) mass 444.0731 rt 217.98 MAP_trans M+H@443.06579(1.0000)
# 	- id (2336, 2) mass 444.0734 rt 217.98 MAP_trans M+H@443.06593(0.9951)
# 	- id (861, 3) mass 444.0652 rt 217.98 MAP_trans M+H@443.05729(0.7198)
# 	Peakset
# 	- id (780, 0) mass 444.0671 rt 217.98 MAP_trans [M-H2O]+H@461.07192(0.9999)
#
# Ground Truth Group 712
# - id (1039, 0) mass 526.0541 rt 222.00
# - id (2258, 1) mass 526.0617 rt 217.98
# - id (2405, 2) mass 526.0653 rt 222.00
# Overlapping peaksets:
# 	Peakset
# 	- id (2405, 2) mass 526.0653 rt 222.00 MAP_trans [M-CO]+K [C13]@514.09298(1.0000)
#
# Ground Truth Group 713
# - id (1250, 0) mass 471.0800 rt 223.98
# - id (2373, 1) mass 471.0968 rt 226.02
# - id (2507, 2) mass 471.0963 rt 223.98
# Overlapping peaksets:
# 	Peakset
# 	- id (2507, 2) mass 471.0963 rt 223.98 MAP_trans [M-CH2O2]+H@516.09661(1.0000)
#
# Ground Truth Group 714
# - id (506, 0) mass 230.8839 rt 214.02
# - id (843, 1) mass 230.8945 rt 211.98
# - id (1053, 2) mass 230.8925 rt 214.02
# - id (409, 3) mass 230.8811 rt 214.02
# Overlapping peaksets:
# 	Peakset
# 	- id (843, 1) mass 230.8945 rt 211.98 MAP_trans M+H@229.88724(1.0000)
# 	- id (1053, 2) mass 230.8925 rt 214.02 MAP_trans M+H@229.88523(1.0000)
# 	Peakset
# 	- id (409, 3) mass 230.8811 rt 214.02 MAP_trans M+H@229.87384(1.0000)
#
# Ground Truth Group 715
# - id (147, 0) mass 119.9681 rt 211.98
# - id (216, 1) mass 119.9676 rt 211.98
# - id (212, 2) mass 119.9732 rt 208.02
# - id (176, 3) mass 119.9682 rt 211.98
# - id (216, 1) mass 119.9676 rt 211.98
# Overlapping peaksets:
# 	Peakset
# 	- id (147, 0) mass 119.9681 rt 211.98 MAP_trans M+H@118.96080(1.0000)
# 	- id (216, 1) mass 119.9676 rt 211.98 MAP_trans M+H@118.96033(1.0000)
# 	- id (176, 3) mass 119.9682 rt 211.98 MAP_trans M+H@118.96090(1.0000)
#
# Ground Truth Group 716
# - id (1040, 0) mass 407.5320 rt 222.00
# - id (2245, 1) mass 407.5424 rt 223.98
# Overlapping peaksets:
# 	Peakset
# 	- id (2245, 1) mass 407.5424 rt 223.98 MAP_trans [M-CO2]+Na [C13]@427.53769(0.9787)
#
# Ground Truth Group 717
# - id (560, 0) mass 282.0242 rt 216.00
# - id (1334, 1) mass 282.0251 rt 211.98
# - id (706, 3) mass 282.0280 rt 214.02
# Overlapping peaksets:
# 	Peakset
# 	- id (1495, 2) mass 282.0252 rt 211.98 MAP_trans [M-H2O]+H@299.02940(0.9999)
# 	- id (706, 3) mass 282.0280 rt 214.02 MAP_trans [M-H2O]+H@299.03008(0.9999)
#
# Ground Truth Group 718
# - id (915, 0) mass 516.0020 rt 217.98
# - id (2303, 1) mass 515.9832 rt 211.98
# - id (971, 3) mass 515.9838 rt 216.00
# Overlapping peaksets:
# 	Peakset
# 	- id (2303, 1) mass 515.9832 rt 211.98 MAP_trans M+H@514.97587(1.0000)
# 	- id (2794, 2) mass 515.9786 rt 211.98 MAP_trans M+H@514.97137(1.0000)
# 	- id (971, 3) mass 515.9838 rt 216.00 MAP_trans M+H@514.97652(1.0000)
#
# Ground Truth Group 719
# - id (805, 0) mass 482.0497 rt 217.98
# - id (786, 3) mass 482.0381 rt 216.00
# Overlapping peaksets:
# 	Peakset
# 	- id (805, 0) mass 482.0497 rt 217.98 MAP_trans M+H@481.04246(0.9932)
# 	- id (2003, 1) mass 482.0483 rt 217.98 MAP_trans M+H@481.03988(1.0000)
# 	- id (2838, 2) mass 482.0606 rt 216.00 MAP_trans M+H@481.05365(1.0000)
# 	Peakset
# 	- id (786, 3) mass 482.0381 rt 216.00 MAP_trans M+H@481.03083(1.0000)
#
# Ground Truth Group 720
# - id (5485, 0) mass 253.0007 rt 214.02
# - id (522, 3) mass 252.9816 rt 214.02
# Overlapping peaksets:
# 	Peakset
# 	- id (522, 3) mass 252.9816 rt 214.02 MAP_trans M+H@251.97428(1.0000)
#
# Ground Truth Group 721
# - id (806, 0) mass 344.0246 rt 220.02
# - id (1610, 1) mass 344.0226 rt 220.02
# Overlapping peaksets:
#
# Ground Truth Group 722
# - id (882, 0) mass 461.0277 rt 220.02
# - id (2117, 1) mass 461.0293 rt 220.02
# Overlapping peaksets:
# 	Peakset
# 	- id (882, 0) mass 461.0277 rt 220.02 MAP_trans M+Na [C13]@437.03489(0.9998)
#
# Ground Truth Group 723
# - id (849, 0) mass 332.5295 rt 220.02
# - id (1873, 1) mass 332.5396 rt 220.02
# - id (752, 3) mass 332.5266 rt 217.98
# Overlapping peaksets:
# 	Peakset
# 	- id (752, 3) mass 332.5266 rt 217.98 MAP_trans M+H@331.51928(1.0000)
#
# Ground Truth Group 724
# - id (1021, 0) mass 405.5232 rt 222.00
# - id (2243, 1) mass 405.5388 rt 222.00
# Overlapping peaksets:
# 	Peakset
# 	- id (1021, 0) mass 405.5232 rt 222.00 MAP_trans [M-CH2O2]+Na [C13]@427.53361(0.8395)
#
# Ground Truth Group 725
# - id (1045, 0) mass 533.0832 rt 220.02
# - id (2305, 1) mass 533.0950 rt 222.00
# Overlapping peaksets:
# 	Peakset
# 	- id (2305, 1) mass 533.0950 rt 222.00 MAP_trans [M-CO]+ACN+H [C13]@518.05225(0.9597)
#
# Ground Truth Group 726
# - id (203, 0) mass 105.9639 rt 232.02
# - id (329, 2) mass 105.9611 rt 234.00
# Overlapping peaksets:
# 	Peakset
# 	- id (203, 0) mass 105.9639 rt 232.02 MAP_trans M+H@104.95665(1.0000)
# 	- id (268, 1) mass 105.9653 rt 232.02 MAP_trans M+H@104.95807(1.0000)
# 	- id (101, 3) mass 105.9621 rt 232.02 MAP_trans M+H@104.95480(1.0000)
#
# Ground Truth Group 727
# - id (236, 0) mass 107.9626 rt 232.02
# - id (588, 2) mass 107.9524 rt 234.00
# Overlapping peaksets:
#
# Ground Truth Group 728
# - id (22, 0) mass 84.0113 rt 190.02
# - id (19, 3) mass 84.0153 rt 187.98
# Overlapping peaksets:
# 	Peakset
# 	- id (18, 1) mass 84.0140 rt 187.98 MAP_trans M+H@83.00671(1.0000)
# 	- id (48, 2) mass 84.0148 rt 187.98 MAP_trans M+H@83.00754(1.0000)
# 	- id (19, 3) mass 84.0153 rt 187.98 MAP_trans M+H@83.00803(1.0000)
#
# Ground Truth Group 729
# - id (49, 0) mass 87.9925 rt 192.00
# - id (32, 3) mass 87.9960 rt 192.00
# Overlapping peaksets:
# 	Peakset
# 	- id (49, 0) mass 87.9925 rt 192.00 MAP_trans M+H@86.98521(1.0000)
# 	Peakset
# 	- id (32, 3) mass 87.9960 rt 192.00 MAP_trans M+H@86.98861(1.0000)
#
# Ground Truth Group 730
# - id (58, 0) mass 112.0087 rt 192.00
# - id (55, 3) mass 112.0063 rt 192.00
# Overlapping peaksets:
# 	Peakset
# 	- id (58, 0) mass 112.0087 rt 192.00 MAP_trans M+H@111.00139(1.0000)
# 	- id (64, 1) mass 112.0117 rt 192.00 MAP_trans M+H@111.00432(0.9924)
# 	- id (16, 2) mass 112.0112 rt 192.00 MAP_trans M+H@111.00388(0.9978)
# 	Peakset
# 	- id (55, 3) mass 112.0063 rt 192.00 MAP_trans M+H@110.99900(1.0000)
#
# Ground Truth Group 731
# - id (259, 0) mass 240.9328 rt 196.02
# - id (239, 3) mass 240.9265 rt 196.02
# Overlapping peaksets:
# 	Peakset
# 	- id (239, 3) mass 240.9265 rt 196.02 MAP_trans M+H@239.91923(1.0000)
#
# Ground Truth Group 732
# - id (544, 0) mass 498.8824 rt 193.98
# - id (597, 1) mass 498.8720 rt 190.02
# - id (658, 2) mass 498.8676 rt 190.02
# Overlapping peaksets:
# 	Peakset
# 	- id (544, 0) mass 498.8824 rt 193.98 MAP_trans M+H@497.87521(1.0000)
# 	- id (597, 1) mass 498.8720 rt 190.02 MAP_trans M+H@497.86500(1.0000)
# 	- id (499, 3) mass 498.8726 rt 192.00 MAP_trans M+H@497.86348(1.0000)
# 	Peakset
# 	- id (658, 2) mass 498.8676 rt 190.02 MAP_trans M+Na@475.87583(0.9999)
#
# Ground Truth Group 733
# - id (202, 0) mass 220.9932 rt 190.02
# - id (309, 1) mass 220.9889 rt 187.98
# - id (382, 2) mass 220.9875 rt 187.98
# - id (204, 3) mass 220.9872 rt 187.98
# Overlapping peaksets:
# 	Peakset
# 	- id (309, 1) mass 220.9889 rt 187.98 MAP_trans M+H [C13]@218.97750(0.9998)
# 	Peakset
# 	- id (202, 0) mass 220.9932 rt 190.02 MAP_trans M+H@219.98595(1.0000)
# 	- id (382, 2) mass 220.9875 rt 187.98 MAP_trans M+H@219.98024(1.0000)
# 	- id (204, 3) mass 220.9872 rt 187.98 MAP_trans M+H@219.97990(0.9496)
#
# Ground Truth Group 734
# - id (282, 0) mass 232.1142 rt 192.00
# - id (339, 1) mass 232.1139 rt 190.02
# - id (351, 2) mass 232.1101 rt 192.00
# Overlapping peaksets:
# 	Peakset
# 	- id (339, 1) mass 232.1139 rt 190.02 MAP_trans M+H [C13]@230.10395(0.9999)
#
# Ground Truth Group 735
# - id (478, 0) mass 364.9038 rt 192.00
# Overlapping peaksets:
#
# Ground Truth Group 736
# - id (132, 0) mass 225.0808 rt 192.00
# - id (302, 1) mass 225.0798 rt 187.98
# - id (304, 2) mass 225.0823 rt 186.00
# - id (172, 3) mass 225.0900 rt 184.02
# Overlapping peaksets:
# 	Peakset
# 	- id (132, 0) mass 225.0808 rt 192.00 MAP_trans M+H@224.07350(1.0000)
# 	- id (302, 1) mass 225.0798 rt 187.98 MAP_trans M+H@224.07239(0.9961)
# 	- id (304, 2) mass 225.0823 rt 186.00 MAP_trans M+H@224.07503(0.9293)
# 	Peakset
# 	- id (172, 3) mass 225.0900 rt 184.02 MAP_trans M+H@224.08276(1.0000)
#
# Ground Truth Group 737
# - id (412, 0) mass 483.8836 rt 190.02
# - id (589, 1) mass 483.8732 rt 187.98
# - id (646, 2) mass 483.8661 rt 190.02
# - id (487, 3) mass 483.8961 rt 192.00
# Overlapping peaksets:
# 	Peakset
# 	- id (487, 3) mass 483.8961 rt 192.00 MAP_trans [M-CO2]+NH4@509.85465(0.8249)
# 	Peakset
# 	- id (412, 0) mass 483.8836 rt 190.02 MAP_trans [M-H2O]+NH4@483.86205(0.7827)
# 	Peakset
# 	- id (646, 2) mass 483.8661 rt 190.02 MAP_trans M+Na [C13]@459.87215(1.0000)
#
# Ground Truth Group 738
# - id (244, 0) mass 344.9112 rt 192.00
# - id (652, 1) mass 344.9105 rt 190.02
# - id (533, 2) mass 344.9157 rt 192.00
# - id (262, 3) mass 344.9045 rt 187.98
# Overlapping peaksets:
# 	Peakset
# 	- id (652, 1) mass 344.9105 rt 190.02 MAP_trans [M-CO2]+H@387.89293(0.9999)
# 	Peakset
# 	- id (262, 3) mass 344.9045 rt 187.98 MAP_trans M+H@343.89727(1.0000)
#
# Ground Truth Group 739
# - id (660, 0) mass 447.8714 rt 193.98
# - id (741, 1) mass 447.8843 rt 192.00
# - id (789, 2) mass 447.8690 rt 190.02
# - id (652, 3) mass 447.8904 rt 193.98
# Overlapping peaksets:
# 	Peakset
# 	- id (741, 1) mass 447.8843 rt 192.00 MAP_trans [M-CO]+H [C13]@473.86980(0.9854)
# 	Peakset
# 	- id (789, 2) mass 447.8690 rt 190.02 MAP_trans [M-CO]+Na [C13]@451.87330(0.6814)
# 	Peakset
# 	- id (652, 3) mass 447.8904 rt 193.98 MAP_trans [M-CH2O2]+Na [C13]@469.90190(0.3890)
#
# Ground Truth Group 740
# - id (406, 0) mass 229.9862 rt 199.98
# Overlapping peaksets:
#
# Ground Truth Group 741
# - id (416, 0) mass 231.9737 rt 199.98
# Overlapping peaksets:
#
# Ground Truth Group 742
# - id (428, 0) mass 226.9861 rt 202.02
# Overlapping peaksets:
#
# Ground Truth Group 743
# - id (524, 0) mass 243.9834 rt 199.98
# Overlapping peaksets:
#
# Ground Truth Group 744
# - id (193, 0) mass 270.9523 rt 192.00
# - id (391, 1) mass 270.9639 rt 186.00
# Overlapping peaksets:
# 	Peakset
# 	- id (391, 1) mass 270.9639 rt 186.00 MAP_trans M+H@269.95667(0.8461)
# 	- id (249, 2) mass 270.9574 rt 186.00 MAP_trans M+H@269.94973(1.0000)
#
# Ground Truth Group 745
# - id (300, 0) mass 269.9803 rt 190.02
# - id (166, 1) mass 269.9626 rt 184.02
# Overlapping peaksets:
#
# Ground Truth Group 746
# - id (509, 0) mass 431.8880 rt 193.98
# - id (721, 1) mass 431.8852 rt 192.00
# - id (605, 2) mass 431.9005 rt 192.00
# Overlapping peaksets:
# 	Peakset
# 	- id (605, 2) mass 431.9005 rt 192.00 MAP_trans [M-CH2O2]+NH4@459.87215(1.0000)
# 	Peakset
# 	- id (721, 1) mass 431.8852 rt 192.00 MAP_trans [M-CO2]+Na [C13]@451.88183(0.8310)
#
# Ground Truth Group 747
# - id (1123, 0) mass 269.1201 rt 271.98
# - id (2380, 1) mass 269.1219 rt 271.98
# - id (2631, 2) mass 269.1199 rt 270.00
# - id (997, 3) mass 269.1203 rt 270.00
# Overlapping peaksets:
# 	Peakset
# 	- id (1123, 0) mass 269.1201 rt 271.98 MAP_trans M+H [C13]@267.11003(0.9999)
# 	- id (2631, 2) mass 269.1199 rt 270.00 MAP_trans M+H [C13]@267.10838(0.9999)
# 	- id (997, 3) mass 269.1203 rt 270.00 MAP_trans M+H [C13]@267.11026(0.9999)
#
# Ground Truth Group 748
# - id (41, 0) mass 117.0729 rt 184.02
# Overlapping peaksets:
#
# Ground Truth Group 749
# - id (63, 0) mass 164.9635 rt 181.98
# Overlapping peaksets:
#
# Ground Truth Group 750
# - id (5479, 0) mass 234.9523 rt 64.02
# Overlapping peaksets:
#
# Ground Truth Group 751
# - id (127, 0) mass 112.8957 rt 210.00
# - id (120, 1) mass 112.8995 rt 208.02
# - id (160, 2) mass 112.8994 rt 208.02
# - id (152, 3) mass 112.8955 rt 210.00
# Overlapping peaksets:
# 	Peakset
# 	- id (120, 1) mass 112.8995 rt 208.02 MAP_trans M+H@111.89218(1.0000)
# 	- id (160, 2) mass 112.8994 rt 208.02 MAP_trans M+H@111.89217(1.0000)
# 	Peakset
# 	- id (152, 3) mass 112.8955 rt 210.00 MAP_trans M+H@111.88820(1.0000)
#
# Ground Truth Group 752
# - id (1449, 0) mass 395.0901 rt 837.96
# - id (2862, 1) mass 395.0808 rt 837.96
# - id (8702, 2) mass 395.0997 rt 835.98
# - id (1388, 3) mass 395.0876 rt 835.98
# Overlapping peaksets:
# 	Peakset
# 	- id (1449, 0) mass 395.0901 rt 837.96 MAP_trans M+H@394.08283(1.0000)
# 	- id (2862, 1) mass 395.0808 rt 837.96 MAP_trans M+H@394.07356(1.0000)
# 	- id (1388, 3) mass 395.0876 rt 835.98 MAP_trans M+H@394.08035(1.0000)
#
# Ground Truth Group 753
# - id (1471, 0) mass 278.1790 rt 895.98
# - id (2891, 1) mass 278.1807 rt 894.00
# - id (3316, 2) mass 278.1794 rt 895.98
# - id (1415, 3) mass 278.1798 rt 895.98
# Overlapping peaksets:
# 	Peakset
# 	- id (1471, 0) mass 278.1790 rt 895.98 MAP_trans M+H [C13]@276.16964(0.9997)
# 	- id (2891, 1) mass 278.1807 rt 894.00 MAP_trans M+H [C13]@276.17033(1.0000)
# 	Peakset
# 	- id (1415, 3) mass 278.1798 rt 895.98 MAP_trans [M-H2O]+NH4@278.15573(0.9666)
#
# Ground Truth Group 754
# - id (1467, 0) mass 464.2763 rt 867.96
# - id (3367, 2) mass 464.2962 rt 865.98
# Overlapping peaksets:
#
# Ground Truth Group 755
# - id (1734, 0) mass 118.0722 rt 1151.94
# - id (3151, 1) mass 118.0743 rt 1149.96
# - id (3838, 2) mass 118.0747 rt 1151.94
# - id (1711, 3) mass 118.0689 rt 1151.94
# Overlapping peaksets:
# 	Peakset
# 	- id (2159, 0) mass 118.0701 rt 1247.94 MAP_trans M+H@117.06278(1.0000)
# 	- id (3622, 1) mass 118.0705 rt 1249.98 MAP_trans M+H@117.06318(1.0000)
# 	- id (4421, 2) mass 118.0694 rt 1249.98 MAP_trans M+H@117.06212(1.0000)
# 	- id (1711, 3) mass 118.0689 rt 1151.94 MAP_trans M+H@117.06159(1.0000)
# 	Peakset
# 	- id (1734, 0) mass 118.0722 rt 1151.94 MAP_trans M+H@117.06493(1.0000)
# 	- id (3151, 1) mass 118.0743 rt 1149.96 MAP_trans M+H@117.06705(1.0000)
# 	- id (3838, 2) mass 118.0747 rt 1151.94 MAP_trans M+H@117.06744(0.7446)
#
# Ground Truth Group 756
# - id (1888, 0) mass 169.5328 rt 1151.94
# - id (3351, 1) mass 169.5329 rt 1151.94
# - id (4130, 2) mass 169.5335 rt 1151.94
# - id (1872, 3) mass 169.5336 rt 1151.94
# Overlapping peaksets:
# 	Peakset
# 	- id (1888, 0) mass 169.5328 rt 1151.94 MAP_trans M+H@168.52553(1.0000)
# 	- id (3351, 1) mass 169.5329 rt 1151.94 MAP_trans M+H@168.52564(1.0000)
# 	- id (1872, 3) mass 169.5336 rt 1151.94 MAP_trans M+H@168.52633(1.0000)
#
# Ground Truth Group 757
# - id (1890, 0) mass 167.5186 rt 1151.94
# - id (3344, 1) mass 167.5226 rt 1151.94
# - id (4090, 2) mass 167.5196 rt 1151.94
# - id (1867, 3) mass 167.5194 rt 1151.94
# Overlapping peaksets:
# 	Peakset
# 	- id (1867, 3) mass 167.5194 rt 1151.94 MAP_trans [M-CO2]+Na@188.52075(0.9999)
# 	Peakset
# 	- id (1890, 0) mass 167.5186 rt 1151.94 MAP_trans M+H@166.51136(1.0000)
# 	- id (3344, 1) mass 167.5226 rt 1151.94 MAP_trans M+H@166.51537(1.0000)
# 	- id (4090, 2) mass 167.5196 rt 1151.94 MAP_trans M+H@166.51237(0.9838)
#
# Ground Truth Group 758
# - id (1904, 0) mass 179.0403 rt 1151.94
# - id (3377, 1) mass 179.0405 rt 1151.94
# - id (4068, 2) mass 179.0418 rt 1151.94
# - id (1894, 3) mass 179.0409 rt 1151.94
# Overlapping peaksets:
# 	Peakset
# 	- id (3377, 1) mass 179.0405 rt 1151.94 MAP_trans M+H@178.03322(0.7662)
# 	- id (4068, 2) mass 179.0418 rt 1151.94 MAP_trans M+H@178.03458(1.0000)
# 	- id (1894, 3) mass 179.0409 rt 1151.94 MAP_trans M+H@178.03358(0.9845)
# 	Peakset
# 	- id (1904, 0) mass 179.0403 rt 1151.94 MAP_trans M+H [C13]@177.02895(0.9998)
#
# Ground Truth Group 759
# - id (1925, 0) mass 197.5158 rt 1151.94
# - id (3442, 1) mass 197.5179 rt 1151.94
# - id (4093, 2) mass 197.5173 rt 1151.94
# - id (1937, 3) mass 197.5167 rt 1151.94
# Overlapping peaksets:
# 	Peakset
# 	- id (4093, 2) mass 197.5173 rt 1151.94 MAP_trans [M-CH2O2]+2H [C13]@438.02041(0.9999)
# 	- id (1937, 3) mass 197.5167 rt 1151.94 MAP_trans [M-CH2O2]+2H [C13]@438.02076(1.0000)
#
# Ground Truth Group 760
# - id (1934, 0) mass 198.5260 rt 1151.94
# - id (3311, 1) mass 198.5259 rt 1151.94
# - id (4102, 2) mass 198.5240 rt 1151.94
# - id (1940, 3) mass 198.5250 rt 1151.94
# Overlapping peaksets:
# 	Peakset
# 	- id (1934, 0) mass 198.5260 rt 1151.94 MAP_trans [M-CO2]+2H [C13]@438.02218(0.9997)
# 	- id (4102, 2) mass 198.5240 rt 1151.94 MAP_trans [M-CO2]+2H [C13]@438.02041(1.0000)
# 	- id (1940, 3) mass 198.5250 rt 1151.94 MAP_trans [M-CO2]+2H [C13]@438.02076(0.9999)
#
# Ground Truth Group 761
# - id (1986, 0) mass 207.5206 rt 1151.94
# - id (3500, 1) mass 207.5206 rt 1151.94
# - id (4234, 2) mass 207.5208 rt 1151.94
# - id (1955, 3) mass 207.5229 rt 1151.94
# Overlapping peaksets:
# 	Peakset
# 	- id (3500, 1) mass 207.5206 rt 1151.94 MAP_trans M+Na@184.53076(0.8297)
# 	Peakset
# 	- id (1986, 0) mass 207.5206 rt 1151.94 MAP_trans [M-CO]+2H [C13]@440.01626(0.9992)
# 	- id (4234, 2) mass 207.5208 rt 1151.94 MAP_trans [M-CO]+2H [C13]@440.01749(0.9999)
# 	Peakset
# 	- id (1955, 3) mass 207.5229 rt 1151.94 MAP_trans M+H@206.51563(1.0000)
#
# Ground Truth Group 762
# - id (2085, 0) mass 262.0001 rt 1151.94
# - id (3579, 1) mass 262.0004 rt 1153.98
# - id (4282, 2) mass 261.9992 rt 1153.98
# - id (2121, 3) mass 262.0007 rt 1153.98
# Overlapping peaksets:
# 	Peakset
# 	- id (2085, 0) mass 262.0001 rt 1151.94 MAP_trans M+H@260.99280(0.9884)
# 	- id (3579, 1) mass 262.0004 rt 1153.98 MAP_trans M+H@260.99312(1.0000)
# 	- id (2121, 3) mass 262.0007 rt 1153.98 MAP_trans M+H@260.99343(0.9512)
# 	Peakset
# 	- id (4282, 2) mass 261.9992 rt 1153.98 MAP_trans [M-H2O]+H@279.00148(1.0000)
#
# Ground Truth Group 763
# - id (1849, 0) mass 159.5315 rt 1151.94
# - id (3310, 1) mass 159.5264 rt 1149.96
# - id (4077, 2) mass 159.5267 rt 1151.94
# Overlapping peaksets:
# 	Peakset
# 	- id (3310, 1) mass 159.5264 rt 1149.96 MAP_trans M+H@158.51917(1.0000)
# 	- id (4077, 2) mass 159.5267 rt 1151.94 MAP_trans M+H@158.51942(1.0000)
#
# Ground Truth Group 764
# - id (1978, 0) mass 218.0154 rt 1151.94
# - id (3431, 1) mass 218.0201 rt 1149.96
# - id (4132, 2) mass 218.0197 rt 1151.94
# - id (1971, 3) mass 218.0191 rt 1149.96
# Overlapping peaksets:
# 	Peakset
# 	- id (1978, 0) mass 218.0154 rt 1151.94 MAP_trans [M-CH2O2]+H@263.01271(0.9998)
# 	Peakset
# 	- id (3431, 1) mass 218.0201 rt 1149.96 MAP_trans [M-CO]+H@245.00841(0.9999)
# 	Peakset
# 	- id (4132, 2) mass 218.0197 rt 1151.94 MAP_trans M+H@217.01240(1.0000)
# 	- id (1971, 3) mass 218.0191 rt 1149.96 MAP_trans M+H@217.01179(1.0000)
#
# Ground Truth Group 765
# - id (1973, 0) mass 149.5018 rt 1151.94
# - id (4107, 2) mass 149.4959 rt 1153.98
# Overlapping peaksets:
#
# Ground Truth Group 766
# - id (2054, 0) mass 239.0146 rt 1151.94
# - id (4297, 2) mass 239.0058 rt 1151.94
# Overlapping peaksets:
# 	Peakset
# 	- id (2054, 0) mass 239.0146 rt 1151.94 MAP_trans [M-H2O]+ACN+H@214.99072(0.9999)
# 	- id (2022, 3) mass 239.0185 rt 1149.96 MAP_trans [M-H2O]+ACN+H@214.99482(0.9999)
#
# Ground Truth Group 767
# - id (1740, 0) mass 120.0621 rt 1151.94
# - id (3254, 1) mass 120.0602 rt 1151.94
# - id (3914, 2) mass 120.0626 rt 1151.94
# - id (1713, 3) mass 120.0628 rt 1151.94
# Overlapping peaksets:
# 	Peakset
# 	- id (1740, 0) mass 120.0621 rt 1151.94 MAP_trans M+H@119.05483(1.0000)
# 	- id (3254, 1) mass 120.0602 rt 1151.94 MAP_trans M+H@119.05290(1.0000)
# 	- id (1713, 3) mass 120.0628 rt 1151.94 MAP_trans M+H@119.05553(1.0000)
# 	Peakset
# 	- id (3914, 2) mass 120.0626 rt 1151.94 MAP_trans M+H [C13]@118.05233(0.9999)
#
# Ground Truth Group 768
# - id (1892, 0) mass 158.5154 rt 1151.94
# - id (3305, 1) mass 158.5112 rt 1151.94
# - id (4084, 2) mass 158.5120 rt 1151.94
# - id (1889, 3) mass 158.5099 rt 1151.94
# Overlapping peaksets:
# 	Peakset
# 	- id (3305, 1) mass 158.5112 rt 1151.94 MAP_trans M+H@157.50392(1.0000)
# 	- id (4084, 2) mass 158.5120 rt 1151.94 MAP_trans M+H@157.50470(1.0000)
# 	- id (1889, 3) mass 158.5099 rt 1151.94 MAP_trans M+H@157.50260(1.0000)
# 	Peakset
# 	- id (1892, 0) mass 158.5154 rt 1151.94 MAP_trans [M-H2O]+H@175.51884(0.9999)
#
# Ground Truth Group 769
# - id (2031, 0) mass 228.0697 rt 1153.98
# - id (3457, 1) mass 228.0632 rt 1153.98
# - id (4288, 2) mass 228.0634 rt 1155.96
# - id (1984, 3) mass 228.0749 rt 1155.96
# Overlapping peaksets:
# 	Peakset
# 	- id (2031, 0) mass 228.0697 rt 1153.98 MAP_trans M+H@227.06247(1.0000)
# 	- id (3457, 1) mass 228.0632 rt 1153.98 MAP_trans M+H@227.05597(1.0000)
# 	- id (4288, 2) mass 228.0634 rt 1155.96 MAP_trans M+H@227.05613(1.0000)
# 	Peakset
# 	- id (1984, 3) mass 228.0749 rt 1155.96 MAP_trans M+H@227.06758(1.0000)
#
# Ground Truth Group 770
# - id (2295, 0) mass 430.9916 rt 1151.94
# - id (3671, 1) mass 430.9740 rt 1151.94
# - id (4463, 2) mass 430.9877 rt 1151.94
# - id (2214, 3) mass 430.9873 rt 1151.94
# Overlapping peaksets:
# 	Peakset
# 	- id (2295, 0) mass 430.9916 rt 1151.94 MAP_trans M+H@429.98430(1.0000)
# 	- id (4463, 2) mass 430.9877 rt 1151.94 MAP_trans M+H@429.98043(1.0000)
# 	- id (2214, 3) mass 430.9873 rt 1151.94 MAP_trans M+H@429.98001(1.0000)
# 	Peakset
# 	- id (3671, 1) mass 430.9740 rt 1151.94 MAP_trans [M-CH2O2]+K@438.01880(0.9999)
#
# Ground Truth Group 771
# - id (2060, 0) mass 208.5037 rt 1151.94
# - id (1962, 3) mass 208.5128 rt 1151.94
# Overlapping peaksets:
# 	Peakset
# 	- id (3471, 1) mass 208.5117 rt 1151.94 MAP_trans M+H@207.50440(1.0000)
# 	- id (4260, 2) mass 208.5126 rt 1151.94 MAP_trans M+H@207.50530(1.0000)
# 	- id (1962, 3) mass 208.5128 rt 1151.94 MAP_trans M+H@207.50548(1.0000)
#
# Ground Truth Group 772
# - id (2151, 0) mass 275.9943 rt 1149.96
# - id (2089, 3) mass 275.9859 rt 1153.98
# Overlapping peaksets:
# 	Peakset
# 	- id (2151, 0) mass 275.9943 rt 1149.96 MAP_trans [M-CO]+Na@281.00085(0.9999)
# 	Peakset
# 	- id (2089, 3) mass 275.9859 rt 1153.98 MAP_trans [M-CO]+Na@280.99169(0.9999)
#
# Ground Truth Group 773
# - id (2066, 0) mass 281.0100 rt 1149.96
# - id (3447, 1) mass 281.0057 rt 1149.96
# - id (4367, 2) mass 281.0128 rt 1151.94
# - id (2075, 3) mass 281.0059 rt 1151.94
# Overlapping peaksets:
# 	Peakset
# 	- id (2066, 0) mass 281.0100 rt 1149.96 MAP_trans M+H [C13]@279.00013(0.9999)
# 	- id (4367, 2) mass 281.0128 rt 1151.94 MAP_trans M+H [C13]@279.00148(0.9870)
# 	Peakset
# 	- id (3447, 1) mass 281.0057 rt 1149.96 MAP_trans [M-CO2]+K [C13]@285.02974(0.9999)
# 	Peakset
# 	- id (2075, 3) mass 281.0059 rt 1151.94 MAP_trans M+H@279.99809(0.5864)
#
# Ground Truth Group 774
# - id (2227, 0) mass 428.9815 rt 1151.94
# - id (3742, 1) mass 428.9945 rt 1151.94
# - id (4462, 2) mass 428.9928 rt 1151.94
# - id (2212, 3) mass 428.9842 rt 1151.94
# Overlapping peaksets:
# 	Peakset
# 	- id (3742, 1) mass 428.9945 rt 1151.94 MAP_trans M+H@427.98723(1.0000)
# 	- id (4462, 2) mass 428.9928 rt 1151.94 MAP_trans M+H@427.98549(1.0000)
# 	- id (2212, 3) mass 428.9842 rt 1151.94 MAP_trans M+H@427.97697(1.0000)
#
# Ground Truth Group 775
# - id (2292, 0) mass 424.0475 rt 1151.94
# - id (3741, 1) mass 424.0366 rt 1149.96
# - id (4459, 2) mass 424.0451 rt 1151.94
# - id (2211, 3) mass 424.0528 rt 1149.96
# Overlapping peaksets:
# 	Peakset
# 	- id (3741, 1) mass 424.0366 rt 1149.96 MAP_trans M+H [C13]@422.02528(1.0000)
# 	- id (4459, 2) mass 424.0451 rt 1151.94 MAP_trans M+H [C13]@422.03445(1.0000)
# 	Peakset
# 	- id (2211, 3) mass 424.0528 rt 1149.96 MAP_trans M+H@423.04555(1.0000)
#
# Ground Truth Group 776
# - id (1948, 0) mass 184.0349 rt 1151.94
# - id (4196, 2) mass 184.0423 rt 1153.98
# - id (1924, 3) mass 184.0429 rt 1151.94
# Overlapping peaksets:
# 	Peakset
# 	- id (4196, 2) mass 184.0423 rt 1153.98 MAP_trans M+H@183.03502(1.0000)
# 	- id (1924, 3) mass 184.0429 rt 1151.94 MAP_trans M+H@183.03536(1.0000)
#
# Ground Truth Group 777
# - id (1957, 0) mass 169.0362 rt 1151.94
# - id (4095, 2) mass 169.0364 rt 1151.94
# - id (1917, 3) mass 169.0353 rt 1151.94
# Overlapping peaksets:
# 	Peakset
# 	- id (3426, 1) mass 169.0366 rt 1151.94 MAP_trans [M-CH2O2]+NH4@197.00783(0.9999)
# 	- id (4095, 2) mass 169.0364 rt 1151.94 MAP_trans [M-CH2O2]+NH4@197.00870(0.9999)
# 	Peakset
# 	- id (1957, 0) mass 169.0362 rt 1151.94 MAP_trans [M-CH2O2]+ACN+H@173.00815(0.6852)
# 	Peakset
# 	- id (1917, 3) mass 169.0353 rt 1151.94 MAP_trans M+H@168.02803(0.9787)
#
# Ground Truth Group 778
# - id (1982, 0) mass 156.0448 rt 1153.98
# - id (3366, 1) mass 156.0475 rt 1149.96
# - id (4078, 2) mass 156.0375 rt 1151.94
# Overlapping peaksets:
#
# Ground Truth Group 779
# - id (2209, 0) mass 390.1062 rt 1155.96
# - id (3693, 1) mass 390.1062 rt 1149.96
# - id (4472, 2) mass 390.0914 rt 1153.98
# Overlapping peaksets:
#
# Ground Truth Group 780
# - id (2192, 0) mass 393.9752 rt 1149.96
# Overlapping peaksets:
#
# Ground Truth Group 781
# - id (2199, 0) mass 348.2696 rt 1153.98
# - id (3645, 1) mass 348.2751 rt 1153.98
# - id (4461, 2) mass 348.2606 rt 1155.96
# - id (2151, 3) mass 348.2732 rt 1155.96
# Overlapping peaksets:
# 	Peakset
# 	- id (2199, 0) mass 348.2696 rt 1153.98 MAP_trans M+H@347.26229(1.0000)
# 	- id (3645, 1) mass 348.2751 rt 1153.98 MAP_trans M+H@347.26784(1.0000)
# 	- id (2151, 3) mass 348.2732 rt 1155.96 MAP_trans M+H@347.26589(1.0000)
#
# Ground Truth Group 782
# - id (2243, 0) mass 396.0923 rt 1151.94
# - id (3697, 1) mass 396.0929 rt 1151.94
# - id (4475, 2) mass 396.0927 rt 1151.94
# - id (2176, 3) mass 396.0840 rt 1151.94
# Overlapping peaksets:
# 	Peakset
# 	- id (2243, 0) mass 396.0923 rt 1151.94 MAP_trans M+H@395.08500(1.0000)
# 	- id (3697, 1) mass 396.0929 rt 1151.94 MAP_trans M+H@395.08560(1.0000)
# 	- id (2176, 3) mass 396.0840 rt 1151.94 MAP_trans M+H@395.07670(1.0000)
#
# Ground Truth Group 783
# - id (1582, 0) mass 398.6272 rt 999.96
# - id (3003, 1) mass 398.6275 rt 999.96
# - id (3759, 2) mass 398.6287 rt 1001.94
# - id (1562, 3) mass 398.6252 rt 999.96
# Overlapping peaksets:
# 	Peakset
# 	- id (1582, 0) mass 398.6272 rt 999.96 MAP_trans M+2H [C13]@794.23636(0.9998)
# 	Peakset
# 	- id (3003, 1) mass 398.6275 rt 999.96 MAP_trans M+H@397.62040(1.0000)
# 	- id (3759, 2) mass 398.6287 rt 1001.94 MAP_trans M+H@397.62145(0.8421)
# 	- id (1562, 3) mass 398.6252 rt 999.96 MAP_trans M+H@397.61780(0.9662)
#
# Ground Truth Group 784
# - id (1583, 0) mass 407.1210 rt 999.96
# - id (3014, 1) mass 407.1186 rt 997.98
# - id (3734, 2) mass 407.1198 rt 999.96
# - id (1569, 3) mass 407.1228 rt 999.96
# Overlapping peaksets:
# 	Peakset
# 	- id (1583, 0) mass 407.1210 rt 999.96 MAP_trans M+H [C13]@405.10946(0.5551)
# 	- id (3014, 1) mass 407.1186 rt 997.98 MAP_trans M+H [C13]@405.10961(1.0000)
# 	- id (1569, 3) mass 407.1228 rt 999.96 MAP_trans M+H [C13]@405.11109(0.9999)
# 	Peakset
# 	- id (3734, 2) mass 407.1198 rt 999.96 MAP_trans M+H@406.11218(0.9407)
#
# Ground Truth Group 785
# - id (1594, 0) mass 387.1371 rt 999.96
# - id (3006, 1) mass 387.1369 rt 999.96
# - id (3738, 2) mass 387.1239 rt 999.96
# - id (1560, 3) mass 387.1401 rt 999.96
# Overlapping peaksets:
# 	Peakset
# 	- id (1594, 0) mass 387.1371 rt 999.96 MAP_trans M+H@386.12975(1.0000)
# 	- id (3006, 1) mass 387.1369 rt 999.96 MAP_trans M+H@386.12967(1.0000)
# 	- id (1560, 3) mass 387.1401 rt 999.96 MAP_trans M+H@386.13282(1.0000)
#
# Ground Truth Group 786
# - id (1614, 0) mass 600.1996 rt 999.96
# - id (3050, 1) mass 600.2039 rt 999.96
# - id (3819, 2) mass 600.2060 rt 1001.94
# - id (1607, 3) mass 600.2022 rt 999.96
# Overlapping peaksets:
# 	Peakset
# 	- id (1614, 0) mass 600.1996 rt 999.96 MAP_trans M+H [C13]@598.18880(0.9999)
# 	- id (1607, 3) mass 600.2022 rt 999.96 MAP_trans M+H [C13]@598.19046(0.9999)
# 	Peakset
# 	- id (3050, 1) mass 600.2039 rt 999.96 MAP_trans M+H@599.19639(0.7957)
# 	- id (3819, 2) mass 600.2060 rt 1001.94 MAP_trans M+H@599.19897(0.9756)
#
# Ground Truth Group 787
# - id (1622, 0) mass 600.7017 rt 999.96
# - id (3058, 1) mass 600.7047 rt 997.98
# - id (3825, 2) mass 600.7042 rt 999.96
# - id (1626, 3) mass 600.7066 rt 999.96
# Overlapping peaksets:
# 	Peakset
# 	- id (1622, 0) mass 600.7017 rt 999.96 MAP_trans M+H [C13]@598.69130(0.9999)
# 	- id (3058, 1) mass 600.7047 rt 997.98 MAP_trans M+H [C13]@598.69341(0.9999)
# 	- id (3825, 2) mass 600.7042 rt 999.96 MAP_trans M+H [C13]@598.69471(0.9999)
# 	Peakset
# 	- id (1626, 3) mass 600.7066 rt 999.96 MAP_trans M+H@599.69935(0.5927)
#
# Ground Truth Group 788
# - id (1519, 0) mass 226.1017 rt 993.96
# - id (1512, 3) mass 226.0950 rt 999.96
# Overlapping peaksets:
# 	Peakset
# 	- id (1512, 3) mass 226.0950 rt 999.96 MAP_trans M+H@225.08771(1.0000)
#
# Ground Truth Group 789
# - id (1585, 0) mass 427.1048 rt 997.98
# - id (3034, 1) mass 427.1148 rt 997.98
# - id (3758, 2) mass 427.1088 rt 997.98
# - id (1540, 3) mass 427.1145 rt 997.98
# Overlapping peaksets:
# 	Peakset
# 	- id (1585, 0) mass 427.1048 rt 997.98 MAP_trans [M-CO2]+H@470.08931(0.9997)
# 	- id (3758, 2) mass 427.1088 rt 997.98 MAP_trans [M-CO2]+H@470.09070(1.0000)
# 	Peakset
# 	- id (1540, 3) mass 427.1145 rt 997.98 MAP_trans M+H@426.10720(1.0000)
#
# Ground Truth Group 790
# - id (1638, 0) mass 790.2425 rt 999.96
# - id (1603, 3) mass 790.2375 rt 997.98
# Overlapping peaksets:
# 	Peakset
# 	- id (1603, 3) mass 790.2375 rt 997.98 MAP_trans [M-CO]+Na [C13]@794.23787(0.6251)
#
# Ground Truth Group 791
# - id (1545, 0) mass 219.0308 rt 1015.98
# - id (2973, 1) mass 219.0212 rt 1019.94
# - id (3712, 2) mass 219.0158 rt 1017.96
# Overlapping peaksets:
# 	Peakset
# 	- id (2973, 1) mass 219.0212 rt 1019.94 MAP_trans M+H@218.01389(1.0000)
# 	- id (3712, 2) mass 219.0158 rt 1017.96 MAP_trans M+H@218.00853(1.0000)
# 	- id (1536, 3) mass 219.0157 rt 1019.94 MAP_trans M+H@218.00844(1.0000)
#
# Ground Truth Group 792
# - id (1549, 0) mass 177.0119 rt 1017.96
# Overlapping peaksets:
#
# Ground Truth Group 793
# - id (1568, 0) mass 422.1312 rt 977.94
# - id (2959, 1) mass 422.1426 rt 975.96
# - id (3721, 2) mass 422.1421 rt 977.94
# - id (1525, 3) mass 422.1362 rt 977.94
# Overlapping peaksets:
# 	Peakset
# 	- id (2959, 1) mass 422.1426 rt 975.96 MAP_trans [M-H2O]+H@439.14675(1.0000)
# 	Peakset
# 	- id (1568, 0) mass 422.1312 rt 977.94 MAP_trans M+H@421.12379(1.0000)
# 	- id (3721, 2) mass 422.1421 rt 977.94 MAP_trans M+H@421.13486(0.9803)
# 	- id (1525, 3) mass 422.1362 rt 977.94 MAP_trans M+H@421.12894(1.0000)
#
# Ground Truth Group 794
# - id (1590, 0) mass 147.0856 rt 1075.98
# - id (1590, 0) mass 147.0856 rt 1075.98
# - id (3678, 2) mass 147.0863 rt 1077.96
# - id (1499, 3) mass 147.0851 rt 1075.98
# Overlapping peaksets:
# 	Peakset
# 	- id (1590, 0) mass 147.0856 rt 1075.98 MAP_trans [M-H2O]+H@164.08948(0.9998)
# 	- id (2981, 1) mass 147.0851 rt 1075.98 MAP_trans [M-H2O]+H@164.08895(0.9999)
# 	Peakset
# 	- id (3678, 2) mass 147.0863 rt 1077.96 MAP_trans M+H@146.07897(1.0000)
# 	- id (1499, 3) mass 147.0851 rt 1075.98 MAP_trans M+H@146.07785(1.0000)
#
# Ground Truth Group 795
# - id (1666, 0) mass 166.0932 rt 1075.98
# - id (3107, 1) mass 166.0899 rt 1075.98
# - id (3754, 2) mass 166.0882 rt 1077.96
# - id (1629, 3) mass 166.0839 rt 1073.94
# Overlapping peaksets:
# 	Peakset
# 	- id (1666, 0) mass 166.0932 rt 1075.98 MAP_trans [M-CO2]+NH4@192.04968(0.9998)
# 	Peakset
# 	- id (3107, 1) mass 166.0899 rt 1075.98 MAP_trans M+H@165.08267(1.0000)
# 	- id (3754, 2) mass 166.0882 rt 1077.96 MAP_trans M+H@165.08088(1.0000)
# 	Peakset
# 	- id (1629, 3) mass 166.0839 rt 1073.94 MAP_trans M+H@165.07664(1.0000)
#
# Ground Truth Group 796
# - id (1800, 0) mass 350.1268 rt 1073.94
# - id (3239, 1) mass 350.1260 rt 1073.94
# - id (3910, 2) mass 350.1240 rt 1075.98
# - id (1834, 3) mass 350.1257 rt 1073.94
# Overlapping peaksets:
# 	Peakset
# 	- id (1800, 0) mass 350.1268 rt 1073.94 MAP_trans M+H [C13]@348.11680(0.9999)
# 	- id (1834, 3) mass 350.1257 rt 1073.94 MAP_trans M+H [C13]@348.11508(0.9999)
# 	Peakset
# 	- id (3239, 1) mass 350.1260 rt 1073.94 MAP_trans M+H@349.11872(1.0000)
# 	- id (3910, 2) mass 350.1240 rt 1075.98 MAP_trans M+H@349.11675(1.0000)
#
# Ground Truth Group 797
# - id (1577, 0) mass 293.1324 rt 1001.94
# Overlapping peaksets:
#
# Ground Truth Group 798
# - id (1673, 0) mass 222.0906 rt 1121.94
# - id (3096, 1) mass 222.0905 rt 1121.94
# - id (3896, 2) mass 222.0901 rt 1123.98
# - id (5572, 3) mass 222.0896 rt 1123.98
# Overlapping peaksets:
# 	Peakset
# 	- id (1673, 0) mass 222.0906 rt 1121.94 MAP_trans M+H@221.08329(0.9408)
# 	- id (3096, 1) mass 222.0905 rt 1121.94 MAP_trans M+H@221.08319(1.0000)
# 	- id (3897, 2) mass 222.0880 rt 1089.96 MAP_trans M+H@221.08069(1.0000)
# 	- id (5572, 3) mass 222.0896 rt 1123.98 MAP_trans M+H@221.08232(0.9242)
# 	Peakset
# 	- id (3896, 2) mass 222.0901 rt 1123.98 MAP_trans [M-CO]+2H@470.16222(0.9999)
#
# Ground Truth Group 799
# - id (1874, 0) mass 213.0860 rt 1121.94
# - id (3286, 1) mass 213.0837 rt 1123.98
# - id (4073, 2) mass 213.0854 rt 1123.98
# - id (1841, 3) mass 213.0853 rt 1123.98
# Overlapping peaksets:
# 	Peakset
# 	- id (1874, 0) mass 213.0860 rt 1121.94 MAP_trans M+H@212.07915(1.0000)
# 	- id (3286, 1) mass 213.0837 rt 1123.98 MAP_trans M+H@212.07671(0.7316)
# 	- id (1841, 3) mass 213.0853 rt 1123.98 MAP_trans M+H@212.07803(1.0000)
# 	Peakset
# 	- id (4073, 2) mass 213.0854 rt 1123.98 MAP_trans [M-CH2O2]+2H@470.16222(1.0000)
#
# Ground Truth Group 800
# - id (1891, 0) mass 222.5933 rt 1121.94
# - id (3299, 1) mass 222.5912 rt 1121.94
# - id (4071, 2) mass 222.6004 rt 1123.98
# - id (1859, 3) mass 222.5967 rt 1123.98
# Overlapping peaksets:
# 	Peakset
# 	- id (4071, 2) mass 222.6004 rt 1123.98 MAP_trans M+H@221.59312(1.0000)
# 	- id (1859, 3) mass 222.5967 rt 1123.98 MAP_trans M+H@221.58939(1.0000)
# 	Peakset
# 	- id (3299, 1) mass 222.5912 rt 1121.94 MAP_trans [M-CO]+2H [C13]@470.15979(0.9999)
#
# Ground Truth Group 801
# - id (2036, 0) mass 405.1519 rt 1121.94
# - id (3448, 1) mass 405.1634 rt 1119.96
# - id (4186, 2) mass 405.1616 rt 1125.96
# Overlapping peaksets:
# 	Peakset
# 	- id (2036, 0) mass 405.1519 rt 1121.94 MAP_trans M+H@404.14463(1.0000)
# 	- id (4186, 2) mass 405.1616 rt 1125.96 MAP_trans M+H@404.15430(1.0000)
#
# Ground Truth Group 802
# - id (2065, 0) mass 457.1836 rt 1121.94
# - id (3493, 1) mass 457.1647 rt 1121.94
# - id (4324, 2) mass 457.2000 rt 1121.94
# Overlapping peaksets:
#
# Ground Truth Group 803
# - id (2058, 0) mass 472.1777 rt 1123.98
# - id (3509, 1) mass 472.1755 rt 1121.94
# - id (4232, 2) mass 472.1760 rt 1123.98
# - id (2044, 3) mass 472.1710 rt 1123.98
# Overlapping peaksets:
# 	Peakset
# 	- id (2058, 0) mass 472.1777 rt 1123.98 MAP_trans M+H@471.17040(1.0000)
# 	- id (3509, 1) mass 472.1755 rt 1121.94 MAP_trans M+H@471.16815(1.0000)
# 	- id (2044, 3) mass 472.1710 rt 1123.98 MAP_trans M+H@471.16373(0.9527)
# 	Peakset
# 	- id (4232, 2) mass 472.1760 rt 1123.98 MAP_trans M+H [C13]@470.16222(0.9998)
#
# Ground Truth Group 804
# - id (1675, 0) mass 171.5538 rt 1087.98
# - id (3099, 1) mass 171.5580 rt 1087.98
# - id (3854, 2) mass 171.5644 rt 1087.98
# - id (1704, 3) mass 171.5564 rt 1087.98
# Overlapping peaksets:
# 	Peakset
# 	- id (1675, 0) mass 171.5538 rt 1087.98 MAP_trans M+H@170.54652(1.0000)
# 	- id (3099, 1) mass 171.5580 rt 1087.98 MAP_trans M+H@170.55069(1.0000)
# 	- id (1704, 3) mass 171.5564 rt 1087.98 MAP_trans M+H@170.54914(1.0000)
#
# Ground Truth Group 805
# - id (1834, 0) mass 637.1641 rt 1053.96
# Overlapping peaksets:
#
# Ground Truth Group 806
# - id (1853, 0) mass 461.1520 rt 1069.98
# - id (3308, 1) mass 461.1531 rt 1069.98
# Overlapping peaksets:
#
# Ground Truth Group 807
# - id (1839, 0) mass 362.6137 rt 1069.98
# - id (3271, 1) mass 362.5983 rt 1063.98
# Overlapping peaksets:
# 	Peakset
# 	- id (3271, 1) mass 362.5983 rt 1063.98 MAP_trans M+H@361.59105(1.0000)
# 	- id (4029, 2) mass 362.5897 rt 1073.94 MAP_trans M+H@361.58240(1.0000)
#
# Ground Truth Group 808
# - id (1930, 0) mass 275.1003 rt 1123.98
# - id (3353, 1) mass 275.0912 rt 1125.96
# - id (4140, 2) mass 275.0997 rt 1127.94
# - id (1916, 3) mass 275.0960 rt 1125.96
# Overlapping peaksets:
# 	Peakset
# 	- id (1930, 0) mass 275.1003 rt 1123.98 MAP_trans M+H@274.09305(1.0000)
# 	- id (4140, 2) mass 275.0997 rt 1127.94 MAP_trans M+H@274.09240(1.0000)
# 	- id (1916, 3) mass 275.0960 rt 1125.96 MAP_trans M+H@274.08875(1.0000)
#
# Ground Truth Group 809
# - id (1790, 0) mass 249.1254 rt 1075.98
# - id (3245, 1) mass 249.1218 rt 1073.94
# Overlapping peaksets:
#
# Ground Truth Group 810
# - id (1989, 0) mass 332.1303 rt 1117.98
# - id (3436, 1) mass 332.1136 rt 1119.96
# - id (4142, 2) mass 332.1139 rt 1119.96
# Overlapping peaksets:
# 	Peakset
# 	- id (3436, 1) mass 332.1136 rt 1119.96 MAP_trans M+H@331.10628(1.0000)
# 	- id (4142, 2) mass 332.1139 rt 1119.96 MAP_trans M+H@331.10666(1.0000)
#
# Ground Truth Group 811
# - id (2148, 0) mass 596.1966 rt 1139.94
# - id (3598, 1) mass 596.1926 rt 1139.94
# - id (4371, 2) mass 596.2000 rt 1141.98
# - id (2135, 3) mass 596.1952 rt 1141.98
# Overlapping peaksets:
# 	Peakset
# 	- id (2148, 0) mass 596.1966 rt 1139.94 MAP_trans M+H [C13]@594.18397(0.9999)
# 	- id (3598, 1) mass 596.1926 rt 1139.94 MAP_trans M+H [C13]@594.18227(1.0000)
# 	- id (2135, 3) mass 596.1952 rt 1141.98 MAP_trans M+H [C13]@594.18337(0.9999)
#
# Ground Truth Group 812
# - id (2158, 0) mass 617.1694 rt 1139.94
# - id (3637, 1) mass 617.1721 rt 1139.94
# - id (4409, 2) mass 617.1708 rt 1141.98
# - id (2140, 3) mass 617.1789 rt 1141.98
# Overlapping peaksets:
# 	Peakset
# 	- id (2158, 0) mass 617.1694 rt 1139.94 MAP_trans M+Na@594.18397(0.9996)
# 	- id (3637, 1) mass 617.1721 rt 1139.94 MAP_trans M+Na@594.18227(1.0000)
# 	- id (4409, 2) mass 617.1708 rt 1141.98 MAP_trans M+Na@594.18243(0.9999)
# 	Peakset
# 	- id (2140, 3) mass 617.1789 rt 1141.98 MAP_trans M+H@616.17183(1.0000)
#
# Ground Truth Group 813
# - id (2185, 0) mass 615.6714 rt 1139.94
# - id (3636, 1) mass 615.6765 rt 1137.96
# - id (4410, 2) mass 615.6852 rt 1139.94
# - id (2145, 3) mass 615.6747 rt 1141.98
# Overlapping peaksets:
# 	Peakset
# 	- id (2185, 0) mass 615.6714 rt 1139.94 MAP_trans M+H [C13]@613.65983(0.9999)
# 	- id (2145, 3) mass 615.6747 rt 1141.98 MAP_trans M+H [C13]@613.66318(0.9999)
# 	Peakset
# 	- id (3636, 1) mass 615.6765 rt 1137.96 MAP_trans M+H@614.66918(0.9850)
# 	- id (4410, 2) mass 615.6852 rt 1139.94 MAP_trans M+H@614.67791(1.0000)
#
# Ground Truth Group 814
# - id (2154, 0) mass 703.6659 rt 1145.94
# - id (3663, 1) mass 703.6685 rt 1143.96
# - id (4452, 2) mass 703.6661 rt 1145.94
# - id (2217, 3) mass 703.6688 rt 1145.94
# Overlapping peaksets:
# 	Peakset
# 	- id (2154, 0) mass 703.6659 rt 1145.94 MAP_trans M+H [C13]@701.65594(0.9999)
# 	- id (3663, 1) mass 703.6685 rt 1143.96 MAP_trans M+H [C13]@701.65567(0.9999)
# 	- id (2217, 3) mass 703.6688 rt 1145.94 MAP_trans M+H [C13]@701.65644(0.9999)
#
# Ground Truth Group 815
# - id (1969, 0) mass 256.5639 rt 1137.96
# - id (1952, 3) mass 256.5547 rt 1137.96
# Overlapping peaksets:
# 	Peakset
# 	- id (1952, 3) mass 256.5547 rt 1137.96 MAP_trans M+H@255.54742(1.0000)
#
# Ground Truth Group 816
# - id (2008, 0) mass 387.2052 rt 1121.94
# Overlapping peaksets:
#
# Ground Truth Group 817
# - id (2073, 0) mass 475.1909 rt 1125.96
# Overlapping peaksets:
#
# Ground Truth Group 818
# - id (2009, 0) mass 410.1711 rt 1119.96
# - id (2005, 3) mass 410.1887 rt 1121.94
# Overlapping peaksets:
# 	Peakset
# 	- id (2005, 3) mass 410.1887 rt 1121.94 MAP_trans M+H@409.18145(1.0000)
#
# Ground Truth Group 819
# - id (2022, 0) mass 426.1666 rt 1117.98
# - id (1997, 3) mass 426.1662 rt 1119.96
# Overlapping peaksets:
# 	Peakset
# 	- id (1997, 3) mass 426.1662 rt 1119.96 MAP_trans M+H@425.15888(0.9459)
#
# Ground Truth Group 820
# - id (2015, 0) mass 203.5711 rt 1151.94
# - id (4238, 2) mass 203.5774 rt 1151.94
# - id (1957, 3) mass 203.5774 rt 1151.94
# Overlapping peaksets:
# 	Peakset
# 	- id (3402, 1) mass 203.5793 rt 1151.94 MAP_trans M+H@202.57199(1.0000)
# 	- id (4238, 2) mass 203.5774 rt 1151.94 MAP_trans M+H@202.57009(1.0000)
# 	- id (1957, 3) mass 203.5774 rt 1151.94 MAP_trans M+H@202.57012(1.0000)
#
# Ground Truth Group 821
# - id (2235, 0) mass 496.1189 rt 1147.98
# - id (4516, 2) mass 496.1119 rt 1149.96
# - id (2204, 3) mass 496.1084 rt 1147.98
# Overlapping peaksets:
# 	Peakset
# 	- id (2235, 0) mass 496.1189 rt 1147.98 MAP_trans M+H [C13]@494.10966(0.9999)
# 	Peakset
# 	- id (4516, 2) mass 496.1119 rt 1149.96 MAP_trans M+H@495.10464(1.0000)
# 	- id (2204, 3) mass 496.1084 rt 1147.98 MAP_trans M+H@495.10116(1.0000)
#
# Ground Truth Group 822
# - id (2070, 0) mass 383.1131 rt 1137.96
# - id (2102, 3) mass 383.1215 rt 1141.98
# Overlapping peaksets:
# 	Peakset
# 	- id (2102, 3) mass 383.1215 rt 1141.98 MAP_trans M+H@382.11427(1.0000)
#
# Ground Truth Group 823
# - id (2083, 0) mass 402.1357 rt 1239.96
# - id (4835, 2) mass 402.1263 rt 1243.98
# Overlapping peaksets:
# 	Peakset
# 	- id (2658, 0) mass 402.1380 rt 1305.96 MAP_trans M+H@401.13073(1.0000)
# 	- id (4835, 2) mass 402.1263 rt 1243.98 MAP_trans M+H@401.11899(1.0000)
# 	- id (2466, 3) mass 402.1273 rt 1241.94 MAP_trans M+H@401.12003(1.0000)
#
# Ground Truth Group 824
# ...
# 	- id (6306, 1) mass 189.1362 rt 2255.94 MAP_trans [M-H2O]+H@206.13876(0.9999)
# 	- id (7707, 2) mass 189.1357 rt 2255.94 MAP_trans [M-H2O]+H@206.13827(1.0000)
# 	Peakset
# 	- id (4865, 3) mass 189.1335 rt 2255.94 MAP_trans M+H@188.12618(1.0000)
#
# Ground Truth Group 967
# - id (5000, 0) mass 347.2240 rt 2255.94
# - id (6473, 1) mass 347.2232 rt 2257.92
# - id (7924, 2) mass 347.2246 rt 2257.92
# - id (4958, 3) mass 347.2229 rt 2255.94
# Overlapping peaksets:
# 	Peakset
# 	- id (4958, 3) mass 347.2229 rt 2255.94 MAP_trans [M-CO2]+NH4 [C13]@372.17432(0.9997)
# 	Peakset
# 	- id (5000, 0) mass 347.2240 rt 2255.94 MAP_trans M+H@346.21676(1.0000)
# 	- id (6473, 1) mass 347.2232 rt 2257.92 MAP_trans M+H@346.21596(1.0000)
# 	- id (7924, 2) mass 347.2246 rt 2257.92 MAP_trans M+H@346.21735(1.0000)
#
# Ground Truth Group 968
# - id (4781, 0) mass 134.0628 rt 2251.92
# - id (7749, 2) mass 134.0707 rt 2259.90
# Overlapping peaksets:
#
# Ground Truth Group 969
# - id (5006, 0) mass 324.1359 rt 2251.92
# Overlapping peaksets:
#
# Ground Truth Group 970
# - id (5011, 0) mass 342.1271 rt 2251.92
# Overlapping peaksets:
#
# Ground Truth Group 971
# - id (4500, 0) mass 269.1604 rt 2093.94
# - id (6009, 1) mass 269.1712 rt 2097.90
# - id (7446, 2) mass 269.1643 rt 2097.90
# - id (4571, 3) mass 269.1598 rt 2095.92
# Overlapping peaksets:
# 	Peakset
# 	- id (6009, 1) mass 269.1712 rt 2097.90 MAP_trans M+H@268.16396(1.0000)
# 	- id (7446, 2) mass 269.1643 rt 2097.90 MAP_trans M+H@268.15706(1.0000)
# 	- id (4571, 3) mass 269.1598 rt 2095.92 MAP_trans M+H@268.15253(1.0000)
#
# Ground Truth Group 972
# - id (4583, 0) mass 351.1851 rt 2093.94
# - id (5919, 1) mass 351.1862 rt 2095.92
# - id (7494, 2) mass 351.1916 rt 2097.90
# - id (4327, 3) mass 351.1928 rt 2095.92
# Overlapping peaksets:
# 	Peakset
# 	- id (7494, 2) mass 351.1916 rt 2097.90 MAP_trans M+H [C13]@349.18079(0.9999)
# 	- id (4327, 3) mass 351.1928 rt 2095.92 MAP_trans M+H [C13]@349.18099(0.9998)
#
# Ground Truth Group 973
# - id (4743, 0) mass 392.2493 rt 2133.90
# - id (6247, 1) mass 392.2505 rt 2135.94
# - id (7658, 2) mass 392.2488 rt 2133.90
# - id (4710, 3) mass 392.2526 rt 2135.94
# Overlapping peaksets:
# 	Peakset
# 	- id (6247, 1) mass 392.2505 rt 2135.94 MAP_trans M+H [C13]@390.24043(0.9999)
# 	- id (4710, 3) mass 392.2526 rt 2135.94 MAP_trans M+H [C13]@390.24262(0.9999)
# 	Peakset
# 	- id (4743, 0) mass 392.2493 rt 2133.90 MAP_trans M+H@391.24205(0.9335)
# 	- id (7658, 2) mass 392.2488 rt 2133.90 MAP_trans M+H@391.24153(0.9483)
#
# Ground Truth Group 974
# - id (4700, 0) mass 715.8152 rt 2093.94
# Overlapping peaksets:
#
# Ground Truth Group 975
# - id (4678, 0) mass 279.1883 rt 2133.90
# - id (7342, 1) mass 279.1773 rt 2133.90
# - id (9087, 2) mass 279.1953 rt 2135.94
# - id (5701, 3) mass 279.1823 rt 2131.92
# Overlapping peaksets:
# 	Peakset
# 	- id (7342, 1) mass 279.1773 rt 2133.90 MAP_trans M+H@278.16998(1.0000)
# 	- id (9090, 2) mass 279.1854 rt 2229.90 MAP_trans M+H@278.17815(1.0000)
# 	- id (5701, 3) mass 279.1823 rt 2131.92 MAP_trans M+H@278.17503(1.0000)
# 	Peakset
# 	- id (4678, 0) mass 279.1883 rt 2133.90 MAP_trans M+H@278.18102(1.0000)
# 	- id (9087, 2) mass 279.1953 rt 2135.94 MAP_trans M+H@278.18805(1.0000)
#
# Ground Truth Group 976
# - id (4705, 0) mass 416.2242 rt 2113.92
# - id (6135, 1) mass 416.2099 rt 2119.92
# - id (7627, 2) mass 416.2290 rt 2119.92
# - id (4697, 3) mass 416.2221 rt 2113.92
# Overlapping peaksets:
# 	Peakset
# 	- id (4705, 0) mass 416.2242 rt 2113.92 MAP_trans M+H@415.21690(1.0000)
# 	- id (7627, 2) mass 416.2290 rt 2119.92 MAP_trans M+H@415.22172(0.9856)
# 	- id (4697, 3) mass 416.2221 rt 2113.92 MAP_trans M+H@415.21484(0.6480)
#
# Ground Truth Group 977
# - id (4652, 0) mass 455.0961 rt 2089.92
# - id (4624, 3) mass 455.1141 rt 2093.94
# Overlapping peaksets:
# 	Peakset
# 	- id (4624, 3) mass 455.1141 rt 2093.94 MAP_trans M+H@454.10687(1.0000)
#
# Ground Truth Group 978
# - id (4698, 0) mass 701.3559 rt 2093.94
# - id (4662, 3) mass 701.3655 rt 2091.90
# Overlapping peaksets:
# 	Peakset
# 	- id (7586, 2) mass 701.3497 rt 2095.92 MAP_trans M+H@700.34243(1.0000)
# 	- id (4662, 3) mass 701.3655 rt 2091.90 MAP_trans M+H@700.35823(1.0000)
#
# Ground Truth Group 979
# - id (4688, 0) mass 476.2261 rt 2107.92
# - id (6347, 1) mass 476.2228 rt 2173.92
# - id (7750, 2) mass 476.2279 rt 2173.92
# - id (4809, 3) mass 476.2307 rt 2173.92
# Overlapping peaksets:
# 	Peakset
# 	- id (4853, 0) mass 476.2240 rt 2171.94 MAP_trans M+H@475.21677(1.0000)
# 	- id (6347, 1) mass 476.2228 rt 2173.92 MAP_trans M+H@475.21548(1.0000)
# 	- id (7750, 2) mass 476.2279 rt 2173.92 MAP_trans M+H@475.22066(1.0000)
# 	- id (4809, 3) mass 476.2307 rt 2173.92 MAP_trans M+H@475.22338(1.0000)
#
# Ground Truth Group 980
# - id (4732, 0) mass 374.6883 rt 2165.94
# - id (4732, 3) mass 374.6943 rt 2167.92
# Overlapping peaksets:
# 	Peakset
# 	- id (4732, 3) mass 374.6943 rt 2167.92 MAP_trans M+H@373.68698(0.9723)
#
# Ground Truth Group 981
# - id (4893, 0) mass 346.1746 rt 2195.94
# - id (6353, 1) mass 346.1821 rt 2197.92
# Overlapping peaksets:
# 	Peakset
# 	- id (4893, 0) mass 346.1746 rt 2195.94 MAP_trans M+H [C13]@344.16472(0.9990)
# 	- id (4830, 3) mass 346.1779 rt 2197.92 MAP_trans M+H [C13]@344.16847(0.9999)
#
# Ground Truth Group 982
# - id (4749, 0) mass 408.2454 rt 2133.90
# - id (7688, 2) mass 408.2264 rt 2135.94
# Overlapping peaksets:
# 	Peakset
# 	- id (7688, 2) mass 408.2264 rt 2135.94 MAP_trans M+H [C13]@406.21679(1.0000)
#
# Ground Truth Group 983
# - id (5734, 0) mass 382.1850 rt 2139.90
# - id (5760, 3) mass 382.1873 rt 2173.92
# Overlapping peaksets:
# 	Peakset
# 	- id (5732, 0) mass 382.1850 rt 2165.94 MAP_trans M+H@381.17774(1.0000)
# 	- id (7392, 1) mass 382.1861 rt 2167.92 MAP_trans M+H@381.17880(1.0000)
# 	- id (8966, 2) mass 382.1865 rt 2165.94 MAP_trans M+H@381.17927(1.0000)
# 	- id (5760, 3) mass 382.1873 rt 2173.92 MAP_trans M+H@381.18000(1.0000)
# 	Peakset
# 	- id (5734, 0) mass 382.1850 rt 2139.90 MAP_trans M+H@381.17772(1.0000)
# 	- id (7396, 1) mass 382.1856 rt 2141.94 MAP_trans M+H@381.17808(1.0000)
# 	- id (8961, 2) mass 382.1870 rt 2143.92 MAP_trans M+H@381.17912(1.0000)
#
# Ground Truth Group 984
# - id (5750, 0) mass 382.6874 rt 2139.90
# - id (5765, 3) mass 382.6884 rt 2173.92
# Overlapping peaksets:
# 	Peakset
# 	- id (7406, 1) mass 382.6861 rt 2167.92 MAP_trans M+H@381.67879(1.0000)
# 	- id (8993, 2) mass 382.6868 rt 2167.92 MAP_trans M+H@381.67957(1.0000)
# 	- id (5765, 3) mass 382.6884 rt 2173.92 MAP_trans M+H@381.68108(1.0000)
# 	Peakset
# 	- id (5750, 0) mass 382.6874 rt 2139.90 MAP_trans M+H@381.68016(1.0000)
# 	- id (7405, 1) mass 382.6872 rt 2143.92 MAP_trans M+H@381.68045(1.0000)
# 	- id (8990, 2) mass 382.6881 rt 2143.92 MAP_trans M+H@381.68106(1.0000)
#
# Ground Truth Group 985
# - id (4914, 0) mass 422.2626 rt 2211.90
# - id (6441, 1) mass 422.2632 rt 2215.92
# - id (7838, 2) mass 422.2642 rt 2215.92
# - id (4890, 3) mass 422.2645 rt 2215.92
# Overlapping peaksets:
# 	Peakset
# 	- id (7838, 2) mass 422.2642 rt 2215.92 MAP_trans M+H [C13]@420.25451(0.9999)
# 	- id (4890, 3) mass 422.2645 rt 2215.92 MAP_trans M+H [C13]@420.25526(0.9999)
#
# Ground Truth Group 986
# - id (4813, 0) mass 211.6353 rt 2213.94
# - id (6325, 1) mass 211.6330 rt 2215.92
# - id (7755, 2) mass 211.6315 rt 2215.92
# Overlapping peaksets:
# 	Peakset
# 	- id (6325, 1) mass 211.6330 rt 2215.92 MAP_trans M+H@210.62573(1.0000)
# 	- id (7755, 2) mass 211.6315 rt 2215.92 MAP_trans M+H@210.62425(1.0000)
# 	- id (4793, 3) mass 211.6268 rt 2215.92 MAP_trans M+H@210.61953(1.0000)
#
# Ground Truth Group 987
# - id (4857, 0) mass 276.2199 rt 2207.94
# - id (6386, 1) mass 276.2081 rt 2211.90
# - id (7817, 2) mass 276.2273 rt 2211.90
# - id (4858, 3) mass 276.2205 rt 2213.94
# Overlapping peaksets:
# 	Peakset
# 	- id (4858, 3) mass 276.2205 rt 2213.94 MAP_trans [M-H2O]+H [C13]@292.22040(0.7679)
# 	Peakset
# 	- id (4857, 0) mass 276.2199 rt 2207.94 MAP_trans M+H [C13]@274.20903(0.9999)
#
# Ground Truth Group 988
# - id (5031, 0) mass 333.1809 rt 2277.90
# - id (6510, 1) mass 333.1788 rt 2279.94
# - id (8012, 2) mass 333.1796 rt 2279.94
# - id (5008, 3) mass 333.1840 rt 2279.94
# Overlapping peaksets:
# 	Peakset
# 	- id (6510, 1) mass 333.1788 rt 2279.94 MAP_trans [M-H2O]+H@350.18236(0.9999)
# 	- id (8012, 2) mass 333.1796 rt 2279.94 MAP_trans [M-H2O]+H@350.18216(0.9999)
# 	- id (5008, 3) mass 333.1840 rt 2279.94 MAP_trans [M-H2O]+H@350.18679(0.9999)
#
# Ground Truth Group 989
# - id (5056, 0) mass 538.3542 rt 2275.92
# - id (5048, 3) mass 538.3458 rt 2277.90
# Overlapping peaksets:
# 	Peakset
# 	- id (6594, 1) mass 538.3333 rt 2277.90 MAP_trans M+H@537.32598(0.9720)
# 	- id (8019, 2) mass 538.3412 rt 2277.90 MAP_trans M+H@537.33391(1.0000)
# 	- id (5048, 3) mass 538.3458 rt 2277.90 MAP_trans M+H@537.33852(1.0000)
#
# Ground Truth Group 990
# - id (5014, 0) mass 131.0012 rt 2379.90
# - id (5038, 3) mass 130.9927 rt 2377.92
# Overlapping peaksets:
# 	Peakset
# 	- id (5038, 3) mass 130.9927 rt 2377.92 MAP_trans M+H@129.98546(1.0000)
#
# Ground Truth Group 991
# - id (5128, 0) mass 513.2561 rt 2335.92
# Overlapping peaksets:
#
# Ground Truth Group 992
# - id (5089, 0) mass 200.1090 rt 2365.92
# - id (6639, 1) mass 200.1105 rt 2367.90
# Overlapping peaksets:
# 	Peakset
# 	- id (6639, 1) mass 200.1105 rt 2367.90 MAP_trans [M-H2O]+2H@416.21823(0.9995)
# 	Peakset
# 	- id (5089, 0) mass 200.1090 rt 2365.92 MAP_trans M+H@199.10172(1.0000)
# 	- id (8078, 2) mass 200.1121 rt 2367.90 MAP_trans M+H@199.10486(1.0000)
# 	- id (5070, 3) mass 200.1128 rt 2365.92 MAP_trans M+H@199.10551(1.0000)
#
# Ground Truth Group 993
# - id (5109, 0) mass 503.2294 rt 2307.90
# - id (8082, 2) mass 503.2237 rt 2311.92
# - id (5112, 3) mass 503.2225 rt 2311.92
# Overlapping peaksets:
# 	Peakset
# 	- id (8082, 2) mass 503.2237 rt 2311.92 MAP_trans M+H [C13]@501.21472(0.9999)
# 	- id (5112, 3) mass 503.2225 rt 2311.92 MAP_trans M+H [C13]@501.21073(0.9999)
#
# Ground Truth Group 994
# - id (5233, 0) mass 395.1876 rt 2411.94
# - id (6749, 1) mass 395.2018 rt 2411.94
# - id (5161, 3) mass 395.1792 rt 2361.90
# Overlapping peaksets:
# 	Peakset
# 	- id (6749, 1) mass 395.2018 rt 2411.94 MAP_trans M+H@394.19453(1.0000)
# 	- id (8233, 2) mass 395.2044 rt 2413.92 MAP_trans M+H@394.19711(1.0000)
# 	- id (5226, 3) mass 395.1933 rt 2409.90 MAP_trans M+H@394.18603(1.0000)
# 	Peakset
# 	- id (5161, 3) mass 395.1792 rt 2361.90 MAP_trans M+H@394.17194(1.0000)
#
# Ground Truth Group 995
# - id (5228, 0) mass 483.2105 rt 2407.92
# - id (6759, 1) mass 483.1907 rt 2413.92
# - id (8220, 2) mass 483.2127 rt 2411.94
# - id (5233, 3) mass 483.2115 rt 2411.94
# Overlapping peaksets:
# 	Peakset
# 	- id (5228, 0) mass 483.2105 rt 2407.92 MAP_trans M+H@482.20326(1.0000)
# 	- id (8220, 2) mass 483.2127 rt 2411.94 MAP_trans M+H@482.20541(1.0000)
# 	- id (5233, 3) mass 483.2115 rt 2411.94 MAP_trans M+H@482.20419(1.0000)
#
# Ground Truth Group 996
# - id (5300, 0) mass 408.2176 rt 2477.94
# - id (6811, 1) mass 408.2257 rt 2475.90
# - id (8322, 2) mass 408.2252 rt 2477.94
# - id (5302, 3) mass 408.2354 rt 2471.94
# Overlapping peaksets:
# 	Peakset
# 	- id (5300, 0) mass 408.2176 rt 2477.94 MAP_trans M+H@407.21028(1.0000)
# 	- id (6811, 1) mass 408.2257 rt 2475.90 MAP_trans M+H@407.21846(1.0000)
# 	- id (8322, 2) mass 408.2252 rt 2477.94 MAP_trans M+H@407.21788(1.0000)
# 	Peakset
# 	- id (5302, 3) mass 408.2354 rt 2471.94 MAP_trans M+H@407.22808(1.0000)
#
# Ground Truth Group 997
# - id (5306, 0) mass 343.1965 rt 2477.94
# - id (6788, 1) mass 343.2110 rt 2477.94
# - id (8313, 2) mass 343.2006 rt 2479.92
# - id (5306, 3) mass 343.1935 rt 2475.90
# Overlapping peaksets:
# 	Peakset
# 	- id (6788, 1) mass 343.2110 rt 2477.94 MAP_trans [M-CO]+Na [C13]@347.21318(0.9999)
# 	Peakset
# 	- id (8313, 2) mass 343.2006 rt 2479.92 MAP_trans M+H@342.19328(1.0000)
# 	- id (5306, 3) mass 343.1935 rt 2475.90 MAP_trans M+H@342.18627(0.9589)
# 	Peakset
# 	- id (5306, 0) mass 343.1965 rt 2477.94 MAP_trans [M-CO2]+K@348.22416(0.9998)
#
# Ground Truth Group 998
# - id (5272, 0) mass 193.1119 rt 2499.90
# - id (8277, 2) mass 193.1073 rt 2501.94
# - id (5279, 3) mass 193.1125 rt 2499.90
# Overlapping peaksets:
# 	Peakset
# 	- id (5272, 0) mass 193.1119 rt 2499.90 MAP_trans M+H@192.10463(1.0000)
# 	- id (6779, 1) mass 193.1163 rt 2503.92 MAP_trans M+H@192.10901(1.0000)
# 	- id (5279, 3) mass 193.1125 rt 2499.90 MAP_trans M+H@192.10525(1.0000)
#
# Ground Truth Group 999
# - id (5308, 0) mass 280.2128 rt 2499.90
# - id (8338, 2) mass 280.2173 rt 2501.94
# - id (5312, 3) mass 280.2056 rt 2497.92
# Overlapping peaksets:
# 	Peakset
# 	- id (5308, 0) mass 280.2128 rt 2499.90 MAP_trans M+H@279.20555(1.0000)
# 	- id (8338, 2) mass 280.2173 rt 2501.94 MAP_trans M+H@279.21005(1.0000)
# 	Peakset
# 	- id (5312, 3) mass 280.2056 rt 2497.92 MAP_trans M+H@279.19832(1.0000)
#
# Ground Truth Group 1000
# - id (5392, 0) mass 163.0408 rt 2707.92
# - id (6911, 1) mass 163.0391 rt 2709.90
# Overlapping peaksets:
#
# Ground Truth Group 1001
# - id (5374, 0) mass 111.1293 rt 2709.90
# - id (6872, 1) mass 111.1237 rt 2711.88
# - id (8375, 2) mass 111.1325 rt 2709.90
# - id (5399, 3) mass 111.1258 rt 2709.90
# Overlapping peaksets:
# 	Peakset
# 	- id (5374, 0) mass 111.1293 rt 2709.90 MAP_trans M+H@110.12199(1.0000)
# 	- id (8375, 2) mass 111.1325 rt 2709.90 MAP_trans M+H@110.12525(1.0000)
# 	Peakset
# 	- id (5399, 3) mass 111.1258 rt 2709.90 MAP_trans M+H@110.11855(1.0000)
#
# Ground Truth Group 1002
# - id (5423, 0) mass 362.2372 rt 2733.90
# - id (6954, 1) mass 362.2364 rt 2737.92
# - id (8472, 2) mass 362.2375 rt 2735.88
# - id (5447, 3) mass 362.2371 rt 2733.90
# Overlapping peaksets:
# 	Peakset
# 	- id (5423, 0) mass 362.2372 rt 2733.90 MAP_trans M+H [C13]@360.22699(0.9999)
# 	- id (6954, 1) mass 362.2364 rt 2737.92 MAP_trans M+H [C13]@360.22637(0.9999)
# 	- id (8472, 2) mass 362.2375 rt 2735.88 MAP_trans M+H [C13]@360.22686(1.0000)
# 	Peakset
# 	- id (5447, 3) mass 362.2371 rt 2733.90 MAP_trans M+H@361.22959(0.5429)
#
# Ground Truth Group 1003
# - id (5662, 0) mass 433.2288 rt 2103.90
# - id (7323, 1) mass 433.2262 rt 2047.92
# - id (8969, 2) mass 433.2284 rt 2089.92
# Overlapping peaksets:
# 	Peakset
# 	- id (5662, 0) mass 433.2288 rt 2103.90 MAP_trans M+H@432.22150(1.0000)
# 	- id (7324, 1) mass 433.2281 rt 2109.90 MAP_trans M+H@432.22083(1.0000)
# 	- id (8969, 2) mass 433.2284 rt 2089.92 MAP_trans M+H@432.22108(1.0000)
# 	- id (5734, 3) mass 433.2317 rt 2111.94 MAP_trans M+H@432.22406(1.0000)
# 	Peakset
# 	- id (5660, 0) mass 433.2269 rt 2045.94 MAP_trans M+H@432.21967(1.0000)
# 	- id (7323, 1) mass 433.2262 rt 2047.92 MAP_trans M+H@432.21894(1.0000)
# 	- id (5732, 3) mass 433.2298 rt 2045.94 MAP_trans M+H@432.22250(1.0000)
#
# Ground Truth Group 1004
# - id (5712, 0) mass 433.7303 rt 2103.90
# - id (7370, 1) mass 433.7291 rt 2047.92
# - id (9000, 2) mass 433.7300 rt 2083.92
# Overlapping peaksets:
# 	Peakset
# 	- id (5714, 0) mass 433.7282 rt 2045.94 MAP_trans M+H@432.72087(1.0000)
# 	- id (7370, 1) mass 433.7291 rt 2047.92 MAP_trans M+H@432.72186(1.0000)
# 	- id (8931, 2) mass 433.7283 rt 2047.92 MAP_trans M+H@432.72100(1.0000)
# 	- id (5752, 3) mass 433.7311 rt 2045.94 MAP_trans M+H@432.72385(1.0000)
# 	Peakset
# 	- id (5712, 0) mass 433.7303 rt 2103.90 MAP_trans M+H@432.72298(1.0000)
# 	- id (9000, 2) mass 433.7300 rt 2083.92 MAP_trans M+H@432.72270(1.0000)
# 	- id (5754, 3) mass 433.7266 rt 2087.94 MAP_trans M+H@432.71928(1.0000)
#
# Ground Truth Group 1005
# - id (5730, 0) mass 382.1867 rt 2199.90
# - id (5760, 3) mass 382.1873 rt 2173.92
# Overlapping peaksets:
# 	Peakset
# 	- id (5732, 0) mass 382.1850 rt 2165.94 MAP_trans M+H@381.17774(1.0000)
# 	- id (7392, 1) mass 382.1861 rt 2167.92 MAP_trans M+H@381.17880(1.0000)
# 	- id (8966, 2) mass 382.1865 rt 2165.94 MAP_trans M+H@381.17927(1.0000)
# 	- id (5760, 3) mass 382.1873 rt 2173.92 MAP_trans M+H@381.18000(1.0000)
# 	Peakset
# 	- id (5730, 0) mass 382.1867 rt 2199.90 MAP_trans M+H@381.17881(1.0000)
# 	- id (7391, 1) mass 382.1871 rt 2201.94 MAP_trans M+H@381.17979(1.0000)
# 	- id (8960, 2) mass 382.1872 rt 2201.94 MAP_trans M+H@381.17982(1.0000)
#
# Ground Truth Group 1006
# - id (5747, 0) mass 382.6877 rt 2195.94
# - id (5765, 3) mass 382.6884 rt 2173.92
# Overlapping peaksets:
# 	Peakset
# 	- id (7406, 1) mass 382.6861 rt 2167.92 MAP_trans M+H@381.67879(1.0000)
# 	- id (8993, 2) mass 382.6868 rt 2167.92 MAP_trans M+H@381.67957(1.0000)
# 	- id (5765, 3) mass 382.6884 rt 2173.92 MAP_trans M+H@381.68108(1.0000)
# 	Peakset
# 	- id (5747, 0) mass 382.6877 rt 2195.94 MAP_trans M+H@381.68039(1.0000)
# 	- id (7402, 1) mass 382.6867 rt 2199.90 MAP_trans M+H@381.67940(1.0000)
# 	- id (8989, 2) mass 382.6881 rt 2201.94 MAP_trans M+H@381.68087(1.0000)

# %% [markdown]
# Some peaks seem to have disappeared from the output aligned peaksets? This looks like a bug, which explains the lower recall ... For example, peak (1327, 1) below ..

# %%
print "Found in input file?"
for f in data_list[1].features:
    key = f._get_key()
    if (1327, 1) == key:
        print "- id %s mass %.4f rt %.2f" % ((key, f.mass, f.rt))

# check in the output of first-stage clustering
print "\nAnd also in the clustering"
first_file_clusterings = file_clusterings[1]
for cluster in first_file_clusterings:
    member_keys = [f._get_key() for f, poss in cluster.members]
    if (1327, 1) in member_keys:
        print "Cluster %d %.4f %.2f" % (cluster.id, cluster.mu_mass, cluster.mu_rt)
        print member_keys   
        for f, poss in cluster.members:
            print "- id %s mass %.4f rt %.2f" % ((f._get_key(), f.mass, f.rt))

# check in the output aligned peaksets
print "\nBut missing in the output ??!!"
for ps in aligned_peaksets:
    ps_keys = [f._get_key() for f in ps]
    if (1327, 1) in ps_keys:
        print ps_keys
# Out:
# Found in input file?
# - id (1327, 1) mass 284.0365 rt 223.98
#
# And also in the clustering
# Cluster 1326 283.0290 224.10
# [(1263, 1), (1327, 1), (1385, 1)]
# - id (1263, 1) mass 238.0311 rt 223.98
# - id (1327, 1) mass 284.0365 rt 223.98
# - id (1385, 1) mass 256.0401 rt 223.98
#
# But missing in the output ??!!
