# %% [markdown]
# <h1>Notebook to plot some cluster-cluster results</h1>

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import os
import sys
basedir = '/Users/joewandy/git/metabolomics_tools'
sys.path.append(basedir)

# %%
import numpy as np
import pylab as plt
import pandas as pd
from scipy.stats import ttest_rel

import seaborn as sns
sns.set(color_codes=True)
from IPython.display import display, HTML

import cPickle
import random
import copy
import glob
import gzip
import string

# %%
from alignment.models import HyperPars as AlignmentHyperPars
from alignment.experiment import *
from efcompute.ef_assigner import ef_assigner

# %%
hp = AlignmentHyperPars()    
hp.within_file_mass_tol = 5
hp.within_file_rt_tol = 30
hp.across_file_mass_tol = 10
hp.across_file_rt_tol = 60
hp.alpha_mass = 1.0
hp.dp_alpha = 1000.0
hp.beta = 0.1
hp.t = 0.0
hp.mass_clustering_n_iterations = 5000
hp.rt_clustering_nsamps = 500
hp.rt_clustering_burnin = 0

print hp
# Out:
# Hyperparameters across_file_mass_tol=10, across_file_rt_tol=60, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=5000, matching_alpha=0.3, rt_clustering_burnin=0, rt_clustering_nsamps=500, second_stage_clustering_use_adduct_likelihood=True, second_stage_clustering_use_mass_likelihood=True, second_stage_clustering_use_rt_likelihood=True, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30

# %% [markdown]
# <h2>1. Load the data</h2>

# %%
gt_file = '/Users/joewandy/git/metabolomics_tools/alignment/input/std1_csv_full_old/ground_truth/ground_truth.txt'
n_set = 5
n = 0

c = string.lowercase[n]
filename = 'pickles/cc_4%s.p' % c
aligner = load_clustering(filename)

c = string.lowercase[n]
filename = 'pickles/cc_no_adduct_4%s.p' % c
aligner_no_adduct = load_clustering(filename)
# Out:
# Loaded from pickles/cc_4a.p
# Loaded from pickles/cc_no_adduct_4a.p

# %% [markdown]
# <h2>2. Plotting Methods</h2>

# %%
def find_in_alignment_results(alignment_results, to_search):
    for item, prob in alignment_results:
        # ps_keys = frozenset([f._get_key() for f in item])
        ps_keys = [f._get_key() for f in item]
        if to_search in ps_keys:
            print prob
            for f in item:
                print '- %s' % f

# %%
def find_identification(id_rows, mass, rt, intensity):
    EPSILON = 0.0001;
    for f_mass, f_rt, f_intensity, f_iden in id_rows:
        if abs(f_mass - mass) < EPSILON and abs(f_rt - rt) < EPSILON and abs(f_intensity - intensity) < EPSILON:
            return f_iden

# %%
def find_diff(a, b, thresh, id_rows):

    a_probs = {}
    b_probs = {}
    key_to_feature = {}
    key_to_id = {}
    
    a_res = []
    for item, p in a:
        aligned = frozenset([f._get_key() for f in item])
        for f in item:
            key_to_feature[f._get_key()] = f
            key_to_id[f._get_key()] = find_identification(id_rows, f.mass, f.rt, f.intensity)
        a_probs[aligned] = p
        a_res.append(aligned)
    a_res = set(a_res)
    
    b_res = []
    for item, p in b:
        aligned = frozenset([f._get_key() for f in item])
        b_probs[aligned] = p
        b_res.append(aligned)
    b_res = set(b_res)    
    
    for aligned in a_res:
        pa = a_probs[aligned]
        if aligned in b_probs:
            pb = b_probs[aligned]
            if pa-pb > thresh and len(aligned)==4:
                print aligned, pa, pb
                found_g = None
                for a in aligned:
                    print "%s identification=%s" % (key_to_feature[a], key_to_id[a])
                    for g in ground_truth:
                        if a in g:
                            found_g = g
                if found_g is not None:
                    print "GT %s" % found_g
                print
                
    return key_to_id

# %%
def find_cluster_of_peak(to_find, acs, file_idx):

    ac = acs[file_idx]
    clusters_list = ac.clusters
    for cluster in clusters_list:
        for p, trans in cluster.members:
            if p._get_key() == to_find:
                return cluster

# %%
def cluster_plot(title, cluster_list, key_to_id, outfile):
    
    tick_fs = 28
    n_cluster = len(cluster_list)
    fig, axs = plt.subplots(nrows=n_cluster, ncols=1, figsize=(20,20), sharex=True)
    
    for i in range(len(cluster_list)):
        
        ax = axs[i]
        cluster = cluster_list[i]
        members = []
        possibles = []
        trans = []        
        cluster_id = []
        for peak, poss in cluster.members:
            members.append(peak)
            possibles.append(poss)
            trans.append(poss.transformation)  
            cluster_id.append(cluster.id)
            
        print "CLUSTER {}".format(cluster.id)
        max_intensity = 0
        for p in range(len(members)):
            iden = None
            if members[p]._get_key() in key_to_id:
                iden = key_to_id[members[p]._get_key()]
            print "Peak {} : {},{},{} -> {},{} (p={}), {}".format(members[p]._get_key(), members[p].mass,members[p].rt,members[p].intensity,
                                                possibles[p].transformation.name,
                                                possibles[p].transformed_mass,
                                                possibles[p].prob, 
                                                iden)
            if members[p].intensity > max_intensity:
                max_intensity = members[p].intensity

        for p_ind in range(len(members)):
            p = members[p_ind]
            po = possibles[p_ind]
            cid = cluster_id[p_ind]
            rel_intensity = p.intensity/max_intensity
            ax.set_title('Precursor Cluster %d, Standard File %d' % (cid, i+1), fontsize=tick_fs*1.5, loc='right') 
            ax.plot((p.mass,p.mass),(0, rel_intensity),'k-', linewidth=4)
            offset = 0.0
            if po.transformation.name in ('M+ACN+H', '2M+H', 'M+NH4'):
                offset = 0.2                
            if po.transformation.name in ('M+NH4'):
                offset = 0.6               
            if po.transformation.name in ('M+H'):
                offset = 0.1               
            label = "%s (%.2f)" % (po.transformation.name, po.prob)                
            ax.annotate(label, (p.mass, rel_intensity),
                        (p.mass, offset+0.2+rel_intensity),
                        arrowprops=dict(arrowstyle='->', lw=4, color='gray'),
                        textcoords='data', size=tick_fs, weight='bold', rotation=0)
            ax.set_ylabel('Rel. intensity', fontsize=tick_fs)
            for tick in ax.xaxis.get_major_ticks():
                tick.label.set_fontsize(tick_fs*1.5) 
            for tick in ax.yaxis.get_major_ticks():
                tick.label.set_fontsize(tick_fs*1.5) 
                
    axs[i].set_xlabel('m/z', fontsize=tick_fs*2)
    plt.subplots_adjust(hspace=0.5, top=0.85)
    plt.suptitle(title, fontsize=tick_fs*2)
#     plt.tight_layout()
    plt.savefig(outfile)

# %% [markdown]
# <h2>3. Find some interesting aligned peaksets</h2>

# %%
import csv
id_rows = []
with open('/Users/joewandy/git/metabolomics_tools/alignment/input/std1_csv_full_old/ground_truth/identification.csv', 'rb') as f:
    reader = csv.reader(f)
    for row in reader:
        mz = float(row[0])
        rt = float(row[1])
        intense = float(row[2])
        iden = row[3]
        item = (mz, rt, intense, iden)
        id_rows.append(item)
print len(id_rows)
# Out:
# 2605

# %%
input_dir = '/Users/joewandy/git/metabolomics_tools/alignment/input/std1_csv_full_old'
gt_file = '/Users/joewandy/git/metabolomics_tools/alignment/input/std1_csv_full_old/ground_truth/ground_truth.txt'

from discretisation.preprocessing import FileLoader
loader = FileLoader()        
data_list = loader.load_model_input(input_dir, synthetic=True, verbose=False)    
file_list = []
for data in data_list:
    file_list.append(data.filename)

gt = GroundTruth(gt_file, file_list, data_list, verbose=False)
# Out:
# 4999 features read from std1-file1.txt
# 4986 features read from std1-file2.txt
# 6836 features read from std1-file3.txt
# 9752 features read from std1-file4.txt
# 7076 features read from std1-file5.txt
# 4146 features read from std1-file6.txt
# 6319 features read from std1-file7.txt
# 4101 features read from std1-file8.txt
# 5485 features read from std1-file9.txt
# 5034 features read from std1-file10.txt
# 5317 features read from std1-file11.txt

# %%
ground_truth = []
for item in gt.gt_features:
    feature_keys = frozenset([f._get_key() for f in item])
    ground_truth.append(feature_keys)    
print len(ground_truth)
# Out:
# 304

# %%
key_to_id = find_diff(aligner.alignment_results, aligner_no_adduct.alignment_results, 0.4, id_rows)
# Out:
# frozenset([(244, 5), (144, 1), (145, 4), (327, 9)]) 0.82 0.218
# id=(244,5) mass=377.1451 rt=464.63 int=601159.94 identification=StdMix1_9;M+H;monoisotopic
# id=(144,1) mass=377.1451 rt=468.55 int=960573.94 identification=StdMix1_9;M+H;monoisotopic
# id=(145,4) mass=377.1451 rt=463.77 int=1483404.50 identification=StdMix1_9;M+H;monoisotopic
# id=(327,9) mass=377.1452 rt=457.23 int=267687.69 identification=StdMix1_9;M+H;monoisotopic
# GT frozenset([(205, 8), (343, 10), (238, 7), (144, 1), (162, 0), (132, 3), (244, 5), (133, 2), (145, 4), (327, 9)])
#
# frozenset([(397, 1), (845, 4), (709, 5), (577, 9)]) 0.772 0.25
# id=(397,1) mass=246.0662 rt=561.11 int=288341.00 identification=None
# id=(845,4) mass=246.0661 rt=575.63 int=138819.84 identification=None
# id=(709,5) mass=246.0660 rt=559.60 int=112463.20 identification=None
# id=(577,9) mass=246.0662 rt=490.62 int=123871.18 identification=None
#
# frozenset([(81, 5), (43, 1), (10, 4), (81, 9)]) 0.87 0.452
# id=(81,5) mass=255.1100 rt=342.45 int=2309139.25 identification=StdMix1_5;M+Na;monoisotopic
# id=(43,1) mass=255.1100 rt=338.16 int=2955535.50 identification=StdMix1_5;M+Na;monoisotopic
# id=(10,4) mass=255.1100 rt=337.54 int=10090335.00 identification=StdMix1_5;M+Na;monoisotopic
# id=(81,9) mass=255.1101 rt=330.71 int=1865922.50 identification=StdMix1_5;M+Na;monoisotopic
# GT frozenset([(81, 5), (10, 4), (84, 3), (53, 2), (38, 0), (47, 10), (43, 1), (129, 7), (50, 8), (81, 9)])
#
# frozenset([(168, 1), (80, 9), (111, 5), (106, 4)]) 0.82 0.398
# id=(168,1) mass=133.0605 rt=1110.75 int=755441.94 identification=StdMix1_32;M+H;monoisotopic
# id=(80,9) mass=133.0607 rt=1114.07 int=1898695.75 identification=StdMix1_32;M+H;monoisotopic
# id=(111,5) mass=133.0606 rt=1112.39 int=1542786.12 identification=StdMix1_32;M+H;monoisotopic
# id=(106,4) mass=133.0605 rt=1119.59 int=1907341.88 identification=StdMix1_32;M+H;monoisotopic
# GT frozenset([(198, 7), (106, 4), (221, 8), (80, 9), (168, 1), (110, 3), (111, 5), (145, 10), (135, 2), (196, 0)])
#
# frozenset([(33, 5), (25, 1), (9, 4), (13, 9)]) 0.974 0.55
# id=(33,5) mass=265.1115 rt=1766.40 int=4344222.00 identification=StdMix1_47;M+H;monoisotopic
# id=(25,1) mass=265.1114 rt=1767.17 int=4251126.50 identification=StdMix1_47;M+H;monoisotopic
# id=(9,4) mass=265.1115 rt=1770.61 int=10424769.00 identification=StdMix1_47;M+H;monoisotopic
# id=(13,9) mass=265.1116 rt=1796.13 int=7655857.50 identification=StdMix1_47;M+H;monoisotopic
# GT frozenset([(33, 8), (28, 3), (33, 5), (27, 10), (25, 1), (9, 4), (25, 2), (13, 9), (24, 0), (23, 7)])
#
# frozenset([(336, 1), (695, 5), (163, 4), (650, 9)]) 0.87 0.452
# id=(336,1) mass=487.2310 rt=339.68 int=358802.75 identification=StdMix1_5;2M+Na;monoisotopic
# id=(695,5) mass=487.2312 rt=340.97 int=118736.85 identification=StdMix1_5;2M+Na;monoisotopic
# id=(163,4) mass=487.2313 rt=339.00 int=1281227.75 identification=StdMix1_5;2M+Na;monoisotopic
# id=(650,9) mass=487.2315 rt=330.71 int=103823.59 identification=StdMix1_5;2M+Na;monoisotopic
# GT frozenset([(617, 10), (331, 0), (695, 5), (728, 7), (658, 2), (720, 3), (336, 1), (493, 8), (163, 4), (650, 9)])
#
# frozenset([(47, 4), (44, 5), (38, 9), (51, 1)]) 0.97 0.002
# id=(47,4) mass=170.0115 rt=1009.00 int=3997116.75 identification=StdMix1_77;M+H;monoisotopic
# id=(44,5) mass=170.0116 rt=1000.23 int=3380173.00 identification=StdMix1_77;M+H;monoisotopic
# id=(38,9) mass=170.0118 rt=988.46 int=3154041.25 identification=StdMix1_77;M+H;monoisotopic
# id=(51,1) mass=170.0115 rt=1007.21 int=2674336.75 identification=StdMix1_77;M+H;monoisotopic
# GT frozenset([(44, 5), (38, 9), (41, 10), (57, 2), (239, 6), (55, 0), (104, 7), (61, 3), (47, 4), (51, 1), (69, 8)])
#
# frozenset([(1357, 9), (2134, 5), (914, 1), (2733, 5)]) 0.928 0.464
# id=(1357,9) mass=155.0425 rt=1117.03 int=32120.82 identification=StdMix1_32;M+Na;monoisotopic
# id=(2134,5) mass=155.0423 rt=1115.30 int=14682.69 identification=StdMix1_32;M+Na;monoisotopic
# id=(914,1) mass=155.0423 rt=1112.39 int=76084.41 identification=StdMix1_32;M+Na;monoisotopic
# id=(2733,5) mass=155.0423 rt=1106.59 int=9224.82 identification=None
# GT frozenset([(994, 8), (484, 4), (2396, 3), (2075, 10), (2134, 5), (2530, 2), (1357, 9), (993, 0), (914, 1)])
#
# frozenset([(43, 4), (38, 1), (40, 5), (49, 9)]) 0.974 0.55
# id=(43,4) mass=133.0594 rt=1770.61 int=4034175.50 identification=StdMix1_47;M+2H;monoisotopic
# id=(38,1) mass=133.0593 rt=1767.17 int=3318968.75 identification=StdMix1_47;M+2H;monoisotopic
# id=(40,5) mass=133.0594 rt=1773.43 int=3508882.75 identification=StdMix1_47;M+2H;monoisotopic
# id=(49,9) mass=133.0595 rt=1798.96 int=2872144.00 identification=StdMix1_47;M+2H;monoisotopic
# GT frozenset([(43, 4), (49, 9), (41, 2), (38, 1), (35, 0), (24, 3), (53, 10), (134, 7), (40, 5), (46, 8)])
#
# frozenset([(744, 1), (425, 9), (897, 4), (363, 5)]) 0.506 0.062
# id=(744,1) mass=102.5323 rt=2207.83 int=119629.82 identification=None
# id=(425,9) mass=102.5323 rt=2149.70 int=197490.20 identification=None
# id=(897,4) mass=102.5323 rt=2160.34 int=124720.89 identification=None
# id=(363,5) mass=102.5323 rt=2132.02 int=330808.16 identification=None
#
# frozenset([(191, 4), (347, 9), (236, 1), (167, 5)]) 0.574 0.116
# id=(191,4) mass=243.0971 rt=424.49 int=1056232.50 identification=StdMix1_56;M+H;monoisotopic
# id=(347,9) mass=243.0973 rt=375.54 int=248278.70 identification=None
# id=(236,1) mass=243.0971 rt=423.23 int=525669.88 identification=StdMix1_56;M+H;monoisotopic
# id=(167,5) mass=243.0972 rt=421.42 int=956533.50 identification=StdMix1_56;M+H;monoisotopic
# GT frozenset([(162, 7), (236, 1), (114, 2), (191, 4), (276, 0), (167, 5), (131, 6), (346, 10), (328, 8), (187, 3), (263, 9)])
#
# frozenset([(306, 5), (206, 1), (766, 9), (266, 4)]) 0.87 0.452
# id=(306,5) mass=465.2492 rt=349.84 int=420141.03 identification=StdMix1_5;2M+H;monoisotopic
# id=(206,1) mass=465.2493 rt=351.85 int=603422.12 identification=StdMix1_5;2M+H;monoisotopic
# id=(766,9) mass=465.2495 rt=330.71 int=84776.48 identification=None
# id=(266,4) mass=465.2495 rt=337.54 int=721128.06 identification=StdMix1_5;2M+H;monoisotopic
# GT frozenset([(546, 7), (256, 8), (266, 4), (306, 5), (870, 10), (221, 0), (206, 1), (223, 3), (270, 2)])
#
# frozenset([(344, 1), (207, 4), (327, 5), (177, 9)]) 0.97 0.002
# id=(344,1) mass=339.0157 rt=1007.21 int=352209.62 identification=StdMix1_77;2M+H;monoisotopic
# id=(207,4) mass=339.0159 rt=1010.44 int=991850.38 identification=StdMix1_77;2M+H;monoisotopic
# id=(327,5) mass=339.0160 rt=1005.93 int=379580.34 identification=StdMix1_77;2M+H;monoisotopic
# id=(177,9) mass=339.0162 rt=988.46 int=600556.19 identification=StdMix1_77;2M+H;monoisotopic
# GT frozenset([(177, 9), (349, 10), (344, 1), (327, 5), (211, 3), (360, 7), (207, 4), (480, 8), (325, 2), (1500, 6), (397, 0)])
#
# frozenset([(2164, 5), (1300, 4), (1577, 1), (2969, 9)]) 0.872 0.26
# id=(2164,5) mass=191.1175 rt=346.89 int=14378.27 identification=None
# id=(1300,4) mass=191.1176 rt=339.00 int=63398.36 identification=None
# id=(1577,1) mass=191.1176 rt=341.21 int=27369.49 identification=None
# id=(2969,9) mass=191.1177 rt=330.71 int=8852.62 identification=None
#
# frozenset([(532, 5), (332, 9), (668, 4), (788, 1)]) 0.974 0.55
# id=(532,5) mass=153.5725 rt=1773.43 int=177453.33 identification=StdMix1_47;M+ACN+2H;monoisotopic
# id=(332,9) mass=153.5727 rt=1797.54 int=265786.06 identification=StdMix1_47;M+ACN+2H;monoisotopic
# id=(668,4) mass=153.5726 rt=1770.61 int=198893.16 identification=StdMix1_47;M+ACN+2H;monoisotopic
# id=(788,1) mass=153.5725 rt=1761.08 int=105966.62 identification=StdMix1_47;M+ACN+2H;monoisotopic
# GT frozenset([(905, 0), (668, 4), (873, 8), (329, 3), (788, 1), (532, 5), (477, 2), (801, 10), (739, 7), (332, 9)])
#
# frozenset([(112, 1), (237, 4), (224, 5), (431, 9)]) 0.842 0.334
# id=(112,1) mass=81.5206 rt=56.54 int=1398574.50 identification=None
# id=(237,4) mass=81.5206 rt=39.11 int=835223.50 identification=None
# id=(224,5) mass=81.5206 rt=33.02 int=663468.44 identification=None
# id=(431,9) mass=81.5206 rt=60.99 int=193490.70 identification=None
#
# frozenset([(504, 9), (362, 5), (174, 1), (137, 4)]) 0.872 0.26
# id=(504,9) mass=174.0912 rt=332.21 int=154008.11 identification=None
# id=(362,5) mass=174.0911 rt=340.97 int=331784.22 identification=None
# id=(174,1) mass=174.0912 rt=341.21 int=738076.50 identification=None
# id=(137,4) mass=174.0912 rt=339.00 int=1535825.50 identification=None
#
# frozenset([(990, 1), (340, 4), (453, 5), (226, 9)]) 0.57 0.118
# id=(990,1) mass=153.0327 rt=2109.77 int=65293.49 identification=None
# id=(340,4) mass=153.0326 rt=2017.85 int=509290.47 identification=None
# id=(453,5) mass=153.0325 rt=2070.74 int=228799.59 identification=None
# id=(226,9) mass=153.0326 rt=2055.94 int=436143.38 identification=None
#
# frozenset([(308, 5), (216, 9), (549, 4), (873, 1)]) 0.97 0.002
# id=(308,5) mass=211.0380 rt=998.81 int=413584.84 identification=StdMix1_77;M+ACN+H;monoisotopic
# id=(216,9) mass=211.0382 rt=985.63 int=475014.94 identification=StdMix1_77;M+ACN+H;monoisotopic
# id=(549,4) mass=211.0379 rt=1009.00 int=259747.52 identification=StdMix1_77;M+ACN+H;monoisotopic
# id=(873,1) mass=211.0379 rt=1007.21 int=83581.69 identification=StdMix1_77;M+ACN+H;monoisotopic
# GT frozenset([(216, 9), (549, 4), (873, 1), (541, 10), (1082, 8), (2497, 6), (308, 5), (388, 2), (1025, 0), (361, 7), (451, 3)])
#
# frozenset([(3, 4), (16, 5), (25, 9), (10, 1)]) 0.87 0.452
# id=(3,4) mass=233.1282 rt=337.54 int=17466296.00 identification=StdMix1_5;M+H;monoisotopic
# id=(16,5) mass=233.1282 rt=340.97 int=7520684.50 identification=StdMix1_5;M+H;monoisotopic
# id=(25,9) mass=233.1283 rt=330.71 int=5221381.50 identification=StdMix1_5;M+H;monoisotopic
# id=(10,1) mass=233.1282 rt=339.68 int=7609486.50 identification=StdMix1_5;M+H;monoisotopic
# GT frozenset([(25, 10), (16, 5), (17, 7), (9, 8), (6, 0), (23, 3), (10, 1), (14, 2), (3, 4), (25, 9)])

# %% [markdown]
# Interesting clusters are:
# - StdMix1_5 Melatonin C13H16N2O2
# - StdMix1_9 riboflavin C17H20N4O6
# - StdMix1_32 Asparagine C4H8N2O3
# - StdMix1_47 Thiamin C12H16N4OS
# - StdMix1_56 Thymidine C10H14N2O5
# - StdMix1_69 MOPS C7H15NO4S
# - StdMix1_77 L-Cysteate C3H7NO5S

# %%
file_idx = {
    1: 3, 
    4: 0,
    5: 2,
    9: 1
}
idx_file = {
    3: 1, 
    0: 4,
    2: 5,
    1: 9
}

# %%
to_find_list = [(3, 4), (16, 5), (25, 9), (10, 1)]
cluster_list = []
for to_find in to_find_list:
    cluster = find_cluster_of_peak(to_find, aligner.clustering_results, file_idx[to_find[1]])
    cluster_list.append(cluster)

title = 'StdMix1_5 (Melatonin, $C_{13}H_{16}N_{2}O_{2}$)'    
cluster_plot(title, cluster_list, key_to_id, 'figures/melatonin.pdf')
# Out:
# CLUSTER 2
# Peak (3, 4) : 233.128216429,337.536987305,17466296.0 -> M+H,232.120939977 (p=1.0), StdMix1_5;M+H;monoisotopic
# Peak (10, 4) : 255.110031265,337.536987305,10090335.0 -> M+Na,232.120810185 (p=0.9945), StdMix1_5;M+Na;monoisotopic
# Peak (163, 4) : 487.231328278,338.99899292,1281227.75 -> 2M+Na,232.121053599 (p=1.0), StdMix1_5;2M+Na;monoisotopic
# Peak (266, 4) : 465.249512894,337.536987305,721128.0625 -> 2M+H,232.121118221 (p=1.0), StdMix1_5;2M+H;monoisotopic
# Peak (2206, 4) : 296.136549495,337.536987305,25124.1621094 -> M+ACN+Na,232.120779313 (p=0.9918), StdMix1_5;M+ACN+Na;monoisotopic
# Peak (2493, 4) : 274.15428669,337.536987305,20278.9375 -> M+ACN+H,232.120461136 (p=0.9968), StdMix1_5;M+ACN+H;monoisotopic
# CLUSTER 15
# Peak (16, 5) : 233.128172547,340.973999023,7520684.5 -> M+H,232.120896095 (p=1.0), StdMix1_5;M+H;monoisotopic
# Peak (81, 5) : 255.109966047,342.454986572,2309139.25 -> M+Na,232.120744967 (p=0.5361), StdMix1_5;M+Na;monoisotopic
# Peak (306, 5) : 465.249239251,349.839996338,420141.03125 -> 2M+H,232.1209814 (p=0.5736), StdMix1_5;2M+H;monoisotopic
# Peak (695, 5) : 487.231214916,340.973999023,118736.851562 -> 2M+Na,232.120996918 (p=0.5344), StdMix1_5;2M+Na;monoisotopic
# CLUSTER 24
# Peak (25, 9) : 233.128277864,330.708007812,5221381.5 -> M+H,232.121001412 (p=1.0), StdMix1_5;M+H;monoisotopic
# Peak (81, 9) : 255.110102453,330.708007812,1865922.5 -> M+Na,232.120881373 (p=1.0), StdMix1_5;M+Na;monoisotopic
# Peak (650, 9) : 487.231480373,330.708007812,103823.59375 -> 2M+Na,232.121129647 (p=1.0), StdMix1_5;2M+Na;monoisotopic
# Peak (766, 9) : 465.249481295,330.708007812,84776.4765625 -> 2M+H,232.121102421 (p=1.0), None
# Peak (4825, 9) : 274.154496317,327.717010498,2230.5390625 -> M+ACN+H,232.120670763 (p=1.0), StdMix1_5;M+ACN+H;monoisotopic
# CLUSTER 9
# Peak (10, 1) : 233.128175153,339.683013916,7609486.5 -> M+H,232.120898701 (p=1.0), StdMix1_5;M+H;monoisotopic
# Peak (43, 1) : 255.110024821,338.157989502,2955535.5 -> M+Na,232.120803741 (p=1.0), StdMix1_5;M+Na;monoisotopic
# Peak (206, 1) : 465.249276458,351.852996826,603422.125 -> 2M+H,232.121000003 (p=1.0), StdMix1_5;2M+H;monoisotopic
# Peak (336, 1) : 487.231038397,339.683013916,358802.75 -> 2M+Na,232.120908658 (p=0.9999), StdMix1_5;2M+Na;monoisotopic

# %%
print sorted([ndl.id for ndl in cluster_list])
print len(aligner.matching_results)
print '----------------------------------------------------------'

counter = dict()
needle = cluster_list[0]
for haystack in aligner.matching_results:
    if needle in haystack:
        peakset = frozenset([h.id for h in haystack])
        if peakset not in counter:
            counter[peakset] = 1
        else:
            counter[peakset] += 1
for key in counter:
    peakset = sorted(list(key))
    c = counter[key]
    print '%-40s%d' % (peakset, c)
# Out:
# [2, 9, 15, 24]
# 6430047
# ----------------------------------------------------------
# [2, 15, 24]                             14
# [2, 9, 15, 47]                          13
# [2, 47]                                 6
# [2, 9, 15, 24]                          435
# [2, 15, 47]                             2
# [2, 9, 24]                              10
# [2, 24]                                 20

# %%
cluster_list_no_adduct = []
for to_find in to_find_list:
    cluster = find_cluster_of_peak(to_find, aligner_no_adduct.clustering_results, file_idx[to_find[1]])
    cluster_list_no_adduct.append(cluster)

# %%
print sorted([ndl.id for ndl in cluster_list_no_adduct])
print len(aligner_no_adduct.matching_results)
print '----------------------------------------------------------'

counter = dict()
needle = cluster_list_no_adduct[0]
for haystack in aligner_no_adduct.matching_results:
    if needle in haystack:
        peakset = frozenset([h.id for h in haystack])
        if peakset not in counter:
            counter[peakset] = 1
        else:
            counter[peakset] += 1
for key in counter:
    peakset = sorted(list(key))
    c = counter[key]
    print '%-40s%d' % (peakset, c)
# Out:
# [2, 9, 15, 24]
# 6581865
# ----------------------------------------------------------
# [2, 9]                                  5
# [2, 15, 24]                             26
# [2]                                     4
# [2, 15]                                 3
# [2, 9, 47]                              20
# [2, 9, 15, 47]                          100
# [2, 9, 15]                              1
# [2, 47]                                 34
# [2, 9, 15, 24]                          226
# [2, 15, 47]                             17
# [2, 9, 24]                              34
# [2, 24]                                 30

# %% [markdown]
# <hr/>

# %%
to_find_list = [(47, 4), (44, 5), (38, 9), (51, 1)]
cluster_list = []
for to_find in to_find_list:
    cluster = find_cluster_of_peak(to_find, aligner.clustering_results, file_idx[to_find[1]])
    cluster_list.append(cluster)

title = 'StdMix1_77 (L-Cysteate, $C_{3}H_{7}NO_{5}S)$'
cluster_plot(title, cluster_list, key_to_id, 'figures/l_cysteate.pdf')
# Out:
# CLUSTER 46
# Peak (47, 4) : 170.011513711,1009.0,3997116.75 -> M+H,169.004237259 (p=1.0), StdMix1_77;M+H;monoisotopic
# Peak (207, 4) : 339.01586509,1010.44000244,991850.375 -> 2M+H,169.004294319 (p=1.0), StdMix1_77;2M+H;monoisotopic
# Peak (549, 4) : 211.037947417,1009.0,259747.515625 -> M+ACN+H,169.004121863 (p=0.9999), StdMix1_77;M+ACN+H;monoisotopic
# Peak (1757, 4) : 187.037954375,1009.0,37857.5390625 -> M+NH4,169.004128821 (p=1.0), StdMix1_77;M+NH4;monoisotopic
# Peak (2376, 4) : 191.993320307,1011.88000488,21984.1542969 -> M+Na,169.004099227 (p=0.9048), StdMix1_77;M+Na;monoisotopic
# CLUSTER 43
# Peak (44, 5) : 170.011581569,1000.22998047,3380173.0 -> M+H,169.004305117 (p=1.0), StdMix1_77;M+H;monoisotopic
# Peak (308, 5) : 211.038045084,998.807983398,413584.84375 -> M+ACN+H,169.004219531 (p=0.9999), StdMix1_77;M+ACN+H;monoisotopic
# Peak (327, 5) : 339.016007273,1005.92999268,379580.34375 -> 2M+H,169.004365411 (p=1.0), StdMix1_77;2M+H;monoisotopic
# Peak (3172, 5) : 191.993357729,1015.90997314,6489.59375 -> M+Na,169.004136649 (p=0.9999), StdMix1_77;M+Na;monoisotopic
# CLUSTER 37
# Peak (38, 9) : 170.0117633,988.458007812,3154041.25 -> M+H,169.004486848 (p=1.0), StdMix1_77;M+H;monoisotopic
# Peak (177, 9) : 339.016157741,988.458007812,600556.1875 -> 2M+H,169.004440644 (p=0.7765), StdMix1_77;2M+H;monoisotopic
# Peak (216, 9) : 211.03815298,985.632019043,475014.9375 -> M+ACN+H,169.004327426 (p=0.7813), StdMix1_77;M+ACN+H;monoisotopic
# Peak (1292, 9) : 187.038105669,984.221984863,35003.6132812 -> M+NH4,169.004280115 (p=0.9999), StdMix1_77;M+NH4;monoisotopic
# CLUSTER 50
# Peak (51, 1) : 170.011481519,1007.21002197,2674336.75 -> M+H,169.004205067 (p=1.0), StdMix1_77;M+H;monoisotopic
# Peak (344, 1) : 339.015731407,1007.21002197,352209.625 -> 2M+H,169.004227478 (p=0.8936), StdMix1_77;2M+H;monoisotopic
# Peak (873, 1) : 211.037882486,1007.21002197,83581.6875 -> M+ACN+H,169.004056933 (p=0.9016), StdMix1_77;M+ACN+H;monoisotopic
# Peak (1624, 1) : 191.993290333,1008.70001221,26240.125 -> M+Na,169.004069253 (p=1.0), StdMix1_77;M+Na;monoisotopic
# Peak (3940, 1) : 360.997913347,1023.58001709,4546.44775391 -> 2M+Na,169.004346133 (p=0.8729), StdMix1_77;2M+Na;monoisotopic
