# %% [markdown]
# <h1>Experiment with std1pos</h1>

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import os
import sys
basedir = '/home/joewandy/git/metabolomics_tools'
sys.path.append(basedir)

# %%
import numpy as np
import pylab as plt
import pandas as pd
import seaborn as sns
sns.set(color_codes=True)
from IPython.display import display, HTML

import cPickle
import random
import copy
import glob
import gzip

# %%
from alignment.models import HyperPars as AlignmentHyperPars
from discretisation.adduct_cluster import AdductCluster, Peak, Possible
from discretisation import utils
from discretisation.preprocessing import FileLoader
from alignment.shared_bin_matching import SharedBinMatching as Aligner
from alignment.ground_truth import GroundTruth

# %% [markdown]
# <h2>Experiment Parameters</h2>

# %% [markdown]
# Set up all the experiment parameters

# %%
input_dir = '/home/joewandy/git/metabolomics_tools/alignment/input/std1_csv_full_old'
transformation_file = '/home/joewandy/git/metabolomics_tools/alignment/pos_transformations_full.yml'
gt_file = '/home/joewandy/git/metabolomics_tools/alignment/input/std1_csv_full_old/ground_truth/ground_truth.txt'

# %%
hp = AlignmentHyperPars()    
hp.within_file_mass_tol = 5
hp.within_file_rt_tol = 30
hp.across_file_mass_tol = 10
hp.across_file_rt_tol = 120
hp.alpha_mass = 1.0
hp.dp_alpha = 1000.0
hp.t = 0.0
hp.mass_clustering_n_iterations = 200
hp.rt_clustering_nsamps = 400
hp.rt_clustering_burnin = 200

print hp
# Out:
# Hyperparameters across_file_mass_tol=10, across_file_rt_tol=120, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30

# %%
evaluation_method = 2
n_iter = 30

# %%
param_list = []
for mass_tol in range(2, 11, 2):
    for rt_tol in range(5, 101, 5):
        param_list.append((mass_tol, rt_tol))

# %% [markdown]
# <h2>Create the first-stage clustering for all input files -- Gibbs, mh_biggest=True</h2>

# %%
def load_or_create_clustering(filename, input_dir, transformation_file, hp):
    try:
        with gzip.GzipFile(filename, 'rb') as f:
            combined_list = cPickle.load(f)
            print "Loaded from %s" % filename
            return combined_list
    except (IOError, EOFError):
        loader = FileLoader()        
        data_list = loader.load_model_input(input_dir, synthetic=True)
        aligner = Aligner(data_list, None, transformation_file, 
                               hp, verbose=False, seed=1234567890, parallel=True, mh_biggest=True, use_vb=False)
        clustering_results = aligner._first_stage_clustering()
        combined_list = zip(data_list, clustering_results)
        with gzip.GzipFile(filename, 'wb') as f:
            cPickle.dump(combined_list, f, protocol=cPickle.HIGHEST_PROTOCOL)        
        print "Saved to %s" % filename
        return combined_list

# %%
combined_list = load_or_create_clustering('pickles/std1_pos_clustering.p', input_dir, transformation_file, hp)
# Out:
# Loaded from pickles/std1_pos_clustering.p

# %% [markdown]
# <h2>Define Experimental Methods</h2>

# %%
def train(selected_data, param_list, hp, match_mode, evaluation_method):
    
    performances = []
    for param in param_list:

        # print "Parameter mass_tol=%f rt_tol=%f" % (param)
        hp.across_file_mass_tol = param[0]
        hp.across_file_rt_tol = param[1]
        selected_files = [x[0] for x in selected_data]  
        selected_clusterings = [x[1] for x in selected_data]            
        aligner = Aligner(selected_files, None, transformation_file, 
                               hp, verbose=False, seed=1234567890)
        aligner.run(match_mode, first_stage_clustering_results=selected_clusterings)

        res = aligner.evaluate_performance(gt_file, verbose=False, print_TP=True, method=evaluation_method)
        output = param+res[0]
        performances.append(output)
    
    df = pd.DataFrame(performances, columns=['mass_tol', 'rt_tol', 'TP', 'FP', 'FN', 'Prec', 'Rec', 'F1', 'Threshold'])
    
    sorted_df = df.sort_values(['F1', 'mass_tol', 'rt_tol'], ascending=[False, True, True])
    best_row = sorted_df.iloc[0]
    return df, best_row

# %%
def test(selected_data, best_row, hp, match_mode, evaluation_method):

    param = (best_row['mass_tol'], best_row['rt_tol'])
    hp.across_file_mass_tol = param[0]
    hp.across_file_rt_tol = param[1]
    selected_files = [x[0] for x in selected_data]
    selected_clusterings = [x[1] for x in selected_data]    
    aligner = Aligner(selected_files, None, transformation_file, 
                           hp, verbose=False, seed=1234567890)
    aligner.run(match_mode, first_stage_clustering_results=selected_clusterings)

    res = aligner.evaluate_performance(gt_file, verbose=False, print_TP=True, method=evaluation_method)
    output = param+res[0]
    return output

# %%
def train_test(match_mode, training_list, testing_list):
    assert len(training_list) == len(testing_list)
    n_iter = len(training_list)
    exp_results = []
    for i in range(n_iter):

        training_data = training_list[i]
        print "Iteration %d" % i
        print "Training on %s" % [x[0].filename for x in training_data]
        training_df, best_training_row = train(training_data, param_list, hp, match_mode, evaluation_method)

        testing_data = testing_list[i]
        print "Testing on %s" % [x[0].filename for x in testing_data]
        match_res = test(testing_data, best_training_row, hp, match_mode, evaluation_method)
        output = (match_mode,) + match_res
        print "match_mode=%d, mass_tol=%d, rt_tol=%d, tp=%d, fp=%d, fn=%d, prec=%.3f, rec=%.3f, f1=%.3f, th_prob=%.3f" % output

        item = (training_data, training_df, best_training_row, match_res)
        exp_results.append(item)
        print
    return exp_results

# %%
def run_experiment(match_mode, training_list, testing_list, filename):
    try:
        with gzip.GzipFile(filename, 'rb') as f:        
            exp_results = cPickle.load(f)
            print "Loaded from %s" % filename
            return exp_results
    except (IOError, EOFError):
        exp_results = train_test(match_mode, training_list, testing_list)
        with gzip.GzipFile(filename, 'wb') as f:
            cPickle.dump(exp_results, f, protocol=cPickle.HIGHEST_PROTOCOL)                        
        print "Saved to %s" % filename
    return exp_results

# %%
def load_or_create_filelist(filename, combined_list, n_iter, n_files):
    try:
        with gzip.GzipFile(filename, 'rb') as f:        
            item_list = cPickle.load(f)
            print "Loaded from %s" % filename
            for item in item_list:
                print "%s" % [x[0].filename for x in item]
            return item_list
    except (IOError, EOFError):
        item_list = []
        for i in range(n_iter):
            item = random.sample(combined_list, n_files)
            print "%s" % [x[0].filename for x in item]
            item_list.append(item)
        with gzip.GzipFile(filename, 'wb') as f:
            cPickle.dump(item_list, f, protocol=cPickle.HIGHEST_PROTOCOL)                    
        print "Saved to %s" % filename
        return item_list

# %% [markdown]
# <h2>Run experiment with 2 random files</h2>

# %%
n_files = 2

# %%
training_list = load_or_create_filelist('pickles/training_list_2.p', combined_list, n_iter, n_files)
# Out:
# Loaded from pickles/training_list_2.p
# ['std1-file5.txt', 'std1-file7.txt']
# ['std1-file5.txt', 'std1-file11.txt']
# ['std1-file10.txt', 'std1-file5.txt']
# ['std1-file9.txt', 'std1-file2.txt']
# ['std1-file8.txt', 'std1-file5.txt']
# ['std1-file7.txt', 'std1-file6.txt']
# ['std1-file10.txt', 'std1-file3.txt']
# ['std1-file8.txt', 'std1-file2.txt']
# ['std1-file11.txt', 'std1-file7.txt']
# ['std1-file1.txt', 'std1-file2.txt']
# ['std1-file8.txt', 'std1-file1.txt']
# ['std1-file6.txt', 'std1-file9.txt']
# ['std1-file11.txt', 'std1-file7.txt']
# ['std1-file7.txt', 'std1-file8.txt']
# ['std1-file2.txt', 'std1-file7.txt']
# ['std1-file2.txt', 'std1-file8.txt']
# ['std1-file10.txt', 'std1-file7.txt']
# ['std1-file9.txt', 'std1-file4.txt']
# ['std1-file9.txt', 'std1-file4.txt']
# ['std1-file7.txt', 'std1-file2.txt']
# ['std1-file1.txt', 'std1-file10.txt']
# ['std1-file2.txt', 'std1-file9.txt']
# ['std1-file11.txt', 'std1-file1.txt']
# ['std1-file1.txt', 'std1-file10.txt']
# ['std1-file9.txt', 'std1-file8.txt']
# ['std1-file3.txt', 'std1-file1.txt']
# ['std1-file3.txt', 'std1-file9.txt']
# ['std1-file8.txt', 'std1-file7.txt']
# ['std1-file8.txt', 'std1-file11.txt']
# ['std1-file7.txt', 'std1-file3.txt']

# %%
testing_list = load_or_create_filelist('pickles/testing_list_2.p', combined_list, n_iter, n_files)

# %%
exp_results_1a = run_experiment(0, training_list, testing_list, 'pickles/res_match_feature_2.p')
# Out:
# Iteration 0
# Training on ['std1-file5.txt', 'std1-file7.txt']
# Testing on ['std1-file6.txt', 'std1-file8.txt']
# match_mode=0, mass_tol=2, rt_tol=100, tp=119, fp=8, fn=11, prec=0.937, rec=0.915, f1=0.926, th_prob=1.000
#
# Iteration 1
# Training on ['std1-file5.txt', 'std1-file11.txt']
# Testing on ['std1-file7.txt', 'std1-file11.txt']
# match_mode=0, mass_tol=4, rt_tol=55, tp=24, fp=3, fn=7, prec=0.889, rec=0.774, f1=0.828, th_prob=1.000
#
# Iteration 2
# Training on ['std1-file10.txt', 'std1-file5.txt']
# Testing on ['std1-file6.txt', 'std1-file2.txt']
# match_mode=0, mass_tol=2, rt_tol=75, tp=119, fp=11, fn=11, prec=0.915, rec=0.915, f1=0.915, th_prob=1.000
#
# Iteration 3
# Training on ['std1-file9.txt', 'std1-file2.txt']
# Testing on ['std1-file4.txt', 'std1-file8.txt']
# match_mode=0, mass_tol=2, rt_tol=25, tp=135, fp=4, fn=21, prec=0.971, rec=0.865, f1=0.915, th_prob=1.000
#
# Iteration 4
# Training on ['std1-file8.txt', 'std1-file5.txt']
# Testing on ['std1-file4.txt', 'std1-file7.txt']
# match_mode=0, mass_tol=6, rt_tol=60, tp=29, fp=3, fn=5, prec=0.906, rec=0.853, f1=0.879, th_prob=1.000
#
# Iteration 5
# Training on ['std1-file7.txt', 'std1-file6.txt']
# Testing on ['std1-file7.txt', 'std1-file11.txt']
# match_mode=0, mass_tol=2, rt_tol=70, tp=28, fp=3, fn=3, prec=0.903, rec=0.903, f1=0.903, th_prob=1.000
#
# Iteration 6
# Training on ['std1-file10.txt', 'std1-file3.txt']
# Testing on ['std1-file10.txt', 'std1-file1.txt']
# match_mode=0, mass_tol=2, rt_tol=35, tp=116, fp=10, fn=17, prec=0.921, rec=0.872, f1=0.896, th_prob=1.000
#
# Iteration 7
# Training on ['std1-file8.txt', 'std1-file2.txt']
# Testing on ['std1-file3.txt', 'std1-file10.txt']
# match_mode=0, mass_tol=6, rt_tol=70, tp=144, fp=4, fn=4, prec=0.973, rec=0.973, f1=0.973, th_prob=1.000
#
# Iteration 8
# Training on ['std1-file11.txt', 'std1-file7.txt']
# Testing on ['std1-file8.txt', 'std1-file11.txt']
# match_mode=0, mass_tol=2, rt_tol=65, tp=132, fp=4, fn=3, prec=0.971, rec=0.978, f1=0.974, th_prob=1.000
#
# Iteration 9
# Training on ['std1-file1.txt', 'std1-file2.txt']
# Testing on ['std1-file5.txt', 'std1-file3.txt']
# match_mode=0, mass_tol=2, rt_tol=35, tp=146, fp=8, fn=27, prec=0.948, rec=0.844, f1=0.893, th_prob=1.000
#
# Iteration 10
# Training on ['std1-file8.txt', 'std1-file1.txt']
# Testing on ['std1-file7.txt', 'std1-file5.txt']
# match_mode=0, mass_tol=4, rt_tol=85, tp=29, fp=4, fn=4, prec=0.879, rec=0.879, f1=0.879, th_prob=1.000
#
# Iteration 11
# Training on ['std1-file6.txt', 'std1-file9.txt']
# Testing on ['std1-file7.txt', 'std1-file10.txt']
# match_mode=0, mass_tol=2, rt_tol=35, tp=12, fp=4, fn=19, prec=0.750, rec=0.387, f1=0.511, th_prob=1.000
#
# Iteration 12
# Training on ['std1-file11.txt', 'std1-file7.txt']
# Testing on ['std1-file11.txt', 'std1-file9.txt']
# match_mode=0, mass_tol=2, rt_tol=65, tp=126, fp=11, fn=12, prec=0.920, rec=0.913, f1=0.916, th_prob=1.000
#
# Iteration 13
# Training on ['std1-file7.txt', 'std1-file8.txt']
# Testing on ['std1-file2.txt', 'std1-file10.txt']
# match_mode=0, mass_tol=4, rt_tol=60, tp=118, fp=10, fn=10, prec=0.922, rec=0.922, f1=0.922, th_prob=1.000
#
# Iteration 14
# Training on ['std1-file2.txt', 'std1-file7.txt']
# Testing on ['std1-file3.txt', 'std1-file7.txt']
# match_mode=0, mass_tol=2, rt_tol=70, tp=23, fp=2, fn=6, prec=0.920, rec=0.793, f1=0.852, th_prob=1.000
#
# Iteration 15
# Training on ['std1-file2.txt', 'std1-file8.txt']
# Testing on ['std1-file11.txt', 'std1-file10.txt']
# match_mode=0, mass_tol=6, rt_tol=70, tp=128, fp=8, fn=6, prec=0.941, rec=0.955, f1=0.948, th_prob=1.000
#
# Iteration 16
# Training on ['std1-file10.txt', 'std1-file7.txt']
# Testing on ['std1-file6.txt', 'std1-file9.txt']
# match_mode=0, mass_tol=2, rt_tol=80, tp=131, fp=5, fn=4, prec=0.963, rec=0.970, f1=0.967, th_prob=1.000
#
# Iteration 17
# Training on ['std1-file9.txt', 'std1-file4.txt']
# Testing on ['std1-file11.txt', 'std1-file2.txt']
# match_mode=0, mass_tol=4, rt_tol=100, tp=116, fp=16, fn=14, prec=0.879, rec=0.892, f1=0.885, th_prob=1.000
#
# Iteration 18
# Training on ['std1-file9.txt', 'std1-file4.txt']
# Testing on ['std1-file4.txt', 'std1-file10.txt']
# match_mode=0, mass_tol=4, rt_tol=100, tp=158, fp=3, fn=3, prec=0.981, rec=0.981, f1=0.981, th_prob=1.000
#
# Iteration 19
# Training on ['std1-file7.txt', 'std1-file2.txt']
# Testing on ['std1-file10.txt', 'std1-file4.txt']
# match_mode=0, mass_tol=2, rt_tol=70, tp=154, fp=4, fn=7, prec=0.975, rec=0.957, f1=0.966, th_prob=1.000
#
# Iteration 20
# Training on ['std1-file1.txt', 'std1-file10.txt']
# Testing on ['std1-file8.txt', 'std1-file3.txt']
# match_mode=0, mass_tol=4, rt_tol=85, tp=139, fp=6, fn=5, prec=0.959, rec=0.965, f1=0.962, th_prob=1.000
#
# Iteration 21
# Training on ['std1-file2.txt', 'std1-file9.txt']
# Testing on ['std1-file8.txt', 'std1-file4.txt']
# match_mode=0, mass_tol=2, rt_tol=25, tp=135, fp=4, fn=21, prec=0.971, rec=0.865, f1=0.915, th_prob=1.000
#
# Iteration 22
# Training on ['std1-file11.txt', 'std1-file1.txt']
# Testing on ['std1-file3.txt', 'std1-file11.txt']
# match_mode=0, mass_tol=4, rt_tol=95, tp=144, fp=5, fn=5, prec=0.966, rec=0.966, f1=0.966, th_prob=1.000
#
# Iteration 23
# Training on ['std1-file1.txt', 'std1-file10.txt']
# Testing on ['std1-file9.txt', 'std1-file5.txt']
# match_mode=0, mass_tol=4, rt_tol=85, tp=148, fp=10, fn=9, prec=0.937, rec=0.943, f1=0.940, th_prob=1.000
#
# Iteration 24
# Training on ['std1-file9.txt', 'std1-file8.txt']
# Testing on ['std1-file7.txt', 'std1-file4.txt']
# match_mode=0, mass_tol=4, rt_tol=70, tp=30, fp=3, fn=4, prec=0.909, rec=0.882, f1=0.896, th_prob=1.000
#
# Iteration 25
# Training on ['std1-file3.txt', 'std1-file1.txt']
# Testing on ['std1-file3.txt', 'std1-file2.txt']
# match_mode=0, mass_tol=4, rt_tol=80, tp=137, fp=12, fn=11, prec=0.919, rec=0.926, f1=0.923, th_prob=1.000
#
# Iteration 26
# Training on ['std1-file3.txt', 'std1-file9.txt']
# Testing on ['std1-file9.txt', 'std1-file1.txt']
# match_mode=0, mass_tol=4, rt_tol=80, tp=147, fp=4, fn=4, prec=0.974, rec=0.974, f1=0.974, th_prob=1.000
#
# Iteration 27
# Training on ['std1-file8.txt', 'std1-file7.txt']
# Testing on ['std1-file6.txt', 'std1-file7.txt']
# match_mode=0, mass_tol=4, rt_tol=60, tp=21, fp=4, fn=7, prec=0.840, rec=0.750, f1=0.792, th_prob=1.000
#
# Iteration 28
# Training on ['std1-file8.txt', 'std1-file11.txt']
# Testing on ['std1-file9.txt', 'std1-file11.txt']
# match_mode=0, mass_tol=2, rt_tol=55, tp=125, fp=11, fn=13, prec=0.919, rec=0.906, f1=0.912, th_prob=1.000
#
# Iteration 29
# Training on ['std1-file7.txt', 'std1-file3.txt']
# Testing on ['std1-file10.txt', 'std1-file9.txt']
# match_mode=0, mass_tol=4, rt_tol=60, tp=132, fp=7, fn=7, prec=0.950, rec=0.950, f1=0.950, th_prob=1.000
#
# Saved to pickles/res_match_feature_2.p

# %%
exp_results_1b = run_experiment(1, training_list, testing_list, 'pickles/res_match_cluster_2.p')
# Out:
# Iteration 0
# Training on ['std1-file5.txt', 'std1-file7.txt']
# Testing on ['std1-file6.txt', 'std1-file8.txt']
# match_mode=1, mass_tol=2, rt_tol=100, tp=120, fp=2, fn=10, prec=0.984, rec=0.923, f1=0.952, th_prob=1.000
#
# Iteration 1
# Training on ['std1-file5.txt', 'std1-file11.txt']
# Testing on ['std1-file7.txt', 'std1-file11.txt']
# match_mode=1, mass_tol=2, rt_tol=55, tp=27, fp=1, fn=4, prec=0.964, rec=0.871, f1=0.915, th_prob=1.000
#
# Iteration 2
# Training on ['std1-file10.txt', 'std1-file5.txt']
# Testing on ['std1-file6.txt', 'std1-file2.txt']
# match_mode=1, mass_tol=2, rt_tol=65, tp=125, fp=4, fn=5, prec=0.969, rec=0.962, f1=0.965, th_prob=1.000
#
# Iteration 3
# Training on ['std1-file9.txt', 'std1-file2.txt']
# Testing on ['std1-file4.txt', 'std1-file8.txt']
# match_mode=1, mass_tol=2, rt_tol=25, tp=126, fp=4, fn=30, prec=0.969, rec=0.808, f1=0.881, th_prob=1.000
#
# Iteration 4
# Training on ['std1-file8.txt', 'std1-file5.txt']
# Testing on ['std1-file4.txt', 'std1-file7.txt']
# match_mode=1, mass_tol=6, rt_tol=60, tp=30, fp=1, fn=4, prec=0.968, rec=0.882, f1=0.923, th_prob=1.000
#
# Iteration 5
# Training on ['std1-file7.txt', 'std1-file6.txt']
# Testing on ['std1-file7.txt', 'std1-file11.txt']
# match_mode=1, mass_tol=2, rt_tol=70, tp=30, fp=1, fn=1, prec=0.968, rec=0.968, f1=0.968, th_prob=1.000
#
# Iteration 6
# Training on ['std1-file10.txt', 'std1-file3.txt']
# Testing on ['std1-file10.txt', 'std1-file1.txt']
# match_mode=1, mass_tol=2, rt_tol=35, tp=119, fp=4, fn=14, prec=0.967, rec=0.895, f1=0.930, th_prob=1.000
#
# Iteration 7
# Training on ['std1-file8.txt', 'std1-file2.txt']
# Testing on ['std1-file3.txt', 'std1-file10.txt']
# match_mode=1, mass_tol=6, rt_tol=70, tp=138, fp=1, fn=10, prec=0.993, rec=0.932, f1=0.962, th_prob=1.000
#
# Iteration 8
# Training on ['std1-file11.txt', 'std1-file7.txt']
# Testing on ['std1-file8.txt', 'std1-file11.txt']
# match_mode=1, mass_tol=2, rt_tol=60, tp=127, fp=5, fn=8, prec=0.962, rec=0.941, f1=0.951, th_prob=1.000
#
# Iteration 9
# Training on ['std1-file1.txt', 'std1-file2.txt']
# Testing on ['std1-file5.txt', 'std1-file3.txt']
# match_mode=1, mass_tol=2, rt_tol=35, tp=139, fp=5, fn=34, prec=0.965, rec=0.803, f1=0.877, th_prob=1.000
#
# Iteration 10
# Training on ['std1-file8.txt', 'std1-file1.txt']
# Testing on ['std1-file7.txt', 'std1-file5.txt']
# match_mode=1, mass_tol=4, rt_tol=80, tp=31, fp=1, fn=2, prec=0.969, rec=0.939, f1=0.954, th_prob=1.000
#
# Iteration 11
# Training on ['std1-file6.txt', 'std1-file9.txt']
# Testing on ['std1-file7.txt', 'std1-file10.txt']
# match_mode=1, mass_tol=2, rt_tol=35, tp=10, fp=4, fn=21, prec=0.714, rec=0.323, f1=0.444, th_prob=1.000
#
# Iteration 12
# Training on ['std1-file11.txt', 'std1-file7.txt']
# Testing on ['std1-file11.txt', 'std1-file9.txt']
# match_mode=1, mass_tol=2, rt_tol=60, tp=129, fp=2, fn=9, prec=0.985, rec=0.935, f1=0.959, th_prob=1.000
#
# Iteration 13
# Training on ['std1-file7.txt', 'std1-file8.txt']
# Testing on ['std1-file2.txt', 'std1-file10.txt']
# match_mode=1, mass_tol=4, rt_tol=70, tp=120, fp=3, fn=8, prec=0.976, rec=0.938, f1=0.956, th_prob=1.000
#
# Iteration 14
# Training on ['std1-file2.txt', 'std1-file7.txt']
# Testing on ['std1-file3.txt', 'std1-file7.txt']
# match_mode=1, mass_tol=2, rt_tol=65, tp=21, fp=2, fn=8, prec=0.913, rec=0.724, f1=0.808, th_prob=1.000
#
# Iteration 15
# Training on ['std1-file2.txt', 'std1-file8.txt']
# Testing on ['std1-file11.txt', 'std1-file10.txt']
# match_mode=1, mass_tol=6, rt_tol=70, tp=126, fp=5, fn=8, prec=0.962, rec=0.940, f1=0.951, th_prob=1.000
#
# Iteration 16
# Training on ['std1-file10.txt', 'std1-file7.txt']
# Testing on ['std1-file6.txt', 'std1-file9.txt']
# match_mode=1, mass_tol=2, rt_tol=80, tp=131, fp=4, fn=4, prec=0.970, rec=0.970, f1=0.970, th_prob=1.000
#
# Iteration 17
# Training on ['std1-file9.txt', 'std1-file4.txt']
# Testing on ['std1-file11.txt', 'std1-file2.txt']
# match_mode=1, mass_tol=4, rt_tol=100, tp=124, fp=4, fn=6, prec=0.969, rec=0.954, f1=0.961, th_prob=1.000
#
# Iteration 18
# Training on ['std1-file9.txt', 'std1-file4.txt']
# Testing on ['std1-file4.txt', 'std1-file10.txt']
# match_mode=1, mass_tol=4, rt_tol=100, tp=147, fp=1, fn=14, prec=0.993, rec=0.913, f1=0.951, th_prob=1.000
#
# Iteration 19
# Training on ['std1-file7.txt', 'std1-file2.txt']
# Testing on ['std1-file10.txt', 'std1-file4.txt']
# match_mode=1, mass_tol=2, rt_tol=65, tp=146, fp=1, fn=15, prec=0.993, rec=0.907, f1=0.948, th_prob=1.000
#
# Iteration 20
# Training on ['std1-file1.txt', 'std1-file10.txt']
# Testing on ['std1-file8.txt', 'std1-file3.txt']
# match_mode=1, mass_tol=6, rt_tol=55, tp=136, fp=4, fn=8, prec=0.971, rec=0.944, f1=0.958, th_prob=1.000
#
# Iteration 21
# Training on ['std1-file2.txt', 'std1-file9.txt']
# Testing on ['std1-file8.txt', 'std1-file4.txt']
# match_mode=1, mass_tol=2, rt_tol=25, tp=126, fp=4, fn=30, prec=0.969, rec=0.808, f1=0.881, th_prob=1.000
#
# Iteration 22
# Training on ['std1-file11.txt', 'std1-file1.txt']
# Testing on ['std1-file3.txt', 'std1-file11.txt']
# match_mode=1, mass_tol=2, rt_tol=95, tp=141, fp=5, fn=8, prec=0.966, rec=0.946, f1=0.956, th_prob=1.000
#
# Iteration 23
# Training on ['std1-file1.txt', 'std1-file10.txt']
# Testing on ['std1-file9.txt', 'std1-file5.txt']
# match_mode=1, mass_tol=6, rt_tol=55, tp=147, fp=1, fn=10, prec=0.993, rec=0.936, f1=0.964, th_prob=1.000
#
# Iteration 24
# Training on ['std1-file9.txt', 'std1-file8.txt']
# Testing on ['std1-file7.txt', 'std1-file4.txt']
# match_mode=1, mass_tol=4, rt_tol=70, tp=30, fp=1, fn=4, prec=0.968, rec=0.882, f1=0.923, th_prob=1.000
#
# Iteration 25
# Training on ['std1-file3.txt', 'std1-file1.txt']
# Testing on ['std1-file3.txt', 'std1-file2.txt']
# match_mode=1, mass_tol=4, rt_tol=80, tp=138, fp=4, fn=10, prec=0.972, rec=0.932, f1=0.952, th_prob=1.000
#
# Iteration 26
# Training on ['std1-file3.txt', 'std1-file9.txt']
# Testing on ['std1-file9.txt', 'std1-file1.txt']
# match_mode=1, mass_tol=4, rt_tol=80, tp=144, fp=4, fn=7, prec=0.973, rec=0.954, f1=0.963, th_prob=1.000
#
# Iteration 27
# Training on ['std1-file8.txt', 'std1-file7.txt']
# Testing on ['std1-file6.txt', 'std1-file7.txt']
# match_mode=1, mass_tol=4, rt_tol=70, tp=27, fp=1, fn=1, prec=0.964, rec=0.964, f1=0.964, th_prob=1.000
#
# Iteration 28
# Training on ['std1-file8.txt', 'std1-file11.txt']
# Testing on ['std1-file9.txt', 'std1-file11.txt']
# match_mode=1, mass_tol=2, rt_tol=55, tp=129, fp=2, fn=9, prec=0.985, rec=0.935, f1=0.959, th_prob=1.000
#
# Iteration 29
# Training on ['std1-file7.txt', 'std1-file3.txt']
# Testing on ['std1-file10.txt', 'std1-file9.txt']
# match_mode=1, mass_tol=4, rt_tol=60, tp=129, fp=4, fn=10, prec=0.970, rec=0.928, f1=0.949, th_prob=1.000
#
# Saved to pickles/res_match_cluster_2.p

# %% [markdown]
# <h2>Run experiment with 3 random files</h2>

# %%
n_files = 3

# %%
training_list = load_or_create_filelist('pickles/training_list_3.p', combined_list, n_iter, n_files)
# Out:
# ['std1-file10.txt', 'std1-file8.txt', 'std1-file4.txt']
# ['std1-file7.txt', 'std1-file9.txt', 'std1-file8.txt']
# ['std1-file4.txt', 'std1-file3.txt', 'std1-file7.txt']
# ['std1-file2.txt', 'std1-file4.txt', 'std1-file10.txt']
# ['std1-file2.txt', 'std1-file11.txt', 'std1-file1.txt']
# ['std1-file11.txt', 'std1-file4.txt', 'std1-file7.txt']
# ['std1-file7.txt', 'std1-file2.txt', 'std1-file6.txt']
# ['std1-file9.txt', 'std1-file2.txt', 'std1-file10.txt']
# ['std1-file1.txt', 'std1-file4.txt', 'std1-file10.txt']
# ['std1-file10.txt', 'std1-file2.txt', 'std1-file7.txt']
# ['std1-file11.txt', 'std1-file2.txt', 'std1-file9.txt']
# ['std1-file1.txt', 'std1-file2.txt', 'std1-file4.txt']
# ['std1-file2.txt', 'std1-file3.txt', 'std1-file1.txt']
# ['std1-file6.txt', 'std1-file3.txt', 'std1-file9.txt']
# ['std1-file2.txt', 'std1-file3.txt', 'std1-file7.txt']
# ['std1-file5.txt', 'std1-file9.txt', 'std1-file6.txt']
# ['std1-file11.txt', 'std1-file7.txt', 'std1-file3.txt']
# ['std1-file7.txt', 'std1-file11.txt', 'std1-file2.txt']
# ['std1-file6.txt', 'std1-file11.txt', 'std1-file3.txt']
# ['std1-file9.txt', 'std1-file7.txt', 'std1-file5.txt']
# ['std1-file1.txt', 'std1-file2.txt', 'std1-file7.txt']
# ['std1-file5.txt', 'std1-file4.txt', 'std1-file2.txt']
# ['std1-file2.txt', 'std1-file9.txt', 'std1-file8.txt']
# ['std1-file1.txt', 'std1-file4.txt', 'std1-file9.txt']
# ['std1-file1.txt', 'std1-file2.txt', 'std1-file10.txt']
# ['std1-file7.txt', 'std1-file1.txt', 'std1-file11.txt']
# ['std1-file5.txt', 'std1-file8.txt', 'std1-file4.txt']
# ['std1-file6.txt', 'std1-file10.txt', 'std1-file1.txt']
# ['std1-file2.txt', 'std1-file10.txt', 'std1-file7.txt']
# ['std1-file3.txt', 'std1-file6.txt', 'std1-file7.txt']
# Saved to pickles/training_list_3.p

# %%
testing_list = load_or_create_filelist('pickles/testing_list_3.p', combined_list, n_iter, n_files)
# Out:
# ['std1-file1.txt', 'std1-file2.txt', 'std1-file7.txt']
# ['std1-file4.txt', 'std1-file6.txt', 'std1-file8.txt']
# ['std1-file6.txt', 'std1-file2.txt', 'std1-file7.txt']
# ['std1-file1.txt', 'std1-file9.txt', 'std1-file3.txt']
# ['std1-file4.txt', 'std1-file9.txt', 'std1-file3.txt']
# ['std1-file8.txt', 'std1-file4.txt', 'std1-file1.txt']
# ['std1-file11.txt', 'std1-file4.txt', 'std1-file6.txt']
# ['std1-file11.txt', 'std1-file1.txt', 'std1-file7.txt']
# ['std1-file3.txt', 'std1-file8.txt', 'std1-file6.txt']
# ['std1-file8.txt', 'std1-file10.txt', 'std1-file6.txt']
# ['std1-file5.txt', 'std1-file9.txt', 'std1-file10.txt']
# ['std1-file9.txt', 'std1-file2.txt', 'std1-file11.txt']
# ['std1-file11.txt', 'std1-file3.txt', 'std1-file8.txt']
# ['std1-file11.txt', 'std1-file7.txt', 'std1-file4.txt']
# ['std1-file9.txt', 'std1-file4.txt', 'std1-file5.txt']
# ['std1-file1.txt', 'std1-file2.txt', 'std1-file5.txt']
# ['std1-file7.txt', 'std1-file8.txt', 'std1-file2.txt']
# ['std1-file8.txt', 'std1-file9.txt', 'std1-file5.txt']
# ['std1-file8.txt', 'std1-file5.txt', 'std1-file1.txt']
# ['std1-file10.txt', 'std1-file1.txt', 'std1-file11.txt']
# ['std1-file10.txt', 'std1-file1.txt', 'std1-file2.txt']
# ['std1-file7.txt', 'std1-file11.txt', 'std1-file5.txt']
# ['std1-file2.txt', 'std1-file3.txt', 'std1-file9.txt']
# ['std1-file2.txt', 'std1-file4.txt', 'std1-file3.txt']
# ['std1-file9.txt', 'std1-file8.txt', 'std1-file5.txt']
# ['std1-file3.txt', 'std1-file6.txt', 'std1-file10.txt']
# ['std1-file5.txt', 'std1-file10.txt', 'std1-file6.txt']
# ['std1-file2.txt', 'std1-file1.txt', 'std1-file6.txt']
# ['std1-file3.txt', 'std1-file6.txt', 'std1-file2.txt']
# ['std1-file2.txt', 'std1-file5.txt', 'std1-file7.txt']
# Saved to pickles/testing_list_3.p

# %%
exp_results_2a = run_experiment(0, training_list, testing_list, 'pickles/res_match_feature_3.p')
# Out:
# Iteration 0
# Training on ['std1-file10.txt', 'std1-file8.txt', 'std1-file4.txt']
# Testing on ['std1-file1.txt', 'std1-file2.txt', 'std1-file7.txt']
# match_mode=0, mass_tol=6, rt_tol=75, tp=192, fp=32, fn=21, prec=0.857, rec=0.901, f1=0.879, th_prob=1.000
#
# Iteration 1
# Training on ['std1-file7.txt', 'std1-file9.txt', 'std1-file8.txt']
# Testing on ['std1-file4.txt', 'std1-file6.txt', 'std1-file8.txt']
# match_mode=0, mass_tol=4, rt_tol=70, tp=401, fp=27, fn=27, prec=0.937, rec=0.937, f1=0.937, th_prob=1.000
#
# Iteration 2
# Training on ['std1-file4.txt', 'std1-file3.txt', 'std1-file7.txt']
# Testing on ['std1-file6.txt', 'std1-file2.txt', 'std1-file7.txt']
# match_mode=0, mass_tol=4, rt_tol=60, tp=160, fp=32, fn=27, prec=0.833, rec=0.856, f1=0.844, th_prob=1.000
#
# Iteration 3
# Training on ['std1-file2.txt', 'std1-file4.txt', 'std1-file10.txt']
# Testing on ['std1-file1.txt', 'std1-file9.txt', 'std1-file3.txt']
# match_mode=0, mass_tol=6, rt_tol=55, tp=418, fp=40, fn=46, prec=0.913, rec=0.901, f1=0.907, th_prob=1.000
#
# Iteration 4
# Training on ['std1-file2.txt', 'std1-file11.txt', 'std1-file1.txt']
# Testing on ['std1-file4.txt', 'std1-file9.txt', 'std1-file3.txt']
# match_mode=0, mass_tol=4, rt_tol=50, tp=482, fp=44, fn=35, prec=0.916, rec=0.932, f1=0.924, th_prob=1.000
#
# Iteration 5
# Training on ['std1-file11.txt', 'std1-file4.txt', 'std1-file7.txt']
# Testing on ['std1-file8.txt', 'std1-file4.txt', 'std1-file1.txt']
# match_mode=0, mass_tol=4, rt_tol=60, tp=402, fp=33, fn=42, prec=0.924, rec=0.905, f1=0.915, th_prob=1.000
#
# Iteration 6
# Training on ['std1-file7.txt', 'std1-file2.txt', 'std1-file6.txt']
# Testing on ['std1-file11.txt', 'std1-file4.txt', 'std1-file6.txt']
# match_mode=0, mass_tol=2, rt_tol=70, tp=379, fp=40, fn=36, prec=0.905, rec=0.913, f1=0.909, th_prob=1.000
#
# Iteration 7
# Training on ['std1-file9.txt', 'std1-file2.txt', 'std1-file10.txt']
# Testing on ['std1-file11.txt', 'std1-file1.txt', 'std1-file7.txt']
# match_mode=0, mass_tol=4, rt_tol=60, tp=163, fp=39, fn=36, prec=0.807, rec=0.819, f1=0.813, th_prob=1.000
#
# Iteration 8
# Training on ['std1-file1.txt', 'std1-file4.txt', 'std1-file10.txt']
# Testing on ['std1-file3.txt', 'std1-file8.txt', 'std1-file6.txt']
# match_mode=0, mass_tol=4, rt_tol=90, tp=384, fp=46, fn=29, prec=0.893, rec=0.930, f1=0.911, th_prob=1.000
#
# Iteration 9
# Training on ['std1-file10.txt', 'std1-file2.txt', 'std1-file7.txt']
# Testing on ['std1-file8.txt', 'std1-file10.txt', 'std1-file6.txt']
# match_mode=0, mass_tol=4, rt_tol=65, tp=378, fp=31, fn=26, prec=0.924, rec=0.936, f1=0.930, th_prob=1.000
#
# Iteration 10
# Training on ['std1-file11.txt', 'std1-file2.txt', 'std1-file9.txt']
# Testing on ['std1-file5.txt', 'std1-file9.txt', 'std1-file10.txt']
# match_mode=0, mass_tol=4, rt_tol=50, tp=425, fp=37, fn=35, prec=0.920, rec=0.924, f1=0.922, th_prob=1.000
#
# Iteration 11
# Training on ['std1-file1.txt', 'std1-file2.txt', 'std1-file4.txt']
# Testing on ['std1-file9.txt', 'std1-file2.txt', 'std1-file11.txt']
# match_mode=0, mass_tol=4, rt_tol=40, tp=378, fp=30, fn=43, prec=0.926, rec=0.898, f1=0.912, th_prob=1.000
#
# Iteration 12
# Training on ['std1-file2.txt', 'std1-file3.txt', 'std1-file1.txt']
# Testing on ['std1-file11.txt', 'std1-file3.txt', 'std1-file8.txt']
# match_mode=0, mass_tol=4, rt_tol=80, tp=411, fp=23, fn=17, prec=0.947, rec=0.960, f1=0.954, th_prob=1.000
#
# Iteration 13
# Training on ['std1-file6.txt', 'std1-file3.txt', 'std1-file9.txt']
# Testing on ['std1-file11.txt', 'std1-file7.txt', 'std1-file4.txt']
# match_mode=0, mass_tol=4, rt_tol=70, tp=193, fp=42, fn=19, prec=0.821, rec=0.910, f1=0.864, th_prob=1.000
#
# Iteration 14
# Training on ['std1-file2.txt', 'std1-file3.txt', 'std1-file7.txt']
# Testing on ['std1-file9.txt', 'std1-file4.txt', 'std1-file5.txt']
# match_mode=0, mass_tol=4, rt_tol=65, tp=457, fp=52, fn=38, prec=0.898, rec=0.923, f1=0.910, th_prob=1.000
#
# Iteration 15
# Training on ['std1-file5.txt', 'std1-file9.txt', 'std1-file6.txt']
# Testing on ['std1-file1.txt', 'std1-file2.txt', 'std1-file5.txt']
# match_mode=0, mass_tol=2, rt_tol=55, tp=418, fp=36, fn=37, prec=0.921, rec=0.919, f1=0.920, th_prob=1.000
#
# Iteration 16
# Training on ['std1-file11.txt', 'std1-file7.txt', 'std1-file3.txt']
# Testing on ['std1-file7.txt', 'std1-file8.txt', 'std1-file2.txt']
# match_mode=0, mass_tol=4, rt_tol=60, tp=169, fp=36, fn=20, prec=0.824, rec=0.894, f1=0.858, th_prob=1.000
#
# Iteration 17
# Training on ['std1-file7.txt', 'std1-file11.txt', 'std1-file2.txt']
# Testing on ['std1-file8.txt', 'std1-file9.txt', 'std1-file5.txt']
# match_mode=0, mass_tol=4, rt_tol=60, tp=399, fp=29, fn=33, prec=0.932, rec=0.924, f1=0.928, th_prob=1.000
#
# Iteration 18
# Training on ['std1-file6.txt', 'std1-file11.txt', 'std1-file3.txt']
# Testing on ['std1-file8.txt', 'std1-file5.txt', 'std1-file1.txt']
# match_mode=0, mass_tol=2, rt_tol=75, tp=389, fp=32, fn=37, prec=0.924, rec=0.913, f1=0.919, th_prob=1.000
#
# Iteration 19
# Training on ['std1-file9.txt', 'std1-file7.txt', 'std1-file5.txt']
# Testing on ['std1-file10.txt', 'std1-file1.txt', 'std1-file11.txt']
# match_mode=0, mass_tol=6, rt_tol=70, tp=367, fp=49, fn=37, prec=0.882, rec=0.908, f1=0.895, th_prob=1.000
#
# Iteration 20
# Training on ['std1-file1.txt', 'std1-file2.txt', 'std1-file7.txt']
# Testing on ['std1-file10.txt', 'std1-file1.txt', 'std1-file2.txt']
# match_mode=0, mass_tol=2, rt_tol=70, tp=375, fp=41, fn=39, prec=0.901, rec=0.906, f1=0.904, th_prob=1.000
#
# Iteration 21
# Training on ['std1-file5.txt', 'std1-file4.txt', 'std1-file2.txt']
# Testing on ['std1-file7.txt', 'std1-file11.txt', 'std1-file5.txt']
# match_mode=0, mass_tol=4, rt_tol=65, tp=202, fp=39, fn=15, prec=0.838, rec=0.931, f1=0.882, th_prob=1.000
#
# Iteration 22
# Training on ['std1-file2.txt', 'std1-file9.txt', 'std1-file8.txt']
# Testing on ['std1-file2.txt', 'std1-file3.txt', 'std1-file9.txt']
# match_mode=0, mass_tol=4, rt_tol=70, tp=429, fp=41, fn=33, prec=0.913, rec=0.929, f1=0.921, th_prob=1.000
#
# Iteration 23
# Training on ['std1-file1.txt', 'std1-file4.txt', 'std1-file9.txt']
# Testing on ['std1-file2.txt', 'std1-file4.txt', 'std1-file3.txt']
# match_mode=0, mass_tol=4, rt_tol=90, tp=459, fp=50, fn=36, prec=0.902, rec=0.927, f1=0.914, th_prob=1.000
#
# Iteration 24
# Training on ['std1-file1.txt', 'std1-file2.txt', 'std1-file10.txt']
# Testing on ['std1-file9.txt', 'std1-file8.txt', 'std1-file5.txt']
# match_mode=0, mass_tol=4, rt_tol=85, tp=405, fp=32, fn=27, prec=0.927, rec=0.938, f1=0.932, th_prob=1.000
#
# Iteration 25
# Training on ['std1-file7.txt', 'std1-file1.txt', 'std1-file11.txt']
# Testing on ['std1-file3.txt', 'std1-file6.txt', 'std1-file10.txt']
# match_mode=0, mass_tol=4, rt_tol=65, tp=393, fp=47, fn=32, prec=0.893, rec=0.925, f1=0.909, th_prob=1.000
#
# Iteration 26
# Training on ['std1-file5.txt', 'std1-file8.txt', 'std1-file4.txt']
# Testing on ['std1-file5.txt', 'std1-file10.txt', 'std1-file6.txt']
# match_mode=0, mass_tol=6, rt_tol=85, tp=424, fp=43, fn=27, prec=0.908, rec=0.940, f1=0.924, th_prob=1.000
#
# Iteration 27
# Training on ['std1-file6.txt', 'std1-file10.txt', 'std1-file1.txt']
# Testing on ['std1-file2.txt', 'std1-file1.txt', 'std1-file6.txt']
# match_mode=0, mass_tol=6, rt_tol=90, tp=389, fp=30, fn=27, prec=0.928, rec=0.935, f1=0.932, th_prob=1.000
#
# Iteration 28
# Training on ['std1-file2.txt', 'std1-file10.txt', 'std1-file7.txt']
# Testing on ['std1-file3.txt', 'std1-file6.txt', 'std1-file2.txt']
# match_mode=0, mass_tol=4, rt_tol=65, tp=372, fp=49, fn=45, prec=0.884, rec=0.892, f1=0.888, th_prob=1.000
#
# Iteration 29
# Training on ['std1-file3.txt', 'std1-file6.txt', 'std1-file7.txt']
# Testing on ['std1-file2.txt', 'std1-file5.txt', 'std1-file7.txt']
# match_mode=0, mass_tol=4, rt_tol=70, tp=193, fp=36, fn=17, prec=0.843, rec=0.919, f1=0.879, th_prob=1.000
#
# Saved to pickles/res_match_feature_3.p

# %%
exp_results_2b = run_experiment(1, training_list, testing_list, 'pickles/res_match_cluster_3.p')
# Out:
# Iteration 0
# Training on ['std1-file10.txt', 'std1-file8.txt', 'std1-file4.txt']
# Testing on ['std1-file1.txt', 'std1-file2.txt', 'std1-file7.txt']
# match_mode=1, mass_tol=2, rt_tol=75, tp=206, fp=20, fn=7, prec=0.912, rec=0.967, f1=0.938, th_prob=1.000
#
# Iteration 1
# Training on ['std1-file7.txt', 'std1-file9.txt', 'std1-file8.txt']
# Testing on ['std1-file4.txt', 'std1-file6.txt', 'std1-file8.txt']
# match_mode=1, mass_tol=4, rt_tol=70, tp=393, fp=21, fn=35, prec=0.949, rec=0.918, f1=0.933, th_prob=1.000
#
# Iteration 2
# Training on ['std1-file4.txt', 'std1-file3.txt', 'std1-file7.txt']
# Testing on ['std1-file6.txt', 'std1-file2.txt', 'std1-file7.txt']
# match_mode=1, mass_tol=4, rt_tol=60, tp=174, fp=20, fn=13, prec=0.897, rec=0.930, f1=0.913, th_prob=1.000
#
# Iteration 3
# Training on ['std1-file2.txt', 'std1-file4.txt', 'std1-file10.txt']
# Testing on ['std1-file1.txt', 'std1-file9.txt', 'std1-file3.txt']
# match_mode=1, mass_tol=4, rt_tol=55, tp=427, fp=21, fn=37, prec=0.953, rec=0.920, f1=0.936, th_prob=1.000
#
# Iteration 4
# Training on ['std1-file2.txt', 'std1-file11.txt', 'std1-file1.txt']
# Testing on ['std1-file4.txt', 'std1-file9.txt', 'std1-file3.txt']
# match_mode=1, mass_tol=4, rt_tol=45, tp=467, fp=23, fn=50, prec=0.953, rec=0.903, f1=0.928, th_prob=1.000
#
# Iteration 5
# Training on ['std1-file11.txt', 'std1-file4.txt', 'std1-file7.txt']
# Testing on ['std1-file8.txt', 'std1-file4.txt', 'std1-file1.txt']
# match_mode=1, mass_tol=4, rt_tol=60, tp=389, fp=24, fn=55, prec=0.942, rec=0.876, f1=0.908, th_prob=1.000
#
# Iteration 6
# Training on ['std1-file7.txt', 'std1-file2.txt', 'std1-file6.txt']
# Testing on ['std1-file11.txt', 'std1-file4.txt', 'std1-file6.txt']
# match_mode=1, mass_tol=2, rt_tol=65, tp=372, fp=27, fn=43, prec=0.932, rec=0.896, f1=0.914, th_prob=1.000
#
# Iteration 7
# Training on ['std1-file9.txt', 'std1-file2.txt', 'std1-file10.txt']
# Testing on ['std1-file11.txt', 'std1-file1.txt', 'std1-file7.txt']
# match_mode=1, mass_tol=2, rt_tol=40, tp=161, fp=14, fn=38, prec=0.920, rec=0.809, f1=0.861, th_prob=1.000
#
# Iteration 8
# Training on ['std1-file1.txt', 'std1-file4.txt', 'std1-file10.txt']
# Testing on ['std1-file3.txt', 'std1-file8.txt', 'std1-file6.txt']
# match_mode=1, mass_tol=6, rt_tol=90, tp=388, fp=25, fn=25, prec=0.939, rec=0.939, f1=0.939, th_prob=1.000
#
# Iteration 9
# Training on ['std1-file10.txt', 'std1-file2.txt', 'std1-file7.txt']
# Testing on ['std1-file8.txt', 'std1-file10.txt', 'std1-file6.txt']
# match_mode=1, mass_tol=2, rt_tol=60, tp=369, fp=16, fn=35, prec=0.958, rec=0.913, f1=0.935, th_prob=1.000
#
# Iteration 10
# Training on ['std1-file11.txt', 'std1-file2.txt', 'std1-file9.txt']
# Testing on ['std1-file5.txt', 'std1-file9.txt', 'std1-file10.txt']
# match_mode=1, mass_tol=4, rt_tol=45, tp=422, fp=19, fn=38, prec=0.957, rec=0.917, f1=0.937, th_prob=1.000
#
# Iteration 11
# Training on ['std1-file1.txt', 'std1-file2.txt', 'std1-file4.txt']
# Testing on ['std1-file9.txt', 'std1-file2.txt', 'std1-file11.txt']
# match_mode=1, mass_tol=4, rt_tol=35, tp=391, fp=10, fn=30, prec=0.975, rec=0.929, f1=0.951, th_prob=1.000
#
# Iteration 12
# Training on ['std1-file2.txt', 'std1-file3.txt', 'std1-file1.txt']
# Testing on ['std1-file11.txt', 'std1-file3.txt', 'std1-file8.txt']
# match_mode=1, mass_tol=4, rt_tol=80, tp=406, fp=20, fn=22, prec=0.953, rec=0.949, f1=0.951, th_prob=1.000
#
# Iteration 13
# Training on ['std1-file6.txt', 'std1-file3.txt', 'std1-file9.txt']
# Testing on ['std1-file11.txt', 'std1-file7.txt', 'std1-file4.txt']
# match_mode=1, mass_tol=4, rt_tol=70, tp=190, fp=28, fn=22, prec=0.872, rec=0.896, f1=0.884, th_prob=1.000
#
# Iteration 14
# Training on ['std1-file2.txt', 'std1-file3.txt', 'std1-file7.txt']
# Testing on ['std1-file9.txt', 'std1-file4.txt', 'std1-file5.txt']
# match_mode=1, mass_tol=4, rt_tol=65, tp=445, fp=31, fn=50, prec=0.935, rec=0.899, f1=0.917, th_prob=1.000
#
# Iteration 15
# Training on ['std1-file5.txt', 'std1-file9.txt', 'std1-file6.txt']
# Testing on ['std1-file1.txt', 'std1-file2.txt', 'std1-file5.txt']
# match_mode=1, mass_tol=2, rt_tol=50, tp=434, fp=14, fn=21, prec=0.969, rec=0.954, f1=0.961, th_prob=1.000
#
# Iteration 16
# Training on ['std1-file11.txt', 'std1-file7.txt', 'std1-file3.txt']
# Testing on ['std1-file7.txt', 'std1-file8.txt', 'std1-file2.txt']
# match_mode=1, mass_tol=2, rt_tol=60, tp=150, fp=24, fn=39, prec=0.862, rec=0.794, f1=0.826, th_prob=1.000
#
# Iteration 17
# Training on ['std1-file7.txt', 'std1-file11.txt', 'std1-file2.txt']
# Testing on ['std1-file8.txt', 'std1-file9.txt', 'std1-file5.txt']
# match_mode=1, mass_tol=4, rt_tol=60, tp=397, fp=18, fn=35, prec=0.957, rec=0.919, f1=0.937, th_prob=1.000
#
# Iteration 18
# Training on ['std1-file6.txt', 'std1-file11.txt', 'std1-file3.txt']
# Testing on ['std1-file8.txt', 'std1-file5.txt', 'std1-file1.txt']
# match_mode=1, mass_tol=4, rt_tol=75, tp=395, fp=21, fn=31, prec=0.950, rec=0.927, f1=0.938, th_prob=1.000
#
# Iteration 19
# Training on ['std1-file9.txt', 'std1-file7.txt', 'std1-file5.txt']
# Testing on ['std1-file10.txt', 'std1-file1.txt', 'std1-file11.txt']
# match_mode=1, mass_tol=2, rt_tol=70, tp=374, fp=21, fn=30, prec=0.947, rec=0.926, f1=0.936, th_prob=1.000
#
# Iteration 20
# Training on ['std1-file1.txt', 'std1-file2.txt', 'std1-file7.txt']
# Testing on ['std1-file10.txt', 'std1-file1.txt', 'std1-file2.txt']
# match_mode=1, mass_tol=2, rt_tol=70, tp=389, fp=23, fn=25, prec=0.944, rec=0.940, f1=0.942, th_prob=1.000
#
# Iteration 21
# Training on ['std1-file5.txt', 'std1-file4.txt', 'std1-file2.txt']
# Testing on ['std1-file7.txt', 'std1-file11.txt', 'std1-file5.txt']
# match_mode=1, mass_tol=4, rt_tol=35, tp=158, fp=15, fn=59, prec=0.913, rec=0.728, f1=0.810, th_prob=1.000
#
# Iteration 22
# Training on ['std1-file2.txt', 'std1-file9.txt', 'std1-file8.txt']
# Testing on ['std1-file2.txt', 'std1-file3.txt', 'std1-file9.txt']
# match_mode=1, mass_tol=4, rt_tol=70, tp=433, fp=19, fn=29, prec=0.958, rec=0.937, f1=0.947, th_prob=1.000
#
# Iteration 23
# Training on ['std1-file1.txt', 'std1-file4.txt', 'std1-file9.txt']
# Testing on ['std1-file2.txt', 'std1-file4.txt', 'std1-file3.txt']
# match_mode=1, mass_tol=4, rt_tol=100, tp=456, fp=28, fn=39, prec=0.942, rec=0.921, f1=0.932, th_prob=1.000
#
# Iteration 24
# Training on ['std1-file1.txt', 'std1-file2.txt', 'std1-file10.txt']
# Testing on ['std1-file9.txt', 'std1-file8.txt', 'std1-file5.txt']
# match_mode=1, mass_tol=6, rt_tol=40, tp=387, fp=17, fn=45, prec=0.958, rec=0.896, f1=0.926, th_prob=1.000
#
# Iteration 25
# Training on ['std1-file7.txt', 'std1-file1.txt', 'std1-file11.txt']
# Testing on ['std1-file3.txt', 'std1-file6.txt', 'std1-file10.txt']
# match_mode=1, mass_tol=2, rt_tol=70, tp=383, fp=23, fn=42, prec=0.943, rec=0.901, f1=0.922, th_prob=1.000
#
# Iteration 26
# Training on ['std1-file5.txt', 'std1-file8.txt', 'std1-file4.txt']
# Testing on ['std1-file5.txt', 'std1-file10.txt', 'std1-file6.txt']
# match_mode=1, mass_tol=6, rt_tol=80, tp=423, fp=27, fn=28, prec=0.940, rec=0.938, f1=0.939, th_prob=1.000
#
# Iteration 27
# Training on ['std1-file6.txt', 'std1-file10.txt', 'std1-file1.txt']
# Testing on ['std1-file2.txt', 'std1-file1.txt', 'std1-file6.txt']
# match_mode=1, mass_tol=6, rt_tol=45, tp=400, fp=17, fn=16, prec=0.959, rec=0.962, f1=0.960, th_prob=1.000
#
# Iteration 28
# Training on ['std1-file2.txt', 'std1-file10.txt', 'std1-file7.txt']
# Testing on ['std1-file3.txt', 'std1-file6.txt', 'std1-file2.txt']
# match_mode=1, mass_tol=2, rt_tol=60, tp=367, fp=27, fn=50, prec=0.931, rec=0.880, f1=0.905, th_prob=1.000
#
# Iteration 29
# Training on ['std1-file3.txt', 'std1-file6.txt', 'std1-file7.txt']
# Testing on ['std1-file2.txt', 'std1-file5.txt', 'std1-file7.txt']
# match_mode=1, mass_tol=4, rt_tol=70, tp=199, fp=24, fn=11, prec=0.892, rec=0.948, f1=0.919, th_prob=1.000
#
# Saved to pickles/res_match_cluster_3.p

# %% [markdown]
# <h2>Run experiment with 4 random files</h2>

# %%
n_files = 4

# %%
training_list = load_or_create_filelist('pickles/training_list_4.p', combined_list, n_iter, n_files)
# Out:
# ['std1-file3.txt', 'std1-file2.txt', 'std1-file9.txt', 'std1-file8.txt']
# ['std1-file6.txt', 'std1-file3.txt', 'std1-file5.txt', 'std1-file11.txt']
# ['std1-file1.txt', 'std1-file8.txt', 'std1-file4.txt', 'std1-file2.txt']
# ['std1-file1.txt', 'std1-file6.txt', 'std1-file5.txt', 'std1-file8.txt']
# ['std1-file9.txt', 'std1-file4.txt', 'std1-file1.txt', 'std1-file8.txt']
# ['std1-file4.txt', 'std1-file11.txt', 'std1-file7.txt', 'std1-file10.txt']
# ['std1-file9.txt', 'std1-file2.txt', 'std1-file4.txt', 'std1-file5.txt']
# ['std1-file11.txt', 'std1-file5.txt', 'std1-file6.txt', 'std1-file3.txt']
# ['std1-file1.txt', 'std1-file10.txt', 'std1-file9.txt', 'std1-file2.txt']
# ['std1-file6.txt', 'std1-file11.txt', 'std1-file8.txt', 'std1-file10.txt']
# ['std1-file5.txt', 'std1-file10.txt', 'std1-file11.txt', 'std1-file6.txt']
# ['std1-file8.txt', 'std1-file4.txt', 'std1-file11.txt', 'std1-file7.txt']
# ['std1-file8.txt', 'std1-file2.txt', 'std1-file10.txt', 'std1-file11.txt']
# ['std1-file7.txt', 'std1-file10.txt', 'std1-file9.txt', 'std1-file2.txt']
# ['std1-file3.txt', 'std1-file8.txt', 'std1-file9.txt', 'std1-file1.txt']
# ['std1-file8.txt', 'std1-file5.txt', 'std1-file10.txt', 'std1-file1.txt']
# ['std1-file9.txt', 'std1-file2.txt', 'std1-file7.txt', 'std1-file11.txt']
# ['std1-file7.txt', 'std1-file5.txt', 'std1-file1.txt', 'std1-file10.txt']
# ['std1-file10.txt', 'std1-file11.txt', 'std1-file6.txt', 'std1-file9.txt']
# ['std1-file11.txt', 'std1-file2.txt', 'std1-file7.txt', 'std1-file4.txt']
# ['std1-file3.txt', 'std1-file10.txt', 'std1-file6.txt', 'std1-file1.txt']
# ['std1-file4.txt', 'std1-file9.txt', 'std1-file5.txt', 'std1-file3.txt']
# ['std1-file8.txt', 'std1-file1.txt', 'std1-file5.txt', 'std1-file11.txt']
# ['std1-file6.txt', 'std1-file9.txt', 'std1-file7.txt', 'std1-file2.txt']
# ['std1-file3.txt', 'std1-file11.txt', 'std1-file10.txt', 'std1-file9.txt']
# ['std1-file9.txt', 'std1-file6.txt', 'std1-file7.txt', 'std1-file8.txt']
# ['std1-file1.txt', 'std1-file6.txt', 'std1-file4.txt', 'std1-file9.txt']
# ['std1-file10.txt', 'std1-file6.txt', 'std1-file4.txt', 'std1-file5.txt']
# ['std1-file6.txt', 'std1-file5.txt', 'std1-file9.txt', 'std1-file3.txt']
# ['std1-file8.txt', 'std1-file11.txt', 'std1-file4.txt', 'std1-file3.txt']
# Saved to pickles/training_list_4.p

# %%
testing_list = load_or_create_filelist('pickles/testing_list_4.p', combined_list, n_iter, n_files)
# Out:
# ['std1-file10.txt', 'std1-file8.txt', 'std1-file7.txt', 'std1-file5.txt']
# ['std1-file7.txt', 'std1-file1.txt', 'std1-file11.txt', 'std1-file9.txt']
# ['std1-file9.txt', 'std1-file4.txt', 'std1-file7.txt', 'std1-file10.txt']
# ['std1-file6.txt', 'std1-file1.txt', 'std1-file8.txt', 'std1-file5.txt']
# ['std1-file1.txt', 'std1-file7.txt', 'std1-file10.txt', 'std1-file9.txt']
# ['std1-file2.txt', 'std1-file10.txt', 'std1-file6.txt', 'std1-file1.txt']
# ['std1-file5.txt', 'std1-file11.txt', 'std1-file7.txt', 'std1-file4.txt']
# ['std1-file3.txt', 'std1-file7.txt', 'std1-file11.txt', 'std1-file5.txt']
# ['std1-file2.txt', 'std1-file10.txt', 'std1-file1.txt', 'std1-file11.txt']
# ['std1-file6.txt', 'std1-file4.txt', 'std1-file9.txt', 'std1-file1.txt']
# ['std1-file11.txt', 'std1-file10.txt', 'std1-file9.txt', 'std1-file7.txt']
# ['std1-file1.txt', 'std1-file4.txt', 'std1-file11.txt', 'std1-file10.txt']
# ['std1-file9.txt', 'std1-file2.txt', 'std1-file7.txt', 'std1-file1.txt']
# ['std1-file2.txt', 'std1-file6.txt', 'std1-file4.txt', 'std1-file3.txt']
# ['std1-file7.txt', 'std1-file11.txt', 'std1-file5.txt', 'std1-file9.txt']
# ['std1-file11.txt', 'std1-file1.txt', 'std1-file2.txt', 'std1-file5.txt']
# ['std1-file2.txt', 'std1-file1.txt', 'std1-file6.txt', 'std1-file7.txt']
# ['std1-file3.txt', 'std1-file1.txt', 'std1-file2.txt', 'std1-file11.txt']
# ['std1-file8.txt', 'std1-file7.txt', 'std1-file3.txt', 'std1-file2.txt']
# ['std1-file3.txt', 'std1-file7.txt', 'std1-file5.txt', 'std1-file9.txt']
# ['std1-file2.txt', 'std1-file10.txt', 'std1-file3.txt', 'std1-file11.txt']
# ['std1-file9.txt', 'std1-file3.txt', 'std1-file8.txt', 'std1-file5.txt']
# ['std1-file3.txt', 'std1-file8.txt', 'std1-file11.txt', 'std1-file7.txt']
# ['std1-file6.txt', 'std1-file1.txt', 'std1-file4.txt', 'std1-file10.txt']
# ['std1-file4.txt', 'std1-file3.txt', 'std1-file8.txt', 'std1-file2.txt']
# ['std1-file6.txt', 'std1-file11.txt', 'std1-file3.txt', 'std1-file7.txt']
# ['std1-file9.txt', 'std1-file2.txt', 'std1-file5.txt', 'std1-file10.txt']
# ['std1-file11.txt', 'std1-file8.txt', 'std1-file1.txt', 'std1-file2.txt']
# ['std1-file6.txt', 'std1-file11.txt', 'std1-file4.txt', 'std1-file1.txt']
# ['std1-file8.txt', 'std1-file5.txt', 'std1-file6.txt', 'std1-file3.txt']
# Saved to pickles/testing_list_4.p

# %%
exp_results_3a = run_experiment(0, training_list, testing_list, 'pickles/res_match_feature_4.p')
# Out:
# Iteration 0
# Training on ['std1-file3.txt', 'std1-file2.txt', 'std1-file9.txt', 'std1-file8.txt']
# Testing on ['std1-file10.txt', 'std1-file8.txt', 'std1-file7.txt', 'std1-file5.txt']
# match_mode=0, mass_tol=4, rt_tol=80, tp=511, fp=90, fn=26, prec=0.850, rec=0.952, f1=0.898, th_prob=1.000
#
# Iteration 1
# Training on ['std1-file6.txt', 'std1-file3.txt', 'std1-file5.txt', 'std1-file11.txt']
# Testing on ['std1-file7.txt', 'std1-file1.txt', 'std1-file11.txt', 'std1-file9.txt']
# match_mode=0, mass_tol=6, rt_tol=70, tp=450, fp=90, fn=70, prec=0.833, rec=0.865, f1=0.849, th_prob=1.000
#
# Iteration 2
# Training on ['std1-file1.txt', 'std1-file8.txt', 'std1-file4.txt', 'std1-file2.txt']
# Testing on ['std1-file9.txt', 'std1-file4.txt', 'std1-file7.txt', 'std1-file10.txt']
# match_mode=0, mass_tol=4, rt_tol=85, tp=507, fp=106, fn=50, prec=0.827, rec=0.910, f1=0.867, th_prob=1.000
#
# Iteration 3
# Training on ['std1-file1.txt', 'std1-file6.txt', 'std1-file5.txt', 'std1-file8.txt']
# Testing on ['std1-file6.txt', 'std1-file1.txt', 'std1-file8.txt', 'std1-file5.txt']
# match_mode=0, mass_tol=6, rt_tol=70, tp=766, fp=65, fn=72, prec=0.922, rec=0.914, f1=0.918, th_prob=1.000
#
# Iteration 4
# Training on ['std1-file9.txt', 'std1-file4.txt', 'std1-file1.txt', 'std1-file8.txt']
# Testing on ['std1-file1.txt', 'std1-file7.txt', 'std1-file10.txt', 'std1-file9.txt']
# match_mode=0, mass_tol=6, rt_tol=100, tp=437, fp=179, fn=80, prec=0.709, rec=0.845, f1=0.771, th_prob=1.000
#
# Iteration 5
# Training on ['std1-file4.txt', 'std1-file11.txt', 'std1-file7.txt', 'std1-file10.txt']
# Testing on ['std1-file2.txt', 'std1-file10.txt', 'std1-file6.txt', 'std1-file1.txt']
# match_mode=0, mass_tol=4, rt_tol=60, tp=747, fp=77, fn=68, prec=0.907, rec=0.917, f1=0.912, th_prob=1.000
#
# Iteration 6
# Training on ['std1-file9.txt', 'std1-file2.txt', 'std1-file4.txt', 'std1-file5.txt']
# Testing on ['std1-file5.txt', 'std1-file11.txt', 'std1-file7.txt', 'std1-file4.txt']
# match_mode=0, mass_tol=6, rt_tol=60, tp=530, fp=78, fn=46, prec=0.872, rec=0.920, f1=0.895, th_prob=1.000
#
# Iteration 7
# Training on ['std1-file11.txt', 'std1-file5.txt', 'std1-file6.txt', 'std1-file3.txt']
# Testing on ['std1-file3.txt', 'std1-file7.txt', 'std1-file11.txt', 'std1-file5.txt']
# match_mode=0, mass_tol=6, rt_tol=70, tp=532, fp=77, fn=36, prec=0.874, rec=0.937, f1=0.904, th_prob=1.000
#
# Iteration 8
# Training on ['std1-file1.txt', 'std1-file10.txt', 'std1-file9.txt', 'std1-file2.txt']
# Testing on ['std1-file2.txt', 'std1-file10.txt', 'std1-file1.txt', 'std1-file11.txt']
# match_mode=0, mass_tol=4, rt_tol=85, tp=727, fp=89, fn=88, prec=0.891, rec=0.892, f1=0.891, th_prob=1.000
#
# Iteration 9
# Training on ['std1-file6.txt', 'std1-file11.txt', 'std1-file8.txt', 'std1-file10.txt']
# Testing on ['std1-file6.txt', 'std1-file4.txt', 'std1-file9.txt', 'std1-file1.txt']
# match_mode=0, mass_tol=2, rt_tol=75, tp=783, fp=92, fn=94, prec=0.895, rec=0.893, f1=0.894, th_prob=1.000
#
# Iteration 10
# Training on ['std1-file5.txt', 'std1-file10.txt', 'std1-file11.txt', 'std1-file6.txt']
# Testing on ['std1-file11.txt', 'std1-file10.txt', 'std1-file9.txt', 'std1-file7.txt']
# match_mode=0, mass_tol=2, rt_tol=75, tp=452, fp=95, fn=53, prec=0.826, rec=0.895, f1=0.859, th_prob=1.000
#
# Iteration 11
# Training on ['std1-file8.txt', 'std1-file4.txt', 'std1-file11.txt', 'std1-file7.txt']
# Testing on ['std1-file1.txt', 'std1-file4.txt', 'std1-file11.txt', 'std1-file10.txt']
# match_mode=0, mass_tol=6, rt_tol=60, tp=798, fp=98, fn=70, prec=0.891, rec=0.919, f1=0.905, th_prob=1.000
#
# Iteration 12
# Training on ['std1-file8.txt', 'std1-file2.txt', 'std1-file10.txt', 'std1-file11.txt']
# Testing on ['std1-file9.txt', 'std1-file2.txt', 'std1-file7.txt', 'std1-file1.txt']
# match_mode=0, mass_tol=4, rt_tol=70, tp=506, fp=62, fn=43, prec=0.891, rec=0.922, f1=0.906, th_prob=1.000
#
# Iteration 13
# Training on ['std1-file7.txt', 'std1-file10.txt', 'std1-file9.txt', 'std1-file2.txt']
# Testing on ['std1-file2.txt', 'std1-file6.txt', 'std1-file4.txt', 'std1-file3.txt']
# match_mode=0, mass_tol=4, rt_tol=70, tp=818, fp=109, fn=88, prec=0.882, rec=0.903, f1=0.893, th_prob=1.000
#
# Iteration 14
# Training on ['std1-file3.txt', 'std1-file8.txt', 'std1-file9.txt', 'std1-file1.txt']
# Testing on ['std1-file7.txt', 'std1-file11.txt', 'std1-file5.txt', 'std1-file9.txt']
# match_mode=0, mass_tol=4, rt_tol=85, tp=495, fp=130, fn=49, prec=0.792, rec=0.910, f1=0.847, th_prob=1.000
#
# Iteration 15
# Training on ['std1-file8.txt', 'std1-file5.txt', 'std1-file10.txt', 'std1-file1.txt']
# Testing on ['std1-file11.txt', 'std1-file1.txt', 'std1-file2.txt', 'std1-file5.txt']
# match_mode=0, mass_tol=6, rt_tol=85, tp=789, fp=90, fn=86, prec=0.898, rec=0.902, f1=0.900, th_prob=1.000
#
# Iteration 16
# Training on ['std1-file9.txt', 'std1-file2.txt', 'std1-file7.txt', 'std1-file11.txt']
# Testing on ['std1-file2.txt', 'std1-file1.txt', 'std1-file6.txt', 'std1-file7.txt']
# match_mode=0, mass_tol=4, rt_tol=50, tp=427, fp=60, fn=77, prec=0.877, rec=0.847, f1=0.862, th_prob=1.000
#
# Iteration 17
# Training on ['std1-file7.txt', 'std1-file5.txt', 'std1-file1.txt', 'std1-file10.txt']
# Testing on ['std1-file3.txt', 'std1-file1.txt', 'std1-file2.txt', 'std1-file11.txt']
# match_mode=0, mass_tol=6, rt_tol=70, tp=782, fp=94, fn=87, prec=0.893, rec=0.900, f1=0.896, th_prob=1.000
#
# Iteration 18
# Training on ['std1-file10.txt', 'std1-file11.txt', 'std1-file6.txt', 'std1-file9.txt']
# Testing on ['std1-file8.txt', 'std1-file7.txt', 'std1-file3.txt', 'std1-file2.txt']
# match_mode=0, mass_tol=4, rt_tol=60, tp=465, fp=83, fn=45, prec=0.849, rec=0.912, f1=0.879, th_prob=1.000
#
# Iteration 19
# Training on ['std1-file11.txt', 'std1-file2.txt', 'std1-file7.txt', 'std1-file4.txt']
# Testing on ['std1-file3.txt', 'std1-file7.txt', 'std1-file5.txt', 'std1-file9.txt']
# match_mode=0, mass_tol=4, rt_tol=65, tp=529, fp=94, fn=56, prec=0.849, rec=0.904, f1=0.876, th_prob=1.000
#
# Iteration 20
# Training on ['std1-file3.txt', 'std1-file10.txt', 'std1-file6.txt', 'std1-file1.txt']
# Testing on ['std1-file2.txt', 'std1-file10.txt', 'std1-file3.txt', 'std1-file11.txt']
# match_mode=0, mass_tol=6, rt_tol=90, tp=768, fp=81, fn=69, prec=0.905, rec=0.918, f1=0.911, th_prob=1.000
#
# Iteration 21
# Training on ['std1-file4.txt', 'std1-file9.txt', 'std1-file5.txt', 'std1-file3.txt']
# Testing on ['std1-file9.txt', 'std1-file3.txt', 'std1-file8.txt', 'std1-file5.txt']
# match_mode=0, mass_tol=6, rt_tol=65, tp=832, fp=76, fn=78, prec=0.916, rec=0.914, f1=0.915, th_prob=1.000
#
# Iteration 22
# Training on ['std1-file8.txt', 'std1-file1.txt', 'std1-file5.txt', 'std1-file11.txt']
# Testing on ['std1-file3.txt', 'std1-file8.txt', 'std1-file11.txt', 'std1-file7.txt']
# match_mode=0, mass_tol=4, rt_tol=85, tp=495, fp=105, fn=26, prec=0.825, rec=0.950, f1=0.883, th_prob=1.000
#
# Iteration 23
# Training on ['std1-file6.txt', 'std1-file9.txt', 'std1-file7.txt', 'std1-file2.txt']
# Testing on ['std1-file6.txt', 'std1-file1.txt', 'std1-file4.txt', 'std1-file10.txt']
# match_mode=0, mass_tol=2, rt_tol=70, tp=762, fp=107, fn=101, prec=0.877, rec=0.883, f1=0.880, th_prob=1.000
#
# Iteration 24
# Training on ['std1-file3.txt', 'std1-file11.txt', 'std1-file10.txt', 'std1-file9.txt']
# Testing on ['std1-file4.txt', 'std1-file3.txt', 'std1-file8.txt', 'std1-file2.txt']
# match_mode=0, mass_tol=2, rt_tol=95, tp=789, fp=78, fn=133, prec=0.910, rec=0.856, f1=0.882, th_prob=1.000
#
# Iteration 25
# Training on ['std1-file9.txt', 'std1-file6.txt', 'std1-file7.txt', 'std1-file8.txt']
# Testing on ['std1-file6.txt', 'std1-file11.txt', 'std1-file3.txt', 'std1-file7.txt']
# match_mode=0, mass_tol=4, rt_tol=70, tp=457, fp=77, fn=45, prec=0.856, rec=0.910, f1=0.882, th_prob=1.000
#
# Iteration 26
# Training on ['std1-file1.txt', 'std1-file6.txt', 'std1-file4.txt', 'std1-file9.txt']
# Testing on ['std1-file9.txt', 'std1-file2.txt', 'std1-file5.txt', 'std1-file10.txt']
# match_mode=0, mass_tol=4, rt_tol=90, tp=814, fp=82, fn=75, prec=0.908, rec=0.916, f1=0.912, th_prob=1.000
#
# Iteration 27
# Training on ['std1-file10.txt', 'std1-file6.txt', 'std1-file4.txt', 'std1-file5.txt']
# Testing on ['std1-file11.txt', 'std1-file8.txt', 'std1-file1.txt', 'std1-file2.txt']
# match_mode=0, mass_tol=4, rt_tol=85, tp=750, fp=72, fn=64, prec=0.912, rec=0.921, f1=0.917, th_prob=1.000
#
# Iteration 28
# Training on ['std1-file6.txt', 'std1-file5.txt', 'std1-file9.txt', 'std1-file3.txt']
# Testing on ['std1-file6.txt', 'std1-file11.txt', 'std1-file4.txt', 'std1-file1.txt']
# match_mode=0, mass_tol=6, rt_tol=75, tp=762, fp=104, fn=79, prec=0.880, rec=0.906, f1=0.893, th_prob=1.000
#
# Iteration 29
# Training on ['std1-file8.txt', 'std1-file11.txt', 'std1-file4.txt', 'std1-file3.txt']
# Testing on ['std1-file8.txt', 'std1-file5.txt', 'std1-file6.txt', 'std1-file3.txt']
# match_mode=0, mass_tol=2, rt_tol=65, tp=793, fp=78, fn=82, prec=0.910, rec=0.906, f1=0.908, th_prob=1.000
#
# Saved to pickles/res_match_feature_4.p

# %%
exp_results_3b = run_experiment(1, training_list, testing_list, 'pickles/res_match_cluster_4.p')
# Out:
# Iteration 0
# Training on ['std1-file3.txt', 'std1-file2.txt', 'std1-file9.txt', 'std1-file8.txt']
# Testing on ['std1-file10.txt', 'std1-file8.txt', 'std1-file7.txt', 'std1-file5.txt']
# match_mode=1, mass_tol=4, rt_tol=80, tp=488, fp=82, fn=49, prec=0.856, rec=0.909, f1=0.882, th_prob=1.000
#
# Iteration 1
# Training on ['std1-file6.txt', 'std1-file3.txt', 'std1-file5.txt', 'std1-file11.txt']
# Testing on ['std1-file7.txt', 'std1-file1.txt', 'std1-file11.txt', 'std1-file9.txt']
# match_mode=1, mass_tol=4, rt_tol=70, tp=488, fp=42, fn=32, prec=0.921, rec=0.938, f1=0.930, th_prob=1.000
#
# Iteration 2
# Training on ['std1-file1.txt', 'std1-file8.txt', 'std1-file4.txt', 'std1-file2.txt']
# Testing on ['std1-file9.txt', 'std1-file4.txt', 'std1-file7.txt', 'std1-file10.txt']
# match_mode=1, mass_tol=4, rt_tol=95, tp=505, fp=133, fn=52, prec=0.792, rec=0.907, f1=0.845, th_prob=1.000
#
# Iteration 3
# Training on ['std1-file1.txt', 'std1-file6.txt', 'std1-file5.txt', 'std1-file8.txt']
# Testing on ['std1-file6.txt', 'std1-file1.txt', 'std1-file8.txt', 'std1-file5.txt']
# match_mode=1, mass_tol=6, rt_tol=65, tp=773, fp=45, fn=65, prec=0.945, rec=0.922, f1=0.934, th_prob=1.000
#
# Iteration 4
# Training on ['std1-file9.txt', 'std1-file4.txt', 'std1-file1.txt', 'std1-file8.txt']
# Testing on ['std1-file1.txt', 'std1-file7.txt', 'std1-file10.txt', 'std1-file9.txt']
# match_mode=1, mass_tol=6, rt_tol=100, tp=461, fp=138, fn=56, prec=0.770, rec=0.892, f1=0.826, th_prob=1.000
#
# Iteration 5
# Training on ['std1-file4.txt', 'std1-file11.txt', 'std1-file7.txt', 'std1-file10.txt']
# Testing on ['std1-file2.txt', 'std1-file10.txt', 'std1-file6.txt', 'std1-file1.txt']
# match_mode=1, mass_tol=4, rt_tol=60, tp=771, fp=37, fn=44, prec=0.954, rec=0.946, f1=0.950, th_prob=1.000
#
# Iteration 6
# Training on ['std1-file9.txt', 'std1-file2.txt', 'std1-file4.txt', 'std1-file5.txt']
# Testing on ['std1-file5.txt', 'std1-file11.txt', 'std1-file7.txt', 'std1-file4.txt']
# match_mode=1, mass_tol=4, rt_tol=65, tp=523, fp=65, fn=53, prec=0.889, rec=0.908, f1=0.899, th_prob=1.000
#
# Iteration 7
# Training on ['std1-file11.txt', 'std1-file5.txt', 'std1-file6.txt', 'std1-file3.txt']
# Testing on ['std1-file3.txt', 'std1-file7.txt', 'std1-file11.txt', 'std1-file5.txt']
# match_mode=1, mass_tol=4, rt_tol=70, tp=521, fp=60, fn=47, prec=0.897, rec=0.917, f1=0.907, th_prob=1.000
#
# Iteration 8
# Training on ['std1-file1.txt', 'std1-file10.txt', 'std1-file9.txt', 'std1-file2.txt']
# Testing on ['std1-file2.txt', 'std1-file10.txt', 'std1-file1.txt', 'std1-file11.txt']
# match_mode=1, mass_tol=2, rt_tol=55, tp=763, fp=46, fn=52, prec=0.943, rec=0.936, f1=0.940, th_prob=1.000
#
# Iteration 9
# Training on ['std1-file6.txt', 'std1-file11.txt', 'std1-file8.txt', 'std1-file10.txt']
# Testing on ['std1-file6.txt', 'std1-file4.txt', 'std1-file9.txt', 'std1-file1.txt']
# match_mode=1, mass_tol=4, rt_tol=75, tp=813, fp=67, fn=64, prec=0.924, rec=0.927, f1=0.925, th_prob=1.000
#
# Iteration 10
# Training on ['std1-file5.txt', 'std1-file10.txt', 'std1-file11.txt', 'std1-file6.txt']
# Testing on ['std1-file11.txt', 'std1-file10.txt', 'std1-file9.txt', 'std1-file7.txt']
# match_mode=1, mass_tol=4, rt_tol=75, tp=466, fp=62, fn=39, prec=0.883, rec=0.923, f1=0.902, th_prob=1.000
#
# Iteration 11
# Training on ['std1-file8.txt', 'std1-file4.txt', 'std1-file11.txt', 'std1-file7.txt']
# Testing on ['std1-file1.txt', 'std1-file4.txt', 'std1-file11.txt', 'std1-file10.txt']
# match_mode=1, mass_tol=6, rt_tol=60, tp=788, fp=61, fn=80, prec=0.928, rec=0.908, f1=0.918, th_prob=1.000
#
# Iteration 12
# Training on ['std1-file8.txt', 'std1-file2.txt', 'std1-file10.txt', 'std1-file11.txt']
# Testing on ['std1-file9.txt', 'std1-file2.txt', 'std1-file7.txt', 'std1-file1.txt']
# match_mode=1, mass_tol=4, rt_tol=55, tp=512, fp=39, fn=37, prec=0.929, rec=0.933, f1=0.931, th_prob=1.000
#
# Iteration 13
# Training on ['std1-file7.txt', 'std1-file10.txt', 'std1-file9.txt', 'std1-file2.txt']
# Testing on ['std1-file2.txt', 'std1-file6.txt', 'std1-file4.txt', 'std1-file3.txt']
# match_mode=1, mass_tol=2, rt_tol=65, tp=805, fp=62, fn=101, prec=0.928, rec=0.889, f1=0.908, th_prob=1.000
#
# Iteration 14
# Training on ['std1-file3.txt', 'std1-file8.txt', 'std1-file9.txt', 'std1-file1.txt']
# Testing on ['std1-file7.txt', 'std1-file11.txt', 'std1-file5.txt', 'std1-file9.txt']
# match_mode=1, mass_tol=4, rt_tol=85, tp=511, fp=80, fn=33, prec=0.865, rec=0.939, f1=0.900, th_prob=1.000
#
# Iteration 15
# Training on ['std1-file8.txt', 'std1-file5.txt', 'std1-file10.txt', 'std1-file1.txt']
# Testing on ['std1-file11.txt', 'std1-file1.txt', 'std1-file2.txt', 'std1-file5.txt']
# match_mode=1, mass_tol=6, rt_tol=60, tp=824, fp=42, fn=51, prec=0.952, rec=0.942, f1=0.947, th_prob=1.000
#
# Iteration 16
# Training on ['std1-file9.txt', 'std1-file2.txt', 'std1-file7.txt', 'std1-file11.txt']
# Testing on ['std1-file2.txt', 'std1-file1.txt', 'std1-file6.txt', 'std1-file7.txt']
# match_mode=1, mass_tol=4, rt_tol=70, tp=483, fp=42, fn=21, prec=0.920, rec=0.958, f1=0.939, th_prob=1.000
#
# Iteration 17
# Training on ['std1-file7.txt', 'std1-file5.txt', 'std1-file1.txt', 'std1-file10.txt']
# Testing on ['std1-file3.txt', 'std1-file1.txt', 'std1-file2.txt', 'std1-file11.txt']
# match_mode=1, mass_tol=6, rt_tol=70, tp=813, fp=48, fn=56, prec=0.944, rec=0.936, f1=0.940, th_prob=1.000
#
# Iteration 18
# Training on ['std1-file10.txt', 'std1-file11.txt', 'std1-file6.txt', 'std1-file9.txt']
# Testing on ['std1-file8.txt', 'std1-file7.txt', 'std1-file3.txt', 'std1-file2.txt']
# match_mode=1, mass_tol=4, rt_tol=60, tp=469, fp=63, fn=41, prec=0.882, rec=0.920, f1=0.900, th_prob=1.000
#
# Iteration 19
# Training on ['std1-file11.txt', 'std1-file2.txt', 'std1-file7.txt', 'std1-file4.txt']
# Testing on ['std1-file3.txt', 'std1-file7.txt', 'std1-file5.txt', 'std1-file9.txt']
# match_mode=1, mass_tol=4, rt_tol=65, tp=530, fp=53, fn=55, prec=0.909, rec=0.906, f1=0.908, th_prob=1.000
#
# Iteration 20
# Training on ['std1-file3.txt', 'std1-file10.txt', 'std1-file6.txt', 'std1-file1.txt']
# Testing on ['std1-file2.txt', 'std1-file10.txt', 'std1-file3.txt', 'std1-file11.txt']
# match_mode=1, mass_tol=6, rt_tol=50, tp=782, fp=42, fn=55, prec=0.949, rec=0.934, f1=0.942, th_prob=1.000
#
# Iteration 21
# Training on ['std1-file4.txt', 'std1-file9.txt', 'std1-file5.txt', 'std1-file3.txt']
# Testing on ['std1-file9.txt', 'std1-file3.txt', 'std1-file8.txt', 'std1-file5.txt']
# match_mode=1, mass_tol=4, rt_tol=100, tp=848, fp=54, fn=62, prec=0.940, rec=0.932, f1=0.936, th_prob=1.000
#
# Iteration 22
# Training on ['std1-file8.txt', 'std1-file1.txt', 'std1-file5.txt', 'std1-file11.txt']
# Testing on ['std1-file3.txt', 'std1-file8.txt', 'std1-file11.txt', 'std1-file7.txt']
# match_mode=1, mass_tol=4, rt_tol=85, tp=489, fp=87, fn=32, prec=0.849, rec=0.939, f1=0.892, th_prob=1.000
#
# Iteration 23
# Training on ['std1-file6.txt', 'std1-file9.txt', 'std1-file7.txt', 'std1-file2.txt']
# Testing on ['std1-file6.txt', 'std1-file1.txt', 'std1-file4.txt', 'std1-file10.txt']
# match_mode=1, mass_tol=2, rt_tol=70, tp=768, fp=76, fn=95, prec=0.910, rec=0.890, f1=0.900, th_prob=1.000
#
# Iteration 24
# Training on ['std1-file3.txt', 'std1-file11.txt', 'std1-file10.txt', 'std1-file9.txt']
# Testing on ['std1-file4.txt', 'std1-file3.txt', 'std1-file8.txt', 'std1-file2.txt']
# match_mode=1, mass_tol=2, rt_tol=85, tp=790, fp=52, fn=132, prec=0.938, rec=0.857, f1=0.896, th_prob=1.000
#
# Iteration 25
# Training on ['std1-file9.txt', 'std1-file6.txt', 'std1-file7.txt', 'std1-file8.txt']
# Testing on ['std1-file6.txt', 'std1-file11.txt', 'std1-file3.txt', 'std1-file7.txt']
# match_mode=1, mass_tol=4, rt_tol=70, tp=463, fp=50, fn=39, prec=0.903, rec=0.922, f1=0.912, th_prob=1.000
#
# Iteration 26
# Training on ['std1-file1.txt', 'std1-file6.txt', 'std1-file4.txt', 'std1-file9.txt']
# Testing on ['std1-file9.txt', 'std1-file2.txt', 'std1-file5.txt', 'std1-file10.txt']
# match_mode=1, mass_tol=4, rt_tol=40, tp=828, fp=40, fn=61, prec=0.954, rec=0.931, f1=0.943, th_prob=1.000
#
# Iteration 27
# Training on ['std1-file10.txt', 'std1-file6.txt', 'std1-file4.txt', 'std1-file5.txt']
# Testing on ['std1-file11.txt', 'std1-file8.txt', 'std1-file1.txt', 'std1-file2.txt']
# match_mode=1, mass_tol=4, rt_tol=75, tp=766, fp=49, fn=48, prec=0.940, rec=0.941, f1=0.940, th_prob=1.000
#
# Iteration 28
# Training on ['std1-file6.txt', 'std1-file5.txt', 'std1-file9.txt', 'std1-file3.txt']
# Testing on ['std1-file6.txt', 'std1-file11.txt', 'std1-file4.txt', 'std1-file1.txt']
# match_mode=1, mass_tol=4, rt_tol=75, tp=764, fp=63, fn=77, prec=0.924, rec=0.908, f1=0.916, th_prob=1.000
#
# Iteration 29
# Training on ['std1-file8.txt', 'std1-file11.txt', 'std1-file4.txt', 'std1-file3.txt']
# Testing on ['std1-file8.txt', 'std1-file5.txt', 'std1-file6.txt', 'std1-file3.txt']
# match_mode=1, mass_tol=2, rt_tol=65, tp=802, fp=56, fn=73, prec=0.935, rec=0.917, f1=0.926, th_prob=1.000
#
# Saved to pickles/res_match_cluster_4.p

# %% [markdown]
# <h2>Run experiment with 5 random files</h2>

# %%
n_files = 5

# %%
training_list = load_or_create_filelist('pickles/training_list_5.p', combined_list, n_iter, n_files)
# Out:
# ['std1-file4.txt', 'std1-file7.txt', 'std1-file9.txt', 'std1-file5.txt', 'std1-file3.txt']
# ['std1-file6.txt', 'std1-file2.txt', 'std1-file11.txt', 'std1-file9.txt', 'std1-file5.txt']
# ['std1-file5.txt', 'std1-file6.txt', 'std1-file10.txt', 'std1-file2.txt', 'std1-file7.txt']
# ['std1-file9.txt', 'std1-file2.txt', 'std1-file8.txt', 'std1-file1.txt', 'std1-file3.txt']
# ['std1-file5.txt', 'std1-file11.txt', 'std1-file7.txt', 'std1-file3.txt', 'std1-file10.txt']
# ['std1-file10.txt', 'std1-file9.txt', 'std1-file1.txt', 'std1-file8.txt', 'std1-file11.txt']
# ['std1-file6.txt', 'std1-file9.txt', 'std1-file3.txt', 'std1-file2.txt', 'std1-file7.txt']
# ['std1-file1.txt', 'std1-file6.txt', 'std1-file7.txt', 'std1-file2.txt', 'std1-file9.txt']
# ['std1-file2.txt', 'std1-file4.txt', 'std1-file8.txt', 'std1-file7.txt', 'std1-file1.txt']
# ['std1-file11.txt', 'std1-file5.txt', 'std1-file7.txt', 'std1-file10.txt', 'std1-file6.txt']
# ['std1-file3.txt', 'std1-file9.txt', 'std1-file10.txt', 'std1-file1.txt', 'std1-file4.txt']
# ['std1-file11.txt', 'std1-file2.txt', 'std1-file7.txt', 'std1-file10.txt', 'std1-file1.txt']
# ['std1-file2.txt', 'std1-file9.txt', 'std1-file6.txt', 'std1-file5.txt', 'std1-file4.txt']
# ['std1-file1.txt', 'std1-file10.txt', 'std1-file11.txt', 'std1-file6.txt', 'std1-file9.txt']
# ['std1-file7.txt', 'std1-file8.txt', 'std1-file4.txt', 'std1-file5.txt', 'std1-file2.txt']
# ['std1-file6.txt', 'std1-file7.txt', 'std1-file3.txt', 'std1-file11.txt', 'std1-file1.txt']
# ['std1-file10.txt', 'std1-file5.txt', 'std1-file8.txt', 'std1-file7.txt', 'std1-file3.txt']
# ['std1-file1.txt', 'std1-file7.txt', 'std1-file10.txt', 'std1-file9.txt', 'std1-file4.txt']
# ['std1-file9.txt', 'std1-file8.txt', 'std1-file5.txt', 'std1-file1.txt', 'std1-file11.txt']
# ['std1-file9.txt', 'std1-file8.txt', 'std1-file10.txt', 'std1-file4.txt', 'std1-file3.txt']
# ['std1-file1.txt', 'std1-file6.txt', 'std1-file11.txt', 'std1-file8.txt', 'std1-file5.txt']
# ['std1-file3.txt', 'std1-file9.txt', 'std1-file8.txt', 'std1-file10.txt', 'std1-file2.txt']
# ['std1-file1.txt', 'std1-file2.txt', 'std1-file3.txt', 'std1-file4.txt', 'std1-file8.txt']
# ['std1-file11.txt', 'std1-file5.txt', 'std1-file8.txt', 'std1-file9.txt', 'std1-file10.txt']
# ['std1-file7.txt', 'std1-file9.txt', 'std1-file11.txt', 'std1-file10.txt', 'std1-file2.txt']
# ['std1-file7.txt', 'std1-file4.txt', 'std1-file1.txt', 'std1-file9.txt', 'std1-file11.txt']
# ['std1-file7.txt', 'std1-file8.txt', 'std1-file1.txt', 'std1-file3.txt', 'std1-file5.txt']
# ['std1-file4.txt', 'std1-file6.txt', 'std1-file5.txt', 'std1-file3.txt', 'std1-file1.txt']
# ['std1-file2.txt', 'std1-file3.txt', 'std1-file7.txt', 'std1-file8.txt', 'std1-file1.txt']
# ['std1-file3.txt', 'std1-file6.txt', 'std1-file7.txt', 'std1-file8.txt', 'std1-file2.txt']
# Saved to pickles/training_list_5.p

# %%
testing_list = load_or_create_filelist('pickles/testing_list_5.p', combined_list, n_iter, n_files)
# Out:
# ['std1-file8.txt', 'std1-file4.txt', 'std1-file10.txt', 'std1-file6.txt', 'std1-file2.txt']
# ['std1-file6.txt', 'std1-file2.txt', 'std1-file8.txt', 'std1-file3.txt', 'std1-file9.txt']
# ['std1-file3.txt', 'std1-file2.txt', 'std1-file5.txt', 'std1-file10.txt', 'std1-file4.txt']
# ['std1-file11.txt', 'std1-file10.txt', 'std1-file1.txt', 'std1-file9.txt', 'std1-file4.txt']
# ['std1-file6.txt', 'std1-file7.txt', 'std1-file5.txt', 'std1-file11.txt', 'std1-file8.txt']
# ['std1-file7.txt', 'std1-file11.txt', 'std1-file10.txt', 'std1-file8.txt', 'std1-file3.txt']
# ['std1-file2.txt', 'std1-file8.txt', 'std1-file9.txt', 'std1-file6.txt', 'std1-file11.txt']
# ['std1-file11.txt', 'std1-file10.txt', 'std1-file9.txt', 'std1-file1.txt', 'std1-file5.txt']
# ['std1-file7.txt', 'std1-file5.txt', 'std1-file10.txt', 'std1-file3.txt', 'std1-file1.txt']
# ['std1-file6.txt', 'std1-file1.txt', 'std1-file8.txt', 'std1-file5.txt', 'std1-file10.txt']
# ['std1-file3.txt', 'std1-file2.txt', 'std1-file8.txt', 'std1-file9.txt', 'std1-file4.txt']
# ['std1-file8.txt', 'std1-file3.txt', 'std1-file11.txt', 'std1-file5.txt', 'std1-file9.txt']
# ['std1-file4.txt', 'std1-file6.txt', 'std1-file10.txt', 'std1-file8.txt', 'std1-file3.txt']
# ['std1-file8.txt', 'std1-file10.txt', 'std1-file7.txt', 'std1-file3.txt', 'std1-file4.txt']
# ['std1-file4.txt', 'std1-file1.txt', 'std1-file11.txt', 'std1-file6.txt', 'std1-file10.txt']
# ['std1-file2.txt', 'std1-file5.txt', 'std1-file11.txt', 'std1-file10.txt', 'std1-file4.txt']
# ['std1-file4.txt', 'std1-file7.txt', 'std1-file6.txt', 'std1-file5.txt', 'std1-file1.txt']
# ['std1-file10.txt', 'std1-file9.txt', 'std1-file7.txt', 'std1-file11.txt', 'std1-file8.txt']
# ['std1-file5.txt', 'std1-file2.txt', 'std1-file6.txt', 'std1-file4.txt', 'std1-file11.txt']
# ['std1-file11.txt', 'std1-file3.txt', 'std1-file8.txt', 'std1-file9.txt', 'std1-file7.txt']
# ['std1-file9.txt', 'std1-file2.txt', 'std1-file6.txt', 'std1-file4.txt', 'std1-file7.txt']
# ['std1-file10.txt', 'std1-file9.txt', 'std1-file8.txt', 'std1-file5.txt', 'std1-file11.txt']
# ['std1-file10.txt', 'std1-file9.txt', 'std1-file4.txt', 'std1-file6.txt', 'std1-file7.txt']
# ['std1-file3.txt', 'std1-file8.txt', 'std1-file9.txt', 'std1-file6.txt', 'std1-file10.txt']
# ['std1-file3.txt', 'std1-file8.txt', 'std1-file4.txt', 'std1-file2.txt', 'std1-file10.txt']
# ['std1-file5.txt', 'std1-file1.txt', 'std1-file8.txt', 'std1-file11.txt', 'std1-file4.txt']
# ['std1-file9.txt', 'std1-file5.txt', 'std1-file11.txt', 'std1-file6.txt', 'std1-file7.txt']
# ['std1-file4.txt', 'std1-file6.txt', 'std1-file5.txt', 'std1-file1.txt', 'std1-file3.txt']
# ['std1-file11.txt', 'std1-file9.txt', 'std1-file2.txt', 'std1-file7.txt', 'std1-file5.txt']
# ['std1-file4.txt', 'std1-file8.txt', 'std1-file2.txt', 'std1-file3.txt', 'std1-file1.txt']
# Saved to pickles/testing_list_5.p

# %%
exp_results_4a = run_experiment(0, training_list, testing_list, 'pickles/res_match_feature_5.p')
# Out:
# Iteration 0
# Training on ['std1-file4.txt', 'std1-file7.txt', 'std1-file9.txt', 'std1-file5.txt', 'std1-file3.txt']
# Testing on ['std1-file8.txt', 'std1-file4.txt', 'std1-file10.txt', 'std1-file6.txt', 'std1-file2.txt']
# match_mode=0, mass_tol=6, rt_tol=60, tp=1292, fp=131, fn=107, prec=0.908, rec=0.924, f1=0.916, th_prob=1.000
#
# Iteration 1
# Training on ['std1-file6.txt', 'std1-file2.txt', 'std1-file11.txt', 'std1-file9.txt', 'std1-file5.txt']
# Testing on ['std1-file6.txt', 'std1-file2.txt', 'std1-file8.txt', 'std1-file3.txt', 'std1-file9.txt']
# match_mode=0, mass_tol=4, rt_tol=70, tp=1260, fp=142, fn=142, prec=0.899, rec=0.899, f1=0.899, th_prob=1.000
#
# Iteration 2
# Training on ['std1-file5.txt', 'std1-file6.txt', 'std1-file10.txt', 'std1-file2.txt', 'std1-file7.txt']
# Testing on ['std1-file3.txt', 'std1-file2.txt', 'std1-file5.txt', 'std1-file10.txt', 'std1-file4.txt']
# match_mode=0, mass_tol=2, rt_tol=70, tp=1306, fp=164, fn=289, prec=0.888, rec=0.819, f1=0.852, th_prob=1.000
#
# Iteration 3
# Training on ['std1-file9.txt', 'std1-file2.txt', 'std1-file8.txt', 'std1-file1.txt', 'std1-file3.txt']
# Testing on ['std1-file11.txt', 'std1-file10.txt', 'std1-file1.txt', 'std1-file9.txt', 'std1-file4.txt']
# match_mode=0, mass_tol=4, rt_tol=85, tp=1338, fp=166, fn=118, prec=0.890, rec=0.919, f1=0.904, th_prob=1.000
#
# Iteration 4
# Training on ['std1-file5.txt', 'std1-file11.txt', 'std1-file7.txt', 'std1-file3.txt', 'std1-file10.txt']
# Testing on ['std1-file6.txt', 'std1-file7.txt', 'std1-file5.txt', 'std1-file11.txt', 'std1-file8.txt']
# match_mode=0, mass_tol=4, rt_tol=65, tp=851, fp=123, fn=107, prec=0.874, rec=0.888, f1=0.881, th_prob=1.000
#
# Iteration 5
# Training on ['std1-file10.txt', 'std1-file9.txt', 'std1-file1.txt', 'std1-file8.txt', 'std1-file11.txt']
# Testing on ['std1-file7.txt', 'std1-file11.txt', 'std1-file10.txt', 'std1-file8.txt', 'std1-file3.txt']
# match_mode=0, mass_tol=2, rt_tol=85, tp=905, fp=161, fn=65, prec=0.849, rec=0.933, f1=0.889, th_prob=1.000
#
# Iteration 6
# Training on ['std1-file6.txt', 'std1-file9.txt', 'std1-file3.txt', 'std1-file2.txt', 'std1-file7.txt']
# Testing on ['std1-file2.txt', 'std1-file8.txt', 'std1-file9.txt', 'std1-file6.txt', 'std1-file11.txt']
# match_mode=0, mass_tol=4, rt_tol=65, tp=1211, fp=119, fn=128, prec=0.911, rec=0.904, f1=0.907, th_prob=1.000
#
# Iteration 7
# Training on ['std1-file1.txt', 'std1-file6.txt', 'std1-file7.txt', 'std1-file2.txt', 'std1-file9.txt']
# Testing on ['std1-file11.txt', 'std1-file10.txt', 'std1-file9.txt', 'std1-file1.txt', 'std1-file5.txt']
# match_mode=0, mass_tol=4, rt_tol=70, tp=1314, fp=149, fn=146, prec=0.898, rec=0.900, f1=0.899, th_prob=1.000
#
# Iteration 8
# Training on ['std1-file2.txt', 'std1-file4.txt', 'std1-file8.txt', 'std1-file7.txt', 'std1-file1.txt']
# Testing on ['std1-file7.txt', 'std1-file5.txt', 'std1-file10.txt', 'std1-file3.txt', 'std1-file1.txt']
# match_mode=0, mass_tol=4, rt_tol=65, tp=944, fp=165, fn=104, prec=0.851, rec=0.901, f1=0.875, th_prob=1.000
#
# Iteration 9
# Training on ['std1-file11.txt', 'std1-file5.txt', 'std1-file7.txt', 'std1-file10.txt', 'std1-file6.txt']
# Testing on ['std1-file6.txt', 'std1-file1.txt', 'std1-file8.txt', 'std1-file5.txt', 'std1-file10.txt']
# match_mode=0, mass_tol=2, rt_tol=65, tp=1240, fp=126, fn=169, prec=0.908, rec=0.880, f1=0.894, th_prob=1.000
#
# Iteration 10
# Training on ['std1-file3.txt', 'std1-file9.txt', 'std1-file10.txt', 'std1-file1.txt', 'std1-file4.txt']
# Testing on ['std1-file3.txt', 'std1-file2.txt', 'std1-file8.txt', 'std1-file9.txt', 'std1-file4.txt']
# match_mode=0, mass_tol=4, rt_tol=80, tp=1411, fp=160, fn=120, prec=0.898, rec=0.922, f1=0.910, th_prob=1.000
#
# Iteration 11
# Training on ['std1-file11.txt', 'std1-file2.txt', 'std1-file7.txt', 'std1-file10.txt', 'std1-file1.txt']
# Testing on ['std1-file8.txt', 'std1-file3.txt', 'std1-file11.txt', 'std1-file5.txt', 'std1-file9.txt']
# match_mode=0, mass_tol=4, rt_tol=65, tp=1386, fp=128, fn=99, prec=0.915, rec=0.933, f1=0.924, th_prob=1.000
#
# Iteration 12
# Training on ['std1-file2.txt', 'std1-file9.txt', 'std1-file6.txt', 'std1-file5.txt', 'std1-file4.txt']
# Testing on ['std1-file4.txt', 'std1-file6.txt', 'std1-file10.txt', 'std1-file8.txt', 'std1-file3.txt']
# match_mode=0, mass_tol=4, rt_tol=60, tp=1382, fp=125, fn=108, prec=0.917, rec=0.928, f1=0.922, th_prob=1.000
#
# Iteration 13
# Training on ['std1-file1.txt', 'std1-file10.txt', 'std1-file11.txt', 'std1-file6.txt', 'std1-file9.txt']
# Testing on ['std1-file8.txt', 'std1-file10.txt', 'std1-file7.txt', 'std1-file3.txt', 'std1-file4.txt']
# match_mode=0, mass_tol=4, rt_tol=70, tp=1006, fp=118, fn=62, prec=0.895, rec=0.942, f1=0.918, th_prob=1.000
#
# Iteration 14
# Training on ['std1-file7.txt', 'std1-file8.txt', 'std1-file4.txt', 'std1-file5.txt', 'std1-file2.txt']
# Testing on ['std1-file4.txt', 'std1-file1.txt', 'std1-file11.txt', 'std1-file6.txt', 'std1-file10.txt']
# match_mode=0, mass_tol=4, rt_tol=60, tp=1261, fp=173, fn=146, prec=0.879, rec=0.896, f1=0.888, th_prob=1.000
#
# Iteration 15
# Training on ['std1-file6.txt', 'std1-file7.txt', 'std1-file3.txt', 'std1-file11.txt', 'std1-file1.txt']
# Testing on ['std1-file2.txt', 'std1-file5.txt', 'std1-file11.txt', 'std1-file10.txt', 'std1-file4.txt']
# match_mode=0, mass_tol=4, rt_tol=70, tp=1372, fp=156, fn=122, prec=0.898, rec=0.918, f1=0.908, th_prob=1.000
#
# Iteration 16
# Training on ['std1-file10.txt', 'std1-file5.txt', 'std1-file8.txt', 'std1-file7.txt', 'std1-file3.txt']
# Testing on ['std1-file4.txt', 'std1-file7.txt', 'std1-file6.txt', 'std1-file5.txt', 'std1-file1.txt']
# match_mode=0, mass_tol=4, rt_tol=65, tp=929, fp=145, fn=109, prec=0.865, rec=0.895, f1=0.880, th_prob=1.000
#
# Iteration 17
# Training on ['std1-file1.txt', 'std1-file7.txt', 'std1-file10.txt', 'std1-file9.txt', 'std1-file4.txt']
# Testing on ['std1-file10.txt', 'std1-file9.txt', 'std1-file7.txt', 'std1-file11.txt', 'std1-file8.txt']
# match_mode=0, mass_tol=6, rt_tol=55, tp=838, fp=105, fn=106, prec=0.889, rec=0.888, f1=0.888, th_prob=1.000
#
# Iteration 18
# Training on ['std1-file9.txt', 'std1-file8.txt', 'std1-file5.txt', 'std1-file1.txt', 'std1-file11.txt']
# Testing on ['std1-file5.txt', 'std1-file2.txt', 'std1-file6.txt', 'std1-file4.txt', 'std1-file11.txt']
# match_mode=0, mass_tol=6, rt_tol=90, tp=1306, fp=176, fn=148, prec=0.881, rec=0.898, f1=0.890, th_prob=1.000
#
# Iteration 19
# Training on ['std1-file9.txt', 'std1-file8.txt', 'std1-file10.txt', 'std1-file4.txt', 'std1-file3.txt']
# Testing on ['std1-file11.txt', 'std1-file3.txt', 'std1-file8.txt', 'std1-file9.txt', 'std1-file7.txt']
# match_mode=0, mass_tol=4, rt_tol=75, tp=902, fp=149, fn=85, prec=0.858, rec=0.914, f1=0.885, th_prob=1.000
#
# Iteration 20
# Training on ['std1-file1.txt', 'std1-file6.txt', 'std1-file11.txt', 'std1-file8.txt', 'std1-file5.txt']
# Testing on ['std1-file9.txt', 'std1-file2.txt', 'std1-file6.txt', 'std1-file4.txt', 'std1-file7.txt']
# match_mode=0, mass_tol=4, rt_tol=85, tp=888, fp=175, fn=106, prec=0.835, rec=0.893, f1=0.863, th_prob=1.000
#
# Iteration 21
# Training on ['std1-file3.txt', 'std1-file9.txt', 'std1-file8.txt', 'std1-file10.txt', 'std1-file2.txt']
# Testing on ['std1-file10.txt', 'std1-file9.txt', 'std1-file8.txt', 'std1-file5.txt', 'std1-file11.txt']
# match_mode=0, mass_tol=4, rt_tol=80, tp=1329, fp=125, fn=102, prec=0.914, rec=0.929, f1=0.921, th_prob=1.000
#
# Iteration 22
# Training on ['std1-file1.txt', 'std1-file2.txt', 'std1-file3.txt', 'std1-file4.txt', 'std1-file8.txt']
# Testing on ['std1-file10.txt', 'std1-file9.txt', 'std1-file4.txt', 'std1-file6.txt', 'std1-file7.txt']
# match_mode=0, mass_tol=4, rt_tol=55, tp=906, fp=123, fn=94, prec=0.880, rec=0.906, f1=0.893, th_prob=1.000
#
# Iteration 23
# Training on ['std1-file11.txt', 'std1-file5.txt', 'std1-file8.txt', 'std1-file9.txt', 'std1-file10.txt']
# Testing on ['std1-file3.txt', 'std1-file8.txt', 'std1-file9.txt', 'std1-file6.txt', 'std1-file10.txt']
# match_mode=0, mass_tol=4, rt_tol=75, tp=1303, fp=140, fn=102, prec=0.903, rec=0.927, f1=0.915, th_prob=1.000
#
# Iteration 24
# Training on ['std1-file7.txt', 'std1-file9.txt', 'std1-file11.txt', 'std1-file10.txt', 'std1-file2.txt']
# Testing on ['std1-file3.txt', 'std1-file8.txt', 'std1-file4.txt', 'std1-file2.txt', 'std1-file10.txt']
# match_mode=0, mass_tol=4, rt_tol=70, tp=1399, fp=123, fn=96, prec=0.919, rec=0.936, f1=0.927, th_prob=1.000
#
# Iteration 25
# Training on ['std1-file7.txt', 'std1-file4.txt', 'std1-file1.txt', 'std1-file9.txt', 'std1-file11.txt']
# Testing on ['std1-file5.txt', 'std1-file1.txt', 'std1-file8.txt', 'std1-file11.txt', 'std1-file4.txt']
# match_mode=0, mass_tol=4, rt_tol=60, tp=1366, fp=136, fn=122, prec=0.909, rec=0.918, f1=0.914, th_prob=1.000
#
# Iteration 26
# Training on ['std1-file7.txt', 'std1-file8.txt', 'std1-file1.txt', 'std1-file3.txt', 'std1-file5.txt']
# Testing on ['std1-file9.txt', 'std1-file5.txt', 'std1-file11.txt', 'std1-file6.txt', 'std1-file7.txt']
# match_mode=0, mass_tol=4, rt_tol=60, tp=866, fp=112, fn=116, prec=0.885, rec=0.882, f1=0.884, th_prob=1.000
#
# Iteration 27
# Training on ['std1-file4.txt', 'std1-file6.txt', 'std1-file5.txt', 'std1-file3.txt', 'std1-file1.txt']
# Testing on ['std1-file4.txt', 'std1-file6.txt', 'std1-file5.txt', 'std1-file1.txt', 'std1-file3.txt']
# match_mode=0, mass_tol=4, rt_tol=90, tp=1443, fp=179, fn=129, prec=0.890, rec=0.918, f1=0.904, th_prob=1.000
#
# Iteration 28
# Training on ['std1-file2.txt', 'std1-file3.txt', 'std1-file7.txt', 'std1-file8.txt', 'std1-file1.txt']
# Testing on ['std1-file11.txt', 'std1-file9.txt', 'std1-file2.txt', 'std1-file7.txt', 'std1-file5.txt']
# match_mode=0, mass_tol=4, rt_tol=70, tp=895, fp=127, fn=109, prec=0.876, rec=0.891, f1=0.884, th_prob=1.000
#
# Iteration 29
# Training on ['std1-file3.txt', 'std1-file6.txt', 'std1-file7.txt', 'std1-file8.txt', 'std1-file2.txt']
# Testing on ['std1-file4.txt', 'std1-file8.txt', 'std1-file2.txt', 'std1-file3.txt', 'std1-file1.txt']
# match_mode=0, mass_tol=4, rt_tol=70, tp=1385, fp=153, fn=130, prec=0.901, rec=0.914, f1=0.907, th_prob=1.000
#
# Saved to pickles/res_match_feature_5.p

# %%
exp_results_4b = run_experiment(1, training_list, testing_list, 'pickles/res_match_cluster_5.p')
# Out:
# Iteration 0
# Training on ['std1-file4.txt', 'std1-file7.txt', 'std1-file9.txt', 'std1-file5.txt', 'std1-file3.txt']
# Testing on ['std1-file8.txt', 'std1-file4.txt', 'std1-file10.txt', 'std1-file6.txt', 'std1-file2.txt']
# match_mode=1, mass_tol=4, rt_tol=60, tp=1269, fp=90, fn=130, prec=0.934, rec=0.907, f1=0.920, th_prob=1.000
#
# Iteration 1
# Training on ['std1-file6.txt', 'std1-file2.txt', 'std1-file11.txt', 'std1-file9.txt', 'std1-file5.txt']
# Testing on ['std1-file6.txt', 'std1-file2.txt', 'std1-file8.txt', 'std1-file3.txt', 'std1-file9.txt']
# match_mode=1, mass_tol=4, rt_tol=65, tp=1298, fp=83, fn=104, prec=0.940, rec=0.926, f1=0.933, th_prob=1.000
#
# Iteration 2
# Training on ['std1-file5.txt', 'std1-file6.txt', 'std1-file10.txt', 'std1-file2.txt', 'std1-file7.txt']
# Testing on ['std1-file3.txt', 'std1-file2.txt', 'std1-file5.txt', 'std1-file10.txt', 'std1-file4.txt']
# match_mode=1, mass_tol=4, rt_tol=60, tp=1460, fp=112, fn=135, prec=0.929, rec=0.915, f1=0.922, th_prob=1.000
#
# Iteration 3
# Training on ['std1-file9.txt', 'std1-file2.txt', 'std1-file8.txt', 'std1-file1.txt', 'std1-file3.txt']
# Testing on ['std1-file11.txt', 'std1-file10.txt', 'std1-file1.txt', 'std1-file9.txt', 'std1-file4.txt']
# match_mode=1, mass_tol=4, rt_tol=70, tp=1328, fp=103, fn=128, prec=0.928, rec=0.912, f1=0.920, th_prob=1.000
#
# Iteration 4
# Training on ['std1-file5.txt', 'std1-file11.txt', 'std1-file7.txt', 'std1-file3.txt', 'std1-file10.txt']
# Testing on ['std1-file6.txt', 'std1-file7.txt', 'std1-file5.txt', 'std1-file11.txt', 'std1-file8.txt']
# match_mode=1, mass_tol=2, rt_tol=65, tp=867, fp=81, fn=91, prec=0.915, rec=0.905, f1=0.910, th_prob=1.000
#
# Iteration 5
# Training on ['std1-file10.txt', 'std1-file9.txt', 'std1-file1.txt', 'std1-file8.txt', 'std1-file11.txt']
# Testing on ['std1-file7.txt', 'std1-file11.txt', 'std1-file10.txt', 'std1-file8.txt', 'std1-file3.txt']
# match_mode=1, mass_tol=6, rt_tol=70, tp=881, fp=101, fn=89, prec=0.897, rec=0.908, f1=0.903, th_prob=1.000
#
# Iteration 6
# Training on ['std1-file6.txt', 'std1-file9.txt', 'std1-file3.txt', 'std1-file2.txt', 'std1-file7.txt']
# Testing on ['std1-file2.txt', 'std1-file8.txt', 'std1-file9.txt', 'std1-file6.txt', 'std1-file11.txt']
# match_mode=1, mass_tol=4, rt_tol=65, tp=1253, fp=70, fn=86, prec=0.947, rec=0.936, f1=0.941, th_prob=1.000
#
# Iteration 7
# Training on ['std1-file1.txt', 'std1-file6.txt', 'std1-file7.txt', 'std1-file2.txt', 'std1-file9.txt']
# Testing on ['std1-file11.txt', 'std1-file10.txt', 'std1-file9.txt', 'std1-file1.txt', 'std1-file5.txt']
# match_mode=1, mass_tol=4, rt_tol=70, tp=1354, fp=74, fn=106, prec=0.948, rec=0.927, f1=0.938, th_prob=1.000
#
# Iteration 8
# Training on ['std1-file2.txt', 'std1-file4.txt', 'std1-file8.txt', 'std1-file7.txt', 'std1-file1.txt']
# Testing on ['std1-file7.txt', 'std1-file5.txt', 'std1-file10.txt', 'std1-file3.txt', 'std1-file1.txt']
# match_mode=1, mass_tol=4, rt_tol=60, tp=935, fp=99, fn=113, prec=0.904, rec=0.892, f1=0.898, th_prob=1.000
#
# Iteration 9
# Training on ['std1-file11.txt', 'std1-file5.txt', 'std1-file7.txt', 'std1-file10.txt', 'std1-file6.txt']
# Testing on ['std1-file6.txt', 'std1-file1.txt', 'std1-file8.txt', 'std1-file5.txt', 'std1-file10.txt']
# match_mode=1, mass_tol=4, rt_tol=65, tp=1296, fp=82, fn=113, prec=0.940, rec=0.920, f1=0.930, th_prob=1.000
#
# Iteration 10
# Training on ['std1-file3.txt', 'std1-file9.txt', 'std1-file10.txt', 'std1-file1.txt', 'std1-file4.txt']
# Testing on ['std1-file3.txt', 'std1-file2.txt', 'std1-file8.txt', 'std1-file9.txt', 'std1-file4.txt']
# match_mode=1, mass_tol=6, rt_tol=80, tp=1420, fp=93, fn=111, prec=0.939, rec=0.927, f1=0.933, th_prob=1.000
#
# Iteration 11
# Training on ['std1-file11.txt', 'std1-file2.txt', 'std1-file7.txt', 'std1-file10.txt', 'std1-file1.txt']
# Testing on ['std1-file8.txt', 'std1-file3.txt', 'std1-file11.txt', 'std1-file5.txt', 'std1-file9.txt']
# match_mode=1, mass_tol=4, rt_tol=65, tp=1372, fp=85, fn=113, prec=0.942, rec=0.924, f1=0.933, th_prob=1.000
#
# Iteration 12
# Training on ['std1-file2.txt', 'std1-file9.txt', 'std1-file6.txt', 'std1-file5.txt', 'std1-file4.txt']
# Testing on ['std1-file4.txt', 'std1-file6.txt', 'std1-file10.txt', 'std1-file8.txt', 'std1-file3.txt']
# match_mode=1, mass_tol=4, rt_tol=50, tp=1352, fp=88, fn=138, prec=0.939, rec=0.907, f1=0.923, th_prob=1.000
#
# Iteration 13
# Training on ['std1-file1.txt', 'std1-file10.txt', 'std1-file11.txt', 'std1-file6.txt', 'std1-file9.txt']
# Testing on ['std1-file8.txt', 'std1-file10.txt', 'std1-file7.txt', 'std1-file3.txt', 'std1-file4.txt']
# match_mode=1, mass_tol=6, rt_tol=70, tp=966, fp=105, fn=102, prec=0.902, rec=0.904, f1=0.903, th_prob=1.000
#
# Iteration 14
# Training on ['std1-file7.txt', 'std1-file8.txt', 'std1-file4.txt', 'std1-file5.txt', 'std1-file2.txt']
# Testing on ['std1-file4.txt', 'std1-file1.txt', 'std1-file11.txt', 'std1-file6.txt', 'std1-file10.txt']
# match_mode=1, mass_tol=4, rt_tol=70, tp=1290, fp=106, fn=117, prec=0.924, rec=0.917, f1=0.920, th_prob=1.000
#
# Iteration 15
# Training on ['std1-file6.txt', 'std1-file7.txt', 'std1-file3.txt', 'std1-file11.txt', 'std1-file1.txt']
# Testing on ['std1-file2.txt', 'std1-file5.txt', 'std1-file11.txt', 'std1-file10.txt', 'std1-file4.txt']
# match_mode=1, mass_tol=4, rt_tol=70, tp=1378, fp=99, fn=116, prec=0.933, rec=0.922, f1=0.928, th_prob=1.000
#
# Iteration 16
# Training on ['std1-file10.txt', 'std1-file5.txt', 'std1-file8.txt', 'std1-file7.txt', 'std1-file3.txt']
# Testing on ['std1-file4.txt', 'std1-file7.txt', 'std1-file6.txt', 'std1-file5.txt', 'std1-file1.txt']
# match_mode=1, mass_tol=4, rt_tol=65, tp=947, fp=101, fn=91, prec=0.904, rec=0.912, f1=0.908, th_prob=1.000
#
# Iteration 17
# Training on ['std1-file1.txt', 'std1-file7.txt', 'std1-file10.txt', 'std1-file9.txt', 'std1-file4.txt']
# Testing on ['std1-file10.txt', 'std1-file9.txt', 'std1-file7.txt', 'std1-file11.txt', 'std1-file8.txt']
# match_mode=1, mass_tol=6, rt_tol=60, tp=859, fp=72, fn=85, prec=0.923, rec=0.910, f1=0.916, th_prob=1.000
#
# Iteration 18
# Training on ['std1-file9.txt', 'std1-file8.txt', 'std1-file5.txt', 'std1-file1.txt', 'std1-file11.txt']
# Testing on ['std1-file5.txt', 'std1-file2.txt', 'std1-file6.txt', 'std1-file4.txt', 'std1-file11.txt']
# match_mode=1, mass_tol=4, rt_tol=90, tp=1337, fp=105, fn=117, prec=0.927, rec=0.920, f1=0.923, th_prob=1.000
#
# Iteration 19
# Training on ['std1-file9.txt', 'std1-file8.txt', 'std1-file10.txt', 'std1-file4.txt', 'std1-file3.txt']
# Testing on ['std1-file11.txt', 'std1-file3.txt', 'std1-file8.txt', 'std1-file9.txt', 'std1-file7.txt']
# match_mode=1, mass_tol=4, rt_tol=65, tp=911, fp=88, fn=76, prec=0.912, rec=0.923, f1=0.917, th_prob=1.000
#
# Iteration 20
# Training on ['std1-file1.txt', 'std1-file6.txt', 'std1-file11.txt', 'std1-file8.txt', 'std1-file5.txt']
# Testing on ['std1-file9.txt', 'std1-file2.txt', 'std1-file6.txt', 'std1-file4.txt', 'std1-file7.txt']
# match_mode=1, mass_tol=4, rt_tol=85, tp=928, fp=120, fn=66, prec=0.885, rec=0.934, f1=0.909, th_prob=1.000
#
# Iteration 21
# Training on ['std1-file3.txt', 'std1-file9.txt', 'std1-file8.txt', 'std1-file10.txt', 'std1-file2.txt']
# Testing on ['std1-file10.txt', 'std1-file9.txt', 'std1-file8.txt', 'std1-file5.txt', 'std1-file11.txt']
# match_mode=1, mass_tol=4, rt_tol=80, tp=1336, fp=77, fn=95, prec=0.946, rec=0.934, f1=0.940, th_prob=1.000
#
# Iteration 22
# Training on ['std1-file1.txt', 'std1-file2.txt', 'std1-file3.txt', 'std1-file4.txt', 'std1-file8.txt']
# Testing on ['std1-file10.txt', 'std1-file9.txt', 'std1-file4.txt', 'std1-file6.txt', 'std1-file7.txt']
# match_mode=1, mass_tol=6, rt_tol=80, tp=921, fp=121, fn=79, prec=0.884, rec=0.921, f1=0.902, th_prob=1.000
#
# Iteration 23
# Training on ['std1-file11.txt', 'std1-file5.txt', 'std1-file8.txt', 'std1-file9.txt', 'std1-file10.txt']
# Testing on ['std1-file3.txt', 'std1-file8.txt', 'std1-file9.txt', 'std1-file6.txt', 'std1-file10.txt']
# match_mode=1, mass_tol=4, rt_tol=55, tp=1297, fp=86, fn=108, prec=0.938, rec=0.923, f1=0.930, th_prob=1.000
#
# Iteration 24
# Training on ['std1-file7.txt', 'std1-file9.txt', 'std1-file11.txt', 'std1-file10.txt', 'std1-file2.txt']
# Testing on ['std1-file3.txt', 'std1-file8.txt', 'std1-file4.txt', 'std1-file2.txt', 'std1-file10.txt']
# match_mode=1, mass_tol=4, rt_tol=70, tp=1377, fp=82, fn=118, prec=0.944, rec=0.921, f1=0.932, th_prob=1.000
#
# Iteration 25
# Training on ['std1-file7.txt', 'std1-file4.txt', 'std1-file1.txt', 'std1-file9.txt', 'std1-file11.txt']
# Testing on ['std1-file5.txt', 'std1-file1.txt', 'std1-file8.txt', 'std1-file11.txt', 'std1-file4.txt']
# match_mode=1, mass_tol=4, rt_tol=60, tp=1359, fp=100, fn=129, prec=0.931, rec=0.913, f1=0.922, th_prob=1.000
#
# Iteration 26
# Training on ['std1-file7.txt', 'std1-file8.txt', 'std1-file1.txt', 'std1-file3.txt', 'std1-file5.txt']
# Testing on ['std1-file9.txt', 'std1-file5.txt', 'std1-file11.txt', 'std1-file6.txt', 'std1-file7.txt']
# match_mode=1, mass_tol=4, rt_tol=70, tp=924, fp=69, fn=58, prec=0.931, rec=0.941, f1=0.936, th_prob=1.000
#
# Iteration 27
# Training on ['std1-file4.txt', 'std1-file6.txt', 'std1-file5.txt', 'std1-file3.txt', 'std1-file1.txt']
# Testing on ['std1-file4.txt', 'std1-file6.txt', 'std1-file5.txt', 'std1-file1.txt', 'std1-file3.txt']
# match_mode=1, mass_tol=6, rt_tol=70, tp=1428, fp=135, fn=144, prec=0.914, rec=0.908, f1=0.911, th_prob=1.000
#
# Iteration 28
# Training on ['std1-file2.txt', 'std1-file3.txt', 'std1-file7.txt', 'std1-file8.txt', 'std1-file1.txt']
# Testing on ['std1-file11.txt', 'std1-file9.txt', 'std1-file2.txt', 'std1-file7.txt', 'std1-file5.txt']
# match_mode=1, mass_tol=4, rt_tol=70, tp=946, fp=69, fn=58, prec=0.932, rec=0.942, f1=0.937, th_prob=1.000
#
# Iteration 29
# Training on ['std1-file3.txt', 'std1-file6.txt', 'std1-file7.txt', 'std1-file8.txt', 'std1-file2.txt']
# Testing on ['std1-file4.txt', 'std1-file8.txt', 'std1-file2.txt', 'std1-file3.txt', 'std1-file1.txt']
# match_mode=1, mass_tol=4, rt_tol=70, tp=1391, fp=103, fn=124, prec=0.931, rec=0.918, f1=0.925, th_prob=1.000
#
# Saved to pickles/res_match_cluster_5.p

# %% [markdown]
# <h2>Run experiment with 6 random files</h2>

# %%
n_files = 6

# %%
training_list = load_or_create_filelist('pickles/training_list_6.p', combined_list, n_iter, n_files)
# Out:
# ['std1-file8.txt', 'std1-file6.txt', 'std1-file3.txt', 'std1-file7.txt', 'std1-file4.txt', 'std1-file5.txt']
# ['std1-file9.txt', 'std1-file6.txt', 'std1-file8.txt', 'std1-file4.txt', 'std1-file11.txt', 'std1-file3.txt']
# ['std1-file4.txt', 'std1-file6.txt', 'std1-file7.txt', 'std1-file9.txt', 'std1-file3.txt', 'std1-file10.txt']
# ['std1-file1.txt', 'std1-file2.txt', 'std1-file3.txt', 'std1-file9.txt', 'std1-file4.txt', 'std1-file11.txt']
# ['std1-file2.txt', 'std1-file8.txt', 'std1-file1.txt', 'std1-file6.txt', 'std1-file11.txt', 'std1-file4.txt']
# ['std1-file4.txt', 'std1-file1.txt', 'std1-file5.txt', 'std1-file8.txt', 'std1-file3.txt', 'std1-file9.txt']
# ['std1-file6.txt', 'std1-file1.txt', 'std1-file4.txt', 'std1-file3.txt', 'std1-file9.txt', 'std1-file8.txt']
# ['std1-file10.txt', 'std1-file1.txt', 'std1-file2.txt', 'std1-file8.txt', 'std1-file5.txt', 'std1-file6.txt']
# ['std1-file2.txt', 'std1-file4.txt', 'std1-file7.txt', 'std1-file3.txt', 'std1-file8.txt', 'std1-file1.txt']
# ['std1-file8.txt', 'std1-file6.txt', 'std1-file4.txt', 'std1-file7.txt', 'std1-file11.txt', 'std1-file2.txt']
# ['std1-file9.txt', 'std1-file6.txt', 'std1-file4.txt', 'std1-file10.txt', 'std1-file1.txt', 'std1-file5.txt']
# ['std1-file10.txt', 'std1-file11.txt', 'std1-file9.txt', 'std1-file8.txt', 'std1-file1.txt', 'std1-file3.txt']
# ['std1-file7.txt', 'std1-file11.txt', 'std1-file4.txt', 'std1-file2.txt', 'std1-file1.txt', 'std1-file6.txt']
# ['std1-file9.txt', 'std1-file6.txt', 'std1-file2.txt', 'std1-file7.txt', 'std1-file10.txt', 'std1-file8.txt']
# ['std1-file8.txt', 'std1-file10.txt', 'std1-file7.txt', 'std1-file6.txt', 'std1-file2.txt', 'std1-file4.txt']
# ['std1-file6.txt', 'std1-file11.txt', 'std1-file10.txt', 'std1-file5.txt', 'std1-file7.txt', 'std1-file4.txt']
# ['std1-file9.txt', 'std1-file5.txt', 'std1-file8.txt', 'std1-file4.txt', 'std1-file11.txt', 'std1-file3.txt']
# ['std1-file2.txt', 'std1-file11.txt', 'std1-file10.txt', 'std1-file3.txt', 'std1-file7.txt', 'std1-file4.txt']
# ['std1-file11.txt', 'std1-file8.txt', 'std1-file2.txt', 'std1-file4.txt', 'std1-file1.txt', 'std1-file9.txt']
# ['std1-file4.txt', 'std1-file3.txt', 'std1-file11.txt', 'std1-file10.txt', 'std1-file2.txt', 'std1-file8.txt']
# ['std1-file7.txt', 'std1-file9.txt', 'std1-file4.txt', 'std1-file2.txt', 'std1-file8.txt', 'std1-file6.txt']
# ['std1-file11.txt', 'std1-file1.txt', 'std1-file9.txt', 'std1-file3.txt', 'std1-file7.txt', 'std1-file8.txt']
# ['std1-file5.txt', 'std1-file3.txt', 'std1-file6.txt', 'std1-file1.txt', 'std1-file7.txt', 'std1-file2.txt']
# ['std1-file9.txt', 'std1-file6.txt', 'std1-file2.txt', 'std1-file10.txt', 'std1-file3.txt', 'std1-file8.txt']
# ['std1-file2.txt', 'std1-file11.txt', 'std1-file9.txt', 'std1-file5.txt', 'std1-file8.txt', 'std1-file6.txt']
# ['std1-file1.txt', 'std1-file5.txt', 'std1-file11.txt', 'std1-file10.txt', 'std1-file2.txt', 'std1-file9.txt']
# ['std1-file1.txt', 'std1-file10.txt', 'std1-file9.txt', 'std1-file11.txt', 'std1-file4.txt', 'std1-file7.txt']
# ['std1-file8.txt', 'std1-file9.txt', 'std1-file3.txt', 'std1-file2.txt', 'std1-file10.txt', 'std1-file1.txt']
# ['std1-file1.txt', 'std1-file5.txt', 'std1-file3.txt', 'std1-file9.txt', 'std1-file10.txt', 'std1-file6.txt']
# ['std1-file7.txt', 'std1-file5.txt', 'std1-file8.txt', 'std1-file3.txt', 'std1-file1.txt', 'std1-file11.txt']
# Saved to pickles/training_list_6.p

# %%
testing_list = load_or_create_filelist('pickles/testing_list_6.p', combined_list, n_iter, n_files)
# Out:
# ['std1-file6.txt', 'std1-file8.txt', 'std1-file3.txt', 'std1-file7.txt', 'std1-file5.txt', 'std1-file10.txt']
# ['std1-file6.txt', 'std1-file10.txt', 'std1-file9.txt', 'std1-file4.txt', 'std1-file8.txt', 'std1-file3.txt']
# ['std1-file3.txt', 'std1-file1.txt', 'std1-file2.txt', 'std1-file5.txt', 'std1-file10.txt', 'std1-file7.txt']
# ['std1-file10.txt', 'std1-file4.txt', 'std1-file11.txt', 'std1-file1.txt', 'std1-file3.txt', 'std1-file6.txt']
# ['std1-file2.txt', 'std1-file8.txt', 'std1-file6.txt', 'std1-file4.txt', 'std1-file3.txt', 'std1-file10.txt']
# ['std1-file6.txt', 'std1-file3.txt', 'std1-file8.txt', 'std1-file9.txt', 'std1-file5.txt', 'std1-file2.txt']
# ['std1-file4.txt', 'std1-file2.txt', 'std1-file10.txt', 'std1-file3.txt', 'std1-file7.txt', 'std1-file11.txt']
# ['std1-file9.txt', 'std1-file10.txt', 'std1-file7.txt', 'std1-file4.txt', 'std1-file2.txt', 'std1-file5.txt']
# ['std1-file9.txt', 'std1-file5.txt', 'std1-file7.txt', 'std1-file10.txt', 'std1-file3.txt', 'std1-file8.txt']
# ['std1-file6.txt', 'std1-file11.txt', 'std1-file3.txt', 'std1-file1.txt', 'std1-file8.txt', 'std1-file4.txt']
# ['std1-file1.txt', 'std1-file4.txt', 'std1-file9.txt', 'std1-file5.txt', 'std1-file6.txt', 'std1-file7.txt']
# ['std1-file11.txt', 'std1-file9.txt', 'std1-file5.txt', 'std1-file8.txt', 'std1-file7.txt', 'std1-file4.txt']
# ['std1-file4.txt', 'std1-file8.txt', 'std1-file9.txt', 'std1-file11.txt', 'std1-file1.txt', 'std1-file10.txt']
# ['std1-file8.txt', 'std1-file4.txt', 'std1-file7.txt', 'std1-file3.txt', 'std1-file10.txt', 'std1-file2.txt']
# ['std1-file11.txt', 'std1-file9.txt', 'std1-file5.txt', 'std1-file6.txt', 'std1-file10.txt', 'std1-file7.txt']
# ['std1-file8.txt', 'std1-file11.txt', 'std1-file6.txt', 'std1-file9.txt', 'std1-file10.txt', 'std1-file2.txt']
# ['std1-file11.txt', 'std1-file5.txt', 'std1-file7.txt', 'std1-file1.txt', 'std1-file10.txt', 'std1-file3.txt']
# ['std1-file4.txt', 'std1-file7.txt', 'std1-file10.txt', 'std1-file2.txt', 'std1-file9.txt', 'std1-file1.txt']
# ['std1-file1.txt', 'std1-file10.txt', 'std1-file4.txt', 'std1-file9.txt', 'std1-file7.txt', 'std1-file3.txt']
# ['std1-file4.txt', 'std1-file7.txt', 'std1-file9.txt', 'std1-file8.txt', 'std1-file5.txt', 'std1-file1.txt']
# ['std1-file2.txt', 'std1-file9.txt', 'std1-file7.txt', 'std1-file1.txt', 'std1-file4.txt', 'std1-file5.txt']
# ['std1-file3.txt', 'std1-file10.txt', 'std1-file9.txt', 'std1-file2.txt', 'std1-file7.txt', 'std1-file5.txt']
# ['std1-file7.txt', 'std1-file4.txt', 'std1-file11.txt', 'std1-file5.txt', 'std1-file8.txt', 'std1-file6.txt']
# ['std1-file9.txt', 'std1-file1.txt', 'std1-file11.txt', 'std1-file7.txt', 'std1-file3.txt', 'std1-file4.txt']
# ['std1-file4.txt', 'std1-file5.txt', 'std1-file8.txt', 'std1-file7.txt', 'std1-file9.txt', 'std1-file11.txt']
# ['std1-file5.txt', 'std1-file4.txt', 'std1-file11.txt', 'std1-file10.txt', 'std1-file9.txt', 'std1-file2.txt']
# ['std1-file3.txt', 'std1-file5.txt', 'std1-file2.txt', 'std1-file8.txt', 'std1-file7.txt', 'std1-file4.txt']
# ['std1-file3.txt', 'std1-file5.txt', 'std1-file4.txt', 'std1-file9.txt', 'std1-file7.txt', 'std1-file8.txt']
# ['std1-file9.txt', 'std1-file6.txt', 'std1-file4.txt', 'std1-file7.txt', 'std1-file2.txt', 'std1-file1.txt']
# ['std1-file7.txt', 'std1-file11.txt', 'std1-file1.txt', 'std1-file4.txt', 'std1-file9.txt', 'std1-file10.txt']
# Saved to pickles/testing_list_6.p

# %%
exp_results_5a = run_experiment(0, training_list, testing_list, 'pickles/res_match_feature_6.p')
# Out:
# Iteration 0
# Training on ['std1-file8.txt', 'std1-file6.txt', 'std1-file3.txt', 'std1-file7.txt', 'std1-file4.txt', 'std1-file5.txt']
# Testing on ['std1-file6.txt', 'std1-file8.txt', 'std1-file3.txt', 'std1-file7.txt', 'std1-file5.txt', 'std1-file10.txt']
# match_mode=0, mass_tol=4, rt_tol=60, tp=1465, fp=184, fn=150, prec=0.888, rec=0.907, f1=0.898, th_prob=1.000
#
# Iteration 1
# Training on ['std1-file9.txt', 'std1-file6.txt', 'std1-file8.txt', 'std1-file4.txt', 'std1-file11.txt', 'std1-file3.txt']
# Testing on ['std1-file6.txt', 'std1-file10.txt', 'std1-file9.txt', 'std1-file4.txt', 'std1-file8.txt', 'std1-file3.txt']
# match_mode=0, mass_tol=4, rt_tol=80, tp=2030, fp=217, fn=190, prec=0.903, rec=0.914, f1=0.909, th_prob=1.000
#
# Iteration 2
# Training on ['std1-file4.txt', 'std1-file6.txt', 'std1-file7.txt', 'std1-file9.txt', 'std1-file3.txt', 'std1-file10.txt']
# Testing on ['std1-file3.txt', 'std1-file1.txt', 'std1-file2.txt', 'std1-file5.txt', 'std1-file10.txt', 'std1-file7.txt']
# match_mode=0, mass_tol=4, rt_tol=65, tp=1456, fp=220, fn=198, prec=0.869, rec=0.880, f1=0.874, th_prob=1.000
#
# Iteration 3
# Training on ['std1-file1.txt', 'std1-file2.txt', 'std1-file3.txt', 'std1-file9.txt', 'std1-file4.txt', 'std1-file11.txt']
# Testing on ['std1-file10.txt', 'std1-file4.txt', 'std1-file11.txt', 'std1-file1.txt', 'std1-file3.txt', 'std1-file6.txt']
# match_mode=0, mass_tol=4, rt_tol=55, tp=1991, fp=245, fn=200, prec=0.890, rec=0.909, f1=0.899, th_prob=1.000
#
# Iteration 4
# Training on ['std1-file2.txt', 'std1-file8.txt', 'std1-file1.txt', 'std1-file6.txt', 'std1-file11.txt', 'std1-file4.txt']
# Testing on ['std1-file2.txt', 'std1-file8.txt', 'std1-file6.txt', 'std1-file4.txt', 'std1-file3.txt', 'std1-file10.txt']
# match_mode=0, mass_tol=4, rt_tol=85, tp=2004, fp=207, fn=170, prec=0.906, rec=0.922, f1=0.914, th_prob=1.000
#
# Iteration 5
# Training on ['std1-file4.txt', 'std1-file1.txt', 'std1-file5.txt', 'std1-file8.txt', 'std1-file3.txt', 'std1-file9.txt']
# Testing on ['std1-file6.txt', 'std1-file3.txt', 'std1-file8.txt', 'std1-file9.txt', 'std1-file5.txt', 'std1-file2.txt']
# match_mode=0, mass_tol=4, rt_tol=90, tp=1977, fp=203, fn=192, prec=0.907, rec=0.911, f1=0.909, th_prob=1.000
#
# Iteration 6
# Training on ['std1-file6.txt', 'std1-file1.txt', 'std1-file4.txt', 'std1-file3.txt', 'std1-file9.txt', 'std1-file8.txt']
# Testing on ['std1-file4.txt', 'std1-file2.txt', 'std1-file10.txt', 'std1-file3.txt', 'std1-file7.txt', 'std1-file11.txt']
# match_mode=0, mass_tol=4, rt_tol=80, tp=1491, fp=239, fn=155, prec=0.862, rec=0.906, f1=0.883, th_prob=1.000
#
# Iteration 7
# Training on ['std1-file10.txt', 'std1-file1.txt', 'std1-file2.txt', 'std1-file8.txt', 'std1-file5.txt', 'std1-file6.txt']
# Testing on ['std1-file9.txt', 'std1-file10.txt', 'std1-file7.txt', 'std1-file4.txt', 'std1-file2.txt', 'std1-file5.txt']
# match_mode=0, mass_tol=6, rt_tol=65, tp=1529, fp=213, fn=169, prec=0.878, rec=0.900, f1=0.889, th_prob=1.000
#
# Iteration 8
# Training on ['std1-file2.txt', 'std1-file4.txt', 'std1-file7.txt', 'std1-file3.txt', 'std1-file8.txt', 'std1-file1.txt']
# Testing on ['std1-file9.txt', 'std1-file5.txt', 'std1-file7.txt', 'std1-file10.txt', 'std1-file3.txt', 'std1-file8.txt']
# match_mode=0, mass_tol=4, rt_tol=65, tp=1483, fp=196, fn=172, prec=0.883, rec=0.896, f1=0.890, th_prob=1.000
#
# Iteration 9
# Training on ['std1-file8.txt', 'std1-file6.txt', 'std1-file4.txt', 'std1-file7.txt', 'std1-file11.txt', 'std1-file2.txt']
# Testing on ['std1-file6.txt', 'std1-file11.txt', 'std1-file3.txt', 'std1-file1.txt', 'std1-file8.txt', 'std1-file4.txt']
# match_mode=0, mass_tol=4, rt_tol=70, tp=1960, fp=222, fn=214, prec=0.898, rec=0.902, f1=0.900, th_prob=1.000
#
# Iteration 10
# Training on ['std1-file9.txt', 'std1-file6.txt', 'std1-file4.txt', 'std1-file10.txt', 'std1-file1.txt', 'std1-file5.txt']
# Testing on ['std1-file1.txt', 'std1-file4.txt', 'std1-file9.txt', 'std1-file5.txt', 'std1-file6.txt', 'std1-file7.txt']
# match_mode=0, mass_tol=4, rt_tol=85, tp=1481, fp=279, fn=192, prec=0.841, rec=0.885, f1=0.863, th_prob=1.000
#
# Iteration 11
# Training on ['std1-file10.txt', 'std1-file11.txt', 'std1-file9.txt', 'std1-file8.txt', 'std1-file1.txt', 'std1-file3.txt']
# Testing on ['std1-file11.txt', 'std1-file9.txt', 'std1-file5.txt', 'std1-file8.txt', 'std1-file7.txt', 'std1-file4.txt']
# match_mode=0, mass_tol=4, rt_tol=85, tp=1511, fp=281, fn=151, prec=0.843, rec=0.909, f1=0.875, th_prob=1.000
#
# Iteration 12
# Training on ['std1-file7.txt', 'std1-file11.txt', 'std1-file4.txt', 'std1-file2.txt', 'std1-file1.txt', 'std1-file6.txt']
# Testing on ['std1-file4.txt', 'std1-file8.txt', 'std1-file9.txt', 'std1-file11.txt', 'std1-file1.txt', 'std1-file10.txt']
# match_mode=0, mass_tol=4, rt_tol=60, tp=1947, fp=205, fn=203, prec=0.905, rec=0.906, f1=0.905, th_prob=1.000
#
# Iteration 13
# Training on ['std1-file9.txt', 'std1-file6.txt', 'std1-file2.txt', 'std1-file7.txt', 'std1-file10.txt', 'std1-file8.txt']
# Testing on ['std1-file8.txt', 'std1-file4.txt', 'std1-file7.txt', 'std1-file3.txt', 'std1-file10.txt', 'std1-file2.txt']
# match_mode=0, mass_tol=4, rt_tol=70, tp=1533, fp=199, fn=118, prec=0.885, rec=0.929, f1=0.906, th_prob=1.000
#
# Iteration 14
# Training on ['std1-file8.txt', 'std1-file10.txt', 'std1-file7.txt', 'std1-file6.txt', 'std1-file2.txt', 'std1-file4.txt']
# Testing on ['std1-file11.txt', 'std1-file9.txt', 'std1-file5.txt', 'std1-file6.txt', 'std1-file10.txt', 'std1-file7.txt']
# match_mode=0, mass_tol=4, rt_tol=60, tp=1408, fp=183, fn=180, prec=0.885, rec=0.887, f1=0.886, th_prob=1.000
#
# Iteration 15
# Training on ['std1-file6.txt', 'std1-file11.txt', 'std1-file10.txt', 'std1-file5.txt', 'std1-file7.txt', 'std1-file4.txt']
# Testing on ['std1-file8.txt', 'std1-file11.txt', 'std1-file6.txt', 'std1-file9.txt', 'std1-file10.txt', 'std1-file2.txt']
# match_mode=0, mass_tol=2, rt_tol=65, tp=1808, fp=191, fn=206, prec=0.904, rec=0.898, f1=0.901, th_prob=1.000
#
# Iteration 16
# Training on ['std1-file9.txt', 'std1-file5.txt', 'std1-file8.txt', 'std1-file4.txt', 'std1-file11.txt', 'std1-file3.txt']
# Testing on ['std1-file11.txt', 'std1-file5.txt', 'std1-file7.txt', 'std1-file1.txt', 'std1-file10.txt', 'std1-file3.txt']
# match_mode=0, mass_tol=4, rt_tol=65, tp=1480, fp=244, fn=172, prec=0.858, rec=0.896, f1=0.877, th_prob=1.000
#
# Iteration 17
# Training on ['std1-file2.txt', 'std1-file11.txt', 'std1-file10.txt', 'std1-file3.txt', 'std1-file7.txt', 'std1-file4.txt']
# Testing on ['std1-file4.txt', 'std1-file7.txt', 'std1-file10.txt', 'std1-file2.txt', 'std1-file9.txt', 'std1-file1.txt']
# match_mode=0, mass_tol=4, rt_tol=60, tp=1464, fp=230, fn=178, prec=0.864, rec=0.892, f1=0.878, th_prob=1.000
#
# Iteration 18
# Training on ['std1-file11.txt', 'std1-file8.txt', 'std1-file2.txt', 'std1-file4.txt', 'std1-file1.txt', 'std1-file9.txt']
# Testing on ['std1-file1.txt', 'std1-file10.txt', 'std1-file4.txt', 'std1-file9.txt', 'std1-file7.txt', 'std1-file3.txt']
# match_mode=0, mass_tol=4, rt_tol=75, tp=1524, fp=259, fn=190, prec=0.855, rec=0.889, f1=0.872, th_prob=1.000
#
# Iteration 19
# Training on ['std1-file4.txt', 'std1-file3.txt', 'std1-file11.txt', 'std1-file10.txt', 'std1-file2.txt', 'std1-file8.txt']
# Testing on ['std1-file4.txt', 'std1-file7.txt', 'std1-file9.txt', 'std1-file8.txt', 'std1-file5.txt', 'std1-file1.txt']
# match_mode=0, mass_tol=4, rt_tol=80, tp=1502, fp=274, fn=180, prec=0.846, rec=0.893, f1=0.869, th_prob=1.000
#
# Iteration 20
# Training on ['std1-file7.txt', 'std1-file9.txt', 'std1-file4.txt', 'std1-file2.txt', 'std1-file8.txt', 'std1-file6.txt']
# Testing on ['std1-file2.txt', 'std1-file9.txt', 'std1-file7.txt', 'std1-file1.txt', 'std1-file4.txt', 'std1-file5.txt']
# match_mode=0, mass_tol=4, rt_tol=65, tp=1509, fp=229, fn=211, prec=0.868, rec=0.877, f1=0.873, th_prob=1.000
#
# Iteration 21
# Training on ['std1-file11.txt', 'std1-file1.txt', 'std1-file9.txt', 'std1-file3.txt', 'std1-file7.txt', 'std1-file8.txt']
# Testing on ['std1-file3.txt', 'std1-file10.txt', 'std1-file9.txt', 'std1-file2.txt', 'std1-file7.txt', 'std1-file5.txt']
# match_mode=0, mass_tol=4, rt_tol=65, tp=1488, fp=198, fn=185, prec=0.883, rec=0.889, f1=0.886, th_prob=1.000
#
# Iteration 22
# Training on ['std1-file5.txt', 'std1-file3.txt', 'std1-file6.txt', 'std1-file1.txt', 'std1-file7.txt', 'std1-file2.txt']
# Testing on ['std1-file7.txt', 'std1-file4.txt', 'std1-file11.txt', 'std1-file5.txt', 'std1-file8.txt', 'std1-file6.txt']
# match_mode=0, mass_tol=4, rt_tol=70, tp=1494, fp=189, fn=121, prec=0.888, rec=0.925, f1=0.906, th_prob=1.000
#
# Iteration 23
# Training on ['std1-file9.txt', 'std1-file6.txt', 'std1-file2.txt', 'std1-file10.txt', 'std1-file3.txt', 'std1-file8.txt']
# Testing on ['std1-file9.txt', 'std1-file1.txt', 'std1-file11.txt', 'std1-file7.txt', 'std1-file3.txt', 'std1-file4.txt']
# match_mode=0, mass_tol=4, rt_tol=70, tp=1498, fp=243, fn=206, prec=0.860, rec=0.879, f1=0.870, th_prob=1.000
#
# Iteration 24
# Training on ['std1-file2.txt', 'std1-file11.txt', 'std1-file9.txt', 'std1-file5.txt', 'std1-file8.txt', 'std1-file6.txt']
# Testing on ['std1-file4.txt', 'std1-file5.txt', 'std1-file8.txt', 'std1-file7.txt', 'std1-file9.txt', 'std1-file11.txt']
# match_mode=0, mass_tol=4, rt_tol=60, tp=1487, fp=188, fn=175, prec=0.888, rec=0.895, f1=0.891, th_prob=1.000
#
# Iteration 25
# Training on ['std1-file1.txt', 'std1-file5.txt', 'std1-file11.txt', 'std1-file10.txt', 'std1-file2.txt', 'std1-file9.txt']
# Testing on ['std1-file5.txt', 'std1-file4.txt', 'std1-file11.txt', 'std1-file10.txt', 'std1-file9.txt', 'std1-file2.txt']
# match_mode=0, mass_tol=6, rt_tol=65, tp=2064, fp=246, fn=177, prec=0.894, rec=0.921, f1=0.907, th_prob=1.000
#
# Iteration 26
# Training on ['std1-file1.txt', 'std1-file10.txt', 'std1-file9.txt', 'std1-file11.txt', 'std1-file4.txt', 'std1-file7.txt']
# Testing on ['std1-file3.txt', 'std1-file5.txt', 'std1-file2.txt', 'std1-file8.txt', 'std1-file7.txt', 'std1-file4.txt']
# match_mode=0, mass_tol=6, rt_tol=65, tp=1569, fp=212, fn=150, prec=0.881, rec=0.913, f1=0.897, th_prob=1.000
#
# Iteration 27
# Training on ['std1-file8.txt', 'std1-file9.txt', 'std1-file3.txt', 'std1-file2.txt', 'std1-file10.txt', 'std1-file1.txt']
# Testing on ['std1-file3.txt', 'std1-file5.txt', 'std1-file4.txt', 'std1-file9.txt', 'std1-file7.txt', 'std1-file8.txt']
# match_mode=0, mass_tol=4, rt_tol=70, tp=1610, fp=232, fn=151, prec=0.874, rec=0.914, f1=0.894, th_prob=1.000
#
# Iteration 28
# Training on ['std1-file1.txt', 'std1-file5.txt', 'std1-file3.txt', 'std1-file9.txt', 'std1-file10.txt', 'std1-file6.txt']
# Testing on ['std1-file9.txt', 'std1-file6.txt', 'std1-file4.txt', 'std1-file7.txt', 'std1-file2.txt', 'std1-file1.txt']
# match_mode=0, mass_tol=4, rt_tol=85, tp=1447, fp=273, fn=171, prec=0.841, rec=0.894, f1=0.867, th_prob=1.000
#
# Iteration 29
# Training on ['std1-file7.txt', 'std1-file5.txt', 'std1-file8.txt', 'std1-file3.txt', 'std1-file1.txt', 'std1-file11.txt']
# Testing on ['std1-file7.txt', 'std1-file11.txt', 'std1-file1.txt', 'std1-file4.txt', 'std1-file9.txt', 'std1-file10.txt']
# match_mode=0, mass_tol=4, rt_tol=80, tp=1398, fp=305, fn=217, prec=0.821, rec=0.866, f1=0.843, th_prob=1.000
#
# Saved to pickles/res_match_feature_6.p

# %%
exp_results_5b = run_experiment(1, training_list, testing_list, 'pickles/res_match_cluster_6.p')
# Out:
# Iteration 0
# Training on ['std1-file8.txt', 'std1-file6.txt', 'std1-file3.txt', 'std1-file7.txt', 'std1-file4.txt', 'std1-file5.txt']
