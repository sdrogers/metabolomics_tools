# %% [markdown]
# <h1>Testing the results with standard data</h1>

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import sys
import os
sys.path.insert(1, os.path.join(sys.path[0], '..'))

# %%
import numpy as np
import pylab as plt
import pandas as pd
import seaborn as sns
sns.set(color_codes=True)
from IPython.display import display, HTML
import copy

# %%
from models import HyperPars as AlignmentHyperPars
from discretisation.adduct_cluster import AdductCluster, Peak, Possible
from shared_bin_matching import SharedBinMatching as Aligner
from ground_truth import GroundTruth

# %%
input_dir = '/home/joewandy/git/metabolomics_tools/alignment/input/std1_csv_4'
database_file = None
transformation_file = '/home/joewandy/git/metabolomics_tools/alignment/pos_transformations_full.yml'
gt_file = '/home/joewandy/git/metabolomics_tools/alignment/input/std1_csv_4/ground_truth/ground_truth.txt'

# %%
hp = AlignmentHyperPars()    
hp.within_file_mass_tol = 5
hp.within_file_rt_tol = 30
hp.across_file_mass_tol = 10
hp.across_file_rt_tol = 120
hp.alpha_mass = 1.0
hp.dp_alpha = 1000.0
hp.t = 0.0
hp.mass_clustering_n_iterations = 200
hp.rt_clustering_nsamps = 400
hp.rt_clustering_burnin = 200

print hp
# Out:
# Hyperparameters across_file_mass_tol=10, across_file_rt_tol=120, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30

# %%
evaluation_method = 1

# %% [markdown]
# <h2>Simple matching</h2>

# %%
match_mode = 0

# %%
param_list = []
for mass_tol in range(2, 11, 2):
    for rt_tol in range(10, 121, 10):
        param_list.append((mass_tol, rt_tol))

# %%
performances_0 = []
for param in param_list:
    print param
    copy_hp = copy.copy(hp)
    copy_hp.across_file_mass_tol = param[0]
    copy_hp.across_file_rt_tol = param[1]
    aligner = Aligner(input_dir, database_file, transformation_file, 
                           copy_hp, verbose=False, seed=1234567890)
    aligner.run(match_mode)
    res = aligner.evaluate_performance(gt_file, verbose=False, print_TP=True, method=evaluation_method)
    output = param+res[0]
    print "mass_tol=%d, rt_tol=%d, tp=%d, fp=%d, fn=%d, prec=%.3f, rec=%.3f, f1=%.3f, th_prob=%.3f\n" % output
    performances_0.append(output)
# Out:
# (2, 10)
# Hyperparameters across_file_mass_tol=2, across_file_rt_tol=10, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 22 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=2, rt_tol=10, tp=81, fp=148, fn=0, prec=0.354, rec=1.000, f1=0.523, th_prob=1.000
#
# (2, 20)
# Hyperparameters across_file_mass_tol=2, across_file_rt_tol=20, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 24 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=2, rt_tol=20, tp=124, fp=105, fn=0, prec=0.541, rec=1.000, f1=0.703, th_prob=1.000
#
# (2, 30)
# Hyperparameters across_file_mass_tol=2, across_file_rt_tol=30, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 25 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=2, rt_tol=30, tp=148, fp=81, fn=0, prec=0.646, rec=1.000, f1=0.785, th_prob=1.000
#
# (2, 40)
# Hyperparameters across_file_mass_tol=2, across_file_rt_tol=40, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 27 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=2, rt_tol=40, tp=153, fp=76, fn=0, prec=0.668, rec=1.000, f1=0.801, th_prob=1.000
#
# (2, 50)
# Hyperparameters across_file_mass_tol=2, across_file_rt_tol=50, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 26 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=2, rt_tol=50, tp=156, fp=73, fn=0, prec=0.681, rec=1.000, f1=0.810, th_prob=1.000
#
# (2, 60)
# Hyperparameters across_file_mass_tol=2, across_file_rt_tol=60, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 26 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=2, rt_tol=60, tp=156, fp=73, fn=0, prec=0.681, rec=1.000, f1=0.810, th_prob=1.000
#
# (2, 70)
# Hyperparameters across_file_mass_tol=2, across_file_rt_tol=70, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 28 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=2, rt_tol=70, tp=156, fp=73, fn=0, prec=0.681, rec=1.000, f1=0.810, th_prob=1.000
#
# (2, 80)
# Hyperparameters across_file_mass_tol=2, across_file_rt_tol=80, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 27 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=2, rt_tol=80, tp=157, fp=72, fn=0, prec=0.686, rec=1.000, f1=0.813, th_prob=1.000
#
# (2, 90)
# Hyperparameters across_file_mass_tol=2, across_file_rt_tol=90, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 27 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=2, rt_tol=90, tp=156, fp=73, fn=0, prec=0.681, rec=1.000, f1=0.810, th_prob=1.000
#
# (2, 100)
# Hyperparameters across_file_mass_tol=2, across_file_rt_tol=100, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 31 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=2, rt_tol=100, tp=156, fp=73, fn=0, prec=0.681, rec=1.000, f1=0.810, th_prob=1.000
#
# (2, 110)
# Hyperparameters across_file_mass_tol=2, across_file_rt_tol=110, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 35 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=2, rt_tol=110, tp=156, fp=73, fn=0, prec=0.681, rec=1.000, f1=0.810, th_prob=1.000
#
# (2, 120)
# Hyperparameters across_file_mass_tol=2, across_file_rt_tol=120, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 28 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=2, rt_tol=120, tp=156, fp=73, fn=0, prec=0.681, rec=1.000, f1=0.810, th_prob=1.000
#
# (4, 10)
# Hyperparameters across_file_mass_tol=4, across_file_rt_tol=10, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 27 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=4, rt_tol=10, tp=87, fp=142, fn=0, prec=0.380, rec=1.000, f1=0.551, th_prob=1.000
#
# (4, 20)
# Hyperparameters across_file_mass_tol=4, across_file_rt_tol=20, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 29 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=4, rt_tol=20, tp=142, fp=87, fn=0, prec=0.620, rec=1.000, f1=0.765, th_prob=1.000
#
# (4, 30)
# Hyperparameters across_file_mass_tol=4, across_file_rt_tol=30, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 32 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=4, rt_tol=30, tp=173, fp=56, fn=0, prec=0.755, rec=1.000, f1=0.861, th_prob=1.000
#
# (4, 40)
# Hyperparameters across_file_mass_tol=4, across_file_rt_tol=40, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 36 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=4, rt_tol=40, tp=179, fp=50, fn=0, prec=0.782, rec=1.000, f1=0.877, th_prob=1.000
#
# (4, 50)
# Hyperparameters across_file_mass_tol=4, across_file_rt_tol=50, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 37 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=4, rt_tol=50, tp=182, fp=47, fn=0, prec=0.795, rec=1.000, f1=0.886, th_prob=1.000
#
# (4, 60)
# Hyperparameters across_file_mass_tol=4, across_file_rt_tol=60, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 37 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=4, rt_tol=60, tp=182, fp=47, fn=0, prec=0.795, rec=1.000, f1=0.886, th_prob=1.000
#
# (4, 70)
# Hyperparameters across_file_mass_tol=4, across_file_rt_tol=70, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 37 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=4, rt_tol=70, tp=182, fp=47, fn=0, prec=0.795, rec=1.000, f1=0.886, th_prob=1.000
#
# (4, 80)
# Hyperparameters across_file_mass_tol=4, across_file_rt_tol=80, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 30 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=4, rt_tol=80, tp=183, fp=46, fn=0, prec=0.799, rec=1.000, f1=0.888, th_prob=1.000
#
# (4, 90)
# Hyperparameters across_file_mass_tol=4, across_file_rt_tol=90, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 32 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=4, rt_tol=90, tp=182, fp=47, fn=0, prec=0.795, rec=1.000, f1=0.886, th_prob=1.000
#
# (4, 100)
# Hyperparameters across_file_mass_tol=4, across_file_rt_tol=100, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 31 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=4, rt_tol=100, tp=182, fp=47, fn=0, prec=0.795, rec=1.000, f1=0.886, th_prob=1.000
#
# (4, 110)
# Hyperparameters across_file_mass_tol=4, across_file_rt_tol=110, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 33 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=4, rt_tol=110, tp=182, fp=47, fn=0, prec=0.795, rec=1.000, f1=0.886, th_prob=1.000
#
# (4, 120)
# Hyperparameters across_file_mass_tol=4, across_file_rt_tol=120, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 36 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=4, rt_tol=120, tp=182, fp=47, fn=0, prec=0.795, rec=1.000, f1=0.886, th_prob=1.000
#
# (6, 10)
# Hyperparameters across_file_mass_tol=6, across_file_rt_tol=10, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 26 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=6, rt_tol=10, tp=87, fp=142, fn=0, prec=0.380, rec=1.000, f1=0.551, th_prob=1.000
#
# (6, 20)
# Hyperparameters across_file_mass_tol=6, across_file_rt_tol=20, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 27 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=6, rt_tol=20, tp=142, fp=87, fn=0, prec=0.620, rec=1.000, f1=0.765, th_prob=1.000
#
# (6, 30)
# Hyperparameters across_file_mass_tol=6, across_file_rt_tol=30, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 29 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=6, rt_tol=30, tp=173, fp=56, fn=0, prec=0.755, rec=1.000, f1=0.861, th_prob=1.000
#
# (6, 40)
# Hyperparameters across_file_mass_tol=6, across_file_rt_tol=40, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 28 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=6, rt_tol=40, tp=179, fp=50, fn=0, prec=0.782, rec=1.000, f1=0.877, th_prob=1.000
#
# (6, 50)
# Hyperparameters across_file_mass_tol=6, across_file_rt_tol=50, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 32 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=6, rt_tol=50, tp=182, fp=47, fn=0, prec=0.795, rec=1.000, f1=0.886, th_prob=1.000
#
# (6, 60)
# Hyperparameters across_file_mass_tol=6, across_file_rt_tol=60, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 31 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=6, rt_tol=60, tp=182, fp=47, fn=0, prec=0.795, rec=1.000, f1=0.886, th_prob=1.000
#
# (6, 70)
# Hyperparameters across_file_mass_tol=6, across_file_rt_tol=70, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 35 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=6, rt_tol=70, tp=182, fp=47, fn=0, prec=0.795, rec=1.000, f1=0.886, th_prob=1.000
#
# (6, 80)
# Hyperparameters across_file_mass_tol=6, across_file_rt_tol=80, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 42 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=6, rt_tol=80, tp=182, fp=47, fn=0, prec=0.795, rec=1.000, f1=0.886, th_prob=1.000
#
# (6, 90)
# Hyperparameters across_file_mass_tol=6, across_file_rt_tol=90, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 41 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=6, rt_tol=90, tp=181, fp=48, fn=0, prec=0.790, rec=1.000, f1=0.883, th_prob=1.000
#
# (6, 100)
# Hyperparameters across_file_mass_tol=6, across_file_rt_tol=100, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 42 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=6, rt_tol=100, tp=181, fp=48, fn=0, prec=0.790, rec=1.000, f1=0.883, th_prob=1.000
#
# (6, 110)
# Hyperparameters across_file_mass_tol=6, across_file_rt_tol=110, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 33 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=6, rt_tol=110, tp=181, fp=48, fn=0, prec=0.790, rec=1.000, f1=0.883, th_prob=1.000
#
# (6, 120)
# Hyperparameters across_file_mass_tol=6, across_file_rt_tol=120, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 33 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=6, rt_tol=120, tp=181, fp=48, fn=0, prec=0.790, rec=1.000, f1=0.883, th_prob=1.000
#
# (8, 10)
# Hyperparameters across_file_mass_tol=8, across_file_rt_tol=10, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 26 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=8, rt_tol=10, tp=87, fp=142, fn=0, prec=0.380, rec=1.000, f1=0.551, th_prob=1.000
#
# (8, 20)
# Hyperparameters across_file_mass_tol=8, across_file_rt_tol=20, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 28 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=8, rt_tol=20, tp=142, fp=87, fn=0, prec=0.620, rec=1.000, f1=0.765, th_prob=1.000
#
# (8, 30)
# Hyperparameters across_file_mass_tol=8, across_file_rt_tol=30, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 34 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=8, rt_tol=30, tp=171, fp=58, fn=0, prec=0.747, rec=1.000, f1=0.855, th_prob=1.000
#
# (8, 40)
# Hyperparameters across_file_mass_tol=8, across_file_rt_tol=40, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 33 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=8, rt_tol=40, tp=177, fp=52, fn=0, prec=0.773, rec=1.000, f1=0.872, th_prob=1.000
#
# (8, 50)
# Hyperparameters across_file_mass_tol=8, across_file_rt_tol=50, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 29 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=8, rt_tol=50, tp=180, fp=49, fn=0, prec=0.786, rec=1.000, f1=0.880, th_prob=1.000
#
# (8, 60)
# Hyperparameters across_file_mass_tol=8, across_file_rt_tol=60, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 37 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=8, rt_tol=60, tp=180, fp=49, fn=0, prec=0.786, rec=1.000, f1=0.880, th_prob=1.000
#
# (8, 70)
# Hyperparameters across_file_mass_tol=8, across_file_rt_tol=70, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 42 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=8, rt_tol=70, tp=180, fp=49, fn=0, prec=0.786, rec=1.000, f1=0.880, th_prob=1.000
#
# (8, 80)
# Hyperparameters across_file_mass_tol=8, across_file_rt_tol=80, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 31 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=8, rt_tol=80, tp=180, fp=49, fn=0, prec=0.786, rec=1.000, f1=0.880, th_prob=1.000
#
# (8, 90)
# Hyperparameters across_file_mass_tol=8, across_file_rt_tol=90, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 28 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=8, rt_tol=90, tp=179, fp=50, fn=0, prec=0.782, rec=1.000, f1=0.877, th_prob=1.000
#
# (8, 100)
# Hyperparameters across_file_mass_tol=8, across_file_rt_tol=100, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 28 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=8, rt_tol=100, tp=179, fp=50, fn=0, prec=0.782, rec=1.000, f1=0.877, th_prob=1.000
#
# (8, 110)
# Hyperparameters across_file_mass_tol=8, across_file_rt_tol=110, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 28 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=8, rt_tol=110, tp=179, fp=50, fn=0, prec=0.782, rec=1.000, f1=0.877, th_prob=1.000
#
# (8, 120)
# Hyperparameters across_file_mass_tol=8, across_file_rt_tol=120, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 28 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=8, rt_tol=120, tp=179, fp=50, fn=0, prec=0.782, rec=1.000, f1=0.877, th_prob=1.000
#
# (10, 10)
# Hyperparameters across_file_mass_tol=10, across_file_rt_tol=10, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 23 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=10, rt_tol=10, tp=85, fp=144, fn=0, prec=0.371, rec=1.000, f1=0.541, th_prob=1.000
#
# (10, 20)
# Hyperparameters across_file_mass_tol=10, across_file_rt_tol=20, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 27 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=10, rt_tol=20, tp=140, fp=89, fn=0, prec=0.611, rec=1.000, f1=0.759, th_prob=1.000
#
# (10, 30)
# Hyperparameters across_file_mass_tol=10, across_file_rt_tol=30, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 26 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=10, rt_tol=30, tp=169, fp=60, fn=0, prec=0.738, rec=1.000, f1=0.849, th_prob=1.000
#
# (10, 40)
# Hyperparameters across_file_mass_tol=10, across_file_rt_tol=40, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 27 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=10, rt_tol=40, tp=175, fp=54, fn=0, prec=0.764, rec=1.000, f1=0.866, th_prob=1.000
#
# (10, 50)
# Hyperparameters across_file_mass_tol=10, across_file_rt_tol=50, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 27 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=10, rt_tol=50, tp=178, fp=51, fn=0, prec=0.777, rec=1.000, f1=0.875, th_prob=1.000
#
# (10, 60)
# Hyperparameters across_file_mass_tol=10, across_file_rt_tol=60, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 29 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=10, rt_tol=60, tp=178, fp=51, fn=0, prec=0.777, rec=1.000, f1=0.875, th_prob=1.000
#
# (10, 70)
# Hyperparameters across_file_mass_tol=10, across_file_rt_tol=70, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 27 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=10, rt_tol=70, tp=178, fp=51, fn=0, prec=0.777, rec=1.000, f1=0.875, th_prob=1.000
#
# (10, 80)
# Hyperparameters across_file_mass_tol=10, across_file_rt_tol=80, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 28 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=10, rt_tol=80, tp=178, fp=51, fn=0, prec=0.777, rec=1.000, f1=0.875, th_prob=1.000
#
# (10, 90)
# Hyperparameters across_file_mass_tol=10, across_file_rt_tol=90, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 28 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=10, rt_tol=90, tp=177, fp=52, fn=0, prec=0.773, rec=1.000, f1=0.872, th_prob=1.000
#
# (10, 100)
# Hyperparameters across_file_mass_tol=10, across_file_rt_tol=100, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 29 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=10, rt_tol=100, tp=177, fp=52, fn=0, prec=0.773, rec=1.000, f1=0.872, th_prob=1.000
#
# (10, 110)
# Hyperparameters across_file_mass_tol=10, across_file_rt_tol=110, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 28 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=10, rt_tol=110, tp=177, fp=52, fn=0, prec=0.773, rec=1.000, f1=0.872, th_prob=1.000
#
# (10, 120)
# Hyperparameters across_file_mass_tol=10, across_file_rt_tol=120, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 0
# Matching peak features
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 28 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=10, rt_tol=120, tp=177, fp=52, fn=0, prec=0.773, rec=1.000, f1=0.872, th_prob=1.000

# %%
df = pd.DataFrame(performances_0, columns=['mass_tol', 'rt_tol', 'TP', 'FP', 'FN', 'Prec', 'Rec', 'F1', 'Threshold'])
display(df)
# Out:
#     mass_tol  rt_tol   TP   FP  FN      Prec  Rec        F1  Threshold
# 0          2      10   81  148   0  0.353712    1  0.522581          1
# 1          2      20  124  105   0  0.541485    1  0.702550          1
# 2          2      30  148   81   0  0.646288    1  0.785146          1
# 3          2      40  153   76   0  0.668122    1  0.801047          1
# 4          2      50  156   73   0  0.681223    1  0.810390          1
# 5          2      60  156   73   0  0.681223    1  0.810390          1
# 6          2      70  156   73   0  0.681223    1  0.810390          1
# 7          2      80  157   72   0  0.685590    1  0.813472          1
# 8          2      90  156   73   0  0.681223    1  0.810390          1
# 9          2     100  156   73   0  0.681223    1  0.810390          1
# 10         2     110  156   73   0  0.681223    1  0.810390          1
# 11         2     120  156   73   0  0.681223    1  0.810390          1
# 12         4      10   87  142   0  0.379913    1  0.550633          1
# 13         4      20  142   87   0  0.620087    1  0.765499          1
# 14         4      30  173   56   0  0.755459    1  0.860697          1
# 15         4      40  179   50   0  0.781659    1  0.877451          1
# 16         4      50  182   47   0  0.794760    1  0.885645          1
# 17         4      60  182   47   0  0.794760    1  0.885645          1
# 18         4      70  182   47   0  0.794760    1  0.885645          1
# 19         4      80  183   46   0  0.799127    1  0.888350          1
# 20         4      90  182   47   0  0.794760    1  0.885645          1
# 21         4     100  182   47   0  0.794760    1  0.885645          1
# 22         4     110  182   47   0  0.794760    1  0.885645          1
# 23         4     120  182   47   0  0.794760    1  0.885645          1
# 24         6      10   87  142   0  0.379913    1  0.550633          1
# 25         6      20  142   87   0  0.620087    1  0.765499          1
# 26         6      30  173   56   0  0.755459    1  0.860697          1
# 27         6      40  179   50   0  0.781659    1  0.877451          1
# 28         6      50  182   47   0  0.794760    1  0.885645          1
# 29         6      60  182   47   0  0.794760    1  0.885645          1
# 30         6      70  182   47   0  0.794760    1  0.885645          1
# 31         6      80  182   47   0  0.794760    1  0.885645          1
# 32         6      90  181   48   0  0.790393    1  0.882927          1
# 33         6     100  181   48   0  0.790393    1  0.882927          1
# 34         6     110  181   48   0  0.790393    1  0.882927          1
# 35         6     120  181   48   0  0.790393    1  0.882927          1
# 36         8      10   87  142   0  0.379913    1  0.550633          1
# 37         8      20  142   87   0  0.620087    1  0.765499          1
# 38         8      30  171   58   0  0.746725    1  0.855000          1
# 39         8      40  177   52   0  0.772926    1  0.871921          1
# 40         8      50  180   49   0  0.786026    1  0.880196          1
# 41         8      60  180   49   0  0.786026    1  0.880196          1
# 42         8      70  180   49   0  0.786026    1  0.880196          1
# 43         8      80  180   49   0  0.786026    1  0.880196          1
# 44         8      90  179   50   0  0.781659    1  0.877451          1
# 45         8     100  179   50   0  0.781659    1  0.877451          1
# 46         8     110  179   50   0  0.781659    1  0.877451          1
# 47         8     120  179   50   0  0.781659    1  0.877451          1
# 48        10      10   85  144   0  0.371179    1  0.541401          1
# 49        10      20  140   89   0  0.611354    1  0.758808          1
# 50        10      30  169   60   0  0.737991    1  0.849246          1
# 51        10      40  175   54   0  0.764192    1  0.866337          1
# 52        10      50  178   51   0  0.777293    1  0.874693          1
# 53        10      60  178   51   0  0.777293    1  0.874693          1
# 54        10      70  178   51   0  0.777293    1  0.874693          1
# 55        10      80  178   51   0  0.777293    1  0.874693          1
# 56        10      90  177   52   0  0.772926    1  0.871921          1
# 57        10     100  177   52   0  0.772926    1  0.871921          1
# 58        10     110  177   52   0  0.772926    1  0.871921          1
# 59        10     120  177   52   0  0.772926    1  0.871921          1

# %% [markdown]
# <h2>Matching the precursor clusters -- Gibbs, mh_biggest=True</h2>

# %%
match_mode = 1

# %%
aligner2 = Aligner(input_dir, database_file, transformation_file, 
                       hp, verbose=False, seed=1234567890, parallel=True, mh_biggest=True, use_vb=False)
clustering_results = aligner2._first_stage_clustering()
# Out:
# Hyperparameters across_file_mass_tol=10, across_file_rt_tol=120, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]

# %%
performances_2 = []
for param in param_list:
    print param
    copy_hp = copy.copy(hp)
    copy_hp.across_file_mass_tol = param[0]
    copy_hp.across_file_rt_tol = param[1]
    aligner2 = Aligner(input_dir, database_file, transformation_file, 
                           copy_hp, verbose=False, seed=1234567890, parallel=True, mh_biggest=True, use_vb=False)    
    aligner2.run(match_mode, first_stage_clustering_results=clustering_results)
    res = aligner2.evaluate_performance(gt_file, verbose=False, method=evaluation_method)
    output = param+res[0]
    print "mass_tol=%d, rt_tol=%d, tp=%d, fp=%d, fn=%d, prec=%.3f, rec=%.3f, f1=%.3f, th_prob=%.3f\n" % output
    performances_2.append(output)
# Out:
# (2, 10)
# Hyperparameters across_file_mass_tol=2, across_file_rt_tol=10, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 25 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=2, rt_tol=10, tp=84, fp=145, fn=0, prec=0.367, rec=1.000, f1=0.537, th_prob=1.000
#
# (2, 20)
# Hyperparameters across_file_mass_tol=2, across_file_rt_tol=20, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 27 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=2, rt_tol=20, tp=129, fp=100, fn=0, prec=0.563, rec=1.000, f1=0.721, th_prob=1.000
#
# (2, 30)
# Hyperparameters across_file_mass_tol=2, across_file_rt_tol=30, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 30 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=2, rt_tol=30, tp=163, fp=66, fn=0, prec=0.712, rec=1.000, f1=0.832, th_prob=1.000
#
# (2, 40)
# Hyperparameters across_file_mass_tol=2, across_file_rt_tol=40, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 28 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=2, rt_tol=40, tp=166, fp=63, fn=0, prec=0.725, rec=1.000, f1=0.841, th_prob=1.000
#
# (2, 50)
# Hyperparameters across_file_mass_tol=2, across_file_rt_tol=50, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 29 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=2, rt_tol=50, tp=167, fp=62, fn=0, prec=0.729, rec=1.000, f1=0.843, th_prob=1.000
#
# (2, 60)
# Hyperparameters across_file_mass_tol=2, across_file_rt_tol=60, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 27 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=2, rt_tol=60, tp=167, fp=62, fn=0, prec=0.729, rec=1.000, f1=0.843, th_prob=1.000
#
# (2, 70)
# Hyperparameters across_file_mass_tol=2, across_file_rt_tol=70, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 37 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=2, rt_tol=70, tp=167, fp=62, fn=0, prec=0.729, rec=1.000, f1=0.843, th_prob=1.000
#
# (2, 80)
# Hyperparameters across_file_mass_tol=2, across_file_rt_tol=80, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 26 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=2, rt_tol=80, tp=168, fp=61, fn=0, prec=0.734, rec=1.000, f1=0.846, th_prob=1.000
#
# (2, 90)
# Hyperparameters across_file_mass_tol=2, across_file_rt_tol=90, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 27 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=2, rt_tol=90, tp=168, fp=61, fn=0, prec=0.734, rec=1.000, f1=0.846, th_prob=1.000
#
# (2, 100)
# Hyperparameters across_file_mass_tol=2, across_file_rt_tol=100, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 27 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=2, rt_tol=100, tp=168, fp=61, fn=0, prec=0.734, rec=1.000, f1=0.846, th_prob=1.000
#
# (2, 110)
# Hyperparameters across_file_mass_tol=2, across_file_rt_tol=110, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 27 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=2, rt_tol=110, tp=168, fp=61, fn=0, prec=0.734, rec=1.000, f1=0.846, th_prob=1.000
#
# (2, 120)
# Hyperparameters across_file_mass_tol=2, across_file_rt_tol=120, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 28 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=2, rt_tol=120, tp=168, fp=61, fn=0, prec=0.734, rec=1.000, f1=0.846, th_prob=1.000
#
# (4, 10)
# Hyperparameters across_file_mass_tol=4, across_file_rt_tol=10, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 23 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=4, rt_tol=10, tp=86, fp=143, fn=0, prec=0.376, rec=1.000, f1=0.546, th_prob=1.000
#
# (4, 20)
# Hyperparameters across_file_mass_tol=4, across_file_rt_tol=20, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 25 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=4, rt_tol=20, tp=152, fp=77, fn=0, prec=0.664, rec=1.000, f1=0.798, th_prob=1.000
#
# (4, 30)
# Hyperparameters across_file_mass_tol=4, across_file_rt_tol=30, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 26 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=4, rt_tol=30, tp=184, fp=45, fn=0, prec=0.803, rec=1.000, f1=0.891, th_prob=1.000
#
# (4, 40)
# Hyperparameters across_file_mass_tol=4, across_file_rt_tol=40, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 30 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=4, rt_tol=40, tp=187, fp=42, fn=0, prec=0.817, rec=1.000, f1=0.899, th_prob=1.000
#
# (4, 50)
# Hyperparameters across_file_mass_tol=4, across_file_rt_tol=50, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 29 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=4, rt_tol=50, tp=187, fp=42, fn=0, prec=0.817, rec=1.000, f1=0.899, th_prob=1.000
#
# (4, 60)
# Hyperparameters across_file_mass_tol=4, across_file_rt_tol=60, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 29 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=4, rt_tol=60, tp=187, fp=42, fn=0, prec=0.817, rec=1.000, f1=0.899, th_prob=1.000
#
# (4, 70)
# Hyperparameters across_file_mass_tol=4, across_file_rt_tol=70, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 40 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=4, rt_tol=70, tp=187, fp=42, fn=0, prec=0.817, rec=1.000, f1=0.899, th_prob=1.000
#
# (4, 80)
# Hyperparameters across_file_mass_tol=4, across_file_rt_tol=80, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 40 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=4, rt_tol=80, tp=187, fp=42, fn=0, prec=0.817, rec=1.000, f1=0.899, th_prob=1.000
#
# (4, 90)
# Hyperparameters across_file_mass_tol=4, across_file_rt_tol=90, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 28 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=4, rt_tol=90, tp=187, fp=42, fn=0, prec=0.817, rec=1.000, f1=0.899, th_prob=1.000
#
# (4, 100)
# Hyperparameters across_file_mass_tol=4, across_file_rt_tol=100, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 28 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=4, rt_tol=100, tp=187, fp=42, fn=0, prec=0.817, rec=1.000, f1=0.899, th_prob=1.000
#
# (4, 110)
# Hyperparameters across_file_mass_tol=4, across_file_rt_tol=110, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 30 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=4, rt_tol=110, tp=187, fp=42, fn=0, prec=0.817, rec=1.000, f1=0.899, th_prob=1.000
#
# (4, 120)
# Hyperparameters across_file_mass_tol=4, across_file_rt_tol=120, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 26 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=4, rt_tol=120, tp=187, fp=42, fn=0, prec=0.817, rec=1.000, f1=0.899, th_prob=1.000
#
# (6, 10)
# Hyperparameters across_file_mass_tol=6, across_file_rt_tol=10, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 23 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=6, rt_tol=10, tp=86, fp=143, fn=0, prec=0.376, rec=1.000, f1=0.546, th_prob=1.000
#
# (6, 20)
# Hyperparameters across_file_mass_tol=6, across_file_rt_tol=20, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 26 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=6, rt_tol=20, tp=153, fp=76, fn=0, prec=0.668, rec=1.000, f1=0.801, th_prob=1.000
#
# (6, 30)
# Hyperparameters across_file_mass_tol=6, across_file_rt_tol=30, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 28 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=6, rt_tol=30, tp=184, fp=45, fn=0, prec=0.803, rec=1.000, f1=0.891, th_prob=1.000
#
# (6, 40)
# Hyperparameters across_file_mass_tol=6, across_file_rt_tol=40, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 33 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=6, rt_tol=40, tp=187, fp=42, fn=0, prec=0.817, rec=1.000, f1=0.899, th_prob=1.000
#
# (6, 50)
# Hyperparameters across_file_mass_tol=6, across_file_rt_tol=50, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 33 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=6, rt_tol=50, tp=188, fp=41, fn=0, prec=0.821, rec=1.000, f1=0.902, th_prob=1.000
#
# (6, 60)
# Hyperparameters across_file_mass_tol=6, across_file_rt_tol=60, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 29 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=6, rt_tol=60, tp=188, fp=41, fn=0, prec=0.821, rec=1.000, f1=0.902, th_prob=1.000
#
# (6, 70)
# Hyperparameters across_file_mass_tol=6, across_file_rt_tol=70, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 35 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=6, rt_tol=70, tp=188, fp=41, fn=0, prec=0.821, rec=1.000, f1=0.902, th_prob=1.000
#
# (6, 80)
# Hyperparameters across_file_mass_tol=6, across_file_rt_tol=80, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 28 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=6, rt_tol=80, tp=188, fp=41, fn=0, prec=0.821, rec=1.000, f1=0.902, th_prob=1.000
#
# (6, 90)
# Hyperparameters across_file_mass_tol=6, across_file_rt_tol=90, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 25 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=6, rt_tol=90, tp=188, fp=41, fn=0, prec=0.821, rec=1.000, f1=0.902, th_prob=1.000
#
# (6, 100)
# Hyperparameters across_file_mass_tol=6, across_file_rt_tol=100, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 31 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=6, rt_tol=100, tp=188, fp=41, fn=0, prec=0.821, rec=1.000, f1=0.902, th_prob=1.000
#
# (6, 110)
# Hyperparameters across_file_mass_tol=6, across_file_rt_tol=110, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 32 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=6, rt_tol=110, tp=188, fp=41, fn=0, prec=0.821, rec=1.000, f1=0.902, th_prob=1.000
#
# (6, 120)
# Hyperparameters across_file_mass_tol=6, across_file_rt_tol=120, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 32 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=6, rt_tol=120, tp=188, fp=41, fn=0, prec=0.821, rec=1.000, f1=0.902, th_prob=1.000
#
# (8, 10)
# Hyperparameters across_file_mass_tol=8, across_file_rt_tol=10, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 22 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=8, rt_tol=10, tp=86, fp=143, fn=0, prec=0.376, rec=1.000, f1=0.546, th_prob=1.000
#
# (8, 20)
# Hyperparameters across_file_mass_tol=8, across_file_rt_tol=20, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 26 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=8, rt_tol=20, tp=153, fp=76, fn=0, prec=0.668, rec=1.000, f1=0.801, th_prob=1.000
#
# (8, 30)
# Hyperparameters across_file_mass_tol=8, across_file_rt_tol=30, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 35 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=8, rt_tol=30, tp=183, fp=46, fn=0, prec=0.799, rec=1.000, f1=0.888, th_prob=1.000
#
# (8, 40)
# Hyperparameters across_file_mass_tol=8, across_file_rt_tol=40, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 39 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=8, rt_tol=40, tp=186, fp=43, fn=0, prec=0.812, rec=1.000, f1=0.896, th_prob=1.000
#
# (8, 50)
# Hyperparameters across_file_mass_tol=8, across_file_rt_tol=50, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 29 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=8, rt_tol=50, tp=187, fp=42, fn=0, prec=0.817, rec=1.000, f1=0.899, th_prob=1.000
#
# (8, 60)
# Hyperparameters across_file_mass_tol=8, across_file_rt_tol=60, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 28 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=8, rt_tol=60, tp=187, fp=42, fn=0, prec=0.817, rec=1.000, f1=0.899, th_prob=1.000
#
# (8, 70)
# Hyperparameters across_file_mass_tol=8, across_file_rt_tol=70, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 27 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=8, rt_tol=70, tp=187, fp=42, fn=0, prec=0.817, rec=1.000, f1=0.899, th_prob=1.000
#
# (8, 80)
# Hyperparameters across_file_mass_tol=8, across_file_rt_tol=80, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 28 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=8, rt_tol=80, tp=187, fp=42, fn=0, prec=0.817, rec=1.000, f1=0.899, th_prob=1.000
#
# (8, 90)
# Hyperparameters across_file_mass_tol=8, across_file_rt_tol=90, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 29 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=8, rt_tol=90, tp=187, fp=42, fn=0, prec=0.817, rec=1.000, f1=0.899, th_prob=1.000
#
# (8, 100)
# Hyperparameters across_file_mass_tol=8, across_file_rt_tol=100, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 33 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=8, rt_tol=100, tp=187, fp=42, fn=0, prec=0.817, rec=1.000, f1=0.899, th_prob=1.000
#
# (8, 110)
# Hyperparameters across_file_mass_tol=8, across_file_rt_tol=110, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 37 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=8, rt_tol=110, tp=187, fp=42, fn=0, prec=0.817, rec=1.000, f1=0.899, th_prob=1.000
#
# (8, 120)
# Hyperparameters across_file_mass_tol=8, across_file_rt_tol=120, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 30 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=8, rt_tol=120, tp=187, fp=42, fn=0, prec=0.817, rec=1.000, f1=0.899, th_prob=1.000
#
# (10, 10)
# Hyperparameters across_file_mass_tol=10, across_file_rt_tol=10, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 22 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=10, rt_tol=10, tp=84, fp=145, fn=0, prec=0.367, rec=1.000, f1=0.537, th_prob=1.000
#
# (10, 20)
# Hyperparameters across_file_mass_tol=10, across_file_rt_tol=20, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 28 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=10, rt_tol=20, tp=151, fp=78, fn=0, prec=0.659, rec=1.000, f1=0.795, th_prob=1.000
#
# (10, 30)
# Hyperparameters across_file_mass_tol=10, across_file_rt_tol=30, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 23 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=10, rt_tol=30, tp=181, fp=48, fn=0, prec=0.790, rec=1.000, f1=0.883, th_prob=1.000
#
# (10, 40)
# Hyperparameters across_file_mass_tol=10, across_file_rt_tol=40, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 26 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=10, rt_tol=40, tp=184, fp=45, fn=0, prec=0.803, rec=1.000, f1=0.891, th_prob=1.000
#
# (10, 50)
# Hyperparameters across_file_mass_tol=10, across_file_rt_tol=50, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 25 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=10, rt_tol=50, tp=185, fp=44, fn=0, prec=0.808, rec=1.000, f1=0.894, th_prob=1.000
#
# (10, 60)
# Hyperparameters across_file_mass_tol=10, across_file_rt_tol=60, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 32 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=10, rt_tol=60, tp=185, fp=44, fn=0, prec=0.808, rec=1.000, f1=0.894, th_prob=1.000
#
# (10, 70)
# Hyperparameters across_file_mass_tol=10, across_file_rt_tol=70, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 30 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=10, rt_tol=70, tp=185, fp=44, fn=0, prec=0.808, rec=1.000, f1=0.894, th_prob=1.000
#
# (10, 80)
# Hyperparameters across_file_mass_tol=10, across_file_rt_tol=80, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 28 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=10, rt_tol=80, tp=185, fp=44, fn=0, prec=0.808, rec=1.000, f1=0.894, th_prob=1.000
#
# (10, 90)
# Hyperparameters across_file_mass_tol=10, across_file_rt_tol=90, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 30 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=10, rt_tol=90, tp=185, fp=44, fn=0, prec=0.808, rec=1.000, f1=0.894, th_prob=1.000
#
# (10, 100)
# Hyperparameters across_file_mass_tol=10, across_file_rt_tol=100, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 25 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=10, rt_tol=100, tp=185, fp=44, fn=0, prec=0.808, rec=1.000, f1=0.894, th_prob=1.000
#
# (10, 110)
# Hyperparameters across_file_mass_tol=10, across_file_rt_tol=110, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 24 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=10, rt_tol=110, tp=185, fp=44, fn=0, prec=0.808, rec=1.000, f1=0.894, th_prob=1.000
#
# (10, 120)
# Hyperparameters across_file_mass_tol=10, across_file_rt_tol=120, alpha_mass=1.0, beta=0.1, dp_alpha=1000.0, mass_clustering_n_iterations=200, rt_clustering_burnin=200, rt_clustering_nsamps=400, t=0.0, within_file_mass_tol=5, within_file_rt_tol=30
# 4999 features read from std1-file1.csv
# 4986 features read from std1-file2.csv
# 6836 features read from std1-file3.csv
# 9752 features read from std1-file4.csv
# [M+ACN+H, 2M+H, 2M+Na, M+ACN+2H, M+2ACN+2H, M+2H, M+H, M+H+NH4, M+2ACN+H, M+NH4, 2M+ACN+H, M+CH3OH+H, M+ACN+Na, M+Na]
# Match mode 1
# Matching precursor bins
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
#
# --- TOTAL TIME 24 seconds ---
#
# Loaded 229 ground truth entries
# {2: 63, 3: 33, 4: 133}
#
# mass_tol=10, rt_tol=120, tp=185, fp=44, fn=0, prec=0.808, rec=1.000, f1=0.894, th_prob=1.000

# %%
df = pd.DataFrame(performances_2, columns=['mass_tol', 'rt_tol', 'TP', 'FP', 'FN', 'Prec', 'Rec', 'F1', 'Threshold'])
display(df)
# Out:
#     mass_tol  rt_tol   TP   FP  FN      Prec  Rec        F1  Threshold
# 0          2      10   84  145   0  0.366812    1  0.536741          1
# 1          2      20  129  100   0  0.563319    1  0.720670          1
# 2          2      30  163   66   0  0.711790    1  0.831633          1
# 3          2      40  166   63   0  0.724891    1  0.840506          1
# 4          2      50  167   62   0  0.729258    1  0.843434          1
# 5          2      60  167   62   0  0.729258    1  0.843434          1
# 6          2      70  167   62   0  0.729258    1  0.843434          1
# 7          2      80  168   61   0  0.733624    1  0.846348          1
# 8          2      90  168   61   0  0.733624    1  0.846348          1
# 9          2     100  168   61   0  0.733624    1  0.846348          1
# 10         2     110  168   61   0  0.733624    1  0.846348          1
# 11         2     120  168   61   0  0.733624    1  0.846348          1
# 12         4      10   86  143   0  0.375546    1  0.546032          1
# 13         4      20  152   77   0  0.663755    1  0.797900          1
# 14         4      30  184   45   0  0.803493    1  0.891041          1
# 15         4      40  187   42   0  0.816594    1  0.899038          1
# 16         4      50  187   42   0  0.816594    1  0.899038          1
# 17         4      60  187   42   0  0.816594    1  0.899038          1
# 18         4      70  187   42   0  0.816594    1  0.899038          1
# 19         4      80  187   42   0  0.816594    1  0.899038          1
# 20         4      90  187   42   0  0.816594    1  0.899038          1
# 21         4     100  187   42   0  0.816594    1  0.899038          1
# 22         4     110  187   42   0  0.816594    1  0.899038          1
# 23         4     120  187   42   0  0.816594    1  0.899038          1
# 24         6      10   86  143   0  0.375546    1  0.546032          1
# 25         6      20  153   76   0  0.668122    1  0.801047          1
# 26         6      30  184   45   0  0.803493    1  0.891041          1
# 27         6      40  187   42   0  0.816594    1  0.899038          1
# 28         6      50  188   41   0  0.820961    1  0.901679          1
# 29         6      60  188   41   0  0.820961    1  0.901679          1
# 30         6      70  188   41   0  0.820961    1  0.901679          1
# 31         6      80  188   41   0  0.820961    1  0.901679          1
# 32         6      90  188   41   0  0.820961    1  0.901679          1
# 33         6     100  188   41   0  0.820961    1  0.901679          1
# 34         6     110  188   41   0  0.820961    1  0.901679          1
# 35         6     120  188   41   0  0.820961    1  0.901679          1
# 36         8      10   86  143   0  0.375546    1  0.546032          1
# 37         8      20  153   76   0  0.668122    1  0.801047          1
# 38         8      30  183   46   0  0.799127    1  0.888350          1
# 39         8      40  186   43   0  0.812227    1  0.896386          1
# 40         8      50  187   42   0  0.816594    1  0.899038          1
# 41         8      60  187   42   0  0.816594    1  0.899038          1
# 42         8      70  187   42   0  0.816594    1  0.899038          1
# 43         8      80  187   42   0  0.816594    1  0.899038          1
# 44         8      90  187   42   0  0.816594    1  0.899038          1
# 45         8     100  187   42   0  0.816594    1  0.899038          1
# 46         8     110  187   42   0  0.816594    1  0.899038          1
# 47         8     120  187   42   0  0.816594    1  0.899038          1
# 48        10      10   84  145   0  0.366812    1  0.536741          1
# 49        10      20  151   78   0  0.659389    1  0.794737          1
# 50        10      30  181   48   0  0.790393    1  0.882927          1
# 51        10      40  184   45   0  0.803493    1  0.891041          1
# 52        10      50  185   44   0  0.807860    1  0.893720          1
# 53        10      60  185   44   0  0.807860    1  0.893720          1
# 54        10      70  185   44   0  0.807860    1  0.893720          1
# 55        10      80  185   44   0  0.807860    1  0.893720          1
# 56        10      90  185   44   0  0.807860    1  0.893720          1
# 57        10     100  185   44   0  0.807860    1  0.893720          1
# 58        10     110  185   44   0  0.807860    1  0.893720          1
# 59        10     120  185   44   0  0.807860    1  0.893720          1
