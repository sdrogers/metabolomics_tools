# %% [markdown]
# ### Preliminary

# %% [markdown]
# Import some stuff

# %%
import sys

basedir = '../'
sys.path.append(basedir) # need to do this to be able to import the stuff below

import itertools
from operator import attrgetter
from operator import itemgetter
import time

from discretisation.discrete_mass_clusterer import DiscreteVB
from discretisation.models import HyperPars
from discretisation.plotting import ClusterPlotter
from discretisation.preprocessing import FileLoader
import discretisation.utils as utils
from dp_rt_clusterer import DpMixtureGibbs

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Define a whole bunch of useful functions

# %%
def plot_hist(mapping, filename, mass_tol, rt_tol):
    no_trans = (mapping > 0).sum(1)
    mini_hist = []
    for i in np.arange(10) + 1:
        mini_hist.append((no_trans == i).sum())
    print 'mini_hist ' + str(mini_hist)
    plt.figure()
    plt.subplot(1, 2, 1)
    plt.bar(np.arange(10) + 1, mini_hist)
    title = 'Binning -- MASS_TOL ' + str(mass_tol) + ', RT_TOL ' + str(rt_tol)
    plt.title(title)
    plt.subplot(1, 2, 2)
    plt.spy(mapping, markersize=1)
    plt.title('possible')
    plt.suptitle(filename)
    plt.show()     
    
def annotate(annotations, feature, msg):
    if feature in annotations:
        current_msg = annotations[feature]
        annotations[feature] = current_msg + " " + msg
    else:
        annotations[feature] = msg
    
def get_transformation_map(transformations):
    tmap = {}
    t = 1
    for trans in transformations:
        tmap[t] = trans
        t += 1
    return tmap

# %% [markdown]
# Parameters. Here we load 3 std1 pos files and process them with the following parameters.

# %%
start = time.time()

basedir = '../discretisation'
database = basedir + '/database/std1_mols.csv'
transformation = basedir + '/mulsubs/mulsub2.txt'
input_file = basedir + '/input/std1_csv_subset'

binning_mass_tol = 2.0                  # mass tolerance in ppm when binning
binning_rt_tol = 5.0                    # rt tolerance in seconds when binning
within_file_rt_sd = binning_rt_tol/2    # standard deviation of each cluster when clustering by precursor masses in a single file
across_file_rt_sd = 10.0                # standard deviation of mixture component when clustering by RT across files
alpha_mass = 10000.0                    # concentration parameter for precursor mass clustering
alpha_rt = 10000.0                      # concentration parameter for DP mixture on RT
t = 0.50                                # threshold for cluster membership for precursor mass clustering
limit_n = -1                            # the number of features to load per file to make debugging easier, -1 to load all

mass_clustering_n_iterations = 20       # no. of iterations for VB precursor clustering
rt_clustering_nsamps = 200              # no. of total samples for Gibbs RT clustering
rt_clustering_burnin = 100              # no. of burn-in samples for Gibbs RT clustering

# %% [markdown]
# ### Step 1

# %% [markdown]
# First stage clustering. Here we do the usual precursor mass clustering of peak features to some common bins shared across files

# %%
# First stage clustering. 
# Here we cluster peak features by their precursor masses to the common bins shared across files.
loader = FileLoader()
data_list = loader.load_model_input(input_file, database, transformation, binning_mass_tol, binning_rt_tol, limit_n=limit_n)
transformations = data_list[0].transformations
tmap = get_transformation_map(transformations)
all_bins = []
posterior_bin_rts = []    
annotations = {}

for j in range(len(data_list)):

    # run precursor mass clustering
    peak_data = data_list[j]
    plot_hist(peak_data.possible, input_file, binning_mass_tol, binning_rt_tol)
    print "Clustering file " + str(j) + " by precursor masses"
    hp = HyperPars()
    hp.rt_prec = 1.0/(within_file_rt_sd*within_file_rt_sd)
    hp.alpha = alpha_mass
    discrete = DiscreteVB(peak_data, hp)
    discrete.n_iterations = mass_clustering_n_iterations
    print discrete
    discrete.run()

    # pick the non-empty bins for the second stage clustering
    cluster_membership = (discrete.Z>t)
    s = cluster_membership.sum(0)
    nnz_idx = s.nonzero()[1]  
    nnz_idx = np.squeeze(np.asarray(nnz_idx)) # flatten the thing

    # find the non-empty bins
    bins = [peak_data.bins[a] for a in nnz_idx]
    all_bins.extend(bins)

    # find the non-empty bins' posterior RT values
    bin_rts = discrete.cluster_rt_mean[nnz_idx]        
    bin_rts = bin_rts.ravel().tolist()
    posterior_bin_rts.extend(bin_rts)

    # make some plots
    cp = ClusterPlotter(peak_data, discrete)
    cp.summary(file_idx=j)
    # cp.plot_biggest(3)        

    # assign peaks into their respective bins, 
    # this makes it easier when matching peaks across the same bins later
    # note: a peak can belong to multiple bins, depending on the choice of threshold t
    cx = cluster_membership.tocoo()
    for i,j,v in itertools.izip(cx.row, cx.col, cx.data):
        f = peak_data.features[i]
        bb = peak_data.bins[j] # copy of the common bin specific to file j
        bb.add_feature(f)    
        # annotate each feature by its precursor mass & adduct type probabilities, for reporting later
        bin_prob = discrete.Z[i, j]
        trans_idx = discrete.possible[i, j]
        tran = tmap[trans_idx]
        msg = "{:s}@{:3.5f} prob={:.2f}".format(tran.name, bb.mass, bin_prob)            
        annotate(annotations, f, msg)
# Out:
# 4999 features read from std1-file1.identified.csv
# 4986 features read from std1-file2.identified.csv
# 6836 features read from std1-file3.identified.csv
# Discretising at mass_tol=2.0, rt_tol=5.0
# Making common bins	....
# ...
# ...
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# .
# Total clusters=14463 total features=16821
# Discretising file 0	..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# .
# Discretising file 1	.
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# Discretising file 2
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# .
# mini_hist [4231, 596, 131, 23, 15, 2, 1, 0, 0, 0]
# Clustering file 0 by precursor masses
# DiscreteVB initialising
# Startup ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# .
# Variational Bayes for discrete mass model
# Hyperparameters alpha=10000.0, mass_prec=100, mass_prior_prec=100, rt_prec=0.16, rt_prior_prec=100
# n_iterations = 20
# 768 peaks to be re-sampled
# Iteration 0 Change in Z: 232.585297229
# Iteration 1 Change in Z: 10.4999139051
# Iteration 2 Change in Z: 0.741717219617
# Iteration 3 Change in Z: 0.0720189574152
# Iteration 4 Change in Z: 0.00856763579488
# Iteration 5 Change in Z: 0.00114926400553
# Iteration 6 Change in Z: 0.000165572990547
# Iteration 7 Change in Z: 2.49550930288e-05
# Iteration 8 Change in Z: 3.87916400756e-06
# Iteration 9 Change in Z: 6.16940616366e-07
# Iteration 10 Change in Z: 9.99190237506e-08
# Iteration 11 Change in Z: 1.64343896212e-08
# Iteration 12 Change in Z: 2.7406639691e-09
# Iteration 13 Change in Z: 4.6297984529e-10
# Iteration 14 Change in Z: 7.91911448789e-11
# Iteration 15 Change in Z: 1.3713224119e-11
# Iteration 16 Change in Z: 2.40419308926e-12
# Iteration 17 Change in Z: 4.26806304381e-13
# Iteration 18 Change in Z: 7.67447490488e-14
# Iteration 19 Change in Z: 1.39750455228e-14
# Cluster output
# Number of non-empty clusters: 4555 (of 14463)
#
# Size: count
# 0: 9908
# 1: 4264
# 2: 254
# 3: 25
# 4: 8
# 5: 2
# 6: 1
# 7: 0
# 8: 1
#
# Trans: count
# M+2H: 9
# M+H+NH4: 0
# M+H+Na: 10
# M+H+K: 2
# M+ACN+2H: 10
# M+2Na: 1
# M+H: 4567
# M+HC13: 166
# M+H2C13: 3
# M+NH4: 16
# M+Na: 42
# M+NaC13: 7
# M+CH3OH+H: 1
# M+K: 12
# M+KC13: 3
# M+ACN+H: 41
# M+2Na-H: 12
# M+IsoProp+H: 1
# M+ACN+Na: 0
# M+2K-H: 0
# M+DMSO+H: 0
# M+2ACN+H: 0
# mini_hist [4223, 581, 136, 28, 12, 5, 1, 0, 0, 0]
# Clustering file 1 by precursor masses
# DiscreteVB initialising
# Startup ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# .
# Variational Bayes for discrete mass model
# Hyperparameters alpha=10000.0, mass_prec=100, mass_prior_prec=100, rt_prec=0.16, rt_prior_prec=100
# n_iterations = 20
# 763 peaks to be re-sampled
# Iteration 0 Change in Z: 282.274832737
# Iteration 1 Change in Z: 11.6031542598
# Iteration 2 Change in Z: 0.703468155058
# Iteration 3 Change in Z: 0.0588275887213
# Iteration 4 Change in Z: 0.00625168645342
# Iteration 5 Change in Z: 0.000782036149132
# Iteration 6 Change in Z: 0.000108769003609
# Iteration 7 Change in Z: 1.62108838861e-05
# Iteration 8 Change in Z: 2.5305173691e-06
# Iteration 9 Change in Z: 4.078568158e-07
# Iteration 10 Change in Z: 6.72528830386e-08
# Iteration 11 Change in Z: 1.12765366852e-08
# Iteration 12 Change in Z: 1.91471862678e-09
# Iteration 13 Change in Z: 3.28283108567e-10
# Iteration 14 Change in Z: 5.67176090212e-11
# Iteration 15 Change in Z: 9.85976554023e-12
# Iteration 16 Change in Z: 1.72281569574e-12
# Iteration 17 Change in Z: 3.02308441356e-13
# Iteration 18 Change in Z: 5.32418681773e-14
# Iteration 19 Change in Z: 9.40625360123e-15
# Cluster output
# Number of non-empty clusters: 4520 (of 14463)
#
# Size: count
# 0: 9943
# 1: 4230
# 2: 245
# 3: 33
# 4: 10
# 5: 1
# 6: 1
#
# Trans: count
# M+2H: 11
# M+H+NH4: 1
# M+H+Na: 7
# M+H+K: 2
# M+ACN+2H: 7
# M+2Na: 2
# M+H: 4497
# M+HC13: 183
# M+H2C13: 4
# M+NH4: 30
# M+Na: 57
# M+NaC13: 9
# M+CH3OH+H: 3
# M+K: 8
# M+KC13: 1
# M+ACN+H: 34
# M+2Na-H: 7
# M+IsoProp+H: 2
# M+ACN+Na: 2
# M+2K-H: 0
# M+DMSO+H: 1
# M+2ACN+H: 2
# mini_hist [5628, 977, 179, 40, 7, 4, 1, 0, 0, 0]
# Clustering file 2 by precursor masses
# DiscreteVB initialising
# Startup ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# .
# Variational Bayes for discrete mass model
# Hyperparameters alpha=10000.0, mass_prec=100, mass_prior_prec=100, rt_prec=0.16, rt_prior_prec=100
# n_iterations = 20
# 1208 peaks to be re-sampled
# Iteration 0 Change in Z: 446.808490071
# Iteration 1 Change in Z: 26.3617921417
# Iteration 2 Change in Z: 2.28151581762
# Iteration 3 Change in Z: 0.28453423107
# Iteration 4 Change in Z: 0.0468221042975
# Iteration 5 Change in Z: 0.00925279248112
# Iteration 6 Change in Z: 0.00204699732873
# Iteration 7 Change in Z: 0.000485664286731
# Iteration 8 Change in Z: 0.000120551958142
# Iteration 9 Change in Z: 3.08508120678e-05
# Iteration 10 Change in Z: 8.06563549634e-06
# Iteration 11 Change in Z: 2.14131076034e-06
# Iteration 12 Change in Z: 5.74921043843e-07
# Iteration 13 Change in Z: 1.55659123914e-07
# Iteration 14 Change in Z: 4.24116601357e-08
# Iteration 15 Change in Z: 1.16115924634e-08
# Iteration 16 Change in Z: 3.19094201801e-09
# Iteration 17 Change in Z: 8.79455711355e-10
# Iteration 18 Change in Z: 2.42948140717e-10
# Iteration 19 Change in Z: 6.72385258054e-11
# Cluster output
# Number of non-empty clusters: 6079 (of 14463)
#
# Size: count
# 0: 8384
# 1: 5587
# 2: 392
# 3: 67
# 4: 19
# 5: 10
# 6: 3
# 7: 1
#
# Trans: count
# M+2H: 27
# M+H+NH4: 1
# M+H+Na: 2
# M+H+K: 1
# M+ACN+2H: 28
# M+2Na: 2
# M+H: 6048
# M+HC13: 323
# M+H2C13: 16
# M+NH4: 31
# M+Na: 97
# M+NaC13: 17
# M+CH3OH+H: 8
# M+K: 13
# M+KC13: 1
# M+ACN+H: 79
# M+2Na-H: 15
# M+IsoProp+H: 1
# M+ACN+Na: 6
# M+2K-H: 0
# M+DMSO+H: 2
# M+2ACN+H: 5

# %% [markdown]
# Notice the distribution of values in the Z matrices (peak to cluster assignment) for each file. This kind of suggests that the problem doesn't have to be solved by a probability model at all? i.e. the graph-based approach in CAMERA is good enough. Especially for high precision mass spec.

# %% [markdown]
# ### Step 2

# %% [markdown]
# Second stage clustering. Here we cluster the bins across all the fils using a DP mixture on the posterior RT values of the bins.

# %%
# Second-stage clustering
N = len(all_bins)
assert N == len(posterior_bin_rts)

# Here we cluster the 'concrete' common bins across files by their posterior RT values
hp = HyperPars()
hp.rt_prec = 1.0/(across_file_rt_sd*across_file_rt_sd)
hp.rt_prior_prec = 5E-3
hp.alpha = alpha_rt
data = (posterior_bin_rts, all_bins)
dp = DpMixtureGibbs(data, hp)
dp.nsamps = rt_clustering_nsamps
dp.burn_in = rt_clustering_burnin
dp.run()
# Out:
# DpMixtureGibbs initialised
# 	BURN-IN	Iteration 1	time 2.15	numClusters 633
# 	BURN-IN	Iteration 2	time 2.93	numClusters 781
# 	BURN-IN	Iteration 3	time 3.28	numClusters 789
# 	BURN-IN	Iteration 4	time 3.22	numClusters 770
# 	BURN-IN	Iteration 5	time 3.16	numClusters 785
# 	BURN-IN	Iteration 6	time 3.32	numClusters 817
# 	BURN-IN	Iteration 7	time 3.31	numClusters 803
# 	BURN-IN	Iteration 8	time 3.21	numClusters 767
# 	BURN-IN	Iteration 9	time 3.14	numClusters 796
# 	BURN-IN	Iteration 10	time 3.16	numClusters 787
# 	BURN-IN	Iteration 11	time 3.15	numClusters 786
# 	BURN-IN	Iteration 12	time 3.18	numClusters 762
# 	BURN-IN	Iteration 13	time 3.08	numClusters 779
# 	BURN-IN	Iteration 14	time 3.07	numClusters 770
# 	BURN-IN	Iteration 15	time 3.15	numClusters 786
# 	BURN-IN	Iteration 16	time 3.33	numClusters 791
# 	BURN-IN	Iteration 17	time 3.39	numClusters 783
# 	BURN-IN	Iteration 18	time 3.39	numClusters 796
# 	BURN-IN	Iteration 19	time 3.22	numClusters 778
# 	BURN-IN	Iteration 20	time 3.23	numClusters 785
# 	BURN-IN	Iteration 21	time 3.26	numClusters 797
# 	BURN-IN	Iteration 22	time 3.30	numClusters 793
# 	BURN-IN	Iteration 23	time 3.18	numClusters 795
# 	BURN-IN	Iteration 24	time 3.18	numClusters 786
# 	BURN-IN	Iteration 25	time 3.27	numClusters 784
# 	BURN-IN	Iteration 26	time 3.19	numClusters 796
# 	BURN-IN	Iteration 27	time 3.12	numClusters 761
# 	BURN-IN	Iteration 28	time 3.10	numClusters 796
# 	BURN-IN	Iteration 29	time 3.21	numClusters 786
# 	BURN-IN	Iteration 30	time 3.34	numClusters 780
# 	BURN-IN	Iteration 31	time 3.11	numClusters 759
# 	BURN-IN	Iteration 32	time 3.09	numClusters 769
# 	BURN-IN	Iteration 33	time 3.22	numClusters 791
# 	BURN-IN	Iteration 34	time 3.22	numClusters 789
# 	BURN-IN	Iteration 35	time 3.13	numClusters 784
# 	BURN-IN	Iteration 36	time 3.10	numClusters 780
# 	BURN-IN	Iteration 37	time 3.13	numClusters 783
# 	BURN-IN	Iteration 38	time 3.11	numClusters 776
# 	BURN-IN	Iteration 39	time 3.22	numClusters 783
# 	BURN-IN	Iteration 40	time 3.25	numClusters 797
# 	BURN-IN	Iteration 41	time 3.28	numClusters 783
# 	BURN-IN	Iteration 42	time 3.18	numClusters 775
# 	BURN-IN	Iteration 43	time 3.13	numClusters 777
# 	BURN-IN	Iteration 44	time 3.16	numClusters 789
# 	BURN-IN	Iteration 45	time 3.29	numClusters 791
# 	BURN-IN	Iteration 46	time 3.21	numClusters 773
# 	BURN-IN	Iteration 47	time 3.10	numClusters 764
# 	BURN-IN	Iteration 48	time 3.11	numClusters 779
# 	BURN-IN	Iteration 49	time 3.30	numClusters 788
# 	BURN-IN	Iteration 50	time 3.12	numClusters 759
# 	BURN-IN	Iteration 51	time 3.07	numClusters 772
# 	BURN-IN	Iteration 52	time 3.04	numClusters 771
# 	BURN-IN	Iteration 53	time 3.13	numClusters 772
# 	BURN-IN	Iteration 54	time 3.22	numClusters 792
# 	BURN-IN	Iteration 55	time 3.25	numClusters 789
# 	BURN-IN	Iteration 56	time 3.38	numClusters 789
# 	BURN-IN	Iteration 57	time 3.30	numClusters 814
# 	BURN-IN	Iteration 58	time 3.29	numClusters 795
# 	BURN-IN	Iteration 59	time 3.20	numClusters 783
# 	BURN-IN	Iteration 60	time 3.25	numClusters 795
# 	BURN-IN	Iteration 61	time 3.21	numClusters 783
# 	BURN-IN	Iteration 62	time 3.32	numClusters 788
# 	BURN-IN	Iteration 63	time 3.19	numClusters 761
# 	BURN-IN	Iteration 64	time 3.14	numClusters 761
# 	BURN-IN	Iteration 65	time 3.24	numClusters 787
# 	BURN-IN	Iteration 66	time 3.29	numClusters 789
# 	BURN-IN	Iteration 67	time 3.31	numClusters 783
# 	BURN-IN	Iteration 68	time 3.13	numClusters 777
# 	BURN-IN	Iteration 69	time 3.23	numClusters 783
# 	BURN-IN	Iteration 70	time 3.20	numClusters 792
# 	BURN-IN	Iteration 71	time 3.33	numClusters 786
# 	BURN-IN	Iteration 72	time 3.27	numClusters 776
# 	BURN-IN	Iteration 73	time 3.21	numClusters 795
# 	BURN-IN	Iteration 74	time 3.32	numClusters 793
# 	BURN-IN	Iteration 75	time 3.33	numClusters 793
# 	BURN-IN	Iteration 76	time 3.28	numClusters 770
# 	BURN-IN	Iteration 77	time 3.20	numClusters 801
# 	BURN-IN	Iteration 78	time 3.31	numClusters 792
# 	BURN-IN	Iteration 79	time 3.30	numClusters 780
# 	BURN-IN	Iteration 80	time 3.16	numClusters 786
# 	BURN-IN	Iteration 81	time 3.12	numClusters 764
# 	BURN-IN	Iteration 82	time 3.07	numClusters 784
# 	BURN-IN	Iteration 83	time 3.15	numClusters 778
# 	BURN-IN	Iteration 84	time 3.05	numClusters 774
# 	BURN-IN	Iteration 85	time 3.06	numClusters 775
# 	BURN-IN	Iteration 86	time 3.06	numClusters 774
# 	BURN-IN	Iteration 87	time 3.28	numClusters 802
# 	BURN-IN	Iteration 88	time 3.28	numClusters 783
# 	BURN-IN	Iteration 89	time 3.19	numClusters 780
# 	BURN-IN	Iteration 90	time 3.27	numClusters 785
# 	BURN-IN	Iteration 91	time 3.21	numClusters 770
# 	BURN-IN	Iteration 92	time 3.05	numClusters 774
# 	BURN-IN	Iteration 93	time 3.08	numClusters 782
# 	BURN-IN	Iteration 94	time 3.09	numClusters 775
# 	BURN-IN	Iteration 95	time 3.19	numClusters 787
# 	BURN-IN	Iteration 96	time 3.20	numClusters 786
# 	BURN-IN	Iteration 97	time 3.16	numClusters 770
# 	BURN-IN	Iteration 98	time 3.06	numClusters 771
# 	BURN-IN	Iteration 99	time 3.04	numClusters 772
# 	BURN-IN	Iteration 100	time 3.10	numClusters 775
# 	SAMPLE	Iteration 101	time 3.03	numClusters 770
# 	SAMPLE	Iteration 102	time 3.13	numClusters 781
# 	SAMPLE	Iteration 103	time 3.26	numClusters 778
# 	SAMPLE	Iteration 104	time 3.09	numClusters 777
# 	SAMPLE	Iteration 105	time 3.10	numClusters 768
# 	SAMPLE	Iteration 106	time 3.19	numClusters 807
# 	SAMPLE	Iteration 107	time 3.33	numClusters 778
# 	SAMPLE	Iteration 108	time 3.19	numClusters 784
# 	SAMPLE	Iteration 109	time 3.23	numClusters 787
# 	SAMPLE	Iteration 110	time 3.11	numClusters 778
# 	SAMPLE	Iteration 111	time 3.16	numClusters 768
# 	SAMPLE	Iteration 112	time 3.17	numClusters 783
# 	SAMPLE	Iteration 113	time 3.26	numClusters 781
# 	SAMPLE	Iteration 114	time 3.11	numClusters 779
# 	SAMPLE	Iteration 115	time 3.08	numClusters 775
# 	SAMPLE	Iteration 116	time 3.11	numClusters 762
# 	SAMPLE	Iteration 117	time 3.18	numClusters 777
# 	SAMPLE	Iteration 118	time 3.26	numClusters 793
# 	SAMPLE	Iteration 119	time 3.27	numClusters 807
# 	SAMPLE	Iteration 120	time 3.37	numClusters 797
# 	SAMPLE	Iteration 121	time 3.31	numClusters 779
# 	SAMPLE	Iteration 122	time 3.10	numClusters 770
# 	SAMPLE	Iteration 123	time 3.06	numClusters 781
# 	SAMPLE	Iteration 124	time 3.11	numClusters 765
# 	SAMPLE	Iteration 125	time 3.10	numClusters 773
# 	SAMPLE	Iteration 126	time 3.27	numClusters 790
# 	SAMPLE	Iteration 127	time 3.12	numClusters 765
# 	SAMPLE	Iteration 128	time 3.04	numClusters 785
# 	SAMPLE	Iteration 129	time 3.23	numClusters 788
# 	SAMPLE	Iteration 130	time 3.11	numClusters 791
# 	SAMPLE	Iteration 131	time 3.22	numClusters 799
# 	SAMPLE	Iteration 132	time 3.25	numClusters 791
# 	SAMPLE	Iteration 133	time 3.30	numClusters 813
# 	SAMPLE	Iteration 134	time 3.26	numClusters 806
# 	SAMPLE	Iteration 135	time 3.18	numClusters 784
# 	SAMPLE	Iteration 136	time 3.18	numClusters 797
# 	SAMPLE	Iteration 137	time 3.10	numClusters 771
# 	SAMPLE	Iteration 138	time 3.06	numClusters 780
# 	SAMPLE	Iteration 139	time 3.14	numClusters 782
# 	SAMPLE	Iteration 140	time 3.18	numClusters 805
# 	SAMPLE	Iteration 141	time 3.27	numClusters 805
# 	SAMPLE	Iteration 142	time 3.16	numClusters 774
# 	SAMPLE	Iteration 143	time 3.12	numClusters 776
# 	SAMPLE	Iteration 144	time 3.15	numClusters 781
# 	SAMPLE	Iteration 145	time 3.34	numClusters 801
# 	SAMPLE	Iteration 146	time 3.27	numClusters 797
# 	SAMPLE	Iteration 147	time 3.32	numClusters 789
# 	SAMPLE	Iteration 148	time 3.26	numClusters 773
# 	SAMPLE	Iteration 149	time 3.09	numClusters 787
# 	SAMPLE	Iteration 150	time 3.13	numClusters 788
# 	SAMPLE	Iteration 151	time 3.17	numClusters 779
# 	SAMPLE	Iteration 152	time 3.20	numClusters 800
# 	SAMPLE	Iteration 153	time 3.25	numClusters 798
# 	SAMPLE	Iteration 154	time 3.27	numClusters 788
# 	SAMPLE	Iteration 155	time 3.21	numClusters 786
# 	SAMPLE	Iteration 156	time 3.19	numClusters 792
# 	SAMPLE	Iteration 157	time 3.30	numClusters 798
# 	SAMPLE	Iteration 158	time 3.25	numClusters 794
# 	SAMPLE	Iteration 159	time 3.20	numClusters 783
# 	SAMPLE	Iteration 160	time 3.09	numClusters 782
# 	SAMPLE	Iteration 161	time 3.19	numClusters 787
# 	SAMPLE	Iteration 162	time 3.30	numClusters 786
# 	SAMPLE	Iteration 163	time 3.14	numClusters 781
# 	SAMPLE	Iteration 164	time 3.07	numClusters 764
# 	SAMPLE	Iteration 165	time 3.05	numClusters 780
# 	SAMPLE	Iteration 166	time 3.13	numClusters 775
# 	SAMPLE	Iteration 167	time 3.15	numClusters 796
# 	SAMPLE	Iteration 168	time 3.23	numClusters 795
# 	SAMPLE	Iteration 169	time 3.11	numClusters 783
# 	SAMPLE	Iteration 170	time 3.12	numClusters 771
# 	SAMPLE	Iteration 171	time 3.10	numClusters 776
# 	SAMPLE	Iteration 172	time 3.07	numClusters 777
# 	SAMPLE	Iteration 173	time 3.11	numClusters 794
# 	SAMPLE	Iteration 174	time 3.22	numClusters 778
# 	SAMPLE	Iteration 175	time 3.11	numClusters 775
# 	SAMPLE	Iteration 176	time 3.14	numClusters 793
# 	SAMPLE	Iteration 177	time 3.21	numClusters 795
# 	SAMPLE	Iteration 178	time 3.20	numClusters 783
# 	SAMPLE	Iteration 179	time 3.14	numClusters 762
# 	SAMPLE	Iteration 180	time 3.07	numClusters 788
# 	SAMPLE	Iteration 181	time 3.08	numClusters 768
# 	SAMPLE	Iteration 182	time 3.05	numClusters 775
# 	SAMPLE	Iteration 183	time 3.22	numClusters 797
# 	SAMPLE	Iteration 184	time 3.14	numClusters 771
# 	SAMPLE	Iteration 185	time 3.25	numClusters 782
# 	SAMPLE	Iteration 186	time 3.12	numClusters 784
# 	SAMPLE	Iteration 187	time 3.29	numClusters 798
# 	SAMPLE	Iteration 188	time 3.31	numClusters 786
# 	SAMPLE	Iteration 189	time 3.20	numClusters 798
# 	SAMPLE	Iteration 190	time 3.23	numClusters 764
# 	SAMPLE	Iteration 191	time 3.19	numClusters 791
# 	SAMPLE	Iteration 192	time 3.08	numClusters 775
# 	SAMPLE	Iteration 193	time 3.18	numClusters 777
# 	SAMPLE	Iteration 194	time 3.15	numClusters 784
# 	SAMPLE	Iteration 195	time 3.11	numClusters 763
# 	SAMPLE	Iteration 196	time 3.06	numClusters 753
# 	SAMPLE	Iteration 197	time 3.08	numClusters 778
# 	SAMPLE	Iteration 198	time 3.11	numClusters 759
# 	SAMPLE	Iteration 199	time 3.04	numClusters 780
# 	SAMPLE	Iteration 200	time 3.13	numClusters 786
# DONE!

# %% [markdown]
# Observe the no. of clusters is so high?? Need to tweak the hyperparameters further ..?
#
# Also, the gibbs sampling code above is not well-vectorised, so this can probably go a lot faster.
#
# Furthermore, within each sample, we match the peaks in each bin to those other peaks with the nearest mass difference in other same bins (but coming from different files) in the same RT cluster. This is probably not necessary?

# %%
# plot distribution of values in ZZ_all
ZZ_all = dp.ZZ_all
x = []
cx = ZZ_all.tocoo()    
for i,j,v in itertools.izip(cx.row, cx.col, cx.data):
    x.append(v)       
x = np.array(x)
plt.figure() 
plt.hist(x, 10)
plt.title('DP RT clustering -- ZZ_all')
plt.xlabel('Probabilities')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# From the distribution of values in Z in the plot above, we don't see much uncertainty in results .. but this is because for the STD dataset that we use, the RT deviations across files are fairly minimal.

# %% [markdown]
# ### Step 3

# %% [markdown]
# Now need to construct the alignment results from all the clustering output above

# %%
# count frequencies of aligned peaksets produced across the Gibbs samples
print "Counting frequencies of aligned peaksets"
matching_results = dp.matching_results
counter = dict()
for peakset in matching_results:
    if len(peakset) > 1:
        peakset = sorted(peakset, key = attrgetter('file_id'))
        peakset = tuple(peakset)
    if peakset not in counter:
        counter[peakset] = 1
    else:
        counter[peakset] += 1

# normalise the counts
print "Normalising counts"
S = dp.samples_obtained
for key, value in counter.items():
    new_value = float(value)/S
    counter[key] = new_value
# Out:
# Counting frequencies of aligned peaksets
# Normalising counts

# %% [markdown]
# Print reports

# %%
# print report of aligned peaksets in descending order of probabilities
print 
print "=========================================================================="
print "REPORT"
print "=========================================================================="
sorted_list = sorted(counter.items(), key=itemgetter(1), reverse=True)
probs = []
i = 0
for item in sorted_list:
    features = item[0]
    if len(features)==1:
        continue # skip all the singleton stuff
    prob = item[1]
    mzs = np.array([f.mass for f in features])
    rts = np.array([f.rt for f in features])
    avg_mz = np.mean(mzs)
    avg_rt = np.mean(rts)
    print str(i+1) + ". avg m/z=" + str(avg_mz) + " avg RT=" + str(avg_rt) + " prob=" + str(prob)
    for f in features:
        msg = annotations[f]            
        output = "\tfile_id {:d} mz {:3.5f} RT {:4.2f} intensity {:.4e}\t{:s}".format(f.file_id, f.mass, f.rt, f.intensity, msg)
        print(output) 
    probs.append(prob)
    i += 1
# Out:
# ==========================================================================
# REPORT
# ==========================================================================
# 1. avg m/z=354.953721266 avg RT=314.520507812 prob=1.0
# 	file_id 0 mz 354.95391 RT 312.76 intensity 3.0736e+03	M+H@353.94664 prob=1.00
# 	file_id 1 mz 354.95353 RT 316.29 intensity 3.2189e+03	M+H@353.94664 prob=1.00
# 2. avg m/z=303.104303541 avg RT=416.194000244 prob=1.0
# 	file_id 0 mz 303.10433 RT 417.18 intensity 1.3757e+04	M+H@302.09705 prob=1.00
# 	file_id 1 mz 303.10428 RT 415.21 intensity 1.6366e+04	M+H@302.09705 prob=1.00
# 3. avg m/z=174.1024085 avg RT=364.550506592 prob=1.0
# 	file_id 1 mz 174.10228 RT 364.02 intensity 1.0861e+06	M+H@173.09501 prob=1.00
# 	file_id 2 mz 174.10253 RT 365.08 intensity 8.3841e+05	M+H@173.09501 prob=1.00
# 4. avg m/z=95.0437035491 avg RT=2591.61999512 prob=1.0
# 	file_id 0 mz 95.04371 RT 2592.70 intensity 6.8709e+04	M+H@94.03643 prob=1.00
# 	file_id 1 mz 95.04370 RT 2590.54 intensity 7.1507e+04	M+H@94.03643 prob=1.00
# 5. avg m/z=707.220763145 avg RT=801.471984863 prob=1.0
# 	file_id 0 mz 707.22069 RT 801.38 intensity 4.2234e+04	M+H@706.21341 prob=1.00
# 	file_id 1 mz 707.22059 RT 801.93 intensity 4.5474e+04	M+H@706.21341 prob=1.00
# 	file_id 2 mz 707.22101 RT 801.10 intensity 1.0390e+04	M+H@706.21341 prob=1.00
# 6. avg m/z=210.479233342 avg RT=2136.625 prob=1.0
# 	file_id 1 mz 210.47923 RT 2134.80 intensity 5.4749e+04	M+H@209.47195 prob=1.00
# 	file_id 2 mz 210.47924 RT 2138.45 intensity 6.3643e+04	M+H@209.47195 prob=1.00
# 7. avg m/z=225.583701672 avg RT=693.869995117 prob=1.0
# 	file_id 1 mz 205.07034 RT 695.52 intensity 2.5992e+05	M+H@204.06306 prob=1.00
# 	file_id 2 mz 246.09706 RT 692.22 intensity 1.4326e+04	M+ACN+H@204.06306 prob=0.56
# 8. avg m/z=102.532269152 avg RT=2239.76000977 prob=1.0
# 	file_id 1 mz 102.53224 RT 2241.01 intensity 1.0301e+05	M+H@101.52496 prob=1.00
# 	file_id 2 mz 102.53230 RT 2238.51 intensity 1.1325e+05	M+H@101.52496 prob=1.00
# 9. avg m/z=153.02696124 avg RT=1950.48999023 prob=1.0
# 	file_id 0 mz 153.02696 RT 1952.12 intensity 4.9809e+03	M+H@152.01968 prob=1.00
# 	file_id 1 mz 153.02697 RT 1948.86 intensity 8.8634e+03	M+H@152.01968 prob=1.00
# 10. avg m/z=167.012734873 avg RT=2307.04504395 prob=1.0
# 	file_id 0 mz 167.01269 RT 2309.11 intensity 1.3889e+06	M+ACN+H@124.97887 prob=0.53
# 	file_id 2 mz 167.01278 RT 2304.98 intensity 1.9806e+06	M+ACN+H@124.97887 prob=0.85
# 11. avg m/z=200.075540818 avg RT=1773.11499023 prob=1.0
# 	file_id 0 mz 200.07555 RT 1773.00 intensity 4.2679e+04	M+H@199.06828 prob=1.00
# 	file_id 1 mz 200.07553 RT 1773.23 intensity 5.1213e+04	M+H@199.06828 prob=1.00
# 12. avg m/z=125.98608106 avg RT=2626.99499512 prob=1.0
# 	file_id 0 mz 125.98610 RT 2625.39 intensity 3.6045e+05	M+H@124.97882 prob=0.62
# 	file_id 1 mz 125.98607 RT 2628.60 intensity 3.7682e+05	M+H@124.97882 prob=1.00
# 13. avg m/z=199.029033658 avg RT=94.2591018677 prob=1.0
# 	file_id 0 mz 199.02904 RT 91.86 intensity 8.7314e+04	M+H@198.02177 prob=1.00
# 	file_id 1 mz 199.02902 RT 96.66 intensity 1.1223e+05	M+H@198.02177 prob=1.00
# 14. avg m/z=113.536080774 avg RT=470.424514771 prob=1.0
# 	file_id 0 mz 114.03778 RT 470.77 intensity 1.7770e+04	M+HC13@112.02710 prob=0.57
# 	file_id 1 mz 113.03438 RT 470.08 intensity 5.3336e+05	M+H@112.02710 prob=1.00
# 15. avg m/z=84.0659724435 avg RT=2540.04504395 prob=1.0
# 	file_id 0 mz 84.06600 RT 2538.35 intensity 1.3257e+04	M+H@83.05872 prob=1.00
# 	file_id 1 mz 84.06595 RT 2541.74 intensity 1.4791e+04	M+H@83.05872 prob=1.00
# 16. avg m/z=197.592881031 avg RT=314.699996948 prob=1.0
# 	file_id 0 mz 197.59270 RT 315.96 intensity 3.2957e+03	M+H@196.58542 prob=1.00
# 	file_id 2 mz 197.59306 RT 313.44 intensity 1.0558e+05	M+H@196.58542 prob=1.00
# 17. avg m/z=1010.30034349 avg RT=747.149993896 prob=1.0
# 	file_id 0 mz 1010.30025 RT 747.48 intensity 9.0517e+03	M+H@1009.29298 prob=1.00
# 	file_id 1 mz 1010.30043 RT 746.82 intensity 9.6775e+03	M+H@1009.29298 prob=1.00
# 18. avg m/z=152.070425696 avg RT=804.584991455 prob=1.0
# 	file_id 0 mz 152.07043 RT 804.32 intensity 1.3559e+06	M+NH4@134.03656 prob=0.64
# 	file_id 1 mz 152.07042 RT 804.85 intensity 1.5576e+06	M+NH4@134.03656 prob=0.67
# 19. avg m/z=73.5318270813 avg RT=2464.40002441 prob=1.0
# 	file_id 0 mz 73.53181 RT 2466.83 intensity 3.4845e+05	M+H@72.52453 prob=1.00
# 	file_id 2 mz 73.53184 RT 2461.97 intensity 7.9496e+04	M+H@72.52453 prob=1.00
# 20. avg m/z=114.558246208 avg RT=2034.68005371 prob=1.0
# 	file_id 0 mz 114.55825 RT 2035.55 intensity 2.7681e+05	M+H@113.55097 prob=1.00
# 	file_id 1 mz 114.55825 RT 2033.81 intensity 3.9259e+05	M+H@113.55097 prob=1.00
# 21. avg m/z=157.049359786 avg RT=772.388977051 prob=1.0
# 	file_id 1 mz 157.04928 RT 772.51 intensity 3.1342e+04	M+H@156.04200 prob=1.00
# 	file_id 2 mz 157.04944 RT 772.27 intensity 7.8951e+03	M+H@156.04200 prob=1.00
# 22. avg m/z=163.132595827 avg RT=337.590667725 prob=1.0
# 	file_id 0 mz 163.13254 RT 338.05 intensity 2.4698e+04	M+H@162.12527 prob=1.00
# 	file_id 1 mz 163.13252 RT 341.21 intensity 2.3603e+04	M+H@162.12527 prob=1.00
# 	file_id 2 mz 163.13272 RT 333.52 intensity 4.5403e+04	M+H@162.12527 prob=1.00
# 23. avg m/z=309.203009042 avg RT=1.54009997845 prob=1.0
# 	file_id 0 mz 309.20300 RT 1.54 intensity 4.2835e+04	M+H@308.19572 prob=1.00
# 	file_id 1 mz 309.20302 RT 1.54 intensity 3.3304e+04	M+H@308.19572 prob=1.00
# 24. avg m/z=377.105230222 avg RT=573.447021484 prob=1.0
# 	file_id 1 mz 377.10493 RT 574.21 intensity 7.2417e+04	M+H@376.09766 prob=1.00
# 	file_id 2 mz 377.10553 RT 572.69 intensity 5.8752e+04	M+H@376.09766 prob=1.00
# 25. avg m/z=325.112590223 avg RT=745.07699585 prob=1.0
# 	file_id 1 mz 325.11228 RT 746.82 intensity 2.4325e+04	M+H@324.10501 prob=1.00
# 	file_id 2 mz 325.11290 RT 743.33 intensity 1.0449e+04	M+H@324.10501 prob=1.00
# 26. avg m/z=182.985050335 avg RT=2035.44500732 prob=1.0
# 	file_id 0 mz 182.98508 RT 2037.08 intensity 7.3615e+05	M+H@181.97780 prob=1.00
# 	file_id 1 mz 182.98503 RT 2033.81 intensity 9.0079e+05	M+H@181.97780 prob=1.00
# 27. avg m/z=102.535345825 avg RT=2506.16503906 prob=1.0
# 	file_id 0 mz 102.53533 RT 2507.29 intensity 2.5080e+05	M+H@101.52805 prob=1.00
# 	file_id 2 mz 102.53536 RT 2505.04 intensity 2.8431e+05	M+H@101.52805 prob=1.00
# 28. avg m/z=151.035215798 avg RT=2174.77502441 prob=1.0
# 	file_id 1 mz 151.03518 RT 2173.45 intensity 5.1682e+05	M+H@150.02797 prob=0.69
# 	file_id 2 mz 151.03525 RT 2176.10 intensity 4.9154e+05	M+H@150.02797 prob=1.00
# 29. avg m/z=187.059710395 avg RT=706.710021973 prob=1.0
# 	file_id 0 mz 187.05974 RT 705.33 intensity 2.4461e+04	M+H@186.05246 prob=1.00
# 	file_id 1 mz 187.05968 RT 708.09 intensity 2.3720e+04	M+H@186.05246 prob=1.00
# 30. avg m/z=157.514491181 avg RT=441.829498291 prob=1.0
# 	file_id 0 mz 158.01612 RT 441.30 intensity 4.3685e+03	M+HC13@156.00562 prob=0.62
# 	file_id 1 mz 157.01287 RT 442.36 intensity 8.4033e+04	M+H@156.00562 prob=1.00
# 31. avg m/z=81.016943636 avg RT=501.371505737 prob=1.0
# 	file_id 0 mz 81.01695 RT 499.46 intensity 4.2199e+04	M+H@80.00967 prob=1.00
# 	file_id 1 mz 81.01694 RT 503.28 intensity 3.4509e+04	M+H@80.00967 prob=1.00
# 32. avg m/z=99.9881114109 avg RT=817.661987305 prob=1.0
# 	file_id 0 mz 99.98810 RT 817.43 intensity 4.8325e+03	M+H@98.98083 prob=1.00
# 	file_id 1 mz 99.98812 RT 817.90 intensity 5.5383e+03	M+H@98.98083 prob=1.00
# 33. avg m/z=157.083218205 avg RT=14.6252503395 prob=1.0
# 	file_id 0 mz 157.08327 RT 16.18 intensity 2.1235e+04	M+H@156.07599 prob=1.00
# 	file_id 1 mz 157.08317 RT 13.07 intensity 2.7714e+04	M+H@156.07599 prob=1.00
# 34. avg m/z=82.537104948 avg RT=54.6358324687 prob=1.0
# 	file_id 0 mz 82.53710 RT 54.20 intensity 1.2300e+05	M+H@81.52982 prob=1.00
# 	file_id 1 mz 82.53710 RT 55.03 intensity 1.1217e+05	M+H@81.52982 prob=1.00
# 	file_id 2 mz 82.53711 RT 54.67 intensity 3.3666e+04	M+H@81.52982 prob=1.00
# 35. avg m/z=255.944016586 avg RT=2112.01501465 prob=1.0
# 	file_id 0 mz 255.94404 RT 2114.26 intensity 5.9481e+05	M+ACN+H@213.91018 prob=0.62
# 	file_id 1 mz 255.94399 RT 2109.77 intensity 6.6507e+05	M+ACN+H@213.91018 prob=0.62
# 36. avg m/z=424.149446574 avg RT=588.163309733 prob=1.0
# 	file_id 0 mz 431.14210 RT 585.53 intensity 3.7487e+04	M+Na@408.15289 prob=0.63
# 	file_id 1 mz 431.14213 RT 588.82 intensity 4.0691e+04	M+Na@408.15289 prob=0.81
# 	file_id 2 mz 410.16411 RT 590.13 intensity 1.5420e+04	M+HC13@408.15289 prob=0.67
# 37. avg m/z=191.138625603 avg RT=1956.77496338 prob=1.0
# 	file_id 0 mz 191.13864 RT 1958.46 intensity 3.7399e+04	M+H@190.13137 prob=1.00
# 	file_id 1 mz 191.13861 RT 1955.09 intensity 3.4651e+04	M+H@190.13137 prob=1.00
# 38. avg m/z=196.096420474 avg RT=706.710021973 prob=1.0
# 	file_id 0 mz 196.09644 RT 705.33 intensity 1.7356e+04	M+H@195.08916 prob=1.00
# 	file_id 1 mz 196.09640 RT 708.09 intensity 1.8091e+04	M+H@195.08916 prob=0.77
# 39. avg m/z=245.098589135 avg RT=423.518493652 prob=1.0
# 	file_id 1 mz 245.09837 RT 424.82 intensity 4.2581e+03	M+H@244.09109 prob=1.00
# 	file_id 2 mz 245.09881 RT 422.21 intensity 3.9987e+03	M+H@244.09109 prob=1.00
# 40. avg m/z=566.887736321 avg RT=1261.0300293 prob=1.0
# 	file_id 0 mz 566.88773 RT 1260.89 intensity 7.8277e+04	M+H@565.88046 prob=1.00
# 	file_id 1 mz 566.88774 RT 1261.17 intensity 8.3116e+04	M+H@565.88046 prob=1.00
# 41. avg m/z=113.049300983 avg RT=541.901519775 prob=1.0
# 	file_id 0 mz 113.04932 RT 543.18 intensity 4.3981e+03	M+H@112.04204 prob=1.00
# 	file_id 1 mz 113.04928 RT 540.62 intensity 3.8968e+03	M+H@112.04204 prob=1.00
# 42. avg m/z=130.521734165 avg RT=54.6502494812 prob=1.0
# 	file_id 0 mz 110.00852 RT 55.76 intensity 2.8622e+04	M+H@109.00124 prob=1.00
# 	file_id 1 mz 151.03495 RT 53.54 intensity 1.6905e+05	M+ACN+H@109.00124 prob=0.75
# 43. avg m/z=298.21521469 avg RT=599.725494385 prob=1.0
# 	file_id 0 mz 298.21523 RT 601.78 intensity 8.7399e+03	M+H@297.20795 prob=1.00
# 	file_id 1 mz 298.21520 RT 597.67 intensity 9.1615e+03	M+H@297.20795 prob=1.00
# 44. avg m/z=211.070936366 avg RT=471.963500977 prob=1.0
# 	file_id 0 mz 211.07095 RT 472.31 intensity 2.5920e+04	M+H@210.06367 prob=1.00
# 	file_id 1 mz 211.07093 RT 471.62 intensity 2.8786e+04	M+H@210.06367 prob=1.00
# 45. avg m/z=347.596062356 avg RT=549.976989746 prob=1.0
# 	file_id 0 mz 348.09770 RT 547.59 intensity 2.6841e+05	M+HC13@346.08723 prob=0.57
# 	file_id 1 mz 347.09442 RT 552.36 intensity 2.2481e+06	M+H@346.08723 prob=1.00
# 46. avg m/z=256.666170147 avg RT=313.274505615 prob=1.0
# 	file_id 1 mz 256.66595 RT 313.11 intensity 3.8779e+03	M+H@255.65867 prob=1.00
# 	file_id 2 mz 256.66639 RT 313.44 intensity 2.3350e+04	M+H@255.65867 prob=1.00
# 47. avg m/z=274.761255931 avg RT=360.708669027 prob=1.0
# 	file_id 0 mz 287.07876 RT 362.43 intensity 4.8272e+03	M+K@248.11573 prob=0.70
# 	file_id 1 mz 287.07844 RT 359.43 intensity 5.0261e+03	M+K@248.11573 prob=0.74
# 	file_id 2 mz 250.12657 RT 360.27 intensity 3.6416e+04	M+HC13@248.11573 prob=0.67
# 48. avg m/z=162.0142672 avg RT=455.843505859 prob=1.0
# 	file_id 0 mz 162.01422 RT 453.85 intensity 4.9084e+03	M+HC13@160.00363 prob=0.57
# 	file_id 1 mz 162.01432 RT 457.84 intensity 4.4972e+03	M+HC13@160.00363 prob=0.81
# 49. avg m/z=104.030045911 avg RT=1935.2699585 prob=1.0
# 	file_id 1 mz 104.02999 RT 1936.35 intensity 6.8534e+04	M+H@103.02271 prob=1.00
# 	file_id 2 mz 104.03010 RT 1934.19 intensity 6.0094e+04	M+H@103.02271 prob=1.00
# 50. avg m/z=141.958387478 avg RT=2630.85009766 prob=1.0
# 	file_id 0 mz 141.95840 RT 2630.08 intensity 9.7871e+04	M+H@140.95113 prob=1.00
# 	file_id 1 mz 141.95837 RT 2631.62 intensity 1.3375e+05	M+H@140.95113 prob=1.00
# 51. avg m/z=321.201598572 avg RT=814.053009033 prob=1.0
# 	file_id 0 mz 321.20163 RT 814.54 intensity 3.1900e+04	M+H@320.19435 prob=1.00
# 	file_id 1 mz 321.20157 RT 813.57 intensity 3.0237e+04	M+H@320.19435 prob=1.00
# 52. avg m/z=330.117640068 avg RT=388.283493042 prob=1.0
# 	file_id 0 mz 330.11766 RT 387.52 intensity 1.7340e+04	M+H@329.11039 prob=1.00
# 	file_id 1 mz 330.11762 RT 389.05 intensity 1.9727e+04	M+H@329.11039 prob=1.00
# 53. avg m/z=334.11247864 avg RT=453.542510986 prob=1.0
# 	file_id 0 mz 334.11244 RT 453.85 intensity 5.8696e+03	M+H@333.10516 prob=1.00
# 	file_id 1 mz 334.11252 RT 453.24 intensity 5.0848e+03	M+H@333.10516 prob=1.00
# 54. avg m/z=140.059006518 avg RT=352.970326742 prob=1.0
# 	file_id 0 mz 140.05892 RT 354.81 intensity 1.2951e+04	M+H@139.05165 prob=1.00
# 	file_id 1 mz 140.05894 RT 353.37 intensity 9.7871e+03	M+H@139.05165 prob=1.00
# 	file_id 2 mz 140.05916 RT 350.73 intensity 5.1815e+03	M+H@139.05165 prob=1.00
# 55. avg m/z=448.180918753 avg RT=744.87298584 prob=1.0
# 	file_id 0 mz 448.18102 RT 745.96 intensity 4.3563e+03	M+H@447.17374 prob=1.00
# 	file_id 1 mz 448.18082 RT 743.79 intensity 4.5750e+03	M+H@447.17374 prob=1.00
# 56. avg m/z=354.998616469 avg RT=311.330505371 prob=1.0
# 	file_id 0 mz 354.99872 RT 311.15 intensity 5.2790e+03	M+H@353.99145 prob=1.00
# 	file_id 1 mz 354.99851 RT 311.51 intensity 5.0586e+03	M+H@353.99145 prob=1.00
# 57. avg m/z=355.083771106 avg RT=308.103012085 prob=1.0
# 	file_id 0 mz 355.08388 RT 306.30 intensity 9.7320e+03	M+H@354.07660 prob=1.00
# 	file_id 1 mz 355.08367 RT 309.91 intensity 1.3583e+04	M+H@354.07660 prob=1.00
# 58. avg m/z=102.033777055 avg RT=2338.11499023 prob=1.0
# 	file_id 0 mz 102.03378 RT 2336.91 intensity 5.6183e+06	M+H@101.02650 prob=1.00
# 	file_id 1 mz 102.03377 RT 2339.32 intensity 5.9512e+06	M+H@101.02650 prob=1.00
# 59. avg m/z=82.537081727 avg RT=2367.03991699 prob=1.0
# 	file_id 1 mz 82.53709 RT 2366.64 intensity 9.1118e+04	M+H@81.52981 prob=1.00
# 	file_id 2 mz 82.53707 RT 2367.44 intensity 2.8262e+04	M+H@81.52981 prob=1.00
# 60. avg m/z=104.106782845 avg RT=1201.11004639 prob=1.0
# 	file_id 0 mz 104.10671 RT 1201.30 intensity 2.4014e+04	M+H@103.09944 prob=1.00
# 	file_id 2 mz 104.10685 RT 1200.92 intensity 1.1855e+04	M+H@103.09944 prob=1.00
# 61. avg m/z=277.082970023 avg RT=1203.52496338 prob=1.0
# 	file_id 0 mz 277.08302 RT 1204.58 intensity 8.1834e+03	M+H@276.07574 prob=1.00
# 	file_id 1 mz 277.08292 RT 1202.47 intensity 8.0368e+03	M+H@276.07574 prob=1.00
# 62. avg m/z=95.0437330767 avg RT=86.3214009603 prob=1.0
# 	file_id 0 mz 95.04370 RT 85.51 intensity 8.7470e+04	M+H@94.03643 prob=1.00
# 	file_id 1 mz 95.04368 RT 90.38 intensity 9.2616e+04	M+H@94.03643 prob=1.00
# 	file_id 2 mz 95.04381 RT 83.08 intensity 1.6394e+05	M+H@94.03643 prob=1.00
# 63. avg m/z=199.216593839 avg RT=814.773010254 prob=1.0
# 	file_id 0 mz 199.21660 RT 814.54 intensity 3.9498e+04	M+H@198.20933 prob=1.00
# 	file_id 1 mz 199.21658 RT 815.01 intensity 3.7564e+04	M+H@198.20933 prob=1.00
# 64. avg m/z=124.11189351 avg RT=818.378997803 prob=1.0
# 	file_id 0 mz 124.11191 RT 820.30 intensity 1.4666e+04	M+H@123.10463 prob=1.00
# 	file_id 1 mz 124.11188 RT 816.46 intensity 1.3503e+04	M+H@123.10463 prob=1.00
# 65. avg m/z=508.202353983 avg RT=753.25 prob=1.0
# 	file_id 0 mz 508.20210 RT 753.55 intensity 5.3261e+05	M+H@507.19483 prob=1.00
# 	file_id 1 mz 508.20201 RT 749.84 intensity 5.4556e+05	M+H@507.19483 prob=1.00
# 	file_id 2 mz 508.20295 RT 756.35 intensity 2.0671e+05	M+H@507.19483 prob=1.00
# 66. avg m/z=207.06477822 avg RT=405.48399353 prob=1.0
# 	file_id 0 mz 207.06480 RT 405.61 intensity 1.9696e+03	M+H@206.05752 prob=1.00
# 	file_id 1 mz 207.06476 RT 405.36 intensity 1.8119e+03	M+H@206.05752 prob=1.00
# 67. avg m/z=326.133077261 avg RT=762.260986328 prob=1.0
# 	file_id 1 mz 326.13279 RT 763.43 intensity 1.2925e+04	M+H@325.12609 prob=0.72
# 	file_id 2 mz 326.13337 RT 761.09 intensity 1.0841e+04	M+H@325.12609 prob=1.00
# 68. avg m/z=138.049005883 avg RT=620.843994141 prob=1.0
# 	file_id 0 mz 137.04565 RT 621.19 intensity 4.3728e+06	M+H@136.03837 prob=1.00
# 	file_id 2 mz 139.05236 RT 620.50 intensity 3.5232e+03	M+H2C13@136.03837 prob=0.65
# 69. avg m/z=205.078924353 avg RT=559.842498779 prob=1.0
# 	file_id 0 mz 205.07884 RT 559.25 intensity 5.5485e+04	M+H@204.07157 prob=1.00
# 	file_id 2 mz 205.07901 RT 560.43 intensity 5.7225e+04	M+H@204.07157 prob=1.00
# 70. avg m/z=227.117498023 avg RT=319.347000122 prob=1.0
# 	file_id 0 mz 227.11753 RT 319.20 intensity 2.7589e+04	M+H@226.11026 prob=1.00
# 	file_id 1 mz 227.11746 RT 319.49 intensity 3.1442e+04	M+H@226.11026 prob=1.00
# 71. avg m/z=166.080830394 avg RT=750.936004639 prob=1.0
# 	file_id 0 mz 166.08084 RT 750.52 intensity 6.3029e+04	M+H@165.07356 prob=1.00
# 	file_id 1 mz 166.08082 RT 751.36 intensity 4.9922e+04	M+H@165.07356 prob=1.00
# 72. avg m/z=382.022059625 avg RT=312.923995972 prob=1.0
# 	file_id 0 mz 382.02184 RT 311.15 intensity 4.2421e+03	M+H@381.01457 prob=1.00
# 	file_id 1 mz 382.02228 RT 314.70 intensity 5.8418e+03	M+H@381.01457 prob=1.00
# 73. avg m/z=81.5205825623 avg RT=2108.30004883 prob=1.0
# 	file_id 0 mz 81.52059 RT 2106.83 intensity 7.8431e+06	M+H@80.51331 prob=1.00
# 	file_id 1 mz 81.52057 RT 2109.77 intensity 7.8867e+06	M+H@80.51331 prob=1.00
# 74. avg m/z=393.136140052 avg RT=477.386993408 prob=1.0
# 	file_id 0 mz 393.13618 RT 475.41 intensity 2.7135e+05	M+H@392.12890 prob=1.00
# 	file_id 1 mz 393.13610 RT 479.36 intensity 2.5585e+05	M+H@392.12890 prob=1.00
# 75. avg m/z=360.018195341 avg RT=594.538482666 prob=1.0
# 	file_id 0 mz 360.01823 RT 592.89 intensity 1.3880e+04	M+H@359.01095 prob=1.00
# 	file_id 1 mz 360.01816 RT 596.19 intensity 2.0354e+04	M+H@359.01095 prob=0.65
# 76. avg m/z=199.02896665 avg RT=31.0579509735 prob=1.0
# 	file_id 0 mz 199.02899 RT 32.77 intensity 2.2381e+04	M+H@198.02172 prob=1.00
# 	file_id 1 mz 199.02894 RT 29.35 intensity 2.4289e+04	M+H@198.02172 prob=1.00
# 77. avg m/z=94.0449763716 avg RT=2566.23510742 prob=1.0
# 	file_id 0 mz 94.04499 RT 2567.85 intensity 4.9385e+05	M+H@93.03771 prob=1.00
# 	file_id 1 mz 94.04497 RT 2564.62 intensity 6.6059e+05	M+H@93.03771 prob=1.00
# 78. avg m/z=94.0449878008 avg RT=2509.29003906 prob=1.0
# 	file_id 0 mz 94.04500 RT 2507.29 intensity 5.8139e+05	M+H@93.03772 prob=1.00
# 	file_id 1 mz 94.04497 RT 2511.29 intensity 6.9962e+05	M+H@93.03772 prob=1.00
# 79. avg m/z=180.989390292 avg RT=2473.15490723 prob=1.0
# 	file_id 0 mz 180.98945 RT 2474.65 intensity 9.3252e+03	M+H@179.98217 prob=1.00
# 	file_id 1 mz 180.98933 RT 2471.66 intensity 1.3023e+04	M+H@179.98217 prob=1.00
# 80. avg m/z=199.168987134 avg RT=316.12449646 prob=1.0
# 	file_id 0 mz 199.16900 RT 315.96 intensity 9.4350e+05	M+H@198.16172 prob=0.62
# 	file_id 1 mz 199.16898 RT 316.29 intensity 7.4952e+05	M+H@198.16172 prob=0.61
# 81. avg m/z=153.032440251 avg RT=2630.10009766 prob=1.0
# 	file_id 0 mz 153.03247 RT 2630.08 intensity 1.7616e+04	M+H@152.02520 prob=1.00
# 	file_id 1 mz 153.03241 RT 2630.12 intensity 1.8518e+04	M+H@152.02520 prob=1.00
# 82. avg m/z=597.139244568 avg RT=76.1870994568 prob=1.0
# 	file_id 0 mz 600.11849 RT 76.00 intensity 1.0030e+04	M+NaC13@576.12618 prob=0.62
# 	file_id 1 mz 594.16000 RT 76.37 intensity 6.9414e+04	M+NH4@576.12618 prob=0.62
# 83. avg m/z=89.5066496892 avg RT=2651.64001465 prob=1.0
# 	file_id 0 mz 89.50666 RT 2653.45 intensity 1.7835e+05	M+H@88.49939 prob=1.00
# 	file_id 1 mz 89.50664 RT 2649.83 intensity 2.4685e+05	M+H@88.49939 prob=1.00
# 84. avg m/z=84.0426900252 avg RT=4.40353012085 prob=1.0
# 	file_id 0 mz 84.04264 RT 2.98 intensity 5.9780e+03	M+H@83.03536 prob=1.00
# 	file_id 1 mz 84.04274 RT 5.83 intensity 7.0560e+03	M+H@83.03536 prob=1.00
# 85. avg m/z=307.043422616 avg RT=616.29901123 prob=1.0
# 	file_id 0 mz 307.04317 RT 615.21 intensity 1.5265e+04	M+K@268.08043 prob=0.62
# 	file_id 2 mz 307.04368 RT 617.39 intensity 1.6465e+04	M+K@268.08043 prob=0.83
# 86. avg m/z=81.0334597981 avg RT=468.885513306 prob=1.0
# 	file_id 0 mz 81.03347 RT 467.69 intensity 1.8156e+05	M+H@80.02619 prob=1.00
# 	file_id 1 mz 81.03345 RT 470.08 intensity 1.7760e+05	M+H@80.02619 prob=1.00
# 87. avg m/z=430.243437911 avg RT=648.966003418 prob=1.0
# 	file_id 1 mz 430.24305 RT 649.01 intensity 1.2957e+04	M+H@429.23577 prob=1.00
# 	file_id 2 mz 430.24383 RT 648.92 intensity 8.9883e+03	M+H@429.23577 prob=1.00
# 88. avg m/z=89.5066511706 avg RT=2625.44506836 prob=1.0
# 	file_id 0 mz 89.50667 RT 2623.83 intensity 1.8829e+05	M+H@88.49939 prob=1.00
# 	file_id 1 mz 89.50664 RT 2627.06 intensity 2.3806e+05	M+H@88.49939 prob=0.75
# 89. avg m/z=151.035149561 avg RT=2236.6550293 prob=1.0
# 	file_id 0 mz 151.03516 RT 2236.84 intensity 3.9589e+05	M+H@150.02789 prob=1.00
# 	file_id 1 mz 151.03513 RT 2236.47 intensity 4.4919e+05	M+H@150.02789 prob=1.00
# 90. avg m/z=122.54692506 avg RT=2591.61999512 prob=1.0
# 	file_id 0 mz 122.54693 RT 2592.70 intensity 1.3154e+05	M+H@121.53966 prob=1.00
# 	file_id 1 mz 122.54692 RT 2590.54 intensity 1.6701e+05	M+H@121.53966 prob=1.00
# 91. avg m/z=152.035893419 avg RT=2236.13500977 prob=1.0
# 	file_id 0 mz 152.03588 RT 2235.30 intensity 3.6763e+04	M+H@151.02861 prob=1.00
# 	file_id 2 mz 152.03590 RT 2236.97 intensity 3.1961e+04	M+H@151.02861 prob=1.00
# 92. avg m/z=341.265602062 avg RT=103.041000366 prob=1.0
# 	file_id 0 mz 341.26558 RT 101.50 intensity 4.2169e+03	M+H@340.25830 prob=1.00
# 	file_id 1 mz 341.26563 RT 104.58 intensity 4.1969e+03	M+H@340.25830 prob=1.00
# 93. avg m/z=415.125909468 avg RT=858.9659729 prob=1.0
# 	file_id 0 mz 415.12596 RT 859.55 intensity 5.7946e+03	M+HC13@413.11524 prob=0.62
# 	file_id 1 mz 415.12586 RT 858.38 intensity 6.4301e+03	M+HC13@413.11524 prob=0.62
# 94. avg m/z=102.033815717 avg RT=2255.05004883 prob=1.0
# 	file_id 1 mz 102.03379 RT 2253.10 intensity 8.0766e+06	M+H@101.02651 prob=1.00
# 	file_id 2 mz 102.03385 RT 2257.00 intensity 8.0350e+06	M+H@101.02651 prob=1.00
# 95. avg m/z=151.03515974 avg RT=2387.08496094 prob=1.0
# 	file_id 1 mz 151.03508 RT 2387.93 intensity 3.1550e+05	M+H@150.02781 prob=1.00
# 	file_id 2 mz 151.03524 RT 2386.24 intensity 2.6394e+05	M+H@150.02781 prob=1.00
# 96. avg m/z=153.032441149 avg RT=2656.99499512 prob=1.0
# 	file_id 0 mz 153.03245 RT 2658.08 intensity 1.9235e+04	M+H@152.02517 prob=1.00
# 	file_id 1 mz 153.03243 RT 2655.91 intensity 2.2705e+04	M+H@152.02517 prob=1.00
# 97. avg m/z=200.577280618 avg RT=1770.81500244 prob=1.0
# 	file_id 0 mz 200.57734 RT 1768.40 intensity 7.5589e+03	M+H@199.57006 prob=1.00
# 	file_id 1 mz 200.57722 RT 1773.23 intensity 1.0871e+04	M+H@199.57006 prob=1.00
# 98. avg m/z=320.568208276 avg RT=103.048999786 prob=1.0
# 	file_id 0 mz 320.56816 RT 103.13 intensity 5.7767e+03	M+H@319.56088 prob=1.00
# 	file_id 1 mz 320.56826 RT 102.97 intensity 4.9442e+03	M+H@319.56088 prob=1.00
# 99. avg m/z=520.1382858 avg RT=300.690002441 prob=1.0
# 	file_id 0 mz 520.13855 RT 301.31 intensity 1.4412e+04	M+H@519.13127 prob=1.00
# 	file_id 1 mz 520.13802 RT 300.07 intensity 1.2634e+04	M+H@519.13127 prob=1.00
# 100. avg m/z=122.130071149 avg RT=814.044006348 prob=1.0
# 	file_id 0 mz 142.14170 RT 813.08 intensity 9.2633e+03	M+ACN+H@100.10793 prob=0.53
# 	file_id 1 mz 102.11844 RT 815.01 intensity 2.8790e+04	M+HC13@100.10793 prob=0.65
# 101. avg m/z=116.608493156 avg RT=344.973999023 prob=1.0
# 	file_id 0 mz 117.11018 RT 344.17 intensity 6.3238e+03	M+HC13@115.09955 prob=0.62
# 	file_id 1 mz 116.10681 RT 345.78 intensity 9.3529e+04	M+H@115.09955 prob=1.00
# 102. avg m/z=90.5258226151 avg RT=2503.00500488 prob=1.0
# 	file_id 0 mz 90.52577 RT 2504.15 intensity 5.8423e+05	M+H@89.51849 prob=1.00
# 	file_id 2 mz 90.52588 RT 2501.86 intensity 1.6535e+05	M+H@89.51849 prob=1.00
# 103. avg m/z=433.822227872 avg RT=740.297993978 prob=1.0
# 	file_id 0 mz 448.14229 RT 739.85 intensity 2.1440e+04	M+Na@425.15287 prob=0.57
# 	file_id 1 mz 426.16008 RT 737.71 intensity 1.5746e+05	M+H@425.15287 prob=1.00
# 	file_id 2 mz 427.16431 RT 743.33 intensity 1.5069e+04	M+HC13@425.15287 prob=0.57
# 104. avg m/z=210.997458994 avg RT=364.761001587 prob=1.0
# 	file_id 0 mz 210.99742 RT 365.50 intensity 9.1358e+03	M+H@209.99014 prob=1.00
# 	file_id 1 mz 210.99750 RT 364.02 intensity 8.7145e+03	M+H@209.99014 prob=1.00
# 105. avg m/z=161.089973714 avg RT=346.497512817 prob=1.0
# 	file_id 0 mz 161.08998 RT 347.21 intensity 6.4299e+04	M+HC13@159.07947 prob=0.62
# 	file_id 1 mz 161.08997 RT 345.78 intensity 5.5028e+04	M+HC13@159.07947 prob=0.53
# 106. avg m/z=298.197903696 avg RT=589.385986328 prob=1.0
# 	file_id 0 mz 298.19792 RT 591.41 intensity 9.9298e+03	M+H@297.19064 prob=1.00
# 	file_id 1 mz 298.19789 RT 587.36 intensity 9.9937e+03	M+H@297.19064 prob=1.00
# 107. avg m/z=417.03749059 avg RT=325.729507446 prob=1.0
# 	file_id 0 mz 417.03748 RT 325.62 intensity 7.2181e+03	M+H@416.03020 prob=1.00
# 	file_id 1 mz 417.03750 RT 325.84 intensity 5.1927e+03	M+H@416.03020 prob=1.00
# 108. avg m/z=147.064913927 avg RT=444.707000732 prob=1.0
# 	file_id 1 mz 147.06486 RT 445.50 intensity 7.1051e+03	M+H@146.05759 prob=0.82
# 	file_id 2 mz 147.06496 RT 443.92 intensity 6.0387e+03	M+H@146.05759 prob=1.00
# 109. avg m/z=223.080849632 avg RT=907.346008301 prob=1.0
# 	file_id 0 mz 223.08079 RT 908.62 intensity 6.6133e+04	M+H@222.07351 prob=1.00
# 	file_id 1 mz 223.08071 RT 905.62 intensity 6.6881e+04	M+H@222.07351 prob=1.00
# 	file_id 2 mz 223.08106 RT 907.80 intensity 2.6820e+04	M+H@222.07351 prob=1.00
# 110. avg m/z=214.917451475 avg RT=2112.01501465 prob=1.0
# 	file_id 0 mz 214.91746 RT 2114.26 intensity 1.1792e+05	M+H@213.91018 prob=1.00
# 	file_id 1 mz 214.91744 RT 2109.77 intensity 1.1157e+05	M+H@213.91018 prob=1.00
# 111. avg m/z=366.108652689 avg RT=803.501983643 prob=1.0
# 	file_id 0 mz 366.10844 RT 804.32 intensity 2.3213e+05	M+H@365.10116 prob=1.00
# 	file_id 2 mz 366.10887 RT 802.68 intensity 9.7049e+04	M+H@365.10116 prob=0.81
# 112. avg m/z=384.181582472 avg RT=645.621002197 prob=1.0
# 	file_id 1 mz 384.18128 RT 645.88 intensity 2.6758e+03	M+H@383.17400 prob=1.00
# 	file_id 2 mz 384.18189 RT 645.37 intensity 3.5763e+03	M+H@383.17400 prob=1.00
# 113. avg m/z=234.1313806 avg RT=339.627502441 prob=1.0
# 	file_id 0 mz 234.13140 RT 338.05 intensity 1.1080e+06	M+HC13@232.12091 prob=0.55
# 	file_id 1 mz 234.13136 RT 341.21 intensity 1.0753e+06	M+HC13@232.12091 prob=0.53
# 114. avg m/z=245.03317031 avg RT=563.8125 prob=1.0
# 	file_id 0 mz 245.03315 RT 565.07 intensity 1.2129e+04	M+KC13@205.06645 prob=0.56
# 	file_id 1 mz 245.03319 RT 562.56 intensity 1.3758e+04	M+KC13@205.06645 prob=0.51
# 115. avg m/z=132.073320008 avg RT=400.569503784 prob=1.0
# 	file_id 0 mz 132.07337 RT 400.67 intensity 3.9040e+03	M+HC13@130.06277 prob=0.50
# 	file_id 1 mz 132.07327 RT 400.47 intensity 4.4237e+03	M+HC13@130.06277 prob=0.54
# 116. avg m/z=286.128030369 avg RT=707.536010742 prob=1.0
# 	file_id 0 mz 286.12789 RT 706.90 intensity 1.8098e+04	M+H@285.12062 prob=1.00
# 	file_id 1 mz 286.12783 RT 708.09 intensity 1.9297e+04	M+H@285.12062 prob=1.00
# 	file_id 2 mz 286.12836 RT 707.62 intensity 3.8620e+04	M+H@285.12062 prob=1.00
# 117. avg m/z=165.054433783 avg RT=338.105499268 prob=1.0
# 	file_id 0 mz 165.05444 RT 339.58 intensity 7.6619e+05	M+H@164.04716 prob=1.00
# 	file_id 1 mz 165.05443 RT 336.63 intensity 7.2810e+05	M+H@164.04716 prob=0.78
# 118. avg m/z=166.148394974 avg RT=745.62600708 prob=1.0
# 	file_id 0 mz 166.14840 RT 744.43 intensity 9.4230e+03	M+H@165.14112 prob=1.00
# 	file_id 1 mz 166.14839 RT 746.82 intensity 9.5925e+03	M+H@165.14112 prob=1.00
# 119. avg m/z=139.002331098 avg RT=440.242492676 prob=1.0
# 	file_id 0 mz 139.00234 RT 439.70 intensity 9.7891e+04	M+H@137.99507 prob=1.00
# 	file_id 1 mz 139.00232 RT 440.78 intensity 8.9039e+04	M+H@137.99507 prob=1.00
# 120. avg m/z=95.018763608 avg RT=2043.73999023 prob=1.0
# 	file_id 0 mz 95.01879 RT 2041.64 intensity 6.6254e+03	M+H@94.01152 prob=1.00
# 	file_id 1 mz 95.01874 RT 2045.84 intensity 5.8726e+03	M+H@94.01152 prob=1.00
# 121. avg m/z=89.506722381 avg RT=2486.41992188 prob=1.0
# 	file_id 1 mz 89.50667 RT 2485.38 intensity 2.7182e+05	M+H@88.49950 prob=0.61
# 	file_id 2 mz 89.50678 RT 2487.46 intensity 1.0217e+05	M+H@88.49950 prob=1.00
# 122. avg m/z=273.736021795 avg RT=937.601989746 prob=1.0
# 	file_id 0 mz 273.73598 RT 939.20 intensity 4.4310e+03	M+H@272.72870 prob=1.00
# 	file_id 1 mz 273.73607 RT 936.00 intensity 3.5499e+03	M+H@272.72870 prob=1.00
# 123. avg m/z=633.149329594 avg RT=295.270004272 prob=1.0
# 	file_id 1 mz 633.14901 RT 296.68 intensity 3.8078e+03	M+H@632.14174 prob=1.00
# 	file_id 2 mz 633.14965 RT 293.86 intensity 2.1327e+04	M+H@632.14174 prob=1.00
# 124. avg m/z=137.380079924 avg RT=616.042012533 prob=1.0
# 	file_id 0 mz 138.04886 RT 615.21 intensity 2.1878e+05	M+HC13@136.03836 prob=0.57
# 	file_id 1 mz 137.04563 RT 615.53 intensity 4.2301e+06	M+H@136.03836 prob=1.00
# 	file_id 2 mz 137.04574 RT 617.39 intensity 3.8343e+06	M+H@136.03836 prob=0.64
# 125. avg m/z=374.062330165 avg RT=1.54009997845 prob=1.0
# 	file_id 0 mz 374.06218 RT 1.54 intensity 2.6421e+04	M+H@373.05491 prob=1.00
# 	file_id 1 mz 374.06248 RT 1.54 intensity 3.0986e+04	M+H@373.05491 prob=1.00
# 126. avg m/z=475.650521764 avg RT=810.591003418 prob=1.0
# 	file_id 1 mz 484.16347 RT 812.12 intensity 1.3950e+04	M+NH4@466.13030 prob=0.64
# 	file_id 2 mz 467.13758 RT 809.06 intensity 4.3987e+04	M+H@466.13030 prob=1.00
# 127. avg m/z=104.030069372 avg RT=2005.85331217 prob=1.0
# 	file_id 0 mz 104.03008 RT 2005.99 intensity 6.3684e+04	M+H@103.02280 prob=1.00
# 	file_id 1 mz 104.03002 RT 2009.50 intensity 6.6642e+04	M+H@103.02280 prob=1.00
# 	file_id 2 mz 104.03011 RT 2002.07 intensity 5.8926e+04	M+H@103.02280 prob=1.00
# 128. avg m/z=396.158671456 avg RT=824.843994141 prob=1.0
# 	file_id 1 mz 396.15849 RT 823.61 intensity 3.4883e+04	M+H@395.15121 prob=1.00
# 	file_id 2 mz 396.15886 RT 826.07 intensity 5.0848e+04	M+H@395.15121 prob=1.00
# 129. avg m/z=166.103830145 avg RT=744.108001709 prob=1.0
# 	file_id 0 mz 166.10385 RT 742.91 intensity 3.4196e+04	M+H@165.09657 prob=1.00
# 	file_id 1 mz 166.10381 RT 745.31 intensity 3.2996e+04	M+H@165.09657 prob=1.00
# 130. avg m/z=350.986877183 avg RT=2706.72009277 prob=1.0
# 	file_id 1 mz 350.98664 RT 2704.58 intensity 2.6412e+04	M+H@349.97936 prob=1.00
# 	file_id 2 mz 350.98712 RT 2708.86 intensity 8.4329e+03	M+H@349.97936 prob=1.00
# 131. avg m/z=300.092209674 avg RT=595.643005371 prob=1.0
# 	file_id 0 mz 300.09207 RT 594.36 intensity 2.7317e+05	M+H@299.08480 prob=1.00
# 	file_id 1 mz 300.09203 RT 597.67 intensity 2.7508e+05	M+H@299.08480 prob=1.00
# 	file_id 2 mz 300.09252 RT 594.90 intensity 2.2188e+05	M+H@299.08480 prob=1.00
# 132. avg m/z=498.04215015 avg RT=910.514984131 prob=1.0
# 	file_id 0 mz 498.04195 RT 911.65 intensity 1.5901e+04	M+H@497.03467 prob=1.00
# 	file_id 2 mz 498.04235 RT 909.38 intensity 5.3940e+03	M+H@497.03467 prob=1.00
# 133. avg m/z=383.094075843 avg RT=269.288497925 prob=1.0
# 	file_id 0 mz 383.09412 RT 268.90 intensity 7.0307e+05	M+H@382.08685 prob=1.00
# 	file_id 1 mz 383.09403 RT 269.68 intensity 7.7096e+05	M+H@382.08685 prob=1.00
# 134. avg m/z=236.077596064 avg RT=661.523986816 prob=1.0
# 	file_id 0 mz 236.07743 RT 661.64 intensity 4.0868e+03	M+H@235.07016 prob=1.00
# 	file_id 2 mz 236.07776 RT 661.41 intensity 8.5552e+03	M+H@235.07016 prob=1.00
# 135. avg m/z=226.938231271 avg RT=1266.32501221 prob=1.0
# 	file_id 0 mz 226.93826 RT 1263.93 intensity 6.2300e+03	M+H@225.93099 prob=1.00
# 	file_id 1 mz 226.93820 RT 1268.72 intensity 6.4648e+03	M+H@225.93099 prob=1.00
# 136. avg m/z=151.035035466 avg RT=2520.85498047 prob=1.0
# 	file_id 0 mz 151.03504 RT 2522.78 intensity 1.9038e+05	M+H@150.02776 prob=1.00
# 	file_id 1 mz 151.03503 RT 2518.93 intensity 2.3868e+05	M+H@150.02776 prob=1.00
# 137. avg m/z=117.138445402 avg RT=1972.48498535 prob=1.0
# 	file_id 0 mz 117.13846 RT 1971.19 intensity 5.0109e+05	M+H@116.13118 prob=1.00
# 	file_id 1 mz 117.13843 RT 1973.78 intensity 5.7038e+05	M+H@116.13118 prob=1.00
# 138. avg m/z=139.049648271 avg RT=614.742004395 prob=1.0
# 	file_id 0 mz 139.04967 RT 615.21 intensity 7.1192e+03	M+H@138.04240 prob=1.00
# 	file_id 2 mz 139.04962 RT 614.27 intensity 5.3391e+03	M+H@138.04240 prob=1.00
# 139. avg m/z=81.5205265542 avg RT=1769.28497314 prob=1.0
# 	file_id 0 mz 81.52053 RT 1766.86 intensity 4.6518e+05	M+H@80.51326 prob=1.00
# 	file_id 1 mz 81.52052 RT 1771.71 intensity 4.4320e+05	M+H@80.51326 prob=1.00
# 140. avg m/z=96.6768801418 avg RT=2334.91341146 prob=1.0
# 	file_id 0 mz 82.02223 RT 2335.37 intensity 1.3347e+05	M+H@81.01496 prob=1.00
# 	file_id 1 mz 82.02224 RT 2334.79 intensity 1.3968e+05	M+H@81.01496 prob=1.00
# 	file_id 2 mz 125.98617 RT 2334.58 intensity 2.8708e+05	M+2Na-H@81.01496 prob=0.83
# 141. avg m/z=153.032482768 avg RT=2455.42492676 prob=1.0
# 	file_id 0 mz 153.03249 RT 2455.96 intensity 2.4115e+04	M+H@152.02521 prob=1.00
# 	file_id 1 mz 153.03247 RT 2454.89 intensity 2.7712e+04	M+H@152.02521 prob=1.00
# 142. avg m/z=310.767144507 avg RT=356.017323812 prob=1.0
# 	file_id 0 mz 318.09435 RT 356.33 intensity 1.4009e+04	M+Na@295.10508 prob=0.62
# 	file_id 1 mz 318.09427 RT 359.43 intensity 1.2459e+04	M+Na@295.10508 prob=0.62
# 	file_id 2 mz 296.11282 RT 352.29 intensity 5.2362e+04	M+H@295.10508 prob=1.00
# 143. avg m/z=102.535301674 avg RT=2567.01000977 prob=1.0
# 	file_id 0 mz 102.53531 RT 2569.40 intensity 2.0739e+05	M+H@101.52804 prob=1.00
# 	file_id 1 mz 102.53529 RT 2564.62 intensity 2.6462e+05	M+H@101.52804 prob=1.00
# 144. avg m/z=84.069014695 avg RT=2663.91003418 prob=1.0
# 	file_id 0 mz 84.06904 RT 2662.75 intensity 1.4881e+04	M+H@83.06176 prob=1.00
# 	file_id 1 mz 84.06899 RT 2665.07 intensity 2.0119e+04	M+H@83.06176 prob=1.00
# 145. avg m/z=89.5067699808 avg RT=2201.74499512 prob=1.0
# 	file_id 0 mz 89.50677 RT 2203.13 intensity 1.9418e+05	M+H@88.49950 prob=1.00
# 	file_id 1 mz 89.50677 RT 2200.36 intensity 2.2409e+05	M+H@88.49950 prob=1.00
# 146. avg m/z=95.0437784262 avg RT=2236.6550293 prob=1.0
# 	file_id 0 mz 95.04379 RT 2236.84 intensity 2.3991e+05	M+H@94.03651 prob=1.00
# 	file_id 1 mz 95.04377 RT 2236.47 intensity 2.4588e+05	M+H@94.03651 prob=1.00
# 147. avg m/z=466.171777407 avg RT=710.618988037 prob=1.0
# 	file_id 0 mz 466.17181 RT 710.03 intensity 1.9424e+04	M+H@465.16454 prob=0.61
# 	file_id 1 mz 466.17174 RT 711.20 intensity 2.7709e+04	M+H@465.16454 prob=0.55
# 148. avg m/z=108.576167145 avg RT=1585.07000732 prob=1.0
# 	file_id 0 mz 108.57617 RT 1587.37 intensity 1.6293e+04	M+ACN+2H@174.11142 prob=0.69
# 	file_id 1 mz 108.57616 RT 1582.77 intensity 1.7675e+04	M+ACN+2H@174.11142 prob=0.89
# 149. avg m/z=298.107056006 avg RT=363.68699646 prob=1.0
# 	file_id 0 mz 298.10698 RT 365.50 intensity 2.7396e+03	M+H@297.09970 prob=1.00
# 	file_id 2 mz 298.10713 RT 361.87 intensity 4.2112e+03	M+H@297.09970 prob=1.00
# 150. avg m/z=100.711518928 avg RT=776.664001465 prob=1.0
# 	file_id 0 mz 100.71153 RT 777.82 intensity 3.1761e+03	M+H@99.70425 prob=1.00
# 	file_id 1 mz 100.71151 RT 775.51 intensity 2.9188e+03	M+H@99.70425 prob=1.00
# 151. avg m/z=94.0449731673 avg RT=93.4892997742 prob=1.0
# 	file_id 0 mz 94.04499 RT 93.45 intensity 5.9687e+05	M+H@93.03771 prob=1.00
# 	file_id 1 mz 94.04496 RT 93.53 intensity 6.0690e+05	M+H@93.03771 prob=1.00
# 152. avg m/z=268.081115085 avg RT=375.651000977 prob=1.0
# 	file_id 0 mz 268.08121 RT 376.43 intensity 4.0920e+03	M+H@267.07393 prob=1.00
# 	file_id 1 mz 268.08102 RT 374.88 intensity 4.7579e+03	M+H@267.07393 prob=1.00
# 153. avg m/z=133.031559842 avg RT=829.803009033 prob=1.0
# 	file_id 0 mz 133.03156 RT 827.45 intensity 1.5888e+05	M+H@132.02428 prob=1.00
# 	file_id 1 mz 133.03156 RT 832.16 intensity 1.7199e+05	M+H@132.02428 prob=0.55
# 154. avg m/z=209.341939218 avg RT=1769.31500244 prob=1.0
# 	file_id 0 mz 153.57248 RT 1771.46 intensity 8.7294e+04	M+ACN+2H@264.10419 prob=0.51
# 	file_id 1 mz 265.11140 RT 1767.17 intensity 4.2511e+06	M+H@264.10419 prob=1.00
# 155. avg m/z=180.725409462 avg RT=777.404998779 prob=1.0
# 	file_id 0 mz 180.72549 RT 776.32 intensity 3.6949e+03	M+H@179.71821 prob=1.00
# 	file_id 1 mz 180.72533 RT 778.49 intensity 4.0487e+03	M+H@179.71821 prob=1.00
# 156. avg m/z=102.535286359 avg RT=95.0861968994 prob=1.0
# 	file_id 0 mz 102.53530 RT 96.64 intensity 2.0482e+05	M+H@101.52802 prob=1.00
# 	file_id 1 mz 102.53527 RT 93.53 intensity 2.0922e+05	M+H@101.52802 prob=1.00
# 157. avg m/z=355.016595479 avg RT=312.136505127 prob=1.0
# 	file_id 0 mz 355.01676 RT 314.36 intensity 6.9021e+03	M+H@354.00948 prob=1.00
# 	file_id 1 mz 355.01643 RT 309.91 intensity 7.0180e+03	M+H@354.00948 prob=1.00
# 158. avg m/z=102.033786146 avg RT=2002.43499756 prob=1.0
# 	file_id 0 mz 102.03373 RT 2004.40 intensity 2.8060e+06	M+H@101.02646 prob=1.00
# 	file_id 2 mz 102.03384 RT 2000.47 intensity 2.7147e+06	M+H@101.02646 prob=1.00
# 159. avg m/z=146.499346116 avg RT=2606.23498535 prob=1.0
# 	file_id 0 mz 125.98613 RT 2606.69 intensity 4.0710e+05	M+H@124.97885 prob=1.00
# 	file_id 1 mz 167.01257 RT 2605.78 intensity 4.6778e+05	M+ACN+H@124.97885 prob=0.83
# 160. avg m/z=537.164856457 avg RT=294.711990356 prob=1.0
# 	file_id 0 mz 537.16501 RT 294.45 intensity 4.0671e+04	M+H@536.15773 prob=1.00
# 	file_id 1 mz 537.16471 RT 294.98 intensity 3.9608e+04	M+H@536.15773 prob=1.00
# 161. avg m/z=615.59066731 avg RT=103.041000366 prob=1.0
# 	file_id 0 mz 616.09238 RT 101.50 intensity 6.9584e+03	M+KC13@576.12581 prob=0.53
# 	file_id 1 mz 615.08896 RT 104.58 intensity 2.4244e+04	M+K@576.12581 prob=0.79
# 162. avg m/z=538.119198877 avg RT=809.684997559 prob=1.0
# 	file_id 0 mz 538.11898 RT 808.70 intensity 2.4399e+04	M+H@537.11170 prob=1.00
# 	file_id 1 mz 538.11942 RT 810.67 intensity 2.2420e+04	M+H@537.11170 prob=1.00
# 163. avg m/z=175.094372005 avg RT=339.627502441 prob=1.0
# 	file_id 0 mz 175.09437 RT 338.05 intensity 8.1352e+04	M+HC13@173.08391 prob=0.72
# 	file_id 1 mz 175.09437 RT 341.21 intensity 6.4608e+04	M+HC13@173.08391 prob=0.66
# 164. avg m/z=201.080175581 avg RT=455.847000122 prob=1.0
# 	file_id 0 mz 201.08019 RT 455.39 intensity 6.6457e+03	M+H@200.07291 prob=1.00
# 	file_id 1 mz 201.08017 RT 456.30 intensity 6.0402e+03	M+H@200.07291 prob=1.00
# 165. avg m/z=151.035048753 avg RT=2501.625 prob=1.0
# 	file_id 0 mz 151.03507 RT 2502.59 intensity 2.1310e+05	M+H@150.02779 prob=1.00
# 	file_id 1 mz 151.03503 RT 2500.66 intensity 2.3410e+05	M+H@150.02779 prob=1.00
# 166. avg m/z=167.089257283 avg RT=741.062988281 prob=1.0
# 	file_id 0 mz 167.08927 RT 739.85 intensity 8.8802e+05	M+HC13@165.07878 prob=0.52
# 	file_id 1 mz 167.08925 RT 742.27 intensity 8.8478e+05	M+HC13@165.07878 prob=0.70
# 167. avg m/z=436.180754438 avg RT=441.837493896 prob=1.0
# 	file_id 0 mz 436.18093 RT 442.89 intensity 7.7328e+03	M+H@435.17365 prob=1.00
# 	file_id 1 mz 436.18058 RT 440.78 intensity 9.4630e+03	M+H@435.17365 prob=1.00
# 168. avg m/z=304.013361579 avg RT=403.840499878 prob=1.0
# 	file_id 0 mz 304.01338 RT 402.32 intensity 6.4780e+03	M+H@303.00610 prob=1.00
# 	file_id 1 mz 304.01334 RT 405.36 intensity 3.9009e+03	M+H@303.00610 prob=1.00
# 169. avg m/z=110.008695231 avg RT=2054.32507324 prob=1.0
# 	file_id 0 mz 110.00872 RT 2052.30 intensity 3.4538e+05	M+H@109.00145 prob=1.00
# 	file_id 1 mz 110.00867 RT 2056.35 intensity 2.6700e+05	M+H@109.00145 prob=1.00
# 170. avg m/z=148.018170841 avg RT=54.8498001099 prob=1.0
# 	file_id 1 mz 148.01810 RT 53.54 intensity 1.8593e+04	M+H@147.01082 prob=1.00
# 	file_id 2 mz 148.01824 RT 56.16 intensity 8.9231e+03	M+H@147.01082 prob=0.51
# 171. avg m/z=232.081287998 avg RT=449.74949646 prob=1.0
# 	file_id 0 mz 232.08108 RT 450.75 intensity 2.9936e+04	M+H@231.07381 prob=1.00
# 	file_id 2 mz 232.08149 RT 448.75 intensity 1.5741e+05	M+H@231.07381 prob=1.00
# 172. avg m/z=152.035921278 avg RT=2207.14001465 prob=1.0
# 	file_id 0 mz 152.03592 RT 2209.24 intensity 3.8165e+04	M+H@151.02865 prob=1.00
# 	file_id 2 mz 152.03592 RT 2205.04 intensity 4.1406e+04	M+H@151.02865 prob=1.00
# 173. avg m/z=175.099125802 avg RT=364.382670085 prob=1.0
# 	file_id 0 mz 175.09906 RT 362.43 intensity 8.3282e+03	M+H@174.09179 prob=1.00
# 	file_id 1 mz 175.09905 RT 364.02 intensity 6.4396e+03	M+H@174.09179 prob=1.00
# 	file_id 2 mz 175.09926 RT 366.70 intensity 4.9184e+03	M+H@174.09179 prob=1.00
# 174. avg m/z=102.033734105 avg RT=2566.23510742 prob=1.0
# 	file_id 0 mz 102.03374 RT 2567.85 intensity 2.3922e+06	M+H@101.02646 prob=1.00
# 	file_id 1 mz 102.03373 RT 2564.62 intensity 2.9638e+06	M+H@101.02646 prob=1.00
# 175. avg m/z=89.5067012316 avg RT=2408.60998535 prob=1.0
# 	file_id 0 mz 89.50671 RT 2409.50 intensity 2.3644e+05	M+H@88.49944 prob=1.00
# 	file_id 1 mz 89.50669 RT 2407.72 intensity 2.8874e+05	M+H@88.49944 prob=1.00
# 176. avg m/z=294.548487849 avg RT=301.727671305 prob=1.0
# 	file_id 0 mz 287.22102 RT 302.99 intensity 3.7850e+03	M+H@286.21374 prob=1.00
# 	file_id 1 mz 309.20287 RT 300.07 intensity 1.2576e+04	M+Na@286.21374 prob=0.78
# 	file_id 2 mz 287.22158 RT 302.12 intensity 1.5750e+04	M+H@286.21374 prob=1.00
# 177. avg m/z=212.092789709 avg RT=492.414489746 prob=1.0
# 	file_id 0 mz 212.09263 RT 492.96 intensity 5.7118e+03	M+H@211.08535 prob=1.00
# 	file_id 2 mz 212.09295 RT 491.86 intensity 5.7541e+03	M+H@211.08535 prob=1.00
# 178. avg m/z=171.098822614 avg RT=355.603988647 prob=1.0
# 	file_id 0 mz 171.09884 RT 356.33 intensity 1.5808e+04	M+H@170.09156 prob=0.73
# 	file_id 1 mz 171.09881 RT 354.88 intensity 1.2723e+04	M+H@170.09156 prob=0.79
# 179. avg m/z=95.0437030209 avg RT=2736.95495605 prob=1.0
# 	file_id 0 mz 95.04371 RT 2737.45 intensity 6.9529e+04	M+H@94.03644 prob=1.00
# 	file_id 1 mz 95.04369 RT 2736.46 intensity 7.3437e+04	M+H@94.03644 prob=1.00
# 180. avg m/z=467.13716608 avg RT=747.95098877 prob=1.0
# 	file_id 0 mz 467.13677 RT 745.96 intensity 6.8076e+05	M+H@466.12950 prob=1.00
# 	file_id 2 mz 467.13756 RT 749.95 intensity 3.3411e+05	M+H@466.12950 prob=1.00
# 181. avg m/z=166.121109731 avg RT=745.631988525 prob=1.0
# 	file_id 0 mz 166.12111 RT 745.96 intensity 1.6623e+04	M+H@165.11384 prob=1.00
# 	file_id 1 mz 166.12111 RT 745.31 intensity 1.7303e+04	M+H@165.11384 prob=1.00
# 182. avg m/z=91.0274512588 avg RT=43.1144504547 prob=1.0
# 	file_id 0 mz 91.02738 RT 41.94 intensity 3.3383e+04	M+H@90.02011 prob=1.00
# 	file_id 2 mz 91.02752 RT 44.28 intensity 1.0051e+04	M+H@90.02011 prob=1.00
# 183. avg m/z=305.006324156 avg RT=350.413665771 prob=1.0
# 	file_id 0 mz 305.00622 RT 350.26 intensity 9.0310e+03	M+H@303.99894 prob=1.00
# 	file_id 1 mz 305.00621 RT 354.88 intensity 8.5055e+03	M+H@303.99894 prob=1.00
# 	file_id 2 mz 305.00655 RT 346.10 intensity 1.5322e+04	M+H@303.99894 prob=1.00
# 184. avg m/z=151.035203731 avg RT=2204.85001628 prob=1.0
# 	file_id 0 mz 151.03519 RT 2204.65 intensity 4.3566e+05	M+H@150.02791 prob=1.00
# 	file_id 1 mz 151.03517 RT 2204.86 intensity 4.8603e+05	M+H@150.02791 prob=1.00
# 	file_id 2 mz 151.03525 RT 2205.04 intensity 4.3512e+05	M+H@150.02791 prob=1.00
# 185. avg m/z=107.049067436 avg RT=812.682006836 prob=1.0
# 	file_id 0 mz 107.04904 RT 813.08 intensity 1.8198e+04	M+H@106.04176 prob=1.00
# 	file_id 2 mz 107.04910 RT 812.29 intensity 5.8179e+03	M+H@106.04176 prob=1.00
# 186. avg m/z=273.113433646 avg RT=390.710006714 prob=1.0
# 	file_id 0 mz 273.11348 RT 389.13 intensity 5.1869e+03	M+H@272.10620 prob=1.00
# 	file_id 1 mz 273.11339 RT 392.29 intensity 5.2700e+03	M+H@272.10620 prob=1.00
# 187. avg m/z=261.059903815 avg RT=413.731994629 prob=1.0
# 	file_id 0 mz 261.05988 RT 415.55 intensity 1.9884e+03	M+H@260.05260 prob=1.00
# 	file_id 1 mz 261.05993 RT 411.92 intensity 2.4059e+03	M+H@260.05260 prob=1.00
# 188. avg m/z=144.734216795 avg RT=561.738342285 prob=1.0
# 	file_id 0 mz 144.06537 RT 559.25 intensity 3.5398e+06	M+H@143.05810 prob=0.63
# 	file_id 1 mz 145.06858 RT 564.01 intensity 2.1737e+05	M+HC13@143.05810 prob=0.51
# 	file_id 2 mz 145.06870 RT 561.95 intensity 1.6465e+05	M+HC13@143.05810 prob=0.57
# 189. avg m/z=102.535281754 avg RT=4.40778493881 prob=1.0
# 	file_id 0 mz 102.53529 RT 4.42 intensity 2.1253e+05	M+H@101.52802 prob=1.00
# 	file_id 1 mz 102.53527 RT 4.39 intensity 2.0545e+05	M+H@101.52802 prob=1.00
# 190. avg m/z=354.971739245 avg RT=312.93800354 prob=1.0
# 	file_id 0 mz 354.97190 RT 314.36 intensity 3.6958e+03	M+H@353.96462 prob=1.00
# 	file_id 1 mz 354.97158 RT 311.51 intensity 3.6959e+03	M+H@353.96462 prob=1.00
# 191. avg m/z=413.564390975 avg RT=271.067993164 prob=1.0
# 	file_id 0 mz 421.04952 RT 270.70 intensity 2.9411e+03	M+K@382.08685 prob=0.67
# 	file_id 1 mz 406.07926 RT 271.44 intensity 3.8346e+03	M+NaC13@382.08685 prob=0.59
# 192. avg m/z=190.071032514 avg RT=326.511505127 prob=1.0
# 	file_id 0 mz 190.07099 RT 327.19 intensity 9.1065e+03	M+H@189.06372 prob=1.00
# 	file_id 1 mz 190.07107 RT 325.84 intensity 5.4231e+03	M+H@189.06372 prob=0.80
# 193. avg m/z=143.996545143 avg RT=57.7075500488 prob=1.0
# 	file_id 0 mz 143.99656 RT 58.87 intensity 1.3019e+05	M+H@142.98929 prob=1.00
# 	file_id 1 mz 143.99653 RT 56.54 intensity 1.4949e+05	M+H@142.98929 prob=1.00
# 194. avg m/z=409.829264672 avg RT=589.671000163 prob=1.0
# 	file_id 0 mz 410.16357 RT 587.00 intensity 1.5509e+05	M+HC13@408.15289 prob=0.67
# 	file_id 1 mz 410.16351 RT 590.29 intensity 1.6885e+05	M+HC13@408.15289 prob=0.69
# 	file_id 2 mz 409.16071 RT 591.72 intensity 9.6000e+04	M+H@408.15289 prob=1.00
# 195. avg m/z=355.038903819 avg RT=304.023010254 prob=1.0
# 	file_id 0 mz 355.03904 RT 306.30 intensity 9.3294e+03	M+H@354.03176 prob=1.00
# 	file_id 1 mz 355.03877 RT 301.75 intensity 8.9016e+03	M+H@354.03176 prob=1.00
# 196. avg m/z=253.089959952 avg RT=583.050994873 prob=1.0
# 	file_id 0 mz 253.08992 RT 585.53 intensity 3.5115e+03	M+H@252.08265 prob=0.80
# 	file_id 2 mz 253.09000 RT 580.57 intensity 1.8319e+03	M+H@252.08265 prob=1.00
# 197. avg m/z=442.228084087 avg RT=813.32699585 prob=1.0
# 	file_id 0 mz 442.22809 RT 814.54 intensity 1.6256e+05	M+H@441.22081 prob=1.00
# 	file_id 1 mz 442.22808 RT 812.12 intensity 1.5286e+05	M+H@441.22081 prob=1.00
# 198. avg m/z=474.140091585 avg RT=831.969991048 prob=1.0
# 	file_id 0 mz 474.13988 RT 831.73 intensity 4.7592e+04	M+H@473.13260 prob=1.00
# 	file_id 1 mz 474.13990 RT 829.31 intensity 4.4489e+04	M+H@473.13260 prob=1.00
# 	file_id 2 mz 474.14050 RT 834.88 intensity 1.4922e+04	M+H@473.13260 prob=1.00
# 199. avg m/z=467.073243026 avg RT=103.041000366 prob=1.0
# 	file_id 0 mz 467.07335 RT 101.50 intensity 8.2269e+03	M+H@466.06608 prob=1.00
# 	file_id 1 mz 467.07313 RT 104.58 intensity 7.9245e+03	M+H@466.06608 prob=1.00
# 200. avg m/z=102.535364194 avg RT=26.7087507248 prob=1.0
# 	file_id 0 mz 102.53531 RT 28.21 intensity 1.6005e+05	M+H@101.52803 prob=1.00
# 	file_id 2 mz 102.53542 RT 25.20 intensity 2.4335e+05	M+H@101.52803 prob=1.00
# 201. avg m/z=777.515586021 avg RT=814.053009033 prob=1.0
# 	file_id 0 mz 777.51556 RT 814.54 intensity 1.5953e+04	M+H@776.50828 prob=1.00
# 	file_id 1 mz 777.51561 RT 813.57 intensity 1.1907e+04	M+H@776.50828 prob=1.00
# 202. avg m/z=152.035945439 avg RT=2148.04492188 prob=1.0
# 	file_id 0 mz 152.03593 RT 2147.14 intensity 4.8296e+04	M+H@151.02866 prob=1.00
# 	file_id 2 mz 152.03596 RT 2148.95 intensity 4.4964e+04	M+H@151.02866 prob=1.00
# 203. avg m/z=102.535315471 avg RT=1970.47998047 prob=1.0
# 	file_id 0 mz 102.53528 RT 1971.19 intensity 2.4940e+05	M+H@101.52800 prob=1.00
# 	file_id 2 mz 102.53536 RT 1969.77 intensity 2.3342e+05	M+H@101.52800 prob=1.00
# 204. avg m/z=347.130221077 avg RT=398.083007812 prob=1.0
# 	file_id 0 mz 347.13030 RT 395.70 intensity 2.4951e+03	M+H@346.12303 prob=1.00
# 	file_id 1 mz 347.13014 RT 400.47 intensity 2.4434e+03	M+H@346.12303 prob=1.00
# 205. avg m/z=384.104476854 avg RT=573.300018311 prob=1.0
# 	file_id 0 mz 384.10423 RT 572.35 intensity 8.1606e+03	M+H@383.09696 prob=1.00
# 	file_id 2 mz 384.10472 RT 574.25 intensity 1.1086e+04	M+H@383.09696 prob=1.00
# 206. avg m/z=269.122065913 avg RT=619.098022461 prob=1.0
# 	file_id 0 mz 269.12208 RT 619.69 intensity 1.1547e+04	M+H@268.11480 prob=1.00
# 	file_id 1 mz 269.12206 RT 618.50 intensity 1.1363e+04	M+H@268.11480 prob=1.00
# 207. avg m/z=166.132577714 avg RT=744.108001709 prob=1.0
# 	file_id 0 mz 166.13259 RT 742.91 intensity 1.1498e+04	M+H@165.12532 prob=1.00
# 	file_id 1 mz 166.13256 RT 745.31 intensity 1.3302e+04	M+H@165.12532 prob=1.00
# 208. avg m/z=395.141756764 avg RT=428.198501587 prob=1.0
# 	file_id 0 mz 395.14180 RT 428.39 intensity 1.2200e+04	M+H@394.13452 prob=1.00
# 	file_id 1 mz 395.14171 RT 428.00 intensity 1.2535e+04	M+H@394.13452 prob=1.00
# 209. avg m/z=163.007917324 avg RT=456.616989136 prob=1.0
# 	file_id 0 mz 163.00793 RT 456.93 intensity 2.2681e+04	M+H@162.00065 prob=1.00
# 	file_id 1 mz 163.00790 RT 456.30 intensity 2.5202e+04	M+H@162.00065 prob=1.00
# 210. avg m/z=202.133514664 avg RT=670.964996338 prob=1.0
# 	file_id 0 mz 202.13342 RT 669.70 intensity 2.2994e+03	M+H@201.12615 prob=1.00
# 	file_id 2 mz 202.13361 RT 672.23 intensity 2.8994e+03	M+H@201.12615 prob=1.00
# 211. avg m/z=111.116656158 avg RT=316.12449646 prob=1.0
# 	file_id 0 mz 111.11666 RT 315.96 intensity 1.0626e+06	M+H@110.10939 prob=1.00
# 	file_id 1 mz 111.11665 RT 316.29 intensity 8.3421e+05	M+H@110.10939 prob=1.00
# 212. avg m/z=248.115015032 avg RT=364.760498047 prob=1.0
# 	file_id 0 mz 248.11509 RT 363.96 intensity 2.0807e+04	M+H@247.10781 prob=1.00
# 	file_id 1 mz 248.11494 RT 365.56 intensity 1.1095e+04	M+H@247.10781 prob=1.00
# 213. avg m/z=298.242851745 avg RT=588.646972656 prob=1.0
# 	file_id 0 mz 298.24286 RT 588.47 intensity 6.1022e+03	M+H@297.23558 prob=1.00
# 	file_id 1 mz 298.24285 RT 588.82 intensity 7.0855e+03	M+H@297.23558 prob=1.00
# 214. avg m/z=99.9526411707 avg RT=822.45300293 prob=1.0
# 	file_id 0 mz 99.95264 RT 820.30 intensity 3.6839e+03	M+H@98.94536 prob=1.00
# 	file_id 2 mz 99.95265 RT 824.60 intensity 4.4121e+03	M+H@98.94536 prob=1.00
# ...
# 	file_id 2 mz 232.06526 RT 981.02 intensity 1.1601e+04	M+H@231.05765 prob=1.00
# 1743. avg m/z=128.017468674 avg RT=978.878997803 prob=0.07
# 	file_id 1 mz 128.01735 RT 978.33 intensity 1.3634e+04	M+H@127.01008 prob=1.00
# 	file_id 2 mz 128.01759 RT 979.43 intensity 1.8355e+04	M+H@127.01008 prob=1.00
# 1744. avg m/z=114.041148181 avg RT=1026.84503174 prob=0.07
# 	file_id 0 mz 114.04116 RT 1025.63 intensity 1.1559e+04	M+H@113.03388 prob=1.00
# 	file_id 1 mz 114.04114 RT 1028.06 intensity 1.1035e+04	M+H@113.03388 prob=1.00
# 1745. avg m/z=279.047332106 avg RT=787.187988281 prob=0.06
# 	file_id 1 mz 279.04716 RT 787.33 intensity 3.5327e+04	M+H@278.03995 prob=1.00
# 	file_id 2 mz 279.04751 RT 787.05 intensity 1.2013e+04	M+H@278.03995 prob=1.00
# 1746. avg m/z=228.053143387 avg RT=1029.09503174 prob=0.06
# 	file_id 0 mz 228.05315 RT 1028.63 intensity 1.4136e+04	M+H@227.04588 prob=1.00
# 	file_id 1 mz 228.05313 RT 1029.56 intensity 1.5810e+04	M+H@227.04588 prob=1.00
# 1747. avg m/z=174.075874609 avg RT=630.255004883 prob=0.06
# 	file_id 1 mz 174.07578 RT 630.50 intensity 3.9671e+04	M+H@173.06850 prob=0.78
# 	file_id 2 mz 174.07597 RT 630.01 intensity 3.5958e+04	M+H@173.06850 prob=0.52
# 1748. avg m/z=195.986667548 avg RT=1133.90997314 prob=0.05
# 	file_id 0 mz 195.98672 RT 1132.13 intensity 1.7201e+04	M+H@194.97945 prob=1.00
# 	file_id 1 mz 195.98661 RT 1135.69 intensity 1.7357e+04	M+H@194.97945 prob=1.00
# 1749. avg m/z=189.035405871 avg RT=783.342010498 prob=0.05
# 	file_id 0 mz 189.03542 RT 782.29 intensity 2.0336e+04	M+H@188.02815 prob=1.00
# 	file_id 1 mz 189.03539 RT 784.39 intensity 2.8207e+04	M+H@188.02815 prob=1.00
# 1750. avg m/z=148.071643193 avg RT=1031.03497314 prob=0.05
# 	file_id 0 mz 148.07153 RT 1030.13 intensity 7.0316e+03	M+H@147.06426 prob=1.00
# 	file_id 2 mz 148.07175 RT 1031.94 intensity 4.9072e+03	M+H@147.06426 prob=1.00
# 1751. avg m/z=114.046025165 avg RT=1028.34997559 prob=0.05
# 	file_id 0 mz 114.04604 RT 1030.13 intensity 1.4911e+04	M+H@113.03876 prob=1.00
# 	file_id 1 mz 114.04601 RT 1026.57 intensity 1.7666e+04	M+H@113.03876 prob=1.00
# 1752. avg m/z=148.060263376 avg RT=1029.06005859 prob=0.04
# 	file_id 1 mz 148.06017 RT 1029.56 intensity 1.1920e+06	M+H@147.05290 prob=1.00
# 	file_id 2 mz 148.06035 RT 1028.56 intensity 1.0752e+06	M+H@147.05290 prob=1.00
# 1753. avg m/z=124.086835192 avg RT=853.697998047 prob=0.04
# 	file_id 0 mz 124.08676 RT 852.04 intensity 2.0445e+05	M+H@123.07948 prob=1.00
# 	file_id 2 mz 124.08691 RT 855.35 intensity 1.4837e+05	M+H@123.07948 prob=1.00
# 1754. avg m/z=474.218105825 avg RT=795.977996826 prob=0.03
# 	file_id 0 mz 474.21784 RT 795.52 intensity 1.5431e+05	M+H@473.21056 prob=1.00
# 	file_id 2 mz 474.21837 RT 796.43 intensity 8.2336e+04	M+H@473.21056 prob=1.00
# 1755. avg m/z=124.086822453 avg RT=856.122009277 prob=0.03
# 	file_id 1 mz 124.08673 RT 856.89 intensity 1.7767e+05	M+H@123.07948 prob=1.00
# 	file_id 2 mz 124.08691 RT 855.35 intensity 1.4837e+05	M+H@123.07948 prob=1.00
# 1756. avg m/z=163.499045102 avg RT=1032.11999512 prob=0.03
# 	file_id 0 mz 163.49905 RT 1033.16 intensity 7.1943e+03	M+H@162.49178 prob=1.00
# 	file_id 1 mz 163.49904 RT 1031.08 intensity 6.9929e+03	M+H@162.49178 prob=1.00
# 1757. avg m/z=342.128847752 avg RT=1126.4050293 prob=0.03
# 	file_id 0 mz 342.12892 RT 1128.80 intensity 3.3398e+04	M+H@341.12164 prob=1.00
# 	file_id 1 mz 342.12878 RT 1124.01 intensity 3.2312e+04	M+H@341.12164 prob=1.00
# 1758. avg m/z=312.182693148 avg RT=831.227996826 prob=0.03
# 	file_id 0 mz 312.18271 RT 831.73 intensity 1.2126e+04	M+HC13@310.17227 prob=0.56
# 	file_id 1 mz 312.18267 RT 830.73 intensity 1.6552e+04	M+HC13@310.17227 prob=0.50
# 1759. avg m/z=228.006393173 avg RT=1126.03997803 prob=0.03
# 	file_id 0 mz 228.00627 RT 1127.12 intensity 3.4793e+03	M+H@226.99899 prob=1.00
# 	file_id 2 mz 228.00651 RT 1124.96 intensity 3.6085e+03	M+H@226.99899 prob=1.00
# 1760. avg m/z=263.07358328 avg RT=785.411987305 prob=0.03
# 	file_id 0 mz 263.07343 RT 783.77 intensity 2.2334e+06	M+H@262.06616 prob=1.00
# 	file_id 2 mz 263.07373 RT 787.05 intensity 1.2799e+06	M+H@262.06616 prob=1.00
# 1761. avg m/z=108.053936262 avg RT=1127.75 prob=0.03
# 	file_id 0 mz 108.05387 RT 1128.80 intensity 2.9425e+03	M+H@107.04660 prob=1.00
# 	file_id 2 mz 108.05400 RT 1126.70 intensity 2.9241e+03	M+H@107.04660 prob=0.83
# 1762. avg m/z=120.09034867 avg RT=891.779998779 prob=0.02
# 	file_id 0 mz 120.09030 RT 893.41 intensity 7.1307e+03	M+H@119.08302 prob=1.00
# 	file_id 2 mz 120.09040 RT 890.15 intensity 9.9664e+03	M+H@119.08302 prob=1.00
# 1763. avg m/z=254.101911963 avg RT=795.806976318 prob=0.02
# 	file_id 0 mz 254.10193 RT 795.52 intensity 1.3403e+05	M+H@253.09465 prob=1.00
# 	file_id 1 mz 254.10189 RT 796.09 intensity 1.4363e+05	M+H@253.09465 prob=1.00
# 1764. avg m/z=70.0651477425 avg RT=944.583007812 prob=0.02
# 	file_id 0 mz 70.06515 RT 947.02 intensity 2.9934e+05	M+H@69.05787 prob=1.00
# 	file_id 1 mz 70.06515 RT 942.15 intensity 2.5625e+05	M+H@69.05787 prob=1.00
# 1765. avg m/z=239.096304646 avg RT=712.976989746 prob=0.02
# 	file_id 0 mz 239.09631 RT 714.75 intensity 1.7662e+04	M+HC13@237.08578 prob=0.62
# 	file_id 1 mz 239.09630 RT 711.20 intensity 1.7318e+04	M+HC13@237.08578 prob=0.62
# 1766. avg m/z=150.064378199 avg RT=1029.34503174 prob=0.02
# 	file_id 0 mz 150.06433 RT 1030.13 intensity 7.8247e+03	M+H@149.05706 prob=1.00
# 	file_id 2 mz 150.06442 RT 1028.56 intensity 7.0952e+03	M+H@149.05706 prob=1.00
# 1767. avg m/z=304.138750202 avg RT=796.263000488 prob=0.02
# 	file_id 1 mz 304.13854 RT 796.09 intensity 5.7518e+03	M+H@303.13140 prob=1.00
# 	file_id 2 mz 304.13896 RT 796.43 intensity 7.6950e+03	M+H@303.13140 prob=1.00
# 1768. avg m/z=72.0808142978 avg RT=891.779998779 prob=0.02
# 	file_id 0 mz 72.08078 RT 893.41 intensity 5.7342e+05	M+H@71.07351 prob=1.00
# 	file_id 2 mz 72.08085 RT 890.15 intensity 4.9213e+05	M+H@71.07351 prob=1.00
# 1769. avg m/z=74.023598655 avg RT=1115.58001709 prob=0.02
# 	file_id 0 mz 74.02360 RT 1117.12 intensity 8.5092e+03	M+H@73.01633 prob=1.00
# 	file_id 1 mz 74.02359 RT 1114.04 intensity 8.8543e+03	M+H@73.01633 prob=1.00
# 1770. avg m/z=211.551839519 avg RT=948.582000732 prob=0.02
# 	file_id 1 mz 211.55177 RT 948.34 intensity 1.0552e+04	M+H@210.54452 prob=1.00
# 	file_id 2 mz 211.55191 RT 948.82 intensity 6.8239e+03	M+H@210.54452 prob=1.00
# 1771. avg m/z=118.086138815 avg RT=891.779998779 prob=0.02
# 	file_id 0 mz 118.08607 RT 893.41 intensity 2.1228e+06	M+H@117.07879 prob=1.00
# 	file_id 2 mz 118.08621 RT 890.15 intensity 2.9516e+06	M+H@117.07879 prob=1.00
# 1772. avg m/z=263.073569124 avg RT=784.985992432 prob=0.02
# 	file_id 1 mz 263.07341 RT 782.92 intensity 2.4184e+06	M+H@262.06616 prob=1.00
# 	file_id 2 mz 263.07373 RT 787.05 intensity 1.2799e+06	M+H@262.06616 prob=1.00
# 1773. avg m/z=238.093037814 avg RT=713.753997803 prob=0.02
# 	file_id 0 mz 238.09306 RT 714.75 intensity 2.3094e+05	M+H@237.08578 prob=1.00
# 	file_id 1 mz 238.09302 RT 712.76 intensity 2.3918e+05	M+H@237.08578 prob=1.00
# 1774. avg m/z=120.090275627 avg RT=894.216003418 prob=0.02
# 	file_id 0 mz 120.09030 RT 893.41 intensity 7.1307e+03	M+H@119.08302 prob=1.00
# 	file_id 1 mz 120.09025 RT 895.02 intensity 5.0538e+03	M+H@119.08302 prob=1.00
# 1775. avg m/z=312.112075167 avg RT=835.014007568 prob=0.02
# 	file_id 1 mz 312.11194 RT 832.16 intensity 1.5854e+04	M+H@311.10454 prob=1.00
# 	file_id 2 mz 312.11221 RT 837.87 intensity 2.3067e+04	M+H@311.10454 prob=1.00
# 1776. avg m/z=311.681301855 avg RT=830.360992432 prob=0.02
# 	file_id 0 mz 312.18271 RT 831.73 intensity 1.2126e+04	M+HC13@310.17227 prob=0.56
# 	file_id 2 mz 311.17989 RT 829.00 intensity 1.4416e+05	M+H@310.17227 prob=1.00
# 1777. avg m/z=70.0651867516 avg RT=945.486022949 prob=0.02
# 	file_id 1 mz 70.06515 RT 942.15 intensity 2.5625e+05	M+H@69.05787 prob=1.00
# 	file_id 2 mz 70.06523 RT 948.82 intensity 2.0139e+05	M+H@69.05787 prob=1.00
# 1778. avg m/z=73.0841092858 avg RT=893.384979248 prob=0.02
# 	file_id 0 mz 73.08408 RT 893.41 intensity 1.7114e+04	M+HC13@71.07351 prob=0.62
# 	file_id 2 mz 73.08414 RT 893.36 intensity 1.6798e+04	M+HC13@71.07351 prob=0.67
# 1779. avg m/z=118.086057291 avg RT=893.486999512 prob=0.02
# 	file_id 0 mz 118.08607 RT 893.41 intensity 2.1228e+06	M+H@117.07879 prob=1.00
# 	file_id 1 mz 118.08605 RT 893.56 intensity 1.9791e+06	M+H@117.07879 prob=1.00
# 1780. avg m/z=406.170281142 avg RT=779.642974854 prob=0.01
# 	file_id 0 mz 406.17033 RT 779.32 intensity 5.4204e+04	M+H@405.16305 prob=1.00
# 	file_id 1 mz 406.17024 RT 779.97 intensity 5.9940e+04	M+H@405.16305 prob=1.00
# 1781. avg m/z=268.051022083 avg RT=780.254974365 prob=0.01
# 	file_id 1 mz 268.05096 RT 779.97 intensity 1.8515e+04	M+H@267.04379 prob=1.00
# 	file_id 2 mz 268.05108 RT 780.54 intensity 5.7412e+03	M+H@267.04379 prob=1.00
# 1782. avg m/z=254.102071411 avg RT=797.528991699 prob=0.01
# 	file_id 0 mz 254.10193 RT 795.52 intensity 1.3403e+05	M+H@253.09465 prob=1.00
# 	file_id 2 mz 254.10221 RT 799.54 intensity 2.8507e+05	M+H@253.09465 prob=1.00
# 1783. avg m/z=228.083617225 avg RT=1125.56500244 prob=0.01
# 	file_id 0 mz 228.08360 RT 1127.12 intensity 1.0057e+04	M+H@227.07633 prob=1.00
# 	file_id 1 mz 228.08363 RT 1124.01 intensity 8.7804e+03	M+H@227.07633 prob=1.00
# 1784. avg m/z=419.151545811 avg RT=831.825012207 prob=0.01
# 	file_id 0 mz 419.15123 RT 831.73 intensity 3.1143e+04	M+H@418.14396 prob=1.00
# 	file_id 2 mz 419.15186 RT 831.92 intensity 5.2398e+04	M+H@418.14396 prob=1.00
# 1785. avg m/z=304.138820673 avg RT=795.977996826 prob=0.01
# 	file_id 0 mz 304.13868 RT 795.52 intensity 5.7087e+03	M+H@303.13140 prob=1.00
# 	file_id 2 mz 304.13896 RT 796.43 intensity 7.6950e+03	M+H@303.13140 prob=1.00
# 1786. avg m/z=189.035496215 avg RT=781.415985107 prob=0.01
# 	file_id 0 mz 189.03542 RT 782.29 intensity 2.0336e+04	M+H@188.02815 prob=1.00
# 	file_id 2 mz 189.03557 RT 780.54 intensity 2.5241e+04	M+H@188.02815 prob=1.00
# 1787. avg m/z=253.709713457 avg RT=1031.36004639 prob=0.01
# 	file_id 0 mz 253.70973 RT 1033.16 intensity 3.1403e+03	M+H@252.70245 prob=1.00
# 	file_id 1 mz 253.70970 RT 1029.56 intensity 3.7271e+03	M+H@252.70245 prob=1.00
# 1788. avg m/z=465.169010537 avg RT=712.628997803 prob=0.01
# 	file_id 1 mz 465.16857 RT 712.76 intensity 1.5705e+05	M+H@464.16135 prob=1.00
# 	file_id 2 mz 465.16945 RT 712.50 intensity 8.8306e+04	M+H@464.16135 prob=1.00
# 1789. avg m/z=407.074814318 avg RT=828.221984863 prob=0.01
# 	file_id 0 mz 407.07471 RT 827.45 intensity 3.6473e+04	M+H@406.06743 prob=1.00
# 	file_id 2 mz 407.07492 RT 829.00 intensity 1.7327e+04	M+H@406.06743 prob=1.00
# 1790. avg m/z=474.218042418 avg RT=794.802001953 prob=0.01
# 	file_id 1 mz 474.21771 RT 793.17 intensity 1.5095e+05	M+H@473.21056 prob=1.00
# 	file_id 2 mz 474.21837 RT 796.43 intensity 8.2336e+04	M+H@473.21056 prob=1.00
# 1791. avg m/z=124.086743025 avg RT=854.466003418 prob=0.01
# 	file_id 0 mz 124.08676 RT 852.04 intensity 2.0445e+05	M+H@123.07948 prob=1.00
# 	file_id 1 mz 124.08673 RT 856.89 intensity 1.7767e+05	M+H@123.07948 prob=1.00
# 1792. avg m/z=389.1335542 avg RT=377.352508545 prob=0.01
# 	file_id 0 mz 389.13322 RT 376.43 intensity 5.9565e+03	M+H@388.12594 prob=1.00
# 	file_id 2 mz 389.13389 RT 378.28 intensity 4.9112e+03	M+H@388.12594 prob=1.00
# 1793. avg m/z=211.082512577 avg RT=831.825012207 prob=0.01
# 	file_id 0 mz 211.08241 RT 831.73 intensity 9.4984e+04	M+HC13@209.07194 prob=0.56
# 	file_id 2 mz 211.08262 RT 831.92 intensity 7.7262e+04	M+HC13@209.07194 prob=0.76
# 1794. avg m/z=441.13355441 avg RT=832.586975098 prob=0.01
# 	file_id 0 mz 441.13325 RT 830.30 intensity 1.1809e+05	M+Na@418.14396 prob=0.64
# 	file_id 2 mz 441.13386 RT 834.88 intensity 1.1459e+05	M+Na@418.14396 prob=0.88
# 1795. avg m/z=312.112014245 avg RT=835.511993408 prob=0.01
# 	file_id 0 mz 312.11181 RT 833.15 intensity 1.7610e+04	M+H@311.10454 prob=1.00
# 	file_id 2 mz 312.11221 RT 837.87 intensity 2.3067e+04	M+H@311.10454 prob=1.00
# 1796. avg m/z=211.551781183 avg RT=947.678985596 prob=0.01
# 	file_id 0 mz 211.55179 RT 947.02 intensity 1.0170e+04	M+H@210.54452 prob=1.00
# 	file_id 1 mz 211.55177 RT 948.34 intensity 1.0552e+04	M+H@210.54452 prob=1.00
# 1797. avg m/z=474.217774336 avg RT=794.345977783 prob=0.01
# 	file_id 0 mz 474.21784 RT 795.52 intensity 1.5431e+05	M+H@473.21056 prob=1.00
# 	file_id 1 mz 474.21771 RT 793.17 intensity 1.5095e+05	M+H@473.21056 prob=1.00
# 1798. avg m/z=258.153173529 avg RT=1198.66503906 prob=0.01
# 	file_id 0 mz 258.15313 RT 1196.41 intensity 2.8019e+03	M+H@257.14585 prob=1.00
# 	file_id 2 mz 258.15322 RT 1200.92 intensity 2.4328e+03	M+H@257.14585 prob=1.00
# 1799. avg m/z=310.187365302 avg RT=831.093017578 prob=0.01
# 	file_id 0 mz 310.18714 RT 831.73 intensity 3.3968e+05	M+HC13@308.17665 prob=0.57
# 	file_id 2 mz 310.18759 RT 830.46 intensity 5.0955e+05	M+HC13@308.17665 prob=0.70
# 1800. avg m/z=389.133694365 avg RT=379.692504883 prob=0.01
# 	file_id 1 mz 389.13350 RT 381.11 intensity 5.6644e+03	M+H@388.12594 prob=1.00
# 	file_id 2 mz 389.13389 RT 378.28 intensity 4.9112e+03	M+H@388.12594 prob=1.00
# 1801. avg m/z=206.073747666 avg RT=828.377990723 prob=0.01
# 	file_id 0 mz 206.07377 RT 827.45 intensity 8.2677e+04	M+H@205.06649 prob=0.62
# 	file_id 1 mz 206.07372 RT 829.31 intensity 8.1614e+04	M+H@205.06649 prob=0.56
# 1802. avg m/z=757.215733173 avg RT=1065.44000244 prob=0.01
# 	file_id 0 mz 757.21534 RT 1065.84 intensity 3.4280e+03	M+H@756.20806 prob=1.00
# 	file_id 1 mz 757.21613 RT 1065.04 intensity 3.2196e+03	M+H@756.20806 prob=1.00
# 1803. avg m/z=239.096460052 avg RT=713.49899292 prob=0.01
# 	file_id 1 mz 239.09630 RT 711.20 intensity 1.7318e+04	M+HC13@237.08578 prob=0.62
# 	file_id 2 mz 239.09662 RT 715.79 intensity 2.4763e+04	M+HC13@237.08578 prob=0.72
# 1804. avg m/z=135.064751671 avg RT=1121.90997314 prob=0.01
# 	file_id 1 mz 135.06471 RT 1122.35 intensity 3.4539e+03	M+H@134.05743 prob=1.00
# 	file_id 2 mz 135.06480 RT 1121.47 intensity 2.7473e+03	M+H@134.05743 prob=1.00
# 1805. avg m/z=678.105952104 avg RT=907.460998535 prob=0.01
# 	file_id 1 mz 678.10550 RT 907.12 intensity 2.9927e+04	M+H@677.09842 prob=1.00
# 	file_id 2 mz 678.10640 RT 907.80 intensity 1.1331e+04	M+H@677.09842 prob=1.00
# 1806. avg m/z=211.551853148 avg RT=947.919006348 prob=0.01
# 	file_id 0 mz 211.55179 RT 947.02 intensity 1.0170e+04	M+H@210.54452 prob=1.00
# 	file_id 2 mz 211.55191 RT 948.82 intensity 6.8239e+03	M+H@210.54452 prob=1.00
# 1807. avg m/z=70.0651886217 avg RT=947.919006348 prob=0.01
# 	file_id 0 mz 70.06515 RT 947.02 intensity 2.9934e+05	M+H@69.05787 prob=1.00
# 	file_id 2 mz 70.06523 RT 948.82 intensity 2.0139e+05	M+H@69.05787 prob=1.00
# 1808. avg m/z=211.082523421 avg RT=832.041015625 prob=0.01
# 	file_id 1 mz 211.08243 RT 832.16 intensity 9.4730e+04	M+HC13@209.07194 prob=0.70
# 	file_id 2 mz 211.08262 RT 831.92 intensity 7.7262e+04	M+HC13@209.07194 prob=0.76
# 1809. avg m/z=254.603708384 avg RT=797.084991455 prob=0.01
# 	file_id 1 mz 255.10521 RT 794.63 intensity 1.6846e+04	M+HC13@253.09465 prob=0.60
# 	file_id 2 mz 254.10221 RT 799.54 intensity 2.8507e+05	M+H@253.09465 prob=1.00
# 1810. avg m/z=193.987471098 avg RT=1130.57495117 prob=0.01
# 	file_id 0 mz 193.98754 RT 1130.46 intensity 7.4348e+03	M+H@192.98026 prob=1.00
# 	file_id 1 mz 193.98740 RT 1130.69 intensity 7.9536e+03	M+H@192.98026 prob=1.00
# 1811. avg m/z=309.184137209 avg RT=828.914978027 prob=0.01
# 	file_id 0 mz 309.18393 RT 830.30 intensity 2.7290e+06	M+H@308.17665 prob=1.00
# 	file_id 2 mz 309.18434 RT 827.53 intensity 3.9220e+06	M+H@308.17665 prob=1.00
# 1812. avg m/z=690.192502221 avg RT=1038.20501709 prob=0.01
# 	file_id 0 mz 690.19302 RT 1037.74 intensity 7.7340e+03	M+H@689.18574 prob=1.00
# 	file_id 1 mz 690.19199 RT 1038.67 intensity 5.8839e+03	M+H@689.18574 prob=1.00
# 1813. avg m/z=189.035477495 avg RT=782.466003418 prob=0.01
# 	file_id 1 mz 189.03539 RT 784.39 intensity 2.8207e+04	M+H@188.02815 prob=1.00
# 	file_id 2 mz 189.03557 RT 780.54 intensity 2.5241e+04	M+H@188.02815 prob=1.00
# 1814. avg m/z=238.093253261 avg RT=714.276000977 prob=0.01
# 	file_id 1 mz 238.09302 RT 712.76 intensity 2.3918e+05	M+H@237.08578 prob=1.00
# 	file_id 2 mz 238.09349 RT 715.79 intensity 3.4476e+05	M+H@237.08578 prob=1.00
# 1815. avg m/z=700.087730117 avg RT=907.376983643 prob=0.01
# 	file_id 1 mz 700.08715 RT 910.13 intensity 8.1757e+03	M+Na@677.09842 prob=0.62
# 	file_id 2 mz 700.08831 RT 904.63 intensity 3.8500e+03	M+Na@677.09842 prob=0.73

# %% [markdown]
# Report above shows the list of numbered aligned peaksets (excluding the singleton peaksets), alongside their probabilit values, and the precursor mass and adduct type annotations for each peak.

# %%
probs = np.array(probs) 
plt.figure()
plt.hist(probs, 10)
plt.title('Aligned peaksets probabilities')
plt.xlabel('Probabilities')
plt.ylabel('Count')
plt.show()

# %%
end = time.time()
utils.timer("TOTAL ELAPSED TIME", start, end)
# Out:
# TOTAL ELAPSED TIME 00 hours 15 minutes 52.84 seconds

# %% [markdown]
# This is definitely a lot faster than the HDP approach (which could run for hours for these 15k features).
#
# We definitely can improve the performance further on the discretisation code, inference codes, etc.

# %% [markdown]
# ### Step 4

# %% [markdown]
# Evaluate performance ..
